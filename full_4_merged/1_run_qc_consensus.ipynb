# %%
import pycisTopic
import glob
import os

# os.environ["TMPDIR"] = "dirty_tmp"
import pybiomart as pbm
import pandas as pd
import pickle
from pycisTopic.qc import *
from IPython.display import Image, display
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import multiprocess as mp  # for kde multithreading calculation
from multiprocess import Pool
from ray.dashboard import *

# %matplotlib inline
# %load_ext lab_black

# %%
import collections as cl
import gc
import logging
import sys
from typing import Dict, List, Optional, Tuple, Union

import matplotlib.backends.backend_pdf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyranges as pr
import ray
import seaborn as sns
from scipy.stats import gaussian_kde, norm

from pycisTopic.cistopic_class import *
from pycisTopic.utils import (
    collapse_duplicates,
    multiplot_from_generator,
    read_fragments_from_file,
)

# %%
import importlib

# %% [markdown]
# # Download annotation

# %%
# !pwd
# Out:
# /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged

# %%
wdir = "/dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged"
os.chdir(wdir)

# %%
genome = "hg38"

pbm_genome_name_dict = {
    "hg38": "hsapiens_gene_ensembl",
    "hg37": "hsapiens_gene_ensembl",
    "mm10": "mmusculus_gene_ensembl",
    "dm6": "dmelanogaster_gene_ensembl",
}

pbm_host_dict = {
    "hg38": "http://www.ensembl.org",
    "hg37": "http://grch37.ensembl.org/",
    "mm10": "http://nov2020.archive.ensembl.org/",
    "dm6": "http://www.ensembl.org",
}

if os.path.exists(f"annotation.tsv"):
    print(f"Loading cached genome annotation...")
    annotation = pd.read_csv("annotation.tsv", sep="\t", header=0, index_col=0)
else:
    dataset = pbm.Dataset(name=pbm_genome_name_dict[genome], host=pbm_host_dict[genome])

    annotation = dataset.query(
        attributes=[
            "chromosome_name",
            "transcription_start_site",
            "strand",
            "external_gene_name",
            "transcript_biotype",
        ]
    )
    filter = annotation["Chromosome/scaffold name"].str.contains("CHR|GL|JH|MT")
    annotation = annotation[~filter]
    annotation["Chromosome/scaffold name"] = annotation[
        "Chromosome/scaffold name"
    ].str.replace(r"(\b\S)", r"chr\1")
    annotation.columns = ["Chromosome", "Start", "Strand", "Gene", "Transcript_type"]
    annotation = annotation[annotation.Transcript_type == "protein_coding"]
    annotation.to_csv("annotation.tsv", sep="\t")
# Out:
# Loading cached genome annotation...

# %%
annotation
# Out:
#                 Chromosome     Start  Strand       Gene       Transcript_type
# 37     chrKI270442chr.chr1    380608       1    5S_rRNA                  rRNA
# 38     chrKI270711chr.chr1     24650      -1        NaN        protein_coding
# 39     chrKI270711chr.chr1     29626      -1        NaN        protein_coding
# 84     chrKI270442chr.chr1    217401      -1  5_8S_rRNA                  rRNA
# 516    chrKI270744chr.chr1     51114      -1         U6                 snRNA
# ...                    ...       ...     ...        ...                   ...
# 45278                chr11  33076149       1  LINC00294                lncRNA
# 45279                chr11  55262155       1     TRIM48        protein_coding
# 45280                chr12    262836      -1    SLC6A13        protein_coding
# 45281                chr12    224431      -1    SLC6A13  processed_transcript
# 45282                chr12    237241      -1    SLC6A13  processed_transcript
#
# [25989 rows x 5 columns]

# %%
fragments_list = sorted(glob.glob("../1_data_repository/full_fragments/*.tsv.gz"))
fragments_dict = {}
for fragments_file in fragments_list:
    sample = fragments_file.split("/")[-1].split(".fragments.tsv.gz")[0]
    fragments_dict[sample] = fragments_file
fragments_dict
# Out:
# {'BIO_ddseq_1.FULL': '../1_data_repository/full_fragments/BIO_ddseq_1.FULL.fragments.tsv.gz',
#  'BIO_ddseq_2.FULL': '../1_data_repository/full_fragments/BIO_ddseq_2.FULL.fragments.tsv.gz',
#  'BIO_ddseq_3.FULL': '../1_data_repository/full_fragments/BIO_ddseq_3.FULL.fragments.tsv.gz',
#  'BIO_ddseq_4.FULL': '../1_data_repository/full_fragments/BIO_ddseq_4.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_1.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_1.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_2.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_2.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_1.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_1.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_2.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_1.FULL': '../1_data_repository/full_fragments/CNA_10xv11_1.FULL.fragments.tsv.gz',
#  'CNA_10xv11_2.FULL': '../1_data_repository/full_fragments/CNA_10xv11_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_3.FULL': '../1_data_repository/full_fragments/CNA_10xv11_3.FULL.fragments.tsv.gz',
#  'CNA_10xv11_4.FULL': '../1_data_repository/full_fragments/CNA_10xv11_4.FULL.fragments.tsv.gz',
#  'CNA_10xv11_5.FULL': '../1_data_repository/full_fragments/CNA_10xv11_5.FULL.fragments.tsv.gz',
#  'CNA_10xv2_1.FULL': '../1_data_repository/full_fragments/CNA_10xv2_1.FULL.fragments.tsv.gz',
#  'CNA_10xv2_2.FULL': '../1_data_repository/full_fragments/CNA_10xv2_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_1.FULL': '../1_data_repository/full_fragments/CNA_hydrop_1.FULL.fragments.tsv.gz',
#  'CNA_hydrop_2.FULL': '../1_data_repository/full_fragments/CNA_hydrop_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_3.FULL': '../1_data_repository/full_fragments/CNA_hydrop_3.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_1.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_1.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_2.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_1.FULL': '../1_data_repository/full_fragments/EPF_hydrop_1.FULL.fragments.tsv.gz',
#  'EPF_hydrop_2.FULL': '../1_data_repository/full_fragments/EPF_hydrop_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_3.FULL': '../1_data_repository/full_fragments/EPF_hydrop_3.FULL.fragments.tsv.gz',
#  'EPF_hydrop_4.FULL': '../1_data_repository/full_fragments/EPF_hydrop_4.FULL.fragments.tsv.gz',
#  'HAR_ddseq_1.FULL': '../1_data_repository/full_fragments/HAR_ddseq_1.FULL.fragments.tsv.gz',
#  'HAR_ddseq_2.FULL': '../1_data_repository/full_fragments/HAR_ddseq_2.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_1.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_1.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_2.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_2.FULL.fragments.tsv.gz',
#  'OHS_s3atac_1.FULL': '../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz',
#  'OHS_s3atac_2.FULL': '../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_1.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_1.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_2.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_2.FULL.fragments.tsv.gz',
#  'STA_10xv11_1.FULL': '../1_data_repository/full_fragments/STA_10xv11_1.FULL.fragments.tsv.gz',
#  'STA_10xv11_2.FULL': '../1_data_repository/full_fragments/STA_10xv11_2.FULL.fragments.tsv.gz',
#  'TXG_10xv11_1.FULL': '../1_data_repository/full_fragments/TXG_10xv11_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_1.FULL': '../1_data_repository/full_fragments/TXG_10xv2_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_2.FULL': '../1_data_repository/full_fragments/TXG_10xv2_2.FULL.fragments.tsv.gz',
#  'UCS_ddseq_1.FULL': '../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz',
#  'UCS_ddseq_2.FULL': '../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_1.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_1.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_2.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_2.FULL.fragments.tsv.gz',
#  'VIB_10xv1_1.FULL': '../1_data_repository/full_fragments/VIB_10xv1_1.FULL.fragments.tsv.gz',
#  'VIB_10xv1_2.FULL': '../1_data_repository/full_fragments/VIB_10xv1_2.FULL.fragments.tsv.gz',
#  'VIB_10xv2_1.FULL': '../1_data_repository/full_fragments/VIB_10xv2_1.FULL.fragments.tsv.gz',
#  'VIB_10xv2_2.FULL': '../1_data_repository/full_fragments/VIB_10xv2_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_1.FULL': '../1_data_repository/full_fragments/VIB_hydrop_1.FULL.fragments.tsv.gz',
#  'VIB_hydrop_11.FULL': '../1_data_repository/full_fragments/VIB_hydrop_11.FULL.fragments.tsv.gz',
#  'VIB_hydrop_12.FULL': '../1_data_repository/full_fragments/VIB_hydrop_12.FULL.fragments.tsv.gz',
#  'VIB_hydrop_2.FULL': '../1_data_repository/full_fragments/VIB_hydrop_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_21.FULL': '../1_data_repository/full_fragments/VIB_hydrop_21.FULL.fragments.tsv.gz',
#  'VIB_hydrop_22.FULL': '../1_data_repository/full_fragments/VIB_hydrop_22.FULL.fragments.tsv.gz'}

# %%
fragments_dict.pop("VIB_hydrop_11.FULL")
fragments_dict.pop("VIB_hydrop_12.FULL")
fragments_dict.pop("VIB_hydrop_21.FULL")
fragments_dict.pop("VIB_hydrop_22.FULL")
# Out:
# '../1_data_repository/full_fragments/VIB_hydrop_22.FULL.fragments.tsv.gz'

# %%
master_set_path = "../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed"

# %%
regions_paths_dict = {x: master_set_path for x in fragments_dict.keys()}
regions_paths_dict
# Out:
# {'BIO_ddseq_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BIO_ddseq_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BIO_ddseq_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BIO_ddseq_4.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BRO_mtscatac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BRO_mtscatac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xmultiome_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xmultiome_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_4.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_5.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv2_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv2_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_hydrop_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_hydrop_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_hydrop_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_mtscatac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_mtscatac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_4.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'HAR_ddseq_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'HAR_ddseq_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'MDC_mtscatac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'MDC_mtscatac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'OHS_s3atac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'OHS_s3atac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'SAN_10xmultiome_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'SAN_10xmultiome_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'STA_10xv11_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'STA_10xv11_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'TXG_10xv11_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'TXG_10xv2_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'TXG_10xv2_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'UCS_ddseq_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'UCS_ddseq_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xmultiome_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xmultiome_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv1_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv1_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv2_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv2_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_hydrop_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_hydrop_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed'}

# %%
len(regions_paths_dict)
# Out:
# 47

# %% [markdown]
# Now, make a sub dictionary of all samples within the fragments dict that have not been run yet (good for resuming a stopped cistopic run):

# %%
cistopic_qc_out = os.path.join(wdir, "cistopic_qc_out_MASTER")
if not os.path.exists(cistopic_qc_out):
    os.makedirs(cistopic_qc_out)

# %%
fragments_sub_dict = {}
regions_sub_dict = {}
for sample in regions_paths_dict.keys():
    metadata_file = os.path.join(cistopic_qc_out, sample + "__metadata_bc.pkl")
    print(f"Checking if {metadata_file} exist...")
    if os.path.exists(metadata_file):
        print("\tMetadata exists! Skipping...")
    else:
        fragments_sub_dict[sample] = fragments_dict[sample]
        print("\tMetadata does not exist, adding to subdict to generate")
# Out:
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/BIO_ddseq_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/BIO_ddseq_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/BIO_ddseq_3.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/BIO_ddseq_4.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/BRO_mtscatac_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/BRO_mtscatac_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xmultiome_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xmultiome_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv11_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv11_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv11_3.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv11_4.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv11_5.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv2_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_10xv2_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_hydrop_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_hydrop_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_hydrop_3.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_mtscatac_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/CNA_mtscatac_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/EPF_hydrop_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/EPF_hydrop_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/EPF_hydrop_3.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/EPF_hydrop_4.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/HAR_ddseq_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/HAR_ddseq_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/MDC_mtscatac_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/MDC_mtscatac_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/OHS_s3atac_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/OHS_s3atac_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/SAN_10xmultiome_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/SAN_10xmultiome_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/STA_10xv11_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/STA_10xv11_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/TXG_10xv11_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/TXG_10xv2_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/TXG_10xv2_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/UCS_ddseq_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/UCS_ddseq_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_10xmultiome_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_10xmultiome_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_10xv1_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_10xv1_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_10xv2_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_10xv2_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_hydrop_1.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER/VIB_hydrop_2.FULL__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate

# %%
regions_sub_dict = {x: regions_paths_dict[x] for x in sorted(fragments_sub_dict.keys())}
regions_sub_dict
# Out:
# {'BIO_ddseq_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BIO_ddseq_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BIO_ddseq_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BIO_ddseq_4.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BRO_mtscatac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'BRO_mtscatac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xmultiome_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xmultiome_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_4.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv11_5.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv2_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_10xv2_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_hydrop_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_hydrop_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_hydrop_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_mtscatac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'CNA_mtscatac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_3.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'EPF_hydrop_4.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'HAR_ddseq_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'HAR_ddseq_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'MDC_mtscatac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'MDC_mtscatac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'OHS_s3atac_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'OHS_s3atac_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'SAN_10xmultiome_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'SAN_10xmultiome_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'STA_10xv11_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'STA_10xv11_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'TXG_10xv11_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'TXG_10xv2_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'TXG_10xv2_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'UCS_ddseq_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'UCS_ddseq_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xmultiome_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xmultiome_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv1_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv1_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv2_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_10xv2_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_hydrop_1.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed',
#  'VIB_hydrop_2.FULL': '../full_3_cistopic_consensus/master_peaks/all.FIXEDCELLS.master_peaks.occurrence_filtered7.bed'}

# %%
def compute_qc_stats_single(
    fragments,
    tss_annotation: Union[pd.DataFrame, pr.PyRanges],
    stats: Optional[List[str]] = [
        "barcode_rank_plot",
        "duplicate_rate",
        "insert_size_distribution",
        "profile_tss",
        "frip",
    ],
    label: Optional[str] = None,
    path_to_regions: Optional[str] = None,
    valid_bc: Optional[List[str]] = None,
    n_frag: Optional[int] = None,
    n_bc: Optional[int] = None,
    tss_flank_window: Optional[int] = 1000,
    tss_window: Optional[int] = 50,
    tss_minimum_signal_window: Optional[int] = 100,
    tss_rolling_window: Optional[int] = 10,
    min_norm: Optional[int] = 0.2,
    partition: Optional[int] = 1,
    check_for_duplicates: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    use_polars: Optional[bool] = True,
):
    """
    Wrapper function to compute QC statistics on several samples. For detailed instructions, please see the independent functions.
    Parameters
    ---
    fragments: str
            Path to fragments file.
    tss_annotation: pd.DataFrame or pr.PyRanges
            A data frame or pyRanges containing transcription start sites for each gene, with 'Chromosome', 'Start' and 'Strand' as columns (additional columns will be ignored).
    stats: list, optional
            A list with the statistics that have to be computed. Default: All ('barcode_rank_plot', 'duplicate_rate', 'insert_size_distribution', 'profile_tss', 'FRIP).
    label: str
            Sample label. Default: None.
    path_to_regions: str
            Path to regions file to use for FRIP.
    valid_bc: list, optional
            A list containing selected barcodes. This parameter is ignored if n_frag or n_bc are specified. Default: None.
    n_frag: int, optional
            Minimal number of fragments assigned to a barcode to be kept. Either n_frag or n_bc can be specified. Default: None.
    n_bc: int, optional
            Number of barcodes to select. Either n_frag or n_bc can be specified. Default: None.
    tss_window: int, optional
            Window around the TSS used to count fragments in the TSS when calculating the TSS enrichment per barcode. Default: 50 (+/- 50 bp).
    tss_flank_window: int, optional
            Flanking window around the TSS. Default: 1000 (+/- 1000 bp).
    tss_minimum_signal_window: int, optional
            Tail window use to normalize the TSS enrichment. Default: 100 (average signal in the 100bp in the extremes of the TSS window).
    tss_rolling_window: int, optional
            Rolling window used to smooth signal. Default: 10.
    min_norm: int, optional
            Minimum normalization score. If the average minimum signal value is below this value, this number is used to normalize the TSS signal. This approach penalizes cells with fewer reads.
    check_for_duplicates: bool, optional
            If no duplicate counts are provided per row in the fragments file, whether to collapse duplicates. Default: True.
    remove_duplicates: bool, optional
            Whether to remove duplicates. Default: True.
    use_polars: bool, optional
            Whether to use polars to read fragments files. Default: True.
    Return
    ---
    pd.DataFrame or list and list
            A list with the barcode statistics for all samples (or a combined data frame with a column 'Sample' indicating the sample of origin) and a list of dictionaries with the sample-level profiles for each sample.
    """

    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")
    # Compute stats
    metrics = {}
    metadata_bc_dict = {}
    profile_data_dict = {}
    # Prepare fragments
    if isinstance(fragments, str):
        log.info("Reading " + label)
        fragments_df = read_fragments_from_file(fragments, use_polars=use_polars).df
    else:
        fragments_df = fragments
    # Convert to category for memory efficiency
    fragments_df["Name"] = fragments_df["Name"].astype("category")
    # Check for duplicates
    if "Score" not in fragments_df or all(fragments_df["Score"] == "."):
        fragments_df = fragments_df[["Chromosome", "Start", "End", "Name"]]
        if check_for_duplicates:
            log.info("Collapsing duplicates")
            fragments_df = pd.concat(
                [
                    collapse_duplicates(fragments_df[fragments_df.Chromosome == x])
                    for x in fragments_df.Chromosome.cat.categories.values
                ]
            )
        else:
            fragments_df["Score"] = 1
    else:
        fragments_df = fragments_df[["Chromosome", "Start", "End", "Name", "Score"]]
    fragments_df["Score"] = fragments_df["Score"].astype("int32")
    # Prepare valid barcodes
    if valid_bc is not None:
        if n_bc is not None or n_frag is not None:
            valid_bc = None
    # Rank plot
    if "barcode_rank_plot" in stats:
        # Rank plot
        log.info("Computing barcode rank plot for " + label)
        metrics["barcode_rank_plot"] = barcode_rank_plot(
            fragments=fragments_df,
            valid_bc=valid_bc,
            n_frag=n_frag,
            n_bc=n_bc,
            remove_duplicates=remove_duplicates,
            plot=False,
            return_bc=True,
            return_plot_data=True,
        )
        if valid_bc is None:
            fragments_df = fragments_df[
                fragments_df.Name.isin(set(metrics["barcode_rank_plot"]["valid_bc"]))
            ]

    gc.collect()
    # Duplicate rate
    if "duplicate_rate" in stats:
        # Duplicate rate
        log.info("Computing duplicate rate plot for " + label)
        metrics["duplicate_rate"] = duplicate_rate(
            fragments=fragments_df, valid_bc=valid_bc, plot=False, return_plot_data=True
        )

    gc.collect()
    # Fragment size
    if "insert_size_distribution" in stats:
        # Fragment size
        log.info("Computing insert size distribution for " + label)
        metrics["insert_size_distribution"] = insert_size_distribution(
            fragments=fragments_df,
            valid_bc=valid_bc,
            remove_duplicates=remove_duplicates,
            plot=False,
            return_plot_data=True,
        )
    fragments_df = pr.PyRanges(fragments_df)
    gc.collect()
    # TSS
    if "profile_tss" in stats:
        # TSS
        log.info("Computing TSS profile for " + label)
        profile_tss_metrics = profile_tss(
            fragments=fragments_df,
            annotation=tss_annotation,
            valid_bc=valid_bc,
            plot=False,
            n_cpu=1,
            partition=partition,
            flank_window=tss_flank_window,
            tss_window=tss_window,
            minimum_signal_window=tss_minimum_signal_window,
            rolling_window=tss_rolling_window,
            min_norm=min_norm,
            return_TSS_enrichment_per_barcode=True,
            return_TSS_coverage_matrix_per_barcode=True,
            return_plot_data=True,
        )
        if profile_tss_metrics is not None:
            metrics["profile_tss"] = profile_tss_metrics
    gc.collect()
    # FRIP
    if "frip" in stats:
        # FRIP
        log.info("Computing FRIP profile for " + label)
        metrics["frip"] = frip(
            fragments=fragments_df,
            path_to_regions=path_to_regions,
            valid_bc=valid_bc,
            remove_duplicates=remove_duplicates,
            n_cpu=1,
            plot=False,
            return_plot_data=True,
        )
    del fragments_df
    gc.collect()
    metadata_bc, profile_data = metrics2data(metrics)

    if isinstance(metadata_bc, pd.DataFrame):
        metadata_bc = metadata_bc.fillna(0)

    metadata_bc_dict = {label: metadata_bc}
    profile_data_dict = {label: profile_data}
    log.info("Sample " + label + " done!")

    return metadata_bc_dict, profile_data_dict

# %%
n_cores = 10
if regions_sub_dict != {}:
    samples_sub = list(regions_sub_dict.keys())
    blocks = [samples_sub[i : i + n_cores] for i in range(0, len(samples_sub), n_cores)]
    for samples_torun_in_block in blocks:
        fragments_sub_dict_block = {
            key: fragments_sub_dict[key] for key in samples_torun_in_block
        }
        regions_sub_dict_block = {
            key: regions_sub_dict[key] for key in samples_torun_in_block
        }

        metadata_bc_dict, profile_data_dict = compute_qc_stats(
            fragments_dict=fragments_sub_dict_block,
            tss_annotation=annotation,
            stats=[
                "barcode_rank_plot",
                "duplicate_rate",
                "insert_size_distribution",
                "profile_tss",
                "frip",
            ],
            label_list=None,
            path_to_regions=regions_sub_dict_block,
            n_cpu=n_cores,
            valid_bc=None,
            n_frag=10,
            n_bc=None,
            tss_flank_window=2000,
            tss_window=50,
            tss_minimum_signal_window=100,
            tss_rolling_window=10,
            # min_norm=0.2,
            remove_duplicates=True,
        )

        ray.shutdown()
        print(f"Dumping files in {cistopic_qc_out}...")
        for sample in sorted(metadata_bc_dict.keys()):
            metadata_bc_dict[sample]["sample_id"] = sample
            metadata_bc_dict[sample].index = [
                x + "___" + sample for x in list(metadata_bc_dict[sample].index)
            ]
            with open(
                os.path.join(cistopic_qc_out, f"{sample}__metadata_bc.pkl"), "wb"
            ) as f:
                pickle.dump(metadata_bc_dict[sample], f, protocol=4)

            with open(
                os.path.join(cistopic_qc_out, f"{sample}__profile_data.pkl"), "wb"
            ) as f:
                pickle.dump(profile_data_dict[sample], f, protocol=4)
else:
    print("All samples already processed.")
# Out:
# 2022-10-01 12:59:34,179	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:00:01,264 cisTopic     INFO     Reading CNA_10xv11_2.FULL
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:00:01,253 cisTopic     INFO     Reading CNA_10xv11_1.FULL
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:00:01,271 cisTopic     INFO     Reading BIO_ddseq_2.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:00:01,256 cisTopic     INFO     Reading CNA_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2087867) 2022-10-01 13:00:01,264 cisTopic     INFO     Reading BIO_ddseq_1.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:00:01,267 cisTopic     INFO     Reading BIO_ddseq_3.FULL
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:00:01,268 cisTopic     INFO     Reading CNA_10xmultiome_1.FULL
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:00:01,247 cisTopic     INFO     Reading BRO_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:00:01,259 cisTopic     INFO     Reading BRO_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:00:01,406 cisTopic     INFO     Reading BIO_ddseq_4.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:10:49,607 cisTopic     INFO     Computing barcode rank plot for BRO_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:10:49,608 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:11:22,274 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:11:22,841 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:11:22,884 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:11:26,616 cisTopic     INFO     Computing barcode rank plot for BRO_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:11:26,616 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:11:49,526 cisTopic     INFO     Computing duplicate rate plot for BRO_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:11:59,778 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:12:00,633 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:12:00,738 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:12:27,471 cisTopic     INFO     Computing duplicate rate plot for BRO_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:12:38,532 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:12:39,359 cisTopic     INFO     Computing insert size distribution for BRO_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:12:39,360 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:12:49,172 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:13:19,724 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:13:20,858 cisTopic     INFO     Computing insert size distribution for BRO_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:13:20,858 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:13:30,773 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:14:06,542 cisTopic     INFO     Computing barcode rank plot for CNA_10xmultiome_1.FULL
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:14:06,542 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:14:44,328 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:14:44,999 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:14:45,045 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:15:09,276 cisTopic     INFO     Computing barcode rank plot for CNA_10xv11_1.FULL
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:15:09,277 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:15:13,597 cisTopic     INFO     Computing duplicate rate plot for CNA_10xmultiome_1.FULL
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:15:24,149 cisTopic     INFO     Computing barcode rank plot for CNA_10xv11_2.FULL
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:15:24,149 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:15:48,335 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:15:49,146 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:15:49,211 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:15:54,061 cisTopic     INFO     Computing barcode rank plot for BIO_ddseq_3.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:15:54,061 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:16:04,394 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:16:05,140 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:16:05,145 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:16:10,147 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:16:10,983 cisTopic     INFO     Computing insert size distribution for CNA_10xmultiome_1.FULL
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:16:10,983 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:16:17,543 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv11_1.FULL
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:16:22,725 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:16:34,167 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv11_2.FULL
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:17:01,273 cisTopic     INFO     Computing barcode rank plot for BIO_ddseq_4.FULL
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:17:01,273 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:17:04,349 cisTopic     INFO     Computing TSS profile for BRO_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:17:16,562 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:17:17,404 cisTopic     INFO     Computing insert size distribution for CNA_10xv11_1.FULL
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:17:17,404 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:17:29,626 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:17:34,752 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:17:35,623 cisTopic     INFO     Computing insert size distribution for CNA_10xv11_2.FULL
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:17:35,624 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:17:47,967 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:17:54,251 cisTopic     INFO     Computing TSS profile for BRO_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:17:55,502 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:17:56,109 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:17:56,458 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:18:00,036 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:18:00,315 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:18:15,960 cisTopic     INFO     Computing duplicate rate plot for BIO_ddseq_3.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:18:38,113 cisTopic     INFO     Computing barcode rank plot for CNA_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:18:38,113 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:18:55,516 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:18:55,861 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:19:14,214 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:19:18,877 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:19:19,014 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:19:23,763 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:19:24,433 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:19:24,508 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:19:36,407 cisTopic     INFO     Computing duplicate rate plot for BIO_ddseq_4.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:20:03,287 cisTopic     INFO     Computing duplicate rate plot for CNA_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:20:52,663 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:21:07,844 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:21:08,907 cisTopic     INFO     Computing insert size distribution for BIO_ddseq_3.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:21:08,907 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:21:13,488 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:21:13,993 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:21:14,338 cisTopic     INFO     Computing insert size distribution for CNA_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:21:14,338 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:21:29,887 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:21:38,072 cisTopic     INFO     Computing TSS profile for CNA_10xmultiome_1.FULL
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:22:09,619 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:22:38,859 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:22:40,323 cisTopic     INFO     Computing insert size distribution for BIO_ddseq_4.FULL
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:22:40,323 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:22:45,323 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:22:50,932 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:22:51,393 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:22:58,449 cisTopic     INFO     Computing TSS profile for CNA_10xv11_1.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:23:25,656 cisTopic     INFO     Computing TSS profile for BIO_ddseq_3.FULL
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:23:28,576 cisTopic     INFO     Computing TSS profile for CNA_10xv11_2.FULL
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:24:18,787 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:24:19,081 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:24:33,814 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:24:34,118 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:24:49,463 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:24:49,748 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:25:02,675 cisTopic     INFO     Computing TSS profile for BIO_ddseq_4.FULL
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:25:15,218 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:26:13,148 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:26:13,449 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:26:43,475 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:27:08,119 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:27:33,206 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:28:07,020 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:28:18,897 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:28:19,756 cisTopic     INFO     Computing FRIP profile for BRO_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:28:32,794 cisTopic     INFO     Computing TSS profile for CNA_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:28:51,305 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:29:36,679 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:30:11,917 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:30:12,184 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:30:20,572 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:30:30,326 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:30:31,565 cisTopic     INFO     Computing FRIP profile for BRO_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:30:37,576 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:31:46,373 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:32:33,142 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087876) 2022-10-01 13:34:08,120 cisTopic     INFO     Sample BRO_mtscatac_1.FULL done!
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:34:14,624 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:35:13,866 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087874) 2022-10-01 13:36:13,275 cisTopic     INFO     Sample BRO_mtscatac_2.FULL done!
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:36:19,258 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:36:27,746 cisTopic     INFO     Computing barcode rank plot for BIO_ddseq_2.FULL
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:36:27,746 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:36:31,183 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:39:44,380 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:39:50,559 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:39:50,780 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:40:11,408 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:40:12,045 cisTopic     INFO     Computing FRIP profile for CNA_10xmultiome_1.FULL
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:40:24,403 cisTopic     INFO     Computing duplicate rate plot for BIO_ddseq_2.FULL
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:41:00,747 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:41:01,427 cisTopic     INFO     Computing FRIP profile for CNA_10xv11_2.FULL
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:41:14,831 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:41:23,244 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:41:40,315 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:41:41,484 cisTopic     INFO     Computing FRIP profile for CNA_10xv11_1.FULL
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:41:54,357 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:42:02,845 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:42:13,704 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:42:43,437 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:42:44,354 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:43:01,783 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:43:23,767 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087872) 2022-10-01 13:44:52,343 cisTopic     INFO     Sample CNA_10xmultiome_1.FULL done!
# (compute_qc_stats_ray pid=2087868) 2022-10-01 13:45:17,132 cisTopic     INFO     Sample CNA_10xv11_2.FULL done!
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:45:26,557 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:45:27,302 cisTopic     INFO     Computing insert size distribution for BIO_ddseq_2.FULL
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:45:27,302 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:45:34,281 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087870) 2022-10-01 13:45:39,860 cisTopic     INFO     Sample CNA_10xv11_1.FULL done!
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:46:55,192 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:46:55,611 cisTopic     INFO     Computing FRIP profile for CNA_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:47:33,599 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:47:52,491 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:47:52,944 cisTopic     INFO     Computing FRIP profile for BIO_ddseq_3.FULL
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:48:05,645 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:48:19,726 cisTopic     INFO     Computing TSS profile for BIO_ddseq_2.FULL
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:48:33,197 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:49:00,912 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:49:01,222 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:49:01,352 cisTopic     INFO     Computing FRIP profile for BIO_ddseq_4.FULL
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:49:39,155 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:49:39,376 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:49:42,077 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:50:12,015 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087873) 2022-10-01 13:50:12,681 cisTopic     INFO     Sample CNA_10xmultiome_2.FULL done!
# (compute_qc_stats_ray pid=2087869) 2022-10-01 13:50:40,959 cisTopic     INFO     Sample BIO_ddseq_3.FULL done!
# (compute_qc_stats_ray pid=2087871) 2022-10-01 13:51:33,937 cisTopic     INFO     Sample BIO_ddseq_4.FULL done!
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:52:31,664 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:56:43,613 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:59:32,332 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:59:32,552 cisTopic     INFO     Computing FRIP profile for BIO_ddseq_2.FULL
# (compute_qc_stats_ray pid=2087875) 2022-10-01 13:59:49,626 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087875) 2022-10-01 14:00:11,366 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087875) 2022-10-01 14:01:34,903 cisTopic     INFO     Sample BIO_ddseq_2.FULL done!
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:02:57,025 cisTopic     INFO     Computing barcode rank plot for BIO_ddseq_1.FULL
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:02:57,025 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:03:44,823 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:03:45,700 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:03:45,870 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:03:57,665 cisTopic     INFO     Computing duplicate rate plot for BIO_ddseq_1.FULL
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:04:57,814 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:04:57,991 cisTopic     INFO     Computing insert size distribution for BIO_ddseq_1.FULL
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:04:57,991 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:05:01,024 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:06:26,218 cisTopic     INFO     Computing TSS profile for BIO_ddseq_1.FULL
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:07:10,248 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:07:10,310 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2087867) /opt/venv/lib/python3.8/site-packages/pycisTopic/utils.py:326: PerformanceWarning: The following operation may generate 2810102350 cells in the resulting pandas object.
# (compute_qc_stats_ray pid=2087867)   TSS_matrix = cut_sites_TSS.groupby(
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:09:28,955 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:19:41,316 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:26:16,758 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:26:16,950 cisTopic     INFO     Computing FRIP profile for BIO_ddseq_1.FULL
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:26:24,877 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:26:46,386 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2087867) 2022-10-01 14:28:02,975 cisTopic     INFO     Sample BIO_ddseq_1.FULL done!
# Dumping files in /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER...
# 2022-10-01 14:30:34,695	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (compute_qc_stats_ray pid=2091811) 2022-10-01 14:31:03,000 cisTopic     INFO     Reading CNA_hydrop_3.FULL
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:31:02,976 cisTopic     INFO     Reading CNA_10xv11_5.FULL
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:31:02,997 cisTopic     INFO     Reading CNA_hydrop_2.FULL
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:31:02,984 cisTopic     INFO     Reading CNA_10xv11_4.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:31:02,995 cisTopic     INFO     Reading CNA_10xv11_3.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:31:02,998 cisTopic     INFO     Reading CNA_10xv2_2.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:31:02,989 cisTopic     INFO     Reading CNA_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:31:02,987 cisTopic     INFO     Reading CNA_10xv2_1.FULL
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:31:02,991 cisTopic     INFO     Reading CNA_hydrop_1.FULL
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:31:02,981 cisTopic     INFO     Reading CNA_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:36:48,389 cisTopic     INFO     Computing barcode rank plot for CNA_10xv11_4.FULL
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:36:48,390 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:04,529 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:04,921 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:04,923 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:37:15,182 cisTopic     INFO     Computing barcode rank plot for CNA_10xv11_5.FULL
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:37:15,182 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:17,311 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv11_4.FULL
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:37:32,356 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:37:32,713 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:37:32,716 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:41,725 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:42,751 cisTopic     INFO     Computing insert size distribution for CNA_10xv11_4.FULL
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:42,751 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:37:47,310 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv11_5.FULL
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:37:48,100 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:38:13,634 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:38:14,461 cisTopic     INFO     Computing insert size distribution for CNA_10xv11_5.FULL
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:38:14,461 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:38:20,332 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:40:04,101 cisTopic     INFO     Computing TSS profile for CNA_10xv11_4.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:40:19,632 cisTopic     INFO     Computing barcode rank plot for CNA_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:40:19,632 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:40:27,058 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:40:27,314 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:40:43,894 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:40:44,313 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:40:44,317 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:40:50,522 cisTopic     INFO     Computing TSS profile for CNA_10xv11_5.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:41:04,997 cisTopic     INFO     Computing duplicate rate plot for CNA_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:41:15,671 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:41:15,956 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:41:41,763 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:41:42,571 cisTopic     INFO     Computing insert size distribution for CNA_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:41:42,571 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:41:48,457 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:41:51,534 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:42:50,720 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:43:38,509 cisTopic     INFO     Computing barcode rank plot for CNA_10xv2_1.FULL
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:43:38,509 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:43:58,767 cisTopic     INFO     Computing barcode rank plot for CNA_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:43:58,767 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:44:10,675 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:44:11,155 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:44:11,159 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:44:29,151 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:44:30,690 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:44:31,163 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:44:31,213 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:44:37,754 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv2_1.FULL
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:44:59,232 cisTopic     INFO     Computing duplicate rate plot for CNA_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:45:23,636 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:45:25,333 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:45:26,499 cisTopic     INFO     Computing insert size distribution for CNA_10xv2_1.FULL
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:45:26,499 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:45:37,630 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:45:46,893 cisTopic     INFO     Computing TSS profile for CNA_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:45:47,167 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:45:47,989 cisTopic     INFO     Computing insert size distribution for CNA_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:45:47,989 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:46:00,120 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:46:23,946 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:46:24,760 cisTopic     INFO     Computing FRIP profile for CNA_10xv11_4.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:46:26,973 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:46:27,218 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:47:14,911 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:47:16,243 cisTopic     INFO     Computing FRIP profile for CNA_10xv11_5.FULL
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:47:42,601 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:48:01,977 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:48:07,423 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:48:32,745 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:48:59,330 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:49:22,389 cisTopic     INFO     Computing barcode rank plot for CNA_hydrop_1.FULL
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:49:22,389 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:49:41,471 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:49:41,726 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:49:41,883 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091809) 2022-10-01 14:49:55,529 cisTopic     INFO     Sample CNA_10xv11_4.FULL done!
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:49:57,137 cisTopic     INFO     Computing duplicate rate plot for CNA_hydrop_1.FULL
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:50:23,812 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:50:24,580 cisTopic     INFO     Computing insert size distribution for CNA_hydrop_1.FULL
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:50:24,580 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:50:30,026 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:50:42,624 cisTopic     INFO     Computing TSS profile for CNA_10xv2_1.FULL
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:50:48,087 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091807) 2022-10-01 14:50:48,578 cisTopic     INFO     Sample CNA_10xv11_5.FULL done!
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:51:11,553 cisTopic     INFO     Computing barcode rank plot for CNA_10xv2_2.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:51:11,553 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:51:20,151 cisTopic     INFO     Computing TSS profile for CNA_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:51:26,458 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:51:26,697 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:51:34,799 cisTopic     INFO     Computing barcode rank plot for CNA_10xv11_3.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:51:34,799 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:51:49,625 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:51:50,137 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:51:50,184 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:52:06,796 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:52:07,036 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:52:12,359 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:52:13,132 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:52:13,178 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:52:23,200 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:52:23,848 cisTopic     INFO     Computing FRIP profile for CNA_mtscatac_2.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:52:27,635 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv2_2.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:52:43,250 cisTopic     INFO     Computing duplicate rate plot for CNA_10xv11_3.FULL
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:52:45,442 cisTopic     INFO     Computing TSS profile for CNA_hydrop_1.FULL
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:53:07,824 cisTopic     INFO     Computing barcode rank plot for CNA_hydrop_2.FULL
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:53:07,866 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:53:23,774 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:53:25,480 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:53:25,655 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:53:25,789 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:53:26,553 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:53:27,247 cisTopic     INFO     Computing insert size distribution for CNA_10xv2_2.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:53:27,247 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:53:38,458 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:53:39,137 cisTopic     INFO     Computing insert size distribution for CNA_10xv11_3.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:53:39,137 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:53:39,967 cisTopic     INFO     Computing duplicate rate plot for CNA_hydrop_2.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:53:41,244 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:53:42,190 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:53:42,424 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:53:52,141 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:53:54,666 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:53:57,697 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:54:06,829 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:54:07,817 cisTopic     INFO     Computing insert size distribution for CNA_hydrop_2.FULL
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:54:07,817 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:54:12,967 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:54:37,624 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091810) 2022-10-01 14:55:03,088 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091804) 2022-10-01 14:55:35,900 cisTopic     INFO     Sample CNA_mtscatac_2.FULL done!
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:56:04,244 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:56:52,359 cisTopic     INFO     Computing TSS profile for CNA_hydrop_2.FULL
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:57:24,631 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:57:25,217 cisTopic     INFO     Computing FRIP profile for CNA_mtscatac_1.FULL
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:57:55,234 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:57:55,485 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091812) 2022-10-01 14:57:58,689 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:58:18,275 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091813) 2022-10-01 14:58:54,645 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091808) 2022-10-01 14:59:25,772 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091805) 2022-10-01 14:59:26,538 cisTopic     INFO     Computing TSS profile for CNA_10xv11_3.FULL
# (compute_qc_stats_ray pid=2091811) 2022-10-01 14:59:30,146 cisTopic     INFO     Computing barcode rank plot for CNA_hydrop_3.FULL
# (compute_qc_stats_ray pid=2091811) 2022-10-01 14:59:30,146 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091806) 2022-10-01 14:59:37,615 cisTopic     INFO     Computing TSS profile for CNA_10xv2_2.FULL
# (compute_qc_stats_ray pid=2091811) 2022-10-01 14:59:50,525 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2091811) 2022-10-01 14:59:50,704 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091811) 2022-10-01 14:59:50,825 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:00:08,084 cisTopic     INFO     Computing duplicate rate plot for CNA_hydrop_3.FULL
# (compute_qc_stats_ray pid=2091812) 2022-10-01 15:00:14,353 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091812) 2022-10-01 15:00:14,935 cisTopic     INFO     Computing FRIP profile for CNA_10xv2_1.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:00:38,605 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:00:38,803 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:00:39,297 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:00:39,875 cisTopic     INFO     Computing insert size distribution for CNA_hydrop_3.FULL
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:00:39,875 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:00:41,515 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:00:41,719 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:00:47,332 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2091813) 2022-10-01 15:00:47,329 cisTopic     INFO     Sample CNA_mtscatac_1.FULL done!
# (compute_qc_stats_ray pid=2091812) 2022-10-01 15:01:06,083 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091812) 2022-10-01 15:01:35,652 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:03:40,572 cisTopic     INFO     Computing TSS profile for CNA_hydrop_3.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:03:42,394 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091812) 2022-10-01 15:04:10,818 cisTopic     INFO     Sample CNA_10xv2_1.FULL done!
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:04:25,249 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:04:47,589 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:04:47,738 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2091810) 2022-10-01 15:05:56,225 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:06:05,602 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:08:16,707 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:08:27,261 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091808) 2022-10-01 15:09:12,230 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:11:14,290 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:11:14,738 cisTopic     INFO     Computing FRIP profile for CNA_10xv2_2.FULL
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:11:22,076 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:11:22,503 cisTopic     INFO     Computing FRIP profile for CNA_10xv11_3.FULL
# (compute_qc_stats_ray pid=2091810) 2022-10-01 15:11:34,935 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091810) 2022-10-01 15:11:35,874 cisTopic     INFO     Computing FRIP profile for CNA_hydrop_1.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:11:51,890 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:11:59,135 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091810) 2022-10-01 15:12:12,137 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091810) 2022-10-01 15:12:23,710 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:12:26,846 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:12:32,785 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091810) 2022-10-01 15:12:56,283 cisTopic     INFO     Sample CNA_hydrop_1.FULL done!
# (compute_qc_stats_ray pid=2091805) 2022-10-01 15:14:41,776 cisTopic     INFO     Sample CNA_10xv11_3.FULL done!
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:14:43,183 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2091808) 2022-10-01 15:14:50,880 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2091808) 2022-10-01 15:14:51,712 cisTopic     INFO     Computing FRIP profile for CNA_hydrop_2.FULL
# (compute_qc_stats_ray pid=2091806) 2022-10-01 15:15:14,344 cisTopic     INFO     Sample CNA_10xv2_2.FULL done!
# (compute_qc_stats_ray pid=2091808) 2022-10-01 15:15:14,621 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2091808) 2022-10-01 15:15:21,449 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2091808) 2022-10-01 15:15:35,988 cisTopic     INFO     Sample CNA_hydrop_2.FULL done!
# (compute_qc_stats_ray pid=2091811) 2022-10-01 15:16:29,702 cisTopic     INFO     Returning normalized sample TSS enrichment data
# ...
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:47:25,183 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:47:30,151 cisTopic     INFO     Computing barcode rank plot for VIB_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:47:30,151 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:47:42,712 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:47:42,968 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:47:42,971 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:47:48,104 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:47:48,435 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:47:48,439 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:48:01,698 cisTopic     INFO     Computing duplicate rate plot for VIB_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:48:02,232 cisTopic     INFO     Computing duplicate rate plot for VIB_10xv2_1.FULL
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:48:28,430 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:48:29,239 cisTopic     INFO     Computing insert size distribution for VIB_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:48:29,239 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:48:29,707 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:48:30,279 cisTopic     INFO     Computing insert size distribution for VIB_10xv2_1.FULL
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:48:30,279 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:48:35,149 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:48:36,916 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:51:02,108 cisTopic     INFO     Computing barcode rank plot for VIB_10xv2_2.FULL
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:51:02,108 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:51:15,356 cisTopic     INFO     Computing TSS profile for VIB_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:51:28,352 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:51:28,839 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:51:28,873 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:51:43,573 cisTopic     INFO     Computing TSS profile for VIB_10xv2_1.FULL
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:51:51,291 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:51:51,510 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:51:53,553 cisTopic     INFO     Computing duplicate rate plot for VIB_10xv2_2.FULL
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:52:12,220 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:52:12,417 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:52:32,742 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:52:33,313 cisTopic     INFO     Computing insert size distribution for VIB_10xv2_2.FULL
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:52:33,313 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:52:43,078 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:53:14,936 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:53:48,718 cisTopic     INFO     Computing barcode rank plot for VIB_hydrop_1.FULL
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:53:48,718 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:08,006 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:08,311 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:08,547 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:20,463 cisTopic     INFO     Computing duplicate rate plot for VIB_hydrop_1.FULL
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:50,548 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:51,542 cisTopic     INFO     Computing insert size distribution for VIB_hydrop_1.FULL
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:51,542 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:54:51,915 cisTopic     INFO     Computing barcode rank plot for VIB_10xv1_1.FULL
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:54:51,915 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:54:55,315 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:54:57,726 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:55:28,499 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:55:28,995 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:55:29,083 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:55:57,079 cisTopic     INFO     Computing duplicate rate plot for VIB_10xv1_1.FULL
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:56:48,870 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:56:49,470 cisTopic     INFO     Computing insert size distribution for VIB_10xv1_1.FULL
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:56:49,470 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:56:50,017 cisTopic     INFO     Computing TSS profile for VIB_hydrop_1.FULL
# (compute_qc_stats_ray pid=2102492) 2022-10-01 18:57:01,749 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:57:05,568 cisTopic     INFO     Computing barcode rank plot for VIB_hydrop_2.FULL
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:57:05,569 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:57:09,915 cisTopic     INFO     Computing TSS profile for VIB_10xv2_2.FULL
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:57:27,021 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:57:27,312 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:57:27,557 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102490) 2022-10-01 18:57:32,753 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:57:41,667 cisTopic     INFO     Computing duplicate rate plot for VIB_hydrop_2.FULL
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:57:49,836 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:57:49,972 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102489) 2022-10-01 18:57:50,208 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:57:58,955 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102494) 2022-10-01 18:57:59,177 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:58:15,866 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:58:16,511 cisTopic     INFO     Computing insert size distribution for VIB_hydrop_2.FULL
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:58:16,511 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102488) 2022-10-01 18:58:21,536 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:59:56,454 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102491) 2022-10-01 18:59:57,035 cisTopic     INFO     Computing FRIP profile for VIB_10xv2_1.FULL
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:00:20,800 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102490) 2022-10-01 19:00:39,476 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102490) 2022-10-01 19:00:40,434 cisTopic     INFO     Computing FRIP profile for VIB_10xmultiome_2.FULL
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:00:46,913 cisTopic     INFO     Computing TSS profile for VIB_hydrop_2.FULL
# (compute_qc_stats_ray pid=2102491) 2022-10-01 19:00:47,573 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102491) 2022-10-01 19:01:17,267 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102490) 2022-10-01 19:01:31,126 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:01:55,725 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102490) 2022-10-01 19:01:56,439 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:02:01,298 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:02:01,532 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:02:42,947 cisTopic     INFO     Computing TSS profile for VIB_10xv1_1.FULL
# (compute_qc_stats_ray pid=2102490) 2022-10-01 19:03:16,927 cisTopic     INFO     Sample VIB_10xmultiome_2.FULL done!
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:03:52,631 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:03:52,796 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102491) 2022-10-01 19:04:04,393 cisTopic     INFO     Sample VIB_10xv2_1.FULL done!
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:04:37,255 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:06:15,679 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:06:18,644 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:08:55,296 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:08:55,708 cisTopic     INFO     Computing FRIP profile for VIB_10xv2_2.FULL
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:09:32,422 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:10:04,050 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:11:27,168 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102494) 2022-10-01 19:13:12,394 cisTopic     INFO     Sample VIB_10xv2_2.FULL done!
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:14:44,556 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:14:44,936 cisTopic     INFO     Computing FRIP profile for VIB_10xv1_1.FULL
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:14:59,070 cisTopic     INFO     Computing barcode rank plot for VIB_10xv1_2.FULL
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:14:59,070 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:15:14,666 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:15:30,934 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:15:42,974 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:15:43,316 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:15:43,871 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:15:45,140 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:16:16,761 cisTopic     INFO     Computing duplicate rate plot for VIB_10xv1_2.FULL
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:17:15,904 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:17:16,261 cisTopic     INFO     Computing insert size distribution for VIB_10xv1_2.FULL
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:17:16,261 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102492) 2022-10-01 19:17:31,050 cisTopic     INFO     Sample VIB_10xv1_1.FULL done!
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:17:31,222 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:18:42,952 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:22:11,833 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:22:12,142 cisTopic     INFO     Computing FRIP profile for VIB_hydrop_1.FULL
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:22:35,536 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:22:43,430 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:22:53,899 cisTopic     INFO     Computing TSS profile for VIB_10xv1_2.FULL
# (compute_qc_stats_ray pid=2102489) 2022-10-01 19:23:16,589 cisTopic     INFO     Sample VIB_hydrop_1.FULL done!
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:23:54,089 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:23:54,146 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:24:33,564 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:24:33,833 cisTopic     INFO     Computing FRIP profile for VIB_hydrop_2.FULL
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:24:48,733 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:24:55,023 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102488) 2022-10-01 19:25:22,041 cisTopic     INFO     Sample VIB_hydrop_2.FULL done!
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:25:44,963 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:26:53,961 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:27:41,371 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:27:41,457 cisTopic     INFO     Computing FRIP profile for VIB_10xv1_2.FULL
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:27:48,748 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:28:03,586 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=2102493) 2022-10-01 19:28:54,926 cisTopic     INFO     Sample VIB_10xv1_2.FULL done!
# Dumping files in /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_4_merged/cistopic_qc_out_MASTER...
