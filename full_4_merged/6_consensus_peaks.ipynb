# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk, peak_calling
import pyranges as pr
import requests
import os
import pandas as pd
import glob
import pickle

# %%
# %load_ext lab_black

# %%
# get chromosome sizes (hg38)
if not os.path.exists("chromsizes.txt"):
    target_url = (
        "http://hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/hg38.chrom.sizes"
    )
    chromsizes = pd.read_csv(target_url, sep="\t", header=None)
    chromsizes.columns = ["Chromosome", "End"]
    chromsizes["Start"] = [0] * chromsizes.shape[0]
    chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
    chromsizes = pr.PyRanges(chromsizes)
    chromsizes.to_csv("chromsizes.txt")
    chromsizes
else:
    chromsizes = pd.read_csv("chromsizes.txt")

# %%
cto_consensus_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(
        glob.glob("cistopic_objects_master/*singlets.model*consensus_harmony.pkl")
    )
}
cto_consensus_path_dict
# Out:
# {'master_all_1.FULL': 'cistopic_objects_master/master_all_1.FULL__cto.scrublet0-4.fmx.singlets.model_60topics.dimreduc.consensus_harmony.pkl'}

# %%
import gc
import logging
import os
import re
import subprocess
import sys
from typing import Dict, List, Optional, Union

import numpy as np
import pandas as pd
import pyBigWig
import pyranges as pr
import ray

from pycisTopic.cistopic_class import *
from pycisTopic.utils import *


def export_pseudobulk(
    input_data: Union["CistopicObject", pd.DataFrame, Dict[str, pd.DataFrame]],
    variable: str,
    chromsizes: Union[pd.DataFrame, pr.PyRanges],
    bed_path: str,
    bigwig_path: str,
    path_to_fragments: Optional[Dict[str, str]] = None,
    sample_id_col: Optional[str] = "sample_id",
    n_cpu: Optional[int] = 1,
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
    use_polars: Optional[bool] = True,
    **kwargs
):
    """
    Create pseudobulks as bed and bigwig from single cell fragments file given a barcode annotation.
    Parameters
    ---------
    input_data: CistopicObject or pd.DataFrame
            A :class:`CistopicObject` containing the specified `variable` as a column in :class:`CistopicObject.cell_data` or a cell metadata
            :class:`pd.DataFrame` containing barcode as rows, containing the specified `variable` as a column (additional columns are
            possible) and a `sample_id` column. Index names must contain the BARCODE (e.g. ATGTCGTC-1), additional tags are possible separating with -
            (e.g. ATGCTGTGCG-1-Sample_1). The levels in the sample_id column must agree with the keys in the path_to_fragments dictionary.
            Alternatively, if the cell metadata contains a column named barcode it will be used instead of the index names.
    variable: str
            A character string indicating the column that will be used to create the different group pseudobulk. It must be included in
            the cell metadata provided as input_data.
    chromsizes: pd.DataFrame or pr.PyRanges
            A data frame or :class:`pr.PyRanges` containing size of each chromosome, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed files per group will be saved. If None, files will not be generated.
    bigwig_path: str
            Path to folder where the bigwig files per group will be saved. If None, files will not be generated.
    path_to_fragments: str or dict, optional
            A dictionary of character strings, with sample name as names indicating the path to the fragments file/s from which pseudobulk profiles have to
            be created. If a :class:`CistopicObject` is provided as input it will be ignored, but if a cell metadata :class:`pd.DataFrame` is provided it
            is necessary to provide it. The keys of the dictionary need to match with the sample_id tag added to the index names of the input data frame.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    n_cpu: int, optional
            Number of cores to use. Default: 1.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str, optional
            Pattern to split cell barcode from sample id. Default: ___ .
    use_polars: bool, optional
            Whether to use polars to read fragments files. Default: True.
    **kwargs
            Additional parameters for ray.init()
    Return
    ------
    dict
            A dictionary containing the paths to the newly created bed fragments files per group a dictionary containing the paths to the
            newly created bigwig files per group.
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    # Get fragments file
    if isinstance(input_data, CistopicObject):
        path_to_fragments = input_data.path_to_fragments
        if path_to_fragments is None:
            log.error("No path_to_fragments in this cisTopic object.")
        cell_data = input_data.cell_data
    elif isinstance(input_data, pd.DataFrame):
        if path_to_fragments is None:
            log.error("Please, provide path_to_fragments.")
        cell_data = input_data
    # Check for sample_id column
    try:
        sample_ids = list(set(cell_data[sample_id_col]))
    except ValueError:
        print(
            'Please, include a sample identification column (e.g. "sample_id") in your cell metadata!'
        )

    # Get fragments
    fragments_df_dict = {}
    for sample_id in path_to_fragments.keys():
        if sample_id not in sample_ids:
            log.info(
                "The following path_to_fragments entry is not found in the cell metadata sample_id_col: ",
                sample_id,
                ". It will be ignored.",
            )
        else:
            log.info("Reading fragments from " + path_to_fragments[sample_id])
            fragments_df = read_fragments_from_file(
                path_to_fragments[sample_id], use_polars=use_polars
            ).df
            # Convert to int32 for memory efficiency
            fragments_df.Start = np.int32(fragments_df.Start)
            fragments_df.End = np.int32(fragments_df.End)
            if "Score" in fragments_df:
                fragments_df.Score = np.int32(fragments_df.Score)
            if "barcode" in cell_data:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(cell_data["barcode"].tolist())
                ]
            else:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(
                        prepare_tag_cells(cell_data.index.tolist(), split_pattern)
                    )
                ]
            fragments_df_dict[sample_id] = fragments_df

    # Set groups
    if "barcode" in cell_data:
        cell_data = cell_data.loc[:, [variable, sample_id_col, "barcode"]]
    else:
        cell_data = cell_data.loc[:, [variable, sample_id_col]]
    cell_data[variable] = cell_data[variable].replace(" ", "", regex=True)
    cell_data[variable] = cell_data[variable].replace("[^A-Za-z0-9]+", "_", regex=True)
    groups = sorted(list(set(cell_data[variable])))
    # Check chromosome sizes
    if isinstance(chromsizes, pd.DataFrame):
        chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
        chromsizes = pr.PyRanges(chromsizes)
    # Check that output dir exist and generate output paths
    if isinstance(bed_path, str):
        if not os.path.exists(bed_path):
            os.makedirs(bed_path)
        bed_paths = {
            group: os.path.join(bed_path, str(group) + ".bed.gz") for group in groups
        }
    else:
        bed_paths = {}
    if isinstance(bigwig_path, str):
        if not os.path.exists(bigwig_path):
            os.makedirs(bigwig_path)
        bw_paths = {
            group: os.path.join(bigwig_path, str(group) + ".bw") for group in groups
        }
    else:
        bw_paths = {}
    # Create pseudobulks
    if n_cpu > 1:
        ray.init(num_cpus=n_cpu, **kwargs)
        ray_handle = ray.wait(
            [
                export_pseudobulk_ray.remote(
                    cell_data,
                    group,
                    fragments_df_dict,
                    chromsizes,
                    bigwig_path,
                    bed_path,
                    sample_id_col,
                    normalize_bigwig,
                    remove_duplicates,
                    split_pattern,
                )
                for group in groups
            ],
            num_returns=len(groups),
        )
        ray.shutdown()
    else:
        [
            export_pseudobulk_one_sample(
                cell_data,
                group,
                fragments_df_dict,
                chromsizes,
                bigwig_path,
                bed_path,
                sample_id_col,
                normalize_bigwig,
                remove_duplicates,
                split_pattern,
            )
            for group in groups
        ]

    return bw_paths, bed_paths


def export_pseudobulk_one_sample(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    log.info("Creating pseudobulk for " + str(group))
    group_fragments_list = []
    group_fragments_dict = {}
    for sample_id in fragments_df_dict:
        sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]
        if "barcode" in sample_data:
            sample_data.index = sample_data["barcode"].tolist()
        else:
            sample_data.index = prepare_tag_cells(
                sample_data.index.tolist(), split_pattern
            )
        group_var = sample_data.iloc[:, 0]
        barcodes = group_var[group_var.isin([group])].index.tolist()
        fragments_df = fragments_df_dict[sample_id]
        group_fragments = fragments_df.loc[fragments_df["Name"].isin(barcodes)]
        if len(fragments_df_dict) > 1:
            group_fragments_dict[sample_id] = group_fragments

    if len(fragments_df_dict) > 1:
        group_fragments_list = [
            group_fragments_dict[list(group_fragments_dict.keys())[x]]
            for x in range(len(fragments_df_dict))
        ]
        group_fragments = group_fragments_list[0].append(group_fragments_list[1:])

    group_fragments = group_fragments[
        group_fragments["Chromosome"].isin(chromsizes.Chromosome)
    ]

    del group_fragments_dict
    del group_fragments_list
    del fragments_df
    gc.collect()

    group_pr = pr.PyRanges(group_fragments)
    if isinstance(bigwig_path, str):
        bigwig_path_group = os.path.join(bigwig_path, str(group) + ".bw")
        if remove_duplicates:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
            )
        else:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
                value_col="Score",
            )
    if isinstance(bed_path, str):
        bed_path_group = os.path.join(bed_path, str(group) + ".bed.gz")
        group_pr.to_bed(
            path=bed_path_group, keep=False, compression="infer", chain=False
        )

    log.info(str(group) + " done!")


@ray.remote
def export_pseudobulk_ray(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    export_pseudobulk_one_sample(
        cell_data,
        group,
        fragments_df_dict,
        chromsizes,
        bigwig_path,
        bed_path,
        sample_id_col,
        normalize_bigwig,
        remove_duplicates,
        split_pattern,
    )

# %%
sample = "master_all_1.FULL"

# %%
cto_path = cto_consensus_path_dict[sample]
with open(cto_path, "rb") as f:
    cto = pickle.load(f)

# %%
cto.cell_data
# Out:
#                                                    cisTopic_nr_acc  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                          11509
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                          13497
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                          12411
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                          15490
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                          14560
# ...                                                            ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                     573
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...             739
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                     646
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                     789
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                     496
#
#                                                    cisTopic_log_nr_acc  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                           4.061038
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                           4.130237
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                           4.093807
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                           4.190051
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                           4.163161
# ...                                                                ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                    2.758155
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...            2.868644
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    2.810233
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                    2.897077
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    2.695482
#
#                                                    cisTopic_nr_frag  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                           15623
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                           19292
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                           15494
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                           23541
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                           21634
# ...                                                             ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                      774
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...             1500
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                      722
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                     1394
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                     1937
#
#                                                    cisTopic_log_nr_frag  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                            4.193764
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                            4.285377
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                            4.190164
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                            4.371825
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                            4.335137
# ...                                                                 ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                     2.888741
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...             3.176091
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                     2.858537
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                     3.144263
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                      3.28713
#
#                                                     Log_total_nr_frag  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                          4.507707
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                          4.556821
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                          4.457942
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                          4.702921
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                          4.620511
# ...                                                               ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                   3.402949
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...           3.936564
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                   3.760347
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                   4.015192
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                   4.036709
#
#                                                     Log_unique_nr_frag  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                           4.253265
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                           4.352646
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                           4.253362
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                           4.436544
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                           4.385159
# ...                                                                ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                    3.255755
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...            3.318481
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    3.308564
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                    3.237544
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    3.416973
#
#                                                     Total_nr_frag  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                         32189
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                         36043
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                         28704
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                         50457
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                         41736
# ...                                                           ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                   2529
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...           8641
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                   5759
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                  10356
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                  10882
#
#                                                     Unique_nr_frag  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                          17917
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                          22524
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                          17921
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                          27324
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                          24275
# ...                                                            ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                    1802
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...            2082
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    2035
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                    1728
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    2612
#
#                                                     Dupl_nr_frag  Dupl_rate  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                        14272   0.443381
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                        13519   0.375080
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                        10783   0.375662
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                        23133   0.458470
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                        17461   0.418368
# ...                                                          ...        ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                   727   0.287465
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...          6559   0.759056
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                  3724   0.646640
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                  8628   0.833140
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                  8270   0.759971
#
#                                                     ...  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                 ...
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                 ...
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                 ...
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                 ...
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                 ...
# ...                                                 ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL          ...
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...  ...
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL          ...
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL          ...
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL          ...
#
#                                                     seurat_cell_type_pred_score_individual  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                                               0.742897
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                                               0.790382
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                                               0.322688
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                               0.940714
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                               1.000000
# ...                                                                                    ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                                        0.321475
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...                                0.377490
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                        0.310746
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                                        0.372690
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                        0.453442
#
#                                                     seurat_cell_type_individual  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                         Natural killer cell
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                                 CD4+ T cell
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                                 CD4+ T cell
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                 CD4+ T cell
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                      B cell
# ...                                                                         ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                          CD4+ T cell
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...             Cytotoxic T cell
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                          CD4+ T cell
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                       CD14+ monocyte
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                          CD4+ T cell
#
#                                                     consensus_cell_type_individual  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                            Natural killer cell
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                               Cytotoxic T cell
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                                 CD16+ monocyte
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                    CD4+ T cell
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                         B cell
# ...                                                                            ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                             CD4+ T cell
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...                  CD14+ monocyte
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                          CD14+ monocyte
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                          CD14+ monocyte
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                             CD4+ T cell
#
#                                                     seurat_cell_type_full_mega  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                        Natural killer cell
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                                CD4+ T cell
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                             CD14+ monocyte
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                CD4+ T cell
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                     B cell
# ...                                                                        ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                    Cytotoxic T cell
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...            Cytotoxic T cell
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    Cytotoxic T cell
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                      CD14+ monocyte
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                    Cytotoxic T cell
#
#                                                    seurat_cell_type_full_mega_pred_score  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                                             0.532817
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                                             0.721850
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                                             0.681844
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                             0.755101
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                             0.987745
# ...                                                                                  ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                                      0.398221
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...                              0.361295
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                      0.443869
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                                      0.427356
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                      0.342330
#
#                                                    seurat_cell_type_full_mega_consensus  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL
# ...                                                                                 ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL
#
#                                                     consensus_cell_type  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                 Natural killer cell
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                    Cytotoxic T cell
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                      CD16+ monocyte
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                         CD4+ T cell
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                              B cell
# ...                                                                 ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL             Cytotoxic T cell
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...       CD14+ monocyte
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL             Cytotoxic T cell
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL               CD14+ monocyte
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                  CD4+ T cell
#
#                                                       tech  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                  10xv2
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                  10xv2
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                  10xv2
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                  10xv2
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                  10xv2
# ...                                                    ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL          hydrop
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...  hydrop
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL          hydrop
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL          hydrop
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL          hydrop
#
#                                                    harmony_pycisTopic_leiden_10_3.0  \
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                                              44
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                                               3
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                                              36
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                              39
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                              63
# ...                                                                             ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                                       53
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...                                9
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                       10
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                                        7
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                       35
#
#                                                    seurat_cell_type_full_mega_harmony_consensus
# CTAGGGCACCCTCGTT___VIB_10xv2_1.FULL                                         Natural killer cell
# CAGGCGACTCTAACGT___VIB_10xv2_1.FULL                                            Cytotoxic T cell
# TACATTCACTGGCAAG___VIB_10xv2_1.FULL                                              CD14+ monocyte
# CGATACCCTAGCAGGT___VIB_10xv2_1.FULL                                                 CD4+ T cell
# CACTTAGGACAGACCC___VIB_10xv2_1.FULL                                                      B cell
# ...                                                                                         ...
# ACCGAAGGCTGCTGTCCTAG-1___VIB_hydrop_2.FULL                                       CD14+ monocyte
# CCTCCATAAGCTGTAATCCA_CCTCCATAAGGGACCGATTC-2___V...                               CD14+ monocyte
# GGTTAACCTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                       CD14+ monocyte
# CGTGAATGAAAGGACGACAG-1___VIB_hydrop_2.FULL                                       CD14+ monocyte
# CACTAGCGTGTGGAAGGAGA-1___VIB_hydrop_2.FULL                                     Cytotoxic T cell
#
# [169047 rows x 31 columns]

# %%
# for sample in ["BRO_mtscatac_1.LIBDS"]:
bw_paths_dict = {}
bed_paths_dict = {}

import ray

if ray.is_initialized():
    print("Shutting down Ray")
    ray.shutdown()

for sample in cto_consensus_path_dict.keys():
    # for sample in ["BRO_mtscatac_1.LIBDS"]:
    bed_path = os.path.join(
        "final_consensus_peaks", f"{sample}__SCREEN_pseudobulk_bed_files"
    )
    bw_path = os.path.join(
        "final_consensus_peaks", f"{sample}__SCREEN_pseudobulk_bw_files"
    )
    if not os.path.exists(bed_path):
        cto_path = cto_consensus_path_dict[sample]
        with open(cto_path, "rb") as f:
            cto = pickle.load(f)

            bw_paths, bed_paths = export_pseudobulk(
                input_data=cto,
                variable="harmony_consensus_cell_type__mega",
                sample_id_col="sample_id",
                chromsizes=chromsizes,
                bed_path=bed_path,
                bigwig_path=bw_path,
                path_to_fragments="merged_all_1.fragments.ID.sorted.tsv.gz",
                n_cpu=16,
                normalize_bigwig=True,
                remove_duplicates=True,
            )

            if ray.is_initialized():
                print("Shutting down Ray")
                ray.shutdown()
    else:
        print(f"{bed_path} exists, skipping...")
# Out:
# 2023-02-20 18:21:14,531 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_10xv2_1.FULL.fragments.tsv.gz
# 2023-02-20 18:22:15,261 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_mtscatac_1.FULL.fragments.tsv.gz
# 2023-02-20 18:23:21,011 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/EPF_hydrop_4.FULL.fragments.tsv.gz
# 2023-02-20 18:23:49,567 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/STA_10xv11_1.FULL.fragments.tsv.gz
# 2023-02-20 18:25:05,723 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xmultiome_1.FULL.fragments.tsv.gz
# 2023-02-20 18:26:11,208 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/TXG_10xv11_1.FULL.fragments.tsv.gz
# 2023-02-20 18:29:43,702 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv11_1.FULL.fragments.tsv.gz
# 2023-02-20 18:30:48,732 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/MDC_mtscatac_1.FULL.fragments.tsv.gz
# 2023-02-20 18:33:21,978 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xmultiome_2.FULL.fragments.tsv.gz
# 2023-02-20 18:34:43,740 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/SAN_10xmultiome_1.FULL.fragments.tsv.gz
# 2023-02-20 18:37:50,731 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz
# 2023-02-20 18:40:27,265 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/EPF_hydrop_1.FULL.fragments.tsv.gz
# 2023-02-20 18:40:54,974 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/HAR_ddseq_1.FULL.fragments.tsv.gz
# 2023-02-20 18:42:36,994 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz
# 2023-02-20 18:44:58,745 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_10xmultiome_2.FULL.fragments.tsv.gz
# 2023-02-20 18:45:46,263 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/BRO_mtscatac_2.FULL.fragments.tsv.gz
# 2023-02-20 18:46:41,480 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/EPF_hydrop_2.FULL.fragments.tsv.gz
# 2023-02-20 18:47:08,680 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv11_3.FULL.fragments.tsv.gz
# 2023-02-20 18:48:34,855 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz
# 2023-02-20 18:51:08,796 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/BIO_ddseq_3.FULL.fragments.tsv.gz
# 2023-02-20 18:51:54,146 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/MDC_mtscatac_2.FULL.fragments.tsv.gz
# 2023-02-20 18:53:44,668 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_hydrop_1.FULL.fragments.tsv.gz
# 2023-02-20 18:54:25,766 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_10xv1_2.FULL.fragments.tsv.gz
# 2023-02-20 18:57:59,301 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_10xmultiome_1.FULL.fragments.tsv.gz
# 2023-02-20 18:58:35,782 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/BRO_mtscatac_1.FULL.fragments.tsv.gz
# 2023-02-20 18:59:30,924 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/BIO_ddseq_1.FULL.fragments.tsv.gz
# 2023-02-20 19:03:45,894 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/HAR_ddseq_2.FULL.fragments.tsv.gz
# 2023-02-20 19:05:37,115 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv11_5.FULL.fragments.tsv.gz
# 2023-02-20 19:06:09,111 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/STA_10xv11_2.FULL.fragments.tsv.gz
# 2023-02-20 19:07:09,526 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_mtscatac_2.FULL.fragments.tsv.gz
# 2023-02-20 19:07:58,169 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv11_2.FULL.fragments.tsv.gz
# 2023-02-20 19:09:07,397 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/TXG_10xv2_1.FULL.fragments.tsv.gz
# 2023-02-20 19:12:58,622 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_10xv2_2.FULL.fragments.tsv.gz
# 2023-02-20 19:14:23,821 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz
# 2023-02-20 19:20:37,647 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/BIO_ddseq_4.FULL.fragments.tsv.gz
# 2023-02-20 19:21:34,248 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_10xv1_1.FULL.fragments.tsv.gz
# 2023-02-20 19:23:17,496 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_hydrop_2.FULL.fragments.tsv.gz
# 2023-02-20 19:24:06,818 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv11_4.FULL.fragments.tsv.gz
# 2023-02-20 19:24:38,403 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/EPF_hydrop_3.FULL.fragments.tsv.gz
# 2023-02-20 19:25:06,792 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/BIO_ddseq_2.FULL.fragments.tsv.gz
# 2023-02-20 19:27:07,453 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_hydrop_1.FULL.fragments.tsv.gz
# 2023-02-20 19:27:42,824 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/SAN_10xmultiome_2.FULL.fragments.tsv.gz
# 2023-02-20 19:31:38,493 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv2_1.FULL.fragments.tsv.gz
# 2023-02-20 19:32:43,782 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_10xv2_2.FULL.fragments.tsv.gz
# 2023-02-20 19:34:21,204 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/TXG_10xv2_2.FULL.fragments.tsv.gz
# 2023-02-20 19:37:29,514 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/CNA_hydrop_3.FULL.fragments.tsv.gz
# 2023-02-20 19:38:29,847 cisTopic     INFO     Reading fragments from ../1_data_repository/full_fragments/VIB_hydrop_2.FULL.fragments.tsv.gz
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 24
#      21 with open(cto_path, "rb") as f:
#      22     cto = pickle.load(f)
# ---> 24     bw_paths, bed_paths = export_pseudobulk(
#      25         input_data=cto,
#      26         variable="harmony_consensus_cell_type__mega",
#      27         sample_id_col="sample_id",
#      28         chromsizes=chromsizes,
#      29         bed_path=bed_path,
#      30         bigwig_path=bw_path,
#      31         path_to_fragments="merged_all_1.fragments.ID.sorted.tsv.gz",
#      32         n_cpu=16,
#      33         normalize_bigwig=True,
#      34         remove_duplicates=True,
#      35     )
#      37     if ray.is_initialized():
#      38         print("Shutting down Ray")
#
# Cell In [6], line 135, in export_pseudobulk(input_data, variable, chromsizes, bed_path, bigwig_path, path_to_fragments, sample_id_col, n_cpu, normalize_bigwig, remove_duplicates, split_pattern, use_polars, **kwargs)
#     133 # Set groups
#     134 if "barcode" in cell_data:
# --> 135     cell_data = cell_data.loc[:, [variable, sample_id_col, "barcode"]]
#     136 else:
#     137     cell_data = cell_data.loc[:, [variable, sample_id_col]]
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1257, in _LocIndexer._getitem_tuple(self, tup)
#    1254 if self._multi_take_opportunity(tup):
#    1255     return self._multi_take(tup)
# -> 1257 return self._getitem_tuple_same_dim(tup)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:925, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     922 if com.is_null_slice(key):
#     923     continue
# --> 925 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     926 # We should never have retval.ndim < self.ndim, as that should
#     927 #  be handled by the _getitem_lowerdim call above.
#     928 assert retval.ndim == self.ndim
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1302, in _LocIndexer._getitem_axis(self, key, axis)
#    1299     if hasattr(key, "ndim") and key.ndim > 1:
#    1300         raise ValueError("Cannot index with multidimensional key")
# -> 1302     return self._getitem_iterable(key, axis=axis)
#    1304 # nested tuple slicing
#    1305 if is_nested_tuple(key, labels):
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1240, in _LocIndexer._getitem_iterable(self, key, axis)
#    1237 self._validate_key(key, axis)
#    1239 # A collection of keys
# -> 1240 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1241 return self.obj._reindex_with_indexers(
#    1242     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1243 )
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1433, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1430 ax = self.obj._get_axis(axis)
#    1431 axis_name = self.obj._get_axis_name(axis)
# -> 1433 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1435 return keyarr, indexer
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['harmony_consensus_cell_type__mega'] not in index"
