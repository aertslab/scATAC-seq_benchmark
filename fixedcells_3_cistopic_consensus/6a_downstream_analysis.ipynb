# %% [markdown]
# # pycisTopic analysis
#
# Full dataset, using consensus peak regions.

# %%
import pycisTopic
# %load_ext nb_black
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import pickle
import pandas as pd
import os

# %%
# !pwd
# Out:
# /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus

# %%
wdir = '/dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus'
os.chdir( wdir )

# %%
# create output directory:
f_final_dir = os.path.join(wdir, 'downstream_analysis')
if not os.path.exists(f_final_dir):
    os.makedirs(f_final_dir)

# %%
import glob

# %%
import re

sample_annot = pd.DataFrame(
    [
        ['Broad_1','BioRad'],
        ['Broad_2','BioRad'],
        ['Stanford_1','10x v1.0'],
        ['Stanford_2','10x v1.0'],
        ['VIB_1','10x v1.0'],
        ['VIB_2','10x v1.0'],
        ['CNAG_1','10x v1.1'],
        ['CNAG_2','10x v1.1'],
        ['Broad_mito_1','mito-scATAC-seq'],
        ['Broad_mito_2','mito-scATAC-seq'],
        ['Sanger_1','10x multiome'],
        ['Sanger_2','10x multiome'],
        ['s3atac','s3-ATAC'],
        ['VIB_Hydrop_1','HyDrop'],
        ['VIB_Hydrop_2','HyDrop'],
        
    ],
    columns=['key','Technology']
)
sample_annot['Sample'] = sample_annot['key']
sample_annot.set_index('key', drop=False, inplace=True)
# rename samples:
sample_annot.loc['Broad_1','Sample'] = 'Harvard_1'
sample_annot.loc['Broad_2','Sample'] = 'Harvard_2'
sample_annot.loc['Broad_mito_1','Sample'] = 'Broad_1'
sample_annot.loc['Broad_mito_2','Sample'] = 'Broad_2'
sample_annot.loc['s3atac','Sample'] = 'OHSU'
sample_annot.loc['VIB_Hydrop_1','Sample'] = 'Hydrop_1'
sample_annot.loc['VIB_Hydrop_2','Sample'] = 'Hydrop_2'

sample_annot['Replicate'] = [ x.Sample.split('_')[-1] for i,x in sample_annot.iterrows() ]
sample_annot['st'] = [ re.sub('_[0-9]','',x.Sample)+' ('+x.Technology+')' for i,x in sample_annot.iterrows() ]

sample_annot.loc[sample_annot['key']=='s3atac','Replicate'] = 1
sample_map = { x: y.Sample for x,y in sample_annot.iterrows() }
sample_annot
# Out:
#                        key       Technology      Sample Replicate  \
# key
# Broad_1            Broad_1           BioRad   Harvard_1         1
# Broad_2            Broad_2           BioRad   Harvard_2         2
# Stanford_1      Stanford_1         10x v1.0  Stanford_1         1
# Stanford_2      Stanford_2         10x v1.0  Stanford_2         2
# VIB_1                VIB_1         10x v1.0       VIB_1         1
# VIB_2                VIB_2         10x v1.0       VIB_2         2
# CNAG_1              CNAG_1         10x v1.1      CNAG_1         1
# CNAG_2              CNAG_2         10x v1.1      CNAG_2         2
# Broad_mito_1  Broad_mito_1  mito-scATAC-seq     Broad_1         1
# Broad_mito_2  Broad_mito_2  mito-scATAC-seq     Broad_2         2
# Sanger_1          Sanger_1     10x multiome    Sanger_1         1
# Sanger_2          Sanger_2     10x multiome    Sanger_2         2
# s3atac              s3atac          s3-ATAC        OHSU         1
# VIB_Hydrop_1  VIB_Hydrop_1           HyDrop    Hydrop_1         1
# VIB_Hydrop_2  VIB_Hydrop_2           HyDrop    Hydrop_2         2
#
#                                    st
# key
# Broad_1              Harvard (BioRad)
# Broad_2              Harvard (BioRad)
# Stanford_1        Stanford (10x v1.0)
# Stanford_2        Stanford (10x v1.0)
# VIB_1                  VIB (10x v1.0)
# VIB_2                  VIB (10x v1.0)
# CNAG_1                CNAG (10x v1.1)
# CNAG_2                CNAG (10x v1.1)
# Broad_mito_1  Broad (mito-scATAC-seq)
# Broad_mito_2  Broad (mito-scATAC-seq)
# Sanger_1        Sanger (10x multiome)
# Sanger_2        Sanger (10x multiome)
# s3atac                 OHSU (s3-ATAC)
# VIB_Hydrop_1          Hydrop (HyDrop)
# VIB_Hydrop_2          Hydrop (HyDrop)

# %% [markdown]
# ## Save/load cisTopic objects

# %%
cto_consensus_paths = sorted(glob.glob(f'cistopic_objects/*consensus.pkl'))
cistopic_obj_path_dict = {x.split('/')[-1].split(f'__')[0]:x for x in cto_consensus_paths}
cistopic_obj_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 'cistopic_objects/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'BIO_ddseq_2.FIXEDCELLS': 'cistopic_objects/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_14topics.dimreduc.consensus.pkl',
#  'BIO_ddseq_3.FIXEDCELLS': 'cistopic_objects/BIO_ddseq_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'BIO_ddseq_4.FIXEDCELLS': 'cistopic_objects/BIO_ddseq_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'BRO_mtscatac_1.FIXEDCELLS': 'cistopic_objects/BRO_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'BRO_mtscatac_2.FIXEDCELLS': 'cistopic_objects/BRO_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_17topics.dimreduc.consensus.pkl',
#  'CNA_10xmultiome_1.FIXEDCELLS': 'cistopic_objects/CNA_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xmultiome_2.FIXEDCELLS': 'cistopic_objects/CNA_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_1.FIXEDCELLS': 'cistopic_objects/CNA_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_2.FIXEDCELLS': 'cistopic_objects/CNA_10xv11_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_3.FIXEDCELLS': 'cistopic_objects/CNA_10xv11_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_4.FIXEDCELLS': 'cistopic_objects/CNA_10xv11_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_5.FIXEDCELLS': 'cistopic_objects/CNA_10xv11_5.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xv2_1.FIXEDCELLS': 'cistopic_objects/CNA_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xv2_2.FIXEDCELLS': 'cistopic_objects/CNA_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'CNA_hydrop_1.FIXEDCELLS': 'cistopic_objects/CNA_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'CNA_hydrop_2.FIXEDCELLS': 'cistopic_objects/CNA_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_hydrop_3.FIXEDCELLS': 'cistopic_objects/CNA_hydrop_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'CNA_mtscatac_1.FIXEDCELLS': 'cistopic_objects/CNA_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_mtscatac_2.FIXEDCELLS': 'cistopic_objects/CNA_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_1.FIXEDCELLS': 'cistopic_objects/EPF_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_2.FIXEDCELLS': 'cistopic_objects/EPF_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_3.FIXEDCELLS': 'cistopic_objects/EPF_hydrop_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_5topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_4.FIXEDCELLS': 'cistopic_objects/EPF_hydrop_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'HAR_ddseq_1.FIXEDCELLS': 'cistopic_objects/HAR_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'HAR_ddseq_2.FIXEDCELLS': 'cistopic_objects/HAR_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'MDC_mtscatac_1.FIXEDCELLS': 'cistopic_objects/MDC_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_19topics.dimreduc.consensus.pkl',
#  'MDC_mtscatac_2.FIXEDCELLS': 'cistopic_objects/MDC_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'OHS_s3atac_1.FIXEDCELLS': 'cistopic_objects/OHS_s3atac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'OHS_s3atac_2.FIXEDCELLS': 'cistopic_objects/OHS_s3atac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_7topics.dimreduc.consensus.pkl',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'cistopic_objects/SAN_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_7topics.dimreduc.consensus.pkl',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'cistopic_objects/SAN_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'STA_10xv11_1.FIXEDCELLS': 'cistopic_objects/STA_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'STA_10xv11_2.FIXEDCELLS': 'cistopic_objects/STA_10xv11_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_7topics.dimreduc.consensus.pkl',
#  'TXG_10xv11_1.FIXEDCELLS': 'cistopic_objects/TXG_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_14topics.dimreduc.consensus.pkl',
#  'TXG_10xv2_1.FIXEDCELLS': 'cistopic_objects/TXG_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_21topics.dimreduc.consensus.pkl',
#  'TXG_10xv2_2.FIXEDCELLS': 'cistopic_objects/TXG_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_21topics.dimreduc.consensus.pkl',
#  'UCS_ddseq_1.FIXEDCELLS': 'cistopic_objects/UCS_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'UCS_ddseq_2.FIXEDCELLS': 'cistopic_objects/UCS_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'cistopic_objects/VIB_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'cistopic_objects/VIB_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_10xv1_1.FIXEDCELLS': 'cistopic_objects/VIB_10xv1_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'VIB_10xv1_2.FIXEDCELLS': 'cistopic_objects/VIB_10xv1_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_19topics.dimreduc.consensus.pkl',
#  'VIB_10xv2_1.FIXEDCELLS': 'cistopic_objects/VIB_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'VIB_10xv2_2.FIXEDCELLS': 'cistopic_objects/VIB_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_1.FIXEDCELLS': 'cistopic_objects/VIB_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_17topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_2.FIXEDCELLS': 'cistopic_objects/VIB_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_19topics.dimreduc.consensus.pkl'}

# %% [markdown]
# ## Topic binarization & QC

# %%
from pycisTopic.topic_binarization import binarize_topics
from pycisTopic.topic_qc import compute_topic_metrics, plot_topic_qc
from pycisTopic.utils import fig2img
import matplotlib.pyplot as plt
from pycisTopic.topic_qc import topic_annotation
from pycisTopic.diff_features import (
    impute_accessibility,
    normalize_scores,
    find_highly_variable_features,
    find_diff_features
)
from pycisTopic.clust_vis import plot_imputed_features
import numpy as np
import copy

# %% [markdown]
# ### Binarize the topic-region distributions

# %%
for sample in cistopic_obj_path_dict.keys():
# for sample  in ['SAN_10xmultiome_1.FIXEDCELLS']:
    path = cistopic_obj_path_dict[sample]
    if not os.path.exists(f'downstream_analysis/DARs/{sample}'):
        if os.path.isfile(path):
            print(f"Loading {path}")
            with open(path, 'rb') as f:
                cto = pickle.load(f)
                
            cto.cell_names = cto.cell_data.index
            if [x.split('-')[0] for x in cto.selected_model.cell_topic.columns] == [x.split('___')[0] for x in list(cto.cell_names)]:
                cto.selected_model.cell_topic.columns =  list(cto.cell_names)
                
            region_bin_topics = binarize_topics(
                cto,
                method='otsu',
                ntop=3000,
                plot=True,
                num_columns=6,
                save=f'plots_qc/{sample}__topic_region_binarized.png'
            )

            with open(
                    f"downstream_analysis/binarized_topics/{sample}__topic_region_binarized.pkl",'wb'
            ) as f:
                pickle.dump(region_bin_topics, f, protocol=4)

            binarized_cell_topics = binarize_topics(
                cto,
                target='cell',
                method='li',
                plot=True,
                num_columns=5,
                nbins=100,
                save=f'plots_qc/{sample}__cells_topic_binarized.png'
            )

            with open(
                    f"downstream_analysis/binarized_topics/{sample}__cells_topic_binarized.pkl",'wb'
            ) as f:
                pickle.dump(region_bin_topics, f, protocol=4)

            topic_qc_metrics = compute_topic_metrics(cto)

            with open(
                    f"downstream_analysis/binarized_topics/{sample}__topic_qc.pkl",'wb'
            ) as f:
                pickle.dump(topic_qc_metrics, f, protocol=4)

            fig_dict= {
                'CoherenceVSAssignments': plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Log10_Assignments',
                                                        var_color='Gini_index', plot=False, return_fig=True),
                'AssignmentsVSCells_in_bin': plot_topic_qc(topic_qc_metrics, var_x='Log10_Assignments',
                                                           var_y='Cells_in_binarized_topic', var_color='Gini_index',
                                                           plot=False, return_fig=True),
                'CoherenceVSCells_in_bin': plot_topic_qc(topic_qc_metrics, var_x='Coherence',
                                                         var_y='Cells_in_binarized_topic', var_color='Gini_index',
                                                         plot=False, return_fig=True),
                'CoherenceVSRegions_in_bin': plot_topic_qc(topic_qc_metrics, var_x='Coherence',
                                                           var_y='Regions_in_binarized_topic', var_color='Gini_index',
                                                           plot=False, return_fig=True),
                'CoherenceVSMarginal_dist': plot_topic_qc(topic_qc_metrics, var_x='Coherence',
                                                          var_y='Marginal_topic_dist', var_color='Gini_index',
                                                          plot=False, return_fig=True),
                'CoherenceVSGini_index': plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Gini_index',
                                                       var_color='Gini_index', plot=False, return_fig=True)}

            fig=plt.figure(figsize=(40, 43))
            i = 1
            for fig_ in fig_dict.keys():
                plt.subplot(2, 3, i)
                img = fig2img(fig_dict[fig_]) #To convert figures to png to plot together, see .utils.py. This converts the figure to png.
                plt.imshow(img)
                plt.axis('off')
                i += 1
            plt.subplots_adjust(wspace=0, hspace=-0.70)
            #plt.tight_layout()
            plt.show()
            plt.savefig(f'plots_qc/{sample}__topic_qc_metrics.png', facecolor='white', dpi=150)

            topic_annot = topic_annotation(
                cto,
                annot_var='consensus_cell_type',
                binarized_cell_topic=binarized_cell_topics,
                general_topic_thr = 0.2
            )
            topic_qc_metrics = pd.concat(
                [
                    topic_annot[['consensus_cell_type', 'Ratio_cells_in_topic', 'Ratio_group_in_population']],
                    topic_qc_metrics
                ],
                axis=1
            )

            imputed_acc_obj = impute_accessibility(
                cto,
                selected_cells=None,
                selected_regions=None,
                scale_factor=10**6
            )

            normalized_imputed_acc_obj = normalize_scores(
                imputed_acc_obj,
                scale_factor=10**4
            )

            with open(
                f"downstream_analysis/imputed_acc_objs/{sample}__imputed_acc_obs.pkl",'wb'
            ) as f:
                pickle.dump(normalized_imputed_acc_obj, f, protocol=4)

            variable_regions = find_highly_variable_features(
                normalized_imputed_acc_obj,
                min_disp = 0.05,
                min_mean = 0.0125,
                max_mean = 3,
                max_disp = np.inf,
                n_bins=20,
                n_top_features=None,
                plot=True,
                save=f'plots_qc/{sample}__HVR.png'
            )

            print(f"Found {len(variable_regions)} variable regions")
            with open(f'downstream_analysis/HVRs/{sample}__HVRs.bed', 'w') as f:
                for line in [x.replace(':','\t').replace('-','\t') for x in variable_regions]:
                    f.write(f"{line}\n")
                    
            with open(
                f'downstream_analysis/HVRs/{sample}__HVRs.pkl', 'w'
            ) as f:
                pickle.dump(variable_regions, f, protocol=4)

            os.mkdir(f'downstream_analysis/DARs/{sample}')

            markers_dict = find_diff_features(
                cto,
                normalized_imputed_acc_obj,
                variable='consensus_cell_type',
                var_features=variable_regions,
                contrasts=None,
                adjpval_thr=0.05,
                log2fc_thr=np.log2(1.5),
                n_cpu=5,
            )
            with open(
                    f"downstream_analysis/DARs/{sample}/{sample}__DARs_dict.pkl",'wb'
            ) as f:
                pickle.dump(markers_dict, f, protocol=4)

            for cell_type in markers_dict.keys():
                markers = markers_dict[cell_type].index.tolist()
                df = pd.DataFrame(markers)
                if len(df) == 0:
                    print(f"no DARs found for {cell_type} in {sample}")
                else:
                    df[[0,1]] = df[0].str.split(':',expand=True)
                    df[[1,2]] = df[1].str.split('-',expand=True)
                    df[3] = markers_dict[cell_type].index.tolist()
                    df[3] = cell_type.replace(' ', '_')# + '_' + df[3].astype(str)
                    score = markers_dict[cell_type]['Log2FC']
                    score = score.reset_index(drop=True)
                    df[4] = score
                    df[5] = '.'
                    pval = markers_dict[cell_type]['Adjusted_pval']
                    pval = pval.reset_index(drop=True)
                    df[6] = pval
                    name = cell_type.replace(' ', '_')
                    # name = name.replace('/', '-')
                    if not os.path.exists(f'downstream_analysis/DARs/{sample}'):
                        os.mkdir(f'downstream_analysis/DARs/{sample}')

                    df.to_csv(f'downstream_analysis/DARs/{sample}/{sample}__{cell_type.replace(" ", "_")}__DARs.bed', sep='\t', header=False, index=False)
                    df[0:2000].to_csv(f'downstream_analysis/DARs/{sample}/{sample}__{cell_type.replace(" ", "_")}__DARs.TOP2k.bed', sep='\t', header=False, index=False)

        else:
            print(f'{path} does not exist!')
    else:
        print(f"downstream_analysis/DARs/{sample} already exists!")
# Out:
# downstream_analysis/DARs/BIO_ddseq_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/BIO_ddseq_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/BIO_ddseq_3.FIXEDCELLS already exists!
# downstream_analysis/DARs/BIO_ddseq_4.FIXEDCELLS already exists!
# downstream_analysis/DARs/BRO_mtscatac_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/BRO_mtscatac_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xmultiome_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xmultiome_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv11_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv11_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv11_3.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv11_4.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv11_5.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv2_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_10xv2_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_hydrop_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_hydrop_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_hydrop_3.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_mtscatac_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/CNA_mtscatac_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/EPF_hydrop_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/EPF_hydrop_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/EPF_hydrop_3.FIXEDCELLS already exists!
# downstream_analysis/DARs/EPF_hydrop_4.FIXEDCELLS already exists!
# downstream_analysis/DARs/HAR_ddseq_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/HAR_ddseq_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/MDC_mtscatac_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/MDC_mtscatac_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/OHS_s3atac_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/OHS_s3atac_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/SAN_10xmultiome_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/SAN_10xmultiome_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/STA_10xv11_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/STA_10xv11_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/TXG_10xv11_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/TXG_10xv2_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/TXG_10xv2_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/UCS_ddseq_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/UCS_ddseq_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_10xmultiome_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_10xmultiome_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_10xv1_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_10xv1_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_10xv2_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_10xv2_2.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_hydrop_1.FIXEDCELLS already exists!
# downstream_analysis/DARs/VIB_hydrop_2.FIXEDCELLS already exists!

# %% [markdown]
# # Calculate DARs between male and female

# %%
normalized_imputed_acc_obj_path_dict = {x.split('/')[-1].split(f'__')[0]:x for x in sorted(glob.glob(f'downstream_analysis/imputed_acc_objs/*normalized_imputed_acc_obs.pkl'))}
normalized_imputed_acc_obj_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BIO_ddseq_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BIO_ddseq_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BIO_ddseq_4.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_4.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BRO_mtscatac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BRO_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BRO_mtscatac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BRO_mtscatac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xmultiome_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xmultiome_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_4.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_4.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_5.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_5.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv2_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv2_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv2_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv2_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_hydrop_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_hydrop_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_hydrop_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_hydrop_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_hydrop_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_hydrop_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_mtscatac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_mtscatac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_mtscatac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_4.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_4.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'HAR_ddseq_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/HAR_ddseq_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'HAR_ddseq_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/HAR_ddseq_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'MDC_mtscatac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/MDC_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'MDC_mtscatac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/MDC_mtscatac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'OHS_s3atac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/OHS_s3atac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'OHS_s3atac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/OHS_s3atac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/SAN_10xmultiome_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/SAN_10xmultiome_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'STA_10xv11_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/STA_10xv11_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'STA_10xv11_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/STA_10xv11_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'TXG_10xv11_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/TXG_10xv11_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'TXG_10xv2_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/TXG_10xv2_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'TXG_10xv2_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/TXG_10xv2_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'UCS_ddseq_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/UCS_ddseq_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'UCS_ddseq_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/UCS_ddseq_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xmultiome_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xmultiome_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv1_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv1_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv1_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv1_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv2_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv2_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv2_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv2_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_hydrop_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_hydrop_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_hydrop_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_hydrop_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl'}

# %%
hvr_path_dict = {x.split('/')[-1].split(f'__')[0]:x for x in sorted(glob.glob(f'downstream_analysis/HVRs/*bed'))}
hvr_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 'downstream_analysis/HVRs/BIO_ddseq_1.FIXEDCELLS__HVRs.bed',
#  'BIO_ddseq_2.FIXEDCELLS': 'downstream_analysis/HVRs/BIO_ddseq_2.FIXEDCELLS__HVRs.bed',
#  'BIO_ddseq_3.FIXEDCELLS': 'downstream_analysis/HVRs/BIO_ddseq_3.FIXEDCELLS__HVRs.bed',
#  'BIO_ddseq_4.FIXEDCELLS': 'downstream_analysis/HVRs/BIO_ddseq_4.FIXEDCELLS__HVRs.bed',
#  'BRO_mtscatac_1.FIXEDCELLS': 'downstream_analysis/HVRs/BRO_mtscatac_1.FIXEDCELLS__HVRs.bed',
#  'BRO_mtscatac_2.FIXEDCELLS': 'downstream_analysis/HVRs/BRO_mtscatac_2.FIXEDCELLS__HVRs.bed',
#  'CNA_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xmultiome_1.FIXEDCELLS__HVRs.bed',
#  'CNA_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xmultiome_2.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv11_1.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv11_1.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv11_2.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv11_2.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv11_3.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv11_3.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv11_4.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv11_4.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv11_5.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv11_5.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv2_1.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv2_1.FIXEDCELLS__HVRs.bed',
#  'CNA_10xv2_2.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_10xv2_2.FIXEDCELLS__HVRs.bed',
#  'CNA_hydrop_1.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_hydrop_1.FIXEDCELLS__HVRs.bed',
#  'CNA_hydrop_2.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_hydrop_2.FIXEDCELLS__HVRs.bed',
#  'CNA_hydrop_3.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_hydrop_3.FIXEDCELLS__HVRs.bed',
#  'CNA_mtscatac_1.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_mtscatac_1.FIXEDCELLS__HVRs.bed',
#  'CNA_mtscatac_2.FIXEDCELLS': 'downstream_analysis/HVRs/CNA_mtscatac_2.FIXEDCELLS__HVRs.bed',
#  'EPF_hydrop_1.FIXEDCELLS': 'downstream_analysis/HVRs/EPF_hydrop_1.FIXEDCELLS__HVRs.bed',
#  'EPF_hydrop_2.FIXEDCELLS': 'downstream_analysis/HVRs/EPF_hydrop_2.FIXEDCELLS__HVRs.bed',
#  'EPF_hydrop_3.FIXEDCELLS': 'downstream_analysis/HVRs/EPF_hydrop_3.FIXEDCELLS__HVRs.bed',
#  'EPF_hydrop_4.FIXEDCELLS': 'downstream_analysis/HVRs/EPF_hydrop_4.FIXEDCELLS__HVRs.bed',
#  'HAR_ddseq_1.FIXEDCELLS': 'downstream_analysis/HVRs/HAR_ddseq_1.FIXEDCELLS__HVRs.bed',
#  'HAR_ddseq_2.FIXEDCELLS': 'downstream_analysis/HVRs/HAR_ddseq_2.FIXEDCELLS__HVRs.bed',
#  'MDC_mtscatac_1.FIXEDCELLS': 'downstream_analysis/HVRs/MDC_mtscatac_1.FIXEDCELLS__HVRs.bed',
#  'MDC_mtscatac_2.FIXEDCELLS': 'downstream_analysis/HVRs/MDC_mtscatac_2.FIXEDCELLS__HVRs.bed',
#  'OHS_s3atac_1.FIXEDCELLS': 'downstream_analysis/HVRs/OHS_s3atac_1.FIXEDCELLS__HVRs.bed',
#  'OHS_s3atac_2.FIXEDCELLS': 'downstream_analysis/HVRs/OHS_s3atac_2.FIXEDCELLS__HVRs.bed',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/HVRs/SAN_10xmultiome_1.FIXEDCELLS__HVRs.bed',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/HVRs/SAN_10xmultiome_2.FIXEDCELLS__HVRs.bed',
#  'STA_10xv11_1.FIXEDCELLS': 'downstream_analysis/HVRs/STA_10xv11_1.FIXEDCELLS__HVRs.bed',
#  'STA_10xv11_2.FIXEDCELLS': 'downstream_analysis/HVRs/STA_10xv11_2.FIXEDCELLS__HVRs.bed',
#  'TXG_10xv11_1.FIXEDCELLS': 'downstream_analysis/HVRs/TXG_10xv11_1.FIXEDCELLS__HVRs.bed',
#  'TXG_10xv2_1.FIXEDCELLS': 'downstream_analysis/HVRs/TXG_10xv2_1.FIXEDCELLS__HVRs.bed',
#  'TXG_10xv2_2.FIXEDCELLS': 'downstream_analysis/HVRs/TXG_10xv2_2.FIXEDCELLS__HVRs.bed',
#  'UCS_ddseq_1.FIXEDCELLS': 'downstream_analysis/HVRs/UCS_ddseq_1.FIXEDCELLS__HVRs.bed',
#  'UCS_ddseq_2.FIXEDCELLS': 'downstream_analysis/HVRs/UCS_ddseq_2.FIXEDCELLS__HVRs.bed',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_10xmultiome_1.FIXEDCELLS__HVRs.bed',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_10xmultiome_2.FIXEDCELLS__HVRs.bed',
#  'VIB_10xv1_1.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_10xv1_1.FIXEDCELLS__HVRs.bed',
#  'VIB_10xv1_2.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_10xv1_2.FIXEDCELLS__HVRs.bed',
#  'VIB_10xv2_1.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_10xv2_1.FIXEDCELLS__HVRs.bed',
#  'VIB_10xv2_2.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_10xv2_2.FIXEDCELLS__HVRs.bed',
#  'VIB_hydrop_1.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_hydrop_1.FIXEDCELLS__HVRs.bed',
#  'VIB_hydrop_2.FIXEDCELLS': 'downstream_analysis/HVRs/VIB_hydrop_2.FIXEDCELLS__HVRs.bed'}

# %%
for sample in cistopic_obj_path_dict.keys():
# for sample  in ['SAN_10xmultiome_1.FIXEDCELLS']:
    if not os.path.exists(f'male_female_DARs/{sample}'):
        cto_path = cistopic_obj_path_dict[sample]
        if os.path.isfile(cto_path):
            print(f"Loading {cto_path}")
            with open(cto_path, 'rb') as f:
                cto = pickle.load(f)
                
            cto.cell_names = cto.cell_data.index
            if [x.split('-')[0] for x in cto.selected_model.cell_topic.columns] == [x.split('___')[0] for x in list(cto.cell_names)]:
                cto.selected_model.cell_topic.columns =  list(cto.cell_names)
                
        if 'fmx_sample' in cto.cell_data.columns:
            acc_path = normalized_imputed_acc_obj_path_dict[sample]

            if os.path.isfile(acc_path):
                print(f"Loading {acc_path}")
                with open(acc_path, 'rb') as f:
                    normalized_imputed_acc_obj = pickle.load(f)


            hvr_pkl_path = f'downstream_analysis/HVRs/{sample}__HVRs.pkl'

            if os.path.exists(hvr_pkl_path):
                print(f"Loading {hvr_pkl_path}")
                with open(hvr_pkl_path, 'rb') as f:
                    variable_regions = pickle.load(f)
            else:
                print("HVRs do not exist!")

            cto.cell_data['fmx_sample_consensus_cell_type'] = cto.cell_data['fmx_sample'] + "_" + cto.cell_data["consensus_cell_type"]

            contrasts = []
            for cell_type in cto.cell_data['consensus_cell_type'].unique():
                print(cell_type)
                ct_a = 'sampleA_' + cell_type
                ct_b = 'sampleB_' + cell_type
                contrast = [[[ct_a], [ct_b]], [[ct_b], [ct_a]]]
                contrasts = contrasts + contrast

            markers_dict = find_diff_features(
                cto,
                normalized_imputed_acc_obj,
                variable='fmx_sample_consensus_cell_type',
                var_features=variable_regions,
                contrasts=contrasts,
                adjpval_thr=0.05,
                log2fc_thr=np.log2(1.2),
                n_cpu=10,
            )
            
            if not os.path.exists(f'male_female_DARs/{sample}'):
                os.mkdir(f'male_female_DARs/{sample}')
                
            with open(
                f"male_female_DARs/{sample}/{sample}__DARs_dict_1-2xfoldchange.pkl",'wb'
            ) as f:
                pickle.dump(markers_dict, f, protocol=4)
                        
            for contrast in markers_dict.keys():
                markers = markers_dict[contrast].index.tolist()
                df = pd.DataFrame(markers)
                if len(df) == 0:
                    print(f"no DARs found for {contrast} in {sample}")
                else:
                    df[[0,1]] = df[0].str.split(':',expand=True)
                    df[[1,2]] = df[1].str.split('-',expand=True)
                    df[3] = markers_dict[contrast].index.tolist()
                    df[3] = contrast.replace(' ', '_')# + '_' + df[3].astype(str)
                    score = markers_dict[contrast]['Log2FC']
                    score = score.reset_index(drop=True)
                    df[4] = score
                    df[5] = '.'
                    pval = markers_dict[contrast]['Adjusted_pval']
                    pval = pval.reset_index(drop=True)
                    df[6] = pval
                    name = contrast.replace(' ', '_')

                    df.to_csv(f'male_female_DARs/{sample}/{sample}__{contrast.replace(" ", "_")}__1-2xfoldchange_DARs.bed', sep='\t', header=False, index=False)
# Out:
# Loading cistopic_objects/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl
# Loading cistopic_objects/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_14topics.dimreduc.consensus.pkl
# Loading cistopic_objects/BIO_ddseq_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl
# Loading cistopic_objects/BIO_ddseq_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl
# Loading cistopic_objects/BRO_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl
# Loading downstream_analysis/imputed_acc_objs/BRO_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl
# Loading downstream_analysis/HVRs/BRO_mtscatac_1.FIXEDCELLS__HVRs.pkl
# Dendritic cell
# CD14+ monocyte
# B cell
# CD4+ T cell
# Cytotoxic T cell
# Natural killer cell
# CD16+ monocyte
# 2022-09-30 13:27:18,976	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (markers_ray pid=4148889) 2022-09-30 13:27:54,906 cisTopic     INFO     Formatting data for sampleA_Dendritic cell_VS_sampleB_Dendritic cell
# (markers_ray pid=4148889) 2022-09-30 13:27:55,931 cisTopic     INFO     Computing p-value for sampleA_Dendritic cell_VS_sampleB_Dendritic cell
# (markers_ray pid=4148888) 2022-09-30 13:27:56,312 cisTopic     INFO     Formatting data for sampleB_Dendritic cell_VS_sampleA_Dendritic cell
# (markers_ray pid=4148888) 2022-09-30 13:27:57,196 cisTopic     INFO     Computing p-value for sampleB_Dendritic cell_VS_sampleA_Dendritic cell
# (markers_ray pid=4148886) 2022-09-30 13:27:57,592 cisTopic     INFO     Formatting data for sampleA_CD14+ monocyte_VS_sampleB_CD14+ monocyte
# (markers_ray pid=4148887) 2022-09-30 13:27:59,134 cisTopic     INFO     Formatting data for sampleB_CD14+ monocyte_VS_sampleA_CD14+ monocyte
# (markers_ray pid=4148885) 2022-09-30 13:28:00,607 cisTopic     INFO     Formatting data for sampleA_B cell_VS_sampleB_B cell
# (markers_ray pid=4148884) 2022-09-30 13:28:02,006 cisTopic     INFO     Formatting data for sampleB_B cell_VS_sampleA_B cell
# (markers_ray pid=4148885) 2022-09-30 13:28:02,598 cisTopic     INFO     Computing p-value for sampleA_B cell_VS_sampleB_B cell
# (markers_ray pid=4148882) 2022-09-30 13:28:03,600 cisTopic     INFO     Formatting data for sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell
# (markers_ray pid=4148884) 2022-09-30 13:28:04,008 cisTopic     INFO     Computing p-value for sampleB_B cell_VS_sampleA_B cell
# (markers_ray pid=4148881) 2022-09-30 13:28:04,905 cisTopic     INFO     Formatting data for sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell
# (markers_ray pid=4148886) 2022-09-30 13:28:05,394 cisTopic     INFO     Computing p-value for sampleA_CD14+ monocyte_VS_sampleB_CD14+ monocyte
# (markers_ray pid=4148878) 2022-09-30 13:28:06,340 cisTopic     INFO     Formatting data for sampleA_Cytotoxic T cell_VS_sampleB_Cytotoxic T cell
# (markers_ray pid=4148887) 2022-09-30 13:28:06,931 cisTopic     INFO     Computing p-value for sampleB_CD14+ monocyte_VS_sampleA_CD14+ monocyte
# (markers_ray pid=4148880) 2022-09-30 13:28:07,581 cisTopic     INFO     Formatting data for sampleB_Cytotoxic T cell_VS_sampleA_Cytotoxic T cell
# (markers_ray pid=4148878) 2022-09-30 13:28:09,321 cisTopic     INFO     Computing p-value for sampleA_Cytotoxic T cell_VS_sampleB_Cytotoxic T cell
# (markers_ray pid=4148880) 2022-09-30 13:28:10,556 cisTopic     INFO     Computing p-value for sampleB_Cytotoxic T cell_VS_sampleA_Cytotoxic T cell
# (markers_ray pid=4148882) 2022-09-30 13:28:10,891 cisTopic     INFO     Computing p-value for sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell
# (markers_ray pid=4148881) 2022-09-30 13:28:12,278 cisTopic     INFO     Computing p-value for sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell
# (markers_ray pid=4148889) 2022-09-30 13:34:39,788 cisTopic     INFO     Computing log2FC for sampleA_Dendritic cell_VS_sampleB_Dendritic cell
# (markers_ray pid=4148888) 2022-09-30 13:34:46,153 cisTopic     INFO     Computing log2FC for sampleB_Dendritic cell_VS_sampleA_Dendritic cell
# (markers_ray pid=4148885) 2022-09-30 13:34:57,032 cisTopic     INFO     Computing log2FC for sampleA_B cell_VS_sampleB_B cell
# (markers_ray pid=4148889) 2022-09-30 13:34:59,622 cisTopic     INFO     sampleA_Dendritic cell_VS_sampleB_Dendritic cell done!
# (markers_ray pid=4148889) 2022-09-30 13:34:59,812 cisTopic     INFO     Formatting data for sampleA_Natural killer cell_VS_sampleB_Natural killer cell
# (markers_ray pid=4148884) 2022-09-30 13:35:00,749 cisTopic     INFO     Computing log2FC for sampleB_B cell_VS_sampleA_B cell
# (markers_ray pid=4148889) 2022-09-30 13:35:02,512 cisTopic     INFO     Computing p-value for sampleA_Natural killer cell_VS_sampleB_Natural killer cell
# (markers_ray pid=
sampleA_Cytotoxic T cell_VS_sampleB_Cytotoxic T cell
# (markers_ray pid=4185674) 2022-09-30 18:36:05,220 cisTopic     INFO     Formatting data for sampleB_B cell_VS_sampleA_B cell
# (markers_ray pid=4185677) 2022-09-30 18:36:05,836 cisTopic     INFO     Computing p-value for sampleB_Cytotoxic T cell_VS_sampleA_Cytotoxic T cell
# (markers_ray pid=4185673) 2022-09-30 18:36:05,951 cisTopic     INFO     Computing p-value for sampleA_B cell_VS_sampleB_B cell
# (markers_ray pid=4185671) 2022-09-30 18:36:05,999 cisTopic     INFO     Formatting data for sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell
# (markers_ray pid=4185672) 2022-09-30 18:36:06,648 cisTopic     INFO     Formatting data for sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell
# (markers_ray pid=4185674) 2022-09-30 18:36:06,853 cisTopic     INFO     Computing p-value for sampleB_B cell_VS_sampleA_B cell
# (markers_ray pid=4185676) 2022-09-30 18:36:07,580 cisTopic     INFO     Computing p-value for sampleA_CD14+ monocyte_VS_sampleB_CD14+ monocyte
# (markers_ray pid=4185671) 2022-09-30 18:36:07,947 cisTopic     INFO     Computing p-value for sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell
# (markers_ray pid=4185675) 2022-09-30 18:36:08,423 cisTopic     INFO     Computing p-value for sampleB_CD14+ monocyte_VS_sampleA_CD14+ monocyte
# (markers_ray pid=4185672) 2022-09-30 18:36:08,592 cisTopic     INFO     Computing p-value for sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell
# (markers_ray pid=4185673) 2022-09-30 18:40:29,559 cisTopic     INFO     Computing log2FC for sampleA_B cell_VS_sampleB_B cell
# (markers_ray pid=4185674) 2022-09-30 18:40:31,033 cisTopic     INFO     Computing log2FC for sampleB_B cell_VS_sampleA_B cell
# (markers_ray pid=4185671) 2022-09-30 18:40:31,369 cisTopic     INFO     Computing log2FC for sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell
# (markers_ray pid=4185672) 2022-09-30 18:40:35,009 cisTopic     INFO     Computing log2FC for sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell
# (markers_ray pid=4185673) 2022-09-30 18:40:42,174 cisTopic     INFO     sampleA_B cell_VS_sampleB_B cell done!
# (markers_ray pid=4185674) 2022-09-30 18:40:43,528 cisTopic     INFO     sampleB_B cell_VS_sampleA_B cell done!
# (markers_ray pid=4185671) 2022-09-30 18:40:43,696 cisTopic     INFO     sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell done!
# (markers_ray pid=4185672) 2022-09-30 18:40:46,329 cisTopic     INFO     sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell done!
# (markers_ray pid=4185677) 2022-09-30 18:40:48,190 cisTopic     INFO     Computing log2FC for sampleB_Cytotoxic T cell_VS_sampleA_Cytotoxic T cell
# (markers_ray pid=4185678) 2022-09-30 18:40:48,409 cisTopic     INFO     Computing log2FC for sampleA_Cytotoxic T cell_VS_sampleB_Cytotoxic T cell
# (markers_ray pid=4185677) 2022-09-30 18:40:55,461 cisTopic     INFO     sampleB_Cytotoxic T cell_VS_sampleA_Cytotoxic T cell done!
# (markers_ray pid=4185678) 2022-09-30 18:40:55,483 cisTopic     INFO     sampleA_Cytotoxic T cell_VS_sampleB_Cytotoxic T cell done!
# (markers_ray pid=4185675) 2022-09-30 18:40:56,751 cisTopic     INFO     Computing log2FC for sampleB_CD14+ monocyte_VS_sampleA_CD14+ monocyte
# (markers_ray pid=4185676) 2022-09-30 18:40:57,627 cisTopic     INFO     Computing log2FC for sampleA_CD14+ monocyte_VS_sampleB_CD14+ monocyte
# (markers_ray pid=4185675) 2022-09-30 18:41:00,886 cisTopic     INFO     sampleB_CD14+ monocyte_VS_sampleA_CD14+ monocyte done!
# no DARs found for sampleA_Cytotoxic T cell_VS_sampleB_Cytotoxic T cell in VIB_hydrop_2.FIXEDCELLS
# no DARs found for sampleA_CD4+ T cell_VS_sampleB_CD4+ T cell in VIB_hydrop_2.FIXEDCELLS
# no DARs found for sampleB_CD4+ T cell_VS_sampleA_CD4+ T cell in VIB_hydrop_2.FIXEDCELLS

# %% [markdown]
# # visualise dars

# %%
markers_path_dict = {x.split('/')[-1].split(f'__')[0]:x for x in sorted(glob.glob(f'downstream_analysis/DARs/*/*.pkl'))}
markers_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 
pkl',
#  'OHS_s3atac_1.FIXEDCELLS': 'downstream_analysis/DARs/OHS_s3atac_1.FIXEDCELLS/OHS_s3atac_1.FIXEDCELLS__DARs_dict.pkl',
#  'OHS_s3atac_2.FIXEDCELLS': 'downstream_analysis/DARs/OHS_s3atac_2.FIXEDCELLS/OHS_s3atac_2.FIXEDCELLS__DARs_dict.pkl',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/DARs/SAN_10xmultiome_1.FIXEDCELLS/SAN_10xmultiome_1.FIXEDCELLS__DARs_dict.pkl',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/DARs/SAN_10xmultiome_2.FIXEDCELLS/SAN_10xmultiome_2.FIXEDCELLS__DARs_dict.pkl',
#  'STA_10xv11_1.FIXEDCELLS': 'downstream_analysis/DARs/STA_10xv11_1.FIXEDCELLS/STA_10xv11_1.FIXEDCELLS__DARs_dict.pkl',
#  'STA_10xv11_2.FIXEDCELLS': 'downstream_analysis/DARs/STA_10xv11_2.FIXEDCELLS/STA_10xv11_2.FIXEDCELLS__DARs_dict.pkl',
#  'TXG_10xv11_1.FIXEDCELLS': 'downstream_analysis/DARs/TXG_10xv11_1.FIXEDCELLS/TXG_10xv11_1.FIXEDCELLS__DARs_dict.pkl',
#  'TXG_10xv2_1.FIXEDCELLS': 'downstream_analysis/DARs/TXG_10xv2_1.FIXEDCELLS/TXG_10xv2_1.FIXEDCELLS__DARs_dict.pkl',
#  'TXG_10xv2_2.FIXEDCELLS': 'downstream_analysis/DARs/TXG_10xv2_2.FIXEDCELLS/TXG_10xv2_2.FIXEDCELLS__DARs_dict.pkl',
#  'UCS_ddseq_1.FIXEDCELLS': 'downstream_analysis/DARs/UCS_ddseq_1.FIXEDCELLS/UCS_ddseq_1.FIXEDCELLS__DARs_dict.pkl',
#  'UCS_ddseq_2.FIXEDCELLS': 'downstream_analysis/DARs/UCS_ddseq_2.FIXEDCELLS/UCS_ddseq_2.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/DARs/VIB_10xmultiome_1.FIXEDCELLS/VIB_10xmultiome_1.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/DARs/VIB_10xmultiome_2.FIXEDCELLS/VIB_10xmultiome_2.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_10xv1_1.FIXEDCELLS': 'downstream_analysis/DARs/VIB_10xv1_1.FIXEDCELLS/VIB_10xv1_1.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_10xv1_2.FIXEDCELLS': 'downstream_analysis/DARs/VIB_10xv1_2.FIXEDCELLS/VIB_10xv1_2.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_10xv2_1.FIXEDCELLS': 'downstream_analysis/DARs/VIB_10xv2_1.FIXEDCELLS/VIB_10xv2_1.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_10xv2_2.FIXEDCELLS': 'downstream_analysis/DARs/VIB_10xv2_2.FIXEDCELLS/VIB_10xv2_2.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_hydrop_1.FIXEDCELLS': 'downstream_analysis/DARs/VIB_hydrop_1.FIXEDCELLS/VIB_hydrop_1.FIXEDCELLS__DARs_dict.pkl',
#  'VIB_hydrop_2.FIXEDCELLS': 'downstream_analysis/DARs/VIB_hydrop_2.FIXEDCELLS/VIB_hydrop_2.FIXEDCELLS__DARs_dict.pkl'}

# %%
imputed_acc_obj_dict = {x.split('/')[-1].split(f'__')[0]:x for x in sorted(glob.glob(f'downstream_analysis/imputed_acc_objs/*.pkl'))}
imputed_acc_obj_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BIO_ddseq_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BIO_ddseq_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BIO_ddseq_4.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BIO_ddseq_4.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BRO_mtscatac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BRO_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'BRO_mtscatac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/BRO_mtscatac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xmultiome_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xmultiome_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_4.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_4.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv11_5.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv11_5.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv2_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv2_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_10xv2_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_10xv2_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_hydrop_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_hydrop_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_hydrop_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_hydrop_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_hydrop_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_hydrop_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_mtscatac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'CNA_mtscatac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/CNA_mtscatac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_3.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_3.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'EPF_hydrop_4.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/EPF_hydrop_4.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'HAR_ddseq_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/HAR_ddseq_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'HAR_ddseq_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/HAR_ddseq_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'MDC_mtscatac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/MDC_mtscatac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'MDC_mtscatac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/MDC_mtscatac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'OHS_s3atac_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/OHS_s3atac_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'OHS_s3atac_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/OHS_s3atac_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/SAN_10xmultiome_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/SAN_10xmultiome_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'STA_10xv11_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/STA_10xv11_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'STA_10xv11_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/STA_10xv11_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'TXG_10xv11_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/TXG_10xv11_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'TXG_10xv2_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/TXG_10xv2_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'TXG_10xv2_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/TXG_10xv2_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'UCS_ddseq_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/UCS_ddseq_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'UCS_ddseq_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/UCS_ddseq_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xmultiome_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xmultiome_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv1_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv1_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv1_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv1_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv2_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv2_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_10xv2_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_10xv2_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_hydrop_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_hydrop_1.FIXEDCELLS__normalized_imputed_acc_obs.pkl',
#  'VIB_hydrop_2.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/VIB_hydrop_2.FIXEDCELLS__normalized_imputed_acc_obs.pkl'}

# %%
for sample in markers_path_dict.keys():
    print(sample)
    fig_path = f'plots_qc/{sample}_DAR_umap.png'
    if not os.path.exists(fig_path):
        with open(cistopic_obj_path_dict[sample], 'rb') as f:
            cto = pickle.load(f)

        with open(imputed_acc_obj_dict[sample], 'rb') as f:
            imputed_acc_obj = pickle.load(f)

        with open(markers_path_dict[sample], 'rb') as f:
            markers_dict = pickle.load(f)

        [ print(x + ': '+ str(len(markers_dict[x]))) for x in markers_dict.keys() ]
        plot_imputed_features(
            cto,
            reduction_name='UMAP',
            imputed_data=imputed_acc_obj,
            features=[markers_dict[x].index.tolist()[0] for x in markers_dict.keys() if len(markers_dict[x])> 0],
            scale=False,
            num_columns=3,
            selected_cells = cto.projections['cell']['UMAP'].index.tolist(),
            save=fig_path
        )
    else:
        print(f"\t{fig_path} already exists")
# Out:
# BIO_ddseq_1.FIXEDCELLS
# 	plots_qc/BIO_ddseq_1.FIXEDCELLS_DAR_umap.png already exists
# BIO_ddseq_2.FIXEDCELLS
# 	plots_qc/BIO_ddseq_2.FIXEDCELLS_DAR_umap.png already exists
# BIO_ddseq_3.FIXEDCELLS
# 	plots_qc/BIO_ddseq_3.FIXEDCELLS_DAR_umap.png already exists
# BIO_ddseq_4.FIXEDCELLS
# 	plots_qc/BIO_ddseq_4.FIXEDCELLS_DAR_umap.png already exists
# BRO_mtscatac_1.FIXEDCELLS
# 	plots_qc/BRO_mtscatac_1.FIXEDCELLS_DAR_umap.png already exists
# BRO_mtscatac_2.FIXEDCELLS
# 	plots_qc/BRO_mtscatac_2.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xmultiome_1.FIXEDCELLS
# 	plots_qc/CNA_10xmultiome_1.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xmultiome_2.FIXEDCELLS
# 	plots_qc/CNA_10xmultiome_2.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv11_1.FIXEDCELLS
# 	plots_qc/CNA_10xv11_1.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv11_2.FIXEDCELLS
# 	plots_qc/CNA_10xv11_2.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv11_3.FIXEDCELLS
# 	plots_qc/CNA_10xv11_3.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv11_4.FIXEDCELLS
# 	plots_qc/CNA_10xv11_4.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv11_5.FIXEDCELLS
# 	plots_qc/CNA_10xv11_5.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv2_1.FIXEDCELLS
# 	plots_qc/CNA_10xv2_1.FIXEDCELLS_DAR_umap.png already exists
# CNA_10xv2_2.FIXEDCELLS
# 	plots_qc/CNA_10xv2_2.FIXEDCELLS_DAR_umap.png already exists
# CNA_hydrop_1.FIXEDCELLS
# 	plots_qc/CNA_hydrop_1.FIXEDCELLS_DAR_umap.png already exists
# CNA_hydrop_2.FIXEDCELLS
# 	plots_qc/CNA_hydrop_2.FIXEDCELLS_DAR_umap.png already exists
# CNA_hydrop_3.FIXEDCELLS
# 	plots_qc/CNA_hydrop_3.FIXEDCELLS_DAR_umap.png already exists
# CNA_mtscatac_1.FIXEDCELLS
# 	plots_qc/CNA_mtscatac_1.FIXEDCELLS_DAR_umap.png already exists
# CNA_mtscatac_2.FIXEDCELLS
# 	plots_qc/CNA_mtscatac_2.FIXEDCELLS_DAR_umap.png already exists
# EPF_hydrop_1.FIXEDCELLS
# 	plots_qc/EPF_hydrop_1.FIXEDCELLS_DAR_umap.png already exists
# EPF_hydrop_2.FIXEDCELLS
# 	plots_qc/EPF_hydrop_2.FIXEDCELLS_DAR_umap.png already exists
# EPF_hydrop_3.FIXEDCELLS
# 	plots_qc/EPF_hydrop_3.FIXEDCELLS_DAR_umap.png already exists
# EPF_hydrop_4.FIXEDCELLS
# 	plots_qc/EPF_hydrop_4.FIXEDCELLS_DAR_umap.png already exists
# HAR_ddseq_1.FIXEDCELLS
# 	plots_qc/HAR_ddseq_1.FIXEDCELLS_DAR_umap.png already exists
# HAR_ddseq_2.FIXEDCELLS
# 	plots_qc/HAR_ddseq_2.FIXEDCELLS_DAR_umap.png already exists
# MDC_mtscatac_1.FIXEDCELLS
# 	plots_qc/MDC_mtscatac_1.FIXEDCELLS_DAR_umap.png already exists
# MDC_mtscatac_2.FIXEDCELLS
# 	plots_qc/MDC_mtscatac_2.FIXEDCELLS_DAR_umap.png already exists
# OHS_s3atac_1.FIXEDCELLS
# 	plots_qc/OHS_s3atac_1.FIXEDCELLS_DAR_umap.png already exists
# OHS_s3atac_2.FIXEDCELLS
# 	plots_qc/OHS_s3atac_2.FIXEDCELLS_DAR_umap.png already exists
# SAN_10xmultiome_1.FIXEDCELLS
# 	plots_qc/SAN_10xmultiome_1.FIXEDCELLS_DAR_umap.png already exists
# SAN_10xmultiome_2.FIXEDCELLS
# 	plots_qc/SAN_10xmultiome_2.FIXEDCELLS_DAR_umap.png already exists
# STA_10xv11_1.FIXEDCELLS
# 	plots_qc/STA_10xv11_1.FIXEDCELLS_DAR_umap.png already exists
# STA_10xv11_2.FIXEDCELLS
# 	plots_qc/STA_10xv11_2.FIXEDCELLS_DAR_umap.png already exists
# TXG_10xv11_1.FIXEDCELLS
# 	plots_qc/TXG_10xv11_1.FIXEDCELLS_DAR_umap.png already exists
# TXG_10xv2_1.FIXEDCELLS
# 	plots_qc/TXG_10xv2_1.FIXEDCELLS_DAR_umap.png already exists
# TXG_10xv2_2.FIXEDCELLS
# 	plots_qc/TXG_10xv2_2.FIXEDCELLS_DAR_umap.png already exists
# UCS_ddseq_1.FIXEDCELLS
# 	plots_qc/UCS_ddseq_1.FIXEDCELLS_DAR_umap.png already exists
# UCS_ddseq_2.FIXEDCELLS
# 	plots_qc/UCS_ddseq_2.FIXEDCELLS_DAR_umap.png already exists
# VIB_10xmultiome_1.FIXEDCELLS
# 	plots_qc/VIB_10xmultiome_1.FIXEDCELLS_DAR_umap.png already exists
# VIB_10xmultiome_2.FIXEDCELLS
# 	plots_qc/VIB_10xmultiome_2.FIXEDCELLS_DAR_umap.png already exists
# VIB_10xv1_1.FIXEDCELLS
# 	plots_qc/VIB_10xv1_1.FIXEDCELLS_DAR_umap.png already exists
# VIB_10xv1_2.FIXEDCELLS
# 	plots_qc/VIB_10xv1_2.FIXEDCELLS_DAR_umap.png already exists
# VIB_10xv2_1.FIXEDCELLS
# 	plots_qc/VIB_10xv2_1.FIXEDCELLS_DAR_umap.png already exists
# VIB_10xv2_2.FIXEDCELLS
# 	plots_qc/VIB_10xv2_2.FIXEDCELLS_DAR_umap.png already exists
# VIB_hydrop_1.FIXEDCELLS
# 	plots_qc/VIB_hydrop_1.FIXEDCELLS_DAR_umap.png already exists
# VIB_hydrop_2.FIXEDCELLS
# 	plots_qc/VIB_hydrop_2.FIXEDCELLS_DAR_umap.png already exists

# %% [markdown]
# # Check chromosome distribution of DARs:

# %%
import glob

# %%
dar_path_dict = {x.split('/')[-1].split('__1-2xfoldchange_DARs.ENCODE3_overlap.bed')[0]: x for x in glob.glob('male_female_DARs/*/*DARs.bed')}

# %%
peaks_df
# Out:
#        0          1          2                                           3  \
# 0   chr9  137591036  137591536  sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell
# 1   chr6  108589182  108589682  sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell
# 2  chr17   36105672   36106172  sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell
#
#           4  5         6
# 0  0.362751  .  0.032575
# 1  0.325670  .  0.044384
# 2  0.272849  .  0.009967

# %%
chroms_in_df
# Out:
# ['chr17', 'chr6', 'chr9']

# %%
chroms_standard
# Out:
# ['chr1',
#  'chr2',
#  'chr3',
#  'chr4',
#  'chr5',
#  'chr6',
#  'chr7',
#  'chr8',
#  'chr9',
#  'chr10',
#  'chr11',
#  'chr12',
#  'chr13',
#  'chr14',
#  'chr15',
#  'chr16',
#  'chr17',
#  'chr18',
#  'chr19',
#  'chr20',
#  'chr21',
#  'chr22',
#  'chrX']

# %%
chroms_standard = ["chr" + str(x + 1) for x in range(22)] + ['chrX']

# %%
peaks_df[0].value_counts()[chroms_standard]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 peaks_df[0].value_counts()[chroms_standard]
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/series.py:1008, in Series.__getitem__(self, key)
#    1005     key = np.asarray(key, dtype=bool)
#    1006     return self._get_values(key)
# -> 1008 return self._get_with(key)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/series.py:1048, in Series._get_with(self, key)
#    1045         return self.iloc[key]
#    1047 # handle the dup indexing case GH#4246
# -> 1048 return self.loc[key]
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1302, in _LocIndexer._getitem_axis(self, key, axis)
#    1299     if hasattr(key, "ndim") and key.ndim > 1:
#    1300         raise ValueError("Cannot index with multidimensional key")
# -> 1302     return self._getitem_iterable(key, axis=axis)
#    1304 # nested tuple slicing
#    1305 if is_nested_tuple(key, labels):
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1240, in _LocIndexer._getitem_iterable(self, key, axis)
#    1237 self._validate_key(key, axis)
#    1239 # A collection of keys
# -> 1240 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1241 return self.obj._reindex_with_indexers(
#    1242     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1243 )
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1433, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1430 ax = self.obj._get_axis(axis)
#    1431 axis_name = self.obj._get_axis_name(axis)
# -> 1433 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1435 return keyarr, indexer
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr7', 'chr8', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX'] not in index"

# %%
# Out:
# {'chr17', 'chr6', 'chr9'}

# %%
for sample, path in dar_path_dict.items():
    print(sample)
    dars_df = pd.read_csv(path, sep='\t', header=None)
    
    chroms_in_df = list(sorted(dars_df[0].unique()))
    chroms_standard = ["chr" + str(x + 1) for x in range(22)] + ['chrX']
    chroms_nonstandard = list(set(chroms_in_df ) - set(chroms_standard) -  set(['chrM']))
    
    chroms_standard_in_sample = set(chroms_in_df).intersection(set(chroms_standard))
    n_standard = dars_df[0].value_counts()[chroms_standard_in_sample].sum()
    
    
    n_contigs = dars_df[0].value_counts()[chroms_nonstandard].sum()
    if 'chrM' in dars_df[0].value_counts().index:
        n_chrm = dars_df[0].value_counts()['chrM'].sum()
    else:
        n_chrm = 0
    pct_nonstandard = (n_contigs + n_chrm)/len(dars_df)*100
        
    print(f"\tdars on standard chromosomes: {n_standard}")
    print(f"\tdars on contigs: {n_contigs}")
    print(f"\tdars on chrM: {n_chrm}")
    print(f"\t% dars non standard chromosomes: {pct_nonstandard}%")
    if 'chrY' in chroms_in_df:
        n_chrY = dars_df[0].value_counts()['chrY'].sum()
        print(f"\tdars on chrY: {n_chrY}")
    else:
        print(f"\tdars on chrY: 0")
# Out:
# EPF_hydrop_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# EPF_hydrop_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 27347
# 	dars on contigs: 60
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.21892217316743898%
# 	dars on chrY: 2
# EPF_hydrop_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 7233
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.08288437629506838%
# 	dars on chrY: 6
# EPF_hydrop_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 260
# 	dars on contigs: 9
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 3.3457249070631967%
# 	dars on chrY: 1
# EPF_hydrop_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 361
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.2762430939226519%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 20
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 630
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.15847860538827258%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 176
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3370
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.02966478789676654%
# 	dars on chrY: 1
# CNA_10xv11_3.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 692
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.5747126436781609%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4164
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.024009603841536616%
# 	dars on chrY: 1
# CNA_10xv11_3.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 133
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_3.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 209
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleB_Natural_killer_cell_VS_sampleA_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 15
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 105
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2529
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.15791551519936833%
# 	dars on chrY: 3
# CNA_10xv11_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1243
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 211
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.4716981132075472%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1080
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 8879
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.01126126126126126%
# 	dars on chrY: 1
# CNA_10xv11_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 419
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleA_CD16+_monocyte_VS_sampleB_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 237
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.42016806722689076%
# 	dars on chrY: 1
# VIB_10xv2_2.FIXEDCELLS__sampleB_CD16+_monocyte_VS_sampleA_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 58
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 9
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 47
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 6921
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.04332755632582322%
# 	dars on chrY: 2
# VIB_10xv2_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 615
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1165
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5005
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.039944078290393446%
# 	dars on chrY: 2
# VIB_10xv2_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4522
# 	dars on contigs: 7
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1545595054095827%
# 	dars on chrY: 4
# VIB_10xv2_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 58
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 252
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 38
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 518
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.5758157389635317%
# 	dars on chrY: 1
# MDC_mtscatac_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1640
# 	dars on contigs: 56
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 3.30188679245283%
# 	dars on chrY: 0
# MDC_mtscatac_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5800
# 	dars on contigs: 27
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.4633602196670671%
# 	dars on chrY: 2
# MDC_mtscatac_2.FIXEDCELLS__sampleB_Natural_killer_cell_VS_sampleA_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 52
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4912
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.02035416242621616%
# 	dars on chrY: 0
# MDC_mtscatac_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 29349
# 	dars on contigs: 10
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.03406110562348854%
# 	dars on chrY: 4
# MDC_mtscatac_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 15223
# 	dars on contigs: 54
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.35347254042023957%
# 	dars on chrY: 2
# VIB_10xv1_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 9
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4083
# 	dars on contigs: 5
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1223091976516634%
# 	dars on chrY: 2
# VIB_10xv1_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 29
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 10
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 82
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 59
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 7366
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.04071108698602253%
# 	dars on chrY: 3
# VIB_10xv1_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1924
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 338
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.5882352941176471%
# 	dars on chrY: 0
# HAR_ddseq_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 317
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 8621
# 	dars on contigs: 10
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.11586142973004288%
# 	dars on chrY: 3
# HAR_ddseq_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 11639
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.00859106529209622%
# 	dars on chrY: 1
# HAR_ddseq_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1331
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.299625468164794%
# 	dars on chrY: 2
# HAR_ddseq_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 10
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 8888
# 	dars on contigs: 15
# 	dars on chrM: 20
# 	% dars non standard chromosomes: 0.392244760730696%
# 	dars on chrY: 3
# HAR_ddseq_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 669
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_5.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 303
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3289473684210526%
# 	dars on chrY: 0
# CNA_10xv11_5.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_5.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 56
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_hydrop_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 12771
# 	dars on contigs: 51
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.39775386055217593%
# 	dars on chrY: 9
# CNA_hydrop_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 20534
# 	dars on contigs: 69
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3349026840751347%
# 	dars on chrY: 6
# CNA_hydrop_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 39073
# 	dars on contigs: 102
# 	dars on chrM: 1
# 	% dars non standard chromosomes: 0.2629160710639167%
# 	dars on chrY: 17
# CNA_hydrop_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 15425
# 	dars on contigs: 53
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3424215014859801%
# 	dars on chrY: 11
# CNA_hydrop_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4530
# 	dars on contigs: 19
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.4176742141129918%
# 	dars on chrY: 3
# CNA_hydrop_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 885
# 	dars on contigs: 13
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 1.447661469933185%
# 	dars on chrY: 0
# CNA_hydrop_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 13323
# 	dars on contigs: 41
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3067943729422329%
# 	dars on chrY: 1
# CNA_hydrop_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 26600
# 	dars on contigs: 76
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.2849002849002849%
# 	dars on chrY: 15
# CNA_10xmultiome_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4431
# 	dars on contigs: 5
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1127141568981064%
# 	dars on chrY: 2
# CNA_10xmultiome_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1087
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xmultiome_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5975
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0669008195350393%
# 	dars on chrY: 4
# CNA_10xmultiome_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1347
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xmultiome_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3569
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.028011204481792715%
# 	dars on chrY: 1
# CNA_10xmultiome_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_hydrop_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1240
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1610305958132045%
# 	dars on chrY: 2
# VIB_hydrop_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3209
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_hydrop_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 738
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.13531799729364005%
# 	dars on chrY: 0
# VIB_hydrop_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 29308
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.020468035750835778%
# 	dars on chrY: 4
# VIB_hydrop_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 9154
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.03276182155727859%
# 	dars on chrY: 2
# CNA_10xv2_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 6962
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.014361625736033319%
# 	dars on chrY: 1
# CNA_10xv2_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 328
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3898
# 	dars on contigs: 9
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.2303557716918352%
# 	dars on chrY: 6
# CNA_10xv2_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4511
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.044316419233325945%
# 	dars on chrY: 2
# CNA_10xv2_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 632
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_2.FIXEDCELLS__sampleB_Natural_killer_cell_VS_sampleA_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 7885
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.07603599036877455%
# 	dars on chrY: 4
# CNA_10xv2_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 682
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_hydrop_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5522
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_hydrop_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 37
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# EPF_hydrop_3.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2844
# 	dars on contigs: 25
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.871383757406762%
# 	dars on chrY: 0
# EPF_hydrop_3.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 297
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.33557046979865773%
# 	dars on chrY: 0
# OHS_s3atac_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 6010
# 	dars on contigs: 8
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.13293452974410103%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1175
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 27204
# 	dars on contigs: 11
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.040418886643395185%
# 	dars on chrY: 2
# SAN_10xmultiome_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 659
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 66
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 1.4925373134328357%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 400
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 21
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2027
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1477832512315271%
# 	dars on chrY: 1
# STA_10xv11_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 291
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3424657534246575%
# 	dars on chrY: 1
# EPF_hydrop_4.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2306
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# EPF_hydrop_4.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 6270
# 	dars on contigs: 11
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.17513134851138354%
# 	dars on chrY: 2
# EPF_hydrop_4.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 46
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# EPF_hydrop_4.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 13539
# 	dars on contigs: 21
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.15486725663716813%
# 	dars on chrY: 1
# CNA_10xv11_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 482
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 14
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_1.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 836
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 8438
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.07105637138796779%
# 	dars on chrY: 6
# CNA_10xv11_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 661
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1510574018126888%
# 	dars on chrY: 1
# CNA_10xv11_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3361
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1782001782001782%
# 	dars on chrY: 4
# CNA_10xv11_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 58
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4115
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.048579062424095217%
# 	dars on chrY: 2
# CNA_10xv11_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 15
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_mtscatac_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 35
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_mtscatac_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 7143
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.05596753882748006%
# 	dars on chrY: 3
# CNA_mtscatac_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_mtscatac_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 27
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_hydrop_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 19352
# 	dars on contigs: 96
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.49362402303578773%
# 	dars on chrY: 13
# CNA_hydrop_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 7837
# 	dars on contigs: 24
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3053046686172243%
# 	dars on chrY: 6
# CNA_hydrop_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 21089
# 	dars on contigs: 83
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3920272057434347%
# 	dars on chrY: 8
# VIB_10xmultiome_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 736
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xmultiome_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 45
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xmultiome_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3562
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.028066236317709797%
# 	dars on chrY: 1
# VIB_10xmultiome_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 29
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2011
# 	dars on contigs: 7
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3468780971258672%
# 	dars on chrY: 3
# BRO_mtscatac_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 234
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 425
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3713
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleB_CD16+_monocyte_VS_sampleA_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 192
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 43
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1543
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1233
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_1.FIXEDCELLS__sampleA_CD16+_monocyte_VS_sampleB_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1166
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv11_4.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 9574
# 	dars on contigs: 9
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.09391631013252635%
# 	dars on chrY: 4
# MDC_mtscatac_1.FIXEDCELLS__sampleA_CD16+_monocyte_VS_sampleB_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2474
# 	dars on contigs: 19
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.762133975130365%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 665
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.15015015015015015%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1832
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3264417845484222%
# 	dars on chrY: 5
# MDC_mtscatac_1.FIXEDCELLS__sampleB_CD16+_monocyte_VS_sampleA_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 8140
# 	dars on contigs: 31
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.37939052747521723%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 811
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.12315270935960591%
# 	dars on chrY: 1
# MDC_mtscatac_1.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3495
# 	dars on contigs: 25
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.7102272727272727%
# 	dars on chrY: 1
# MDC_mtscatac_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 506
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.5893909626719057%
# 	dars on chrY: 3
# MDC_mtscatac_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1487
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleB_Natural_killer_cell_VS_sampleA_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 89
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# MDC_mtscatac_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5170
# 	dars on contigs: 13
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.25081998842369285%
# 	dars on chrY: 10
# VIB_10xmultiome_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 251
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xmultiome_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5037
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0793493354493156%
# 	dars on chrY: 4
# VIB_10xmultiome_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2869
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.03484320557491289%
# 	dars on chrY: 1
# VIB_10xmultiome_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 69
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xmultiome_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4229
# 	dars on contigs: 5
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.11809163911195086%
# 	dars on chrY: 5
# VIB_10xmultiome_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 568
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 906
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.11025358324145534%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 145
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.684931506849315%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleB_CD16+_monocyte_VS_sampleA_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 205
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 530
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.37593984962406013%
# 	dars on chrY: 2
# BRO_mtscatac_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 73
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 73
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 85
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 49
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 2.0%
# 	dars on chrY: 1
# BRO_mtscatac_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 310
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# BRO_mtscatac_2.FIXEDCELLS__sampleA_CD16+_monocyte_VS_sampleB_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 45
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 10
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 2455
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.12205044751830757%
# 	dars on chrY: 2
# VIB_10xv2_1.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 874
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 91
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 484
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5562
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.03594536304816679%
# 	dars on chrY: 2
# VIB_10xv2_1.FIXEDCELLS__sampleB_CD16+_monocyte_VS_sampleA_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 28
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 603
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv2_1.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 46
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1213
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1646090534979424%
# 	dars on chrY: 1
# VIB_10xv1_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1360
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleB_Dendritic_cell_VS_sampleA_Dendritic_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 153
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 6234
# 	dars on contigs: 6
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.09615384615384616%
# 	dars on chrY: 1
# VIB_10xv1_2.FIXEDCELLS__sampleA_Dendritic_cell_VS_sampleB_Dendritic_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 316
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 7216
# 	dars on contigs: 7
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.09691264017721168%
# 	dars on chrY: 4
# VIB_10xv1_2.FIXEDCELLS__sampleB_Natural_killer_cell_VS_sampleA_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 280
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 207
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 8927
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0335946248600224%
# 	dars on chrY: 1
# VIB_10xv1_2.FIXEDCELLS__sampleB_CD16+_monocyte_VS_sampleA_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 20
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3091
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.03234152652005175%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 9601
# 	dars on contigs: 5
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.052050801582344375%
# 	dars on chrY: 2
# VIB_10xv1_2.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 139
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# VIB_10xv1_2.FIXEDCELLS__sampleA_CD16+_monocyte_VS_sampleB_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3312
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.12062726176115801%
# 	dars on chrY: 2
# EPF_hydrop_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 22915
# 	dars on contigs: 15
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.06541648495420846%
# 	dars on chrY: 9
# EPF_hydrop_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5186
# 	dars on contigs: 77
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 1.4630438913167394%
# 	dars on chrY: 0
# EPF_hydrop_1.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 11030
# 	dars on contigs: 79
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.7111351156719777%
# 	dars on chrY: 2
# CNA_10xmultiome_2.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xmultiome_2.FIXEDCELLS__sampleA_Cytotoxic_T_cell_VS_sampleB_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 870
# 	dars on contigs: 3
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.3436426116838488%
# 	dars on chrY: 2
# CNA_10xmultiome_2.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 26
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# STA_10xv11_2.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4346
# 	dars on contigs: 7
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.16080863772111187%
# 	dars on chrY: 3
# SAN_10xmultiome_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4289
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.09317493594223154%
# 	dars on chrY: 2
# SAN_10xmultiome_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 64
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 686
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1455604075691412%
# 	dars on chrY: 1
# SAN_10xmultiome_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# SAN_10xmultiome_1.FIXEDCELLS__sampleA_CD16+_monocyte_VS_sampleB_CD16+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 995
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 82
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_1.FIXEDCELLS__sampleA_B_cell_VS_sampleB_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1664
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 10
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_1.FIXEDCELLS__sampleA_CD14+_monocyte_VS_sampleB_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1501
# 	dars on contigs: 2
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.1330671989354624%
# 	dars on chrY: 0
# CNA_10xv2_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 20
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# CNA_10xv2_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 3307
# 	dars on contigs: 4
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.12080942313500453%
# 	dars on chrY: 1
# HAR_ddseq_1.FIXEDCELLS__sampleA_Natural_killer_cell_VS_sampleB_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1036
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleB_Dendritic_cell_VS_sampleA_Dendritic_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 424
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleB_CD4+_T_cell_VS_sampleA_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 126
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleB_CD14+_monocyte_VS_sampleA_CD14+_monocyte__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleA_Dendritic_cell_VS_sampleB_Dendritic_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1979
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleB_Natural_killer_cell_VS_sampleA_Natural_killer_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 4
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleA_CD4+_T_cell_VS_sampleB_CD4+_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 1118
# 	dars on contigs: 1
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.08936550491510277%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleB_Cytotoxic_T_cell_VS_sampleA_Cytotoxic_T_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 5
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0
# HAR_ddseq_1.FIXEDCELLS__sampleB_B_cell_VS_sampleA_B_cell__1-2xfoldchange_DARs.bed
# 	dars on standard chromosomes: 72
# 	dars on contigs: 0
# 	dars on chrM: 0
# 	% dars non standard chromosomes: 0.0%
# 	dars on chrY: 0

# %% [markdown]
# ## Gene activity

# %%
import pyranges as pr
import requests
import pybiomart as pbm

# %% [markdown]
# ### Get gene annotations and chromosome sizes

# %%
# For human
dataset = pbm.Dataset(name='hsapiens_gene_ensembl',  host='http://www.ensembl.org')
annot = dataset.query(attributes=['chromosome_name', 'start_position', 'end_position', 'strand', 'external_gene_name', 'transcription_start_site', 'transcript_biotype'])
annot['Chromosome/scaffold name'] = 'chr' + annot['Chromosome/scaffold name'].astype(str)
annot.columns=['Chromosome', 'Start', 'End', 'Strand', 'Gene','Transcription_Start_Site', 'Transcript_type']
annot = annot[annot.Transcript_type == 'protein_coding']
annot.Strand[annot.Strand == 1] = '+'
annot.Strand[annot.Strand == -1] = '-'
pr_annotation = pr.PyRanges(annot.dropna(axis = 0))
pr_annotation
# Out:
# +--------------+-----------+-----------+--------------+------------+-------+
# | Chromosome   | Start     | End       | Strand       | Gene       | +2    |
# | (category)   | (int32)   | (int32)   | (category)   | (object)   | ...   |
# |--------------+-----------+-----------+--------------+------------+-------|
# | chr1         | 1471765   | 1497848   | +            | ATAD3B     | ...   |
# | chr1         | 1471765   | 1497848   | +            | ATAD3B     | ...   |
# | chr1         | 3069168   | 3438621   | +            | PRDM16     | ...   |
# | chr1         | 3069168   | 3438621   | +            | PRDM16     | ...   |
# | ...          | ...       | ...       | ...          | ...        | ...   |
# | chrY         | 6865918   | 6911752   | -            | AMELY      | ...   |
# | chrY         | 21903618  | 21918042  | -            | RBMY1E     | ...   |
# | chrY         | 24045229  | 24048019  | -            | CDY1B      | ...   |
# | chrY         | 24045229  | 24048019  | -            | CDY1B      | ...   |
# +--------------+-----------+-----------+--------------+------------+-------+
# Stranded PyRanges object has 85,686 rows and 7 columns from 330 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 2 hidden columns: Transcription_Start_Site, Transcript_type

# %%
# get chromosome sizes (hg38)
target_url = 'http://hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/hg38.chrom.sizes'
chromsizes = pd.read_csv(target_url, sep='\t', header=None)
chromsizes.columns = ['Chromosome', 'End']
chromsizes['Start'] = [0]*chromsizes.shape[0]
chromsizes = chromsizes.loc[:,['Chromosome', 'Start', 'End']]
chromsizes = pr.PyRanges(chromsizes)
chromsizes
# Out:
# +------------------------+-----------+-----------+
# | Chromosome             | Start     | End       |
# | (category)             | (int32)   | (int32)   |
# |------------------------+-----------+-----------|
# | chr1                   | 0         | 248956422 |
# | chr1_GL383518v1_alt    | 0         | 182439    |
# | chr1_GL383519v1_alt    | 0         | 110268    |
# | chr1_GL383520v2_alt    | 0         | 366580    |
# | ...                    | ...       | ...       |
# | chrX_KI270881v1_alt    | 0         | 144206    |
# | chrX_KI270913v1_alt    | 0         | 274009    |
# | chrY                   | 0         | 57227415  |
# | chrY_KI270740v1_random | 0         | 37240     |
# +------------------------+-----------+-----------+
# Unstranded PyRanges object has 455 rows and 3 columns from 455 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.

# %% [markdown]
# ### Infer gene activity

# %%
from pycisTopic.gene_activity import get_gene_activity
from pycisTopic.diff_features import find_diff_features

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
gene_act_dict = {}

for key in cistopic_obj_dict.keys():
    print(key)
    gene_act, weights = get_gene_activity(
        imputed_acc_obj_dict[key], # Region-cell probabilities
        pr_annotation, # Gene annotation
        chromsizes, # Chromosome size
        use_gene_boundaries=True, # Whether to use the whole search space or stop when encountering another gene
        upstream=[1000, 100000], # Search space upstream. The minimum means that even if there is a gene right next to it 
                                 #these bp will be taken (1kbp here)
        downstream=[1000,100000], # Search space downstream
        distance_weight=True, # Whether to add a distance weight (an exponential function, the weight will decrease with distance)
        decay_rate=1, # Exponent for the distance exponential funciton (the higher the faster will be the decrease)
        extend_gene_body_upstream=10000, # Number of bp upstream immune to the distance weight (their value will be maximum for 
                                         #this weight)
        extend_gene_body_downstream=500, # Number of bp downstream immune to the distance weight
        gene_size_weight=False, # Whether to add a weights based on the length of the gene
        gene_size_scale_factor='median', # Dividend to calculate the gene size weigth. Default is the median value of all genes
                                         #in the genome
        remove_promoters=False, # Whether to remove promoters when computing gene activity scores
        average_scores=True, # Whether to divide by the total number of region assigned to a gene when calculating the gene 
                             # activity score
        scale_factor=1, # Value to multiply for the final gene activity matrix
        extend_tss=[10,10], # Space to consider a promoter
        gini_weight = True, # Whether to add a gini index weigth. The more unique the region is, the higher this weight will be
        return_weights= True, # Whether to return the final weights
        project='Gene_activity') # Project name for the gene activity object
    gene_act_dict[key] = copy.copy(gene_act)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 gene_act_dict = {}
# ----> 3 for key in cistopic_obj_dict.keys():
#       4     print(key)
#       5     gene_act, weights = get_gene_activity(
#       6         imputed_acc_obj_dict[key], # Region-cell probabilities
#       7         pr_annotation, # Gene annotation
#    (...)
#      27         return_weights= True, # Whether to return the final weights
#      28         project='Gene_activity') # Project name for the gene activity object
#
# NameError: name 'cistopic_obj_dict' is not defined

# %% [markdown]
# ### Infer the Differentially Accessible Genes (DAGs)

# %%
from pycisTopic.clust_vis import plot_imputed_features

# %%
dag_markers_dict = {}
for key in cistopic_obj_dict.keys():
    print(key)
    dag_markers_dict[key] = find_diff_features(cistopic_obj_dict[key],
                      gene_act_dict[key],
                      variable='consensus_cell_type',
                      var_features=None,
                      contrasts=None,
                      adjpval_thr=0.05,
                      log2fc_thr=np.log2(1.5),
                      n_cpu=5,
                      )

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    plot_imputed_features(cistopic_obj_dict[key],
                    reduction_name='UMAP',
                    imputed_data=gene_act,
                    features=['CD34', 'THY1', # CD34+
                              'NCAM1', 'FCGR3A', # NK
                              'CD14', 'CD68', # Monocytes
                              'MS4A1', 'CD79A', # B cells
                              'CD8A', 'CD8B', # Cytotoxic CD8 cells
                              'CD4', # CD4 T
                              'CD3D', # T
                              'IL3RA', 'CD1C', 'BATF3', # Dendritic
                             ],
                    scale=True,
                    num_columns=5,
                    )

# %% [markdown]
# ## Export to loom

# %%
# cistopic_obj_dict # ok
# imputed_acc_obj_dict # ok
# region_bin_topics #(region_bin_topics_dict) ok
# binarized_cell_topic # ok
# DARs_dict #(markers_dict_dict) ok

# %%
f_region_loom_dir = os.path.join(f_final_dir, 'region_acc_loom')
if not os.path.exists(f_region_loom_dir):
    os.makedirs(f_region_loom_dir)
    
f_gene_loom_dir = os.path.join(f_final_dir, 'gene_act_loom')
if not os.path.exists(f_gene_loom_dir):
    os.makedirs(f_gene_loom_dir)

# %% [markdown]
# ### Region accessibility

# %%
from pycisTopic.loom import (
    export_region_accessibility_to_loom,
    export_gene_activity_to_loom
)

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    s = 'merged' if key=='merged' else sample_annot.loc[key,'Sample']
    f_out = os.path.join(f_region_loom_dir, s + '__libDS_region_accessibility.loom')
    if os.path.exists(f_out):
        print(f"Skipping {f_out}: already exists.")
        continue
    # Subset regions, we will use only regions in topics and DARs here to make it faster
    regions_in_topics = list(set(sum([region_bin_topics_dict[key][i].index.tolist() for i in region_bin_topics_dict[key].keys()],[])))
    regions_in_DARs = list(set(sum([markers_dict_dict[key][i].index.tolist() for i in markers_dict_dict[key].keys()],[])))
    # make sure we only take regions that actually exist in the accessibility matrix:
    selected_regions = list(set(regions_in_topics + regions_in_DARs).intersection(set(imputed_acc_obj_dict[key].feature_names)))

    # Export to loom
    export_region_accessibility_to_loom(
        accessibility_matrix = imputed_acc_obj_dict[key],
        cistopic_obj = cistopic_obj_dict[key], 
        binarized_topic_region = region_bin_topics_dict[key],
        binarized_cell_topic = binarized_cell_topic_dict[key],
        out_fname = f_out,
        selected_regions = selected_regions ,
        selected_cells = [ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ], # this leaves a cell barcode of the format type 'TGCATGTCGCCGTTCCAAGA-21'
        # selected_cells = cistopic_obj_dict[key].projections['cell']['UMAP'].index.tolist(), # cflerin original
        cluster_annotation = ['consensus_cell_type'],
        cluster_markers = {'consensus_cell_type': markers_dict_dict[key]},
        tree_structure = ('scATAC-seq_Benchmark', 'ATAC_library_downsampled', 'Region_accessibility'),
        title = s + ' - Region accessibility all',
        nomenclature = "hg38"
    )

# %%
len([ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ])

# %% [markdown]
# ### Gene activity

# %%
from ctxcore.genesig import Regulon

# generate a dummy regulon (required for export_gene_activity_to_loom):
phreg = Regulon(
        name='placeholder regulon',
        gene2weight={'phreg': 1.0},
        transcription_factor="phreg",
        gene2occurrence={"phreg": 1},
    )

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    s = 'merged' if key=='merged' else sample_annot.loc[key,'Sample']
    f_out = os.path.join(f_gene_loom_dir, s + '__libDS_gene_activity.loom')
    if os.path.exists(f_out):
        print(f"Skipping {f_out}: already exists.")
        continue
    export_gene_activity_to_loom(
        gene_activity_matrix = gene_act_dict[key],
        cistopic_obj = cistopic_obj_dict[key], 
        regulons = [phreg],
        selected_cells = [ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ], # this leaves a cell barcode of the format type 'TGCATGTCGCCGTTCCAAGA-21'
        # selected_cells = cistopic_obj_dict[key].projections['cell']['UMAP'].index.tolist(), # cflerin original        out_fname = f_out,
        cluster_annotation = ['consensus_cell_type'],
        cluster_markers = {'consensus_cell_type': markers_dict_dict[key]},
        tree_structure = ('scATAC-seq_Benchmark', 'ATAC_library_downsampled', 'Gene_activity'),
        title = s + ' - Gene activity',
        nomenclature = "hg38"
    )
