# %%
import pycisTopic
import glob
import os
import pybiomart as pbm
import pandas as pd
import pickle
from pycisTopic.qc import *
from IPython.display import Image, display
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import multiprocess as mp  # for kde multithreading calculation
from multiprocess import Pool

# %matplotlib inline
# %load_ext lab_black

# %% [markdown]
# # Download annotation

# %%
# !pwd
# Out:
# /lustre1/project/stg_00090/scatac_benchmark/fixedcells_3_cistopic_consensus

# %%
wdir = "/lustre1/project/stg_00090/scatac_benchmark/fixedcells_3_cistopic_consensus"
os.chdir(wdir)

# %%
genome = "hg38"

pbm_genome_name_dict = {
    "hg38": "hsapiens_gene_ensembl",
    "hg37": "hsapiens_gene_ensembl",
    "mm10": "mmusculus_gene_ensembl",
    "dm6": "dmelanogaster_gene_ensembl",
}

pbm_host_dict = {
    "hg38": "http://www.ensembl.org",
    "hg37": "http://grch37.ensembl.org/",
    "mm10": "http://nov2020.archive.ensembl.org/",
    "dm6": "http://www.ensembl.org",
}

if os.path.exists(f"annotation.tsv"):
    print(f"Loading cached genome annotation...")
    annotation = pd.read_csv("annotation.tsv", sep="\t", header=0, index_col=0)
else:
    dataset = pbm.Dataset(name=pbm_genome_name_dict[genome], host=pbm_host_dict[genome])

    annotation = dataset.query(
        attributes=[
            "chromosome_name",
            "transcription_start_site",
            "strand",
            "external_gene_name",
            "transcript_biotype",
        ]
    )
    filter = annotation["Chromosome/scaffold name"].str.contains("CHR|GL|JH|MT")
    annotation = annotation[~filter]
    annotation["Chromosome/scaffold name"] = annotation[
        "Chromosome/scaffold name"
    ].str.replace(r"(\b\S)", r"chr\1")
    annotation.columns = ["Chromosome", "Start", "Strand", "Gene", "Transcript_type"]
    annottation = annotation[annotation.Transcript_type == "protein_coding"]
    annotation.to_csv("annotation.tsv", sep="\t")
# Out:
# Loading cached genome annotation...

# %%
annotation
# Out:
#                  Chromosome      Start  Strand    Gene Transcript_type
# 57      chrKI270711chr.chr1      24650      -1     NaN  protein_coding
# 58      chrKI270711chr.chr1      29626      -1     NaN  protein_coding
# 628     chrKI270734chr.chr1     161852      -1     NaN  protein_coding
# 629     chrKI270734chr.chr1     161750      -1     NaN  protein_coding
# 713     chrKI270734chr.chr1     131494       1     NaN  protein_coding
# ...                     ...        ...     ...     ...             ...
# 242597                 chr1  154257071       1  UBAP2L  protein_coding
# 242604                 chr1  154272589       1    HAX1  protein_coding
# 242605                 chr1  154272609       1    HAX1  protein_coding
# 242607                 chr1  154272629       1    HAX1  protein_coding
# 242610                 chr1  154272668       1    HAX1  protein_coding
#
# [77891 rows x 5 columns]

# %%
annotation
# Out:
#                  Chromosome      Start  Strand    Gene Transcript_type  \
# 57      chrKI270711chr.chr1      24650      -1     NaN  protein_coding
# 58      chrKI270711chr.chr1      29626      -1     NaN  protein_coding
# 628     chrKI270734chr.chr1     161852      -1     NaN  protein_coding
# 629     chrKI270734chr.chr1     161750      -1     NaN  protein_coding
# 713     chrKI270734chr.chr1     131494       1     NaN  protein_coding
# ...                     ...        ...     ...     ...             ...
# 242597                 chr1  154257071       1  UBAP2L  protein_coding
# 242604                 chr1  154272589       1    HAX1  protein_coding
# 242605                 chr1  154272609       1    HAX1  protein_coding
# 242607                 chr1  154272629       1    HAX1  protein_coding
# 242610                 chr1  154272668       1    HAX1  protein_coding
#
#               End
# 57          24651
# 58          29627
# 628        161853
# 629        161751
# 713        131495
# ...           ...
# 242597  154257072
# 242604  154272590
# 242605  154272610
# 242607  154272630
# 242610  154272669
#
# [77891 rows x 6 columns]

# %%
# save TSS_ann also to .bed

annotation["End"] = annotation["Start"] + 1
annotation["Score"] = None
annotation[["Chromosome", "Start", "End", "Gene", "Score", "Strand"]].to_csv(
    "tss.bed", sep="\t", index=False, header=None
)

# %%
fragments_list = sorted(glob.glob("../1_data_repository/fixedcells_fragments/*.tsv.gz"))
fragments_dict = {}
for fragments_file in fragments_list:
    sample = fragments_file.split("/")[-1].split(".fragments.tsv.gz")[0]
    fragments_dict[sample] = fragments_file
fragments_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS.fragments.tsv.gz',
#  'BIO_ddseq_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_2.FIXEDCELLS.fragments.tsv.gz',
#  'BIO_ddseq_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_3.FIXEDCELLS.fragments.tsv.gz',
#  'BIO_ddseq_4.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_4.FIXEDCELLS.fragments.tsv.gz',
#  'BRO_mtscatac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BRO_mtscatac_1.FIXEDCELLS.fragments.tsv.gz',
#  'BRO_mtscatac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BRO_mtscatac_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xmultiome_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xmultiome_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_3.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_4.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_4.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_5.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_5.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv2_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv2_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv2_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv2_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_hydrop_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_hydrop_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_hydrop_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_hydrop_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_hydrop_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_hydrop_3.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_mtscatac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_mtscatac_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_mtscatac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_mtscatac_2.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_1.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_2.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_3.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_4.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_4.FIXEDCELLS.fragments.tsv.gz',
#  'HAR_ddseq_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/HAR_ddseq_1.FIXEDCELLS.fragments.tsv.gz',
#  'HAR_ddseq_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/HAR_ddseq_2.FIXEDCELLS.fragments.tsv.gz',
#  'MDC_mtscatac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/MDC_mtscatac_1.FIXEDCELLS.fragments.tsv.gz',
#  'MDC_mtscatac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/MDC_mtscatac_2.FIXEDCELLS.fragments.tsv.gz',
#  'OHS_s3atac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/OHS_s3atac_1.FIXEDCELLS.fragments.tsv.gz',
#  'OHS_s3atac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/OHS_s3atac_2.FIXEDCELLS.fragments.tsv.gz',
#  'SAN_10xmultiome_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/SAN_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz',
#  'SAN_10xmultiome_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/SAN_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz',
#  'STA_10xv11_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/STA_10xv11_1.FIXEDCELLS.fragments.tsv.gz',
#  'STA_10xv11_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/STA_10xv11_2.FIXEDCELLS.fragments.tsv.gz',
#  'TXG_10xv11_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/TXG_10xv11_1.FIXEDCELLS.fragments.tsv.gz',
#  'TXG_10xv2_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/TXG_10xv2_1.FIXEDCELLS.fragments.tsv.gz',
#  'TXG_10xv2_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/TXG_10xv2_2.FIXEDCELLS.fragments.tsv.gz',
#  'UCS_ddseq_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/UCS_ddseq_1.FIXEDCELLS.fragments.tsv.gz',
#  'UCS_ddseq_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/UCS_ddseq_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xmultiome_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xmultiome_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv1_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv1_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv1_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv1_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv2_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv2_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv2_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv2_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_11.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_11.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_12.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_12.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_21.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_21.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_22.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_22.FIXEDCELLS.fragments.tsv.gz'}

# %%
regions_paths_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("SCREEN_peaks/*consensus_peaks.bed"))
}
regions_paths_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 'SCREEN_peaks/BIO_ddseq_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_2.FIXEDCELLS': 'SCREEN_peaks/BIO_ddseq_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_3.FIXEDCELLS': 'SCREEN_peaks/BIO_ddseq_3.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_4.FIXEDCELLS': 'SCREEN_peaks/BIO_ddseq_4.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'BRO_mtscatac_1.FIXEDCELLS': 'SCREEN_peaks/BRO_mtscatac_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'BRO_mtscatac_2.FIXEDCELLS': 'SCREEN_peaks/BRO_mtscatac_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xmultiome_1.FIXEDCELLS': 'SCREEN_peaks/CNA_10xmultiome_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xmultiome_2.FIXEDCELLS': 'SCREEN_peaks/CNA_10xmultiome_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_1.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv11_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_2.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv11_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_3.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv11_3.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_4.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv11_4.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_5.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv11_5.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv2_1.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv2_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_10xv2_2.FIXEDCELLS': 'SCREEN_peaks/CNA_10xv2_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_hydrop_1.FIXEDCELLS': 'SCREEN_peaks/CNA_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_hydrop_2.FIXEDCELLS': 'SCREEN_peaks/CNA_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_hydrop_3.FIXEDCELLS': 'SCREEN_peaks/CNA_hydrop_3.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_mtscatac_1.FIXEDCELLS': 'SCREEN_peaks/CNA_mtscatac_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'CNA_mtscatac_2.FIXEDCELLS': 'SCREEN_peaks/CNA_mtscatac_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_1.FIXEDCELLS': 'SCREEN_peaks/EPF_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_2.FIXEDCELLS': 'SCREEN_peaks/EPF_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_3.FIXEDCELLS': 'SCREEN_peaks/EPF_hydrop_3.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_4.FIXEDCELLS': 'SCREEN_peaks/EPF_hydrop_4.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'HAR_ddseq_1.FIXEDCELLS': 'SCREEN_peaks/HAR_ddseq_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'HAR_ddseq_2.FIXEDCELLS': 'SCREEN_peaks/HAR_ddseq_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'MDC_mtscatac_1.FIXEDCELLS': 'SCREEN_peaks/MDC_mtscatac_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'MDC_mtscatac_2.FIXEDCELLS': 'SCREEN_peaks/MDC_mtscatac_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'OHS_s3atac_1.FIXEDCELLS': 'SCREEN_peaks/OHS_s3atac_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'OHS_s3atac_2.FIXEDCELLS': 'SCREEN_peaks/OHS_s3atac_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'SCREEN_peaks/SAN_10xmultiome_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'SCREEN_peaks/SAN_10xmultiome_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'STA_10xv11_1.FIXEDCELLS': 'SCREEN_peaks/STA_10xv11_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'STA_10xv11_2.FIXEDCELLS': 'SCREEN_peaks/STA_10xv11_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'TXG_10xv11_1.FIXEDCELLS': 'SCREEN_peaks/TXG_10xv11_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'TXG_10xv2_1.FIXEDCELLS': 'SCREEN_peaks/TXG_10xv2_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'TXG_10xv2_2.FIXEDCELLS': 'SCREEN_peaks/TXG_10xv2_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'UCS_ddseq_1.FIXEDCELLS': 'SCREEN_peaks/UCS_ddseq_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'UCS_ddseq_2.FIXEDCELLS': 'SCREEN_peaks/UCS_ddseq_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'SCREEN_peaks/VIB_10xmultiome_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'SCREEN_peaks/VIB_10xmultiome_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_10xv1_1.FIXEDCELLS': 'SCREEN_peaks/VIB_10xv1_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_10xv1_2.FIXEDCELLS': 'SCREEN_peaks/VIB_10xv1_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_10xv2_1.FIXEDCELLS': 'SCREEN_peaks/VIB_10xv2_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_10xv2_2.FIXEDCELLS': 'SCREEN_peaks/VIB_10xv2_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_1.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_11.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_11.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_12.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_12.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_2.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_21.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_21.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_22.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_22.FIXEDCELLS__SCREEN_consensus_peaks.bed'}

# %%
regions_paths_dict["VIB_hydrop_11.FIXEDCELLS"] = "SCREEN_peaks/VIB_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed"
regions_paths_dict["VIB_hydrop_12.FIXEDCELLS"] = "SCREEN_peaks/VIB_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed"
regions_paths_dict["VIB_hydrop_21.FIXEDCELLS"] = "SCREEN_peaks/VIB_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed"
regions_paths_dict["VIB_hydrop_22.FIXEDCELLS"] = "SCREEN_peaks/VIB_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed"

# %% [markdown]
# Now, make a sub dictionary of all samples within the fragments dict that have not been run yet (good for resuming a stopped cistopic run):

# %%
cistopic_qc_out = os.path.join(wdir, "cistopic_qc_out_CONSENSUS")
if not os.path.exists(cistopic_qc_out):
    os.makedirs(cistopic_qc_out)

# %%
fragments_sub_dict = {}
regions_sub_dict = {}
for sample in regions_paths_dict.keys():
    metadata_file = os.path.join(cistopic_qc_out, sample + "__metadata_bc.pkl")
    print(f"Checking if {metadata_file} exist...")
    if os.path.exists(metadata_file):
        print("\tMetadata exists! Skipping...")
    else:
        fragments_sub_dict[sample] = fragments_dict[sample]
        print("\tMetadata does not exist, adding to subdict to generate")
# Out:
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/BIO_ddseq_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/BIO_ddseq_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/BIO_ddseq_3.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/BIO_ddseq_4.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/BRO_mtscatac_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/BRO_mtscatac_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xmultiome_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xmultiome_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv11_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv11_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv11_3.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv11_4.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv11_5.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv2_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_10xv2_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_hydrop_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_hydrop_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_hydrop_3.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_mtscatac_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/CNA_mtscatac_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/EPF_hydrop_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/EPF_hydrop_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/EPF_hydrop_3.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/EPF_hydrop_4.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/HAR_ddseq_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/HAR_ddseq_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/MDC_mtscatac_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/MDC_mtscatac_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/OHS_s3atac_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/OHS_s3atac_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/SAN_10xmultiome_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/SAN_10xmultiome_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/STA_10xv11_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/STA_10xv11_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/TXG_10xv11_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/TXG_10xv2_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/TXG_10xv2_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/UCS_ddseq_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/UCS_ddseq_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_10xmultiome_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_10xmultiome_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_10xv1_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_10xv1_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_10xv2_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_10xv2_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_hydrop_1.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_hydrop_11.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_hydrop_12.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_hydrop_2.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata exists! Skipping...
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_hydrop_21.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate
# Checking if /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS/VIB_hydrop_22.FIXEDCELLS__metadata_bc.pkl exist...
# 	Metadata does not exist, adding to subdict to generate

# %%
regions_sub_dict = {x: regions_paths_dict[x] for x in sorted(fragments_sub_dict.keys())}
regions_sub_dict
# Out:
# {'VIB_hydrop_11.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_12.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_1.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_21.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_22.FIXEDCELLS': 'SCREEN_peaks/VIB_hydrop_2.FIXEDCELLS__SCREEN_consensus_peaks.bed'}

# %%
ray.shutdown()

# %%
n_cores = 8
if regions_sub_dict != {}:
    samples_sub = list(regions_sub_dict.keys())
    blocks = [samples_sub[i : i + n_cores] for i in range(0, len(samples_sub), n_cores)]
    for samples_torun_in_block in blocks:
        fragments_sub_dict_block = {
            key: fragments_sub_dict[key] for key in samples_torun_in_block
        }
        regions_sub_dict_block = {
            key: regions_sub_dict[key] for key in samples_torun_in_block
        }

        metadata_bc_dict, profile_data_dict = compute_qc_stats(
            fragments_dict=fragments_sub_dict_block,
            tss_annotation=annotation,
            stats=[
                "barcode_rank_plot",
                "duplicate_rate",
                "insert_size_distribution",
                "profile_tss",
                "frip",
            ],
            label_list=None,
            path_to_regions=regions_sub_dict_block,
            n_cpu=n_cores,
            valid_bc=None,
            n_frag=10,
            n_bc=None,
            tss_flank_window=2000,
            tss_window=50,
            tss_minimum_signal_window=100,
            tss_rolling_window=10,
            # min_norm=0.2,
            remove_duplicates=True,
        )

        ray.shutdown()
        print(f"Dumping files in {cistopic_qc_out}...")
        for sample in sorted(metadata_bc_dict.keys()):
            metadata_bc_dict[sample]["sample_id"] = sample
            metadata_bc_dict[sample].index = [
                x + "___" + sample for x in list(metadata_bc_dict[sample].index)
            ]
            with open(
                os.path.join(cistopic_qc_out, f"{sample}__metadata_bc.pkl"), "wb"
            ) as f:
                pickle.dump(metadata_bc_dict[sample], f, protocol=4)

            with open(
                os.path.join(cistopic_qc_out, f"{sample}__profile_data.pkl"), "wb"
            ) as f:
                pickle.dump(profile_data_dict[sample], f, protocol=4)
else:
    print("All samples already processed.")
# Out:
# 2022-09-16 16:02:24,220 cisTopic     INFO     n_cpu is larger than the number of samples. Setting n_cpu to the number of samples
# 2022-09-16 16:02:28,277	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:02:42,302 cisTopic     INFO     Reading VIB_hydrop_12.FIXEDCELLS
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:02:42,305 cisTopic     INFO     Reading VIB_hydrop_11.FIXEDCELLS
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:02:42,360 cisTopic     INFO     Reading VIB_hydrop_21.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:02:42,362 cisTopic     INFO     Reading VIB_hydrop_22.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:21,297 cisTopic     INFO     Computing barcode rank plot for VIB_hydrop_22.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:21,297 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:23,680 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:23,786 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:23,808 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:24,542 cisTopic     INFO     Computing barcode rank plot for VIB_hydrop_11.FIXEDCELLS
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:24,542 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:25,991 cisTopic     INFO     Computing duplicate rate plot for VIB_hydrop_22.FIXEDCELLS
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:27,089 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:27,204 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:27,220 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:29,460 cisTopic     INFO     Computing duplicate rate plot for VIB_hydrop_11.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:29,809 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:30,119 cisTopic     INFO     Computing insert size distribution for VIB_hydrop_22.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:30,120 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:30,861 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:33,391 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:33,703 cisTopic     INFO     Computing insert size distribution for VIB_hydrop_11.FIXEDCELLS
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:33,703 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:34,489 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:40,803 cisTopic     INFO     Computing barcode rank plot for VIB_hydrop_12.FIXEDCELLS
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:40,804 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:43,866 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:43,894 cisTopic     INFO     Computing TSS profile for VIB_hydrop_22.FIXEDCELLS
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:43,982 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:44,003 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:47,031 cisTopic     INFO     Computing duplicate rate plot for VIB_hydrop_12.FIXEDCELLS
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:49,191 cisTopic     INFO     Computing TSS profile for VIB_hydrop_11.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:50,059 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:03:50,301 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:52,107 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:52,417 cisTopic     INFO     Computing insert size distribution for VIB_hydrop_12.FIXEDCELLS
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:52,417 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:03:53,538 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:56,049 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:03:56,294 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:04:13,768 cisTopic     INFO     Computing TSS profile for VIB_hydrop_12.FIXEDCELLS
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:14,404 cisTopic     INFO     Computing barcode rank plot for VIB_hydrop_21.FIXEDCELLS
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:14,404 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:18,880 cisTopic     INFO     Marking barcodes with more than 10
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:19,025 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:19,086 cisTopic     INFO     Returning valid barcodes
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:23,238 cisTopic     INFO     Computing duplicate rate plot for VIB_hydrop_21.FIXEDCELLS
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:04:23,499 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:04:23,745 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:30,167 cisTopic     INFO     Return plot data
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:30,484 cisTopic     INFO     Computing insert size distribution for VIB_hydrop_21.FIXEDCELLS
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:30,484 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:04:32,219 cisTopic     INFO     Returning plot data
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:05:03,597 cisTopic     INFO     Computing TSS profile for VIB_hydrop_21.FIXEDCELLS
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:05:18,858 cisTopic     INFO     Formatting annnotation
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:05:19,122 cisTopic     INFO     Creating coverage matrix
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:05:27,278 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:05:34,010 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:06:25,742 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:08:24,140 cisTopic     INFO     Coverage matrix done
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:09:47,245 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:09:56,405 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:11:13,308 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:12:39,245 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:12:39,617 cisTopic     INFO     Computing FRIP profile for VIB_hydrop_22.FIXEDCELLS
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:12:41,018 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:12:43,644 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:12:50,836 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:12:51,174 cisTopic     INFO     Computing FRIP profile for VIB_hydrop_11.FIXEDCELLS
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:12:52,443 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490946) 2022-09-16 16:12:54,183 cisTopic     INFO     Sample VIB_hydrop_22.FIXEDCELLS done!
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:12:55,904 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=3490948) 2022-09-16 16:13:04,256 cisTopic     INFO     Sample VIB_hydrop_11.FIXEDCELLS done!
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:13:18,455 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:13:45,957 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:13:46,123 cisTopic     INFO     Computing FRIP profile for VIB_hydrop_12.FIXEDCELLS
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:13:46,726 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:13:48,358 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=3490945) 2022-09-16 16:13:54,691 cisTopic     INFO     Sample VIB_hydrop_12.FIXEDCELLS done!
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:14:29,902 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:14:29,988 cisTopic     INFO     Computing FRIP profile for VIB_hydrop_21.FIXEDCELLS
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:14:30,396 cisTopic     INFO     Counting fragments
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:14:31,518 cisTopic     INFO     Intersecting fragments with regions
# (compute_qc_stats_ray pid=3490947) 2022-09-16 16:14:36,385 cisTopic     INFO     Sample VIB_hydrop_21.FIXEDCELLS done!
# Dumping files in /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_3_cistopic_consensus/cistopic_qc_out_CONSENSUS...

# %% [markdown]
# # Plot

# %% [markdown]
# Calculating a KDE is simultaneously expensive and scales poorly with increasing n. Therefore, I wrote a multithreaded script that divides the QC array into equal parts (interleaved to avoid biases in the order!) and performs a KDE calculation on each part. Here, Otsu thresholding is used to find the right threshold for minimum fragments and minimum TSS enrichment. ddseq samples have a significantly higher noise floor than the other samples when it comes to fragment distribution. Therefore, the otsu algorithm is performed on all barcodes with a minimum of 300 fragments for the ddseq samples, and a minimum of 100 fragments for all the other samples. I tried to perform this filtering completely independent of sample/technique (e.g. using gaussian mixture modeling, Jenks natural breaks, or multiple step Otsu thresholding) but found that no solution worked perfectly for all samples.

# %% [markdown]
# This is regulated by the code below in qc_plots.py:
# ```
# min_otsu_frags_dict = {}
# for fragments_file in fragments_list:
#     sample = fragments_file.split("/")[-1].split(".")[0]
#     tech = sample.split('_')[1]
#     if tech == "ddseq":
#         if sample == "BIO_ddseq_1":
#             min_otsu_frags_dict[sample] = 600
#         else:
#             min_otsu_frags_dict[sample] = 300
#     elif tech == "hydrop":
#         min_otsu_frags_dict[sample] = 300
#     else:
#         min_otsu_frags_dict[sample] = 100
# ```

# %%
# !cat ../0_resources/scripts/qc_plots.py
# Out:
# import kde
# import pycisTopic
# import glob
# import os
# import pandas as pd
# import pickle
# import matplotlib.pyplot as plt
# import numpy as np
# import seaborn as sns
# import multiprocess as mp
# from multiprocess import Pool
# import pprint as pp
#
# def histogram(array, nbins=100):
#     """
#     Draw histogram from distribution and identify centers.
#     Parameters
#     ---------
#     array: `class::np.array`
#             Scores distribution
#     nbins: int
#             Number of bins to use in the histogram
#     Return
#     ---------
#     float
#             Histogram values and bin centers.
#     """
#     array = array.ravel().flatten()
#     hist, bin_edges = np.histogram(array, bins=nbins, range=None)
#     bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2.0
#     return hist, bin_centers
#
#
# def threshold_otsu(array, nbins=100, min_value=100):
#     """
#     Apply Otsu threshold on topic-region distributions [Otsu, 1979].
#     Parameters
#     ---------
#     array: `class::np.array`
#             Array containing the region values for the topic to be binarized.
#     nbins: int
#             Number of bins to use in the binarization histogram
#     Return
#     ---------
#     float
#             Binarization threshold.
#     Reference
#     ---------
#     Otsu, N., 1979. A threshold selection method from gray-level histograms. IEEE transactions on systems, man, and
#     cybernetics, 9(1), pp.62-66.
#     """
#     array = array[(array >= min_value)]
#     hist, bin_centers = histogram(array, nbins)
#     hist = hist.astype(float)
#     # Class probabilities for all possible thresholds
#     weight1 = np.cumsum(hist)
#     weight2 = np.cumsum(hist[::-1])[::-1]
#     # Class means for all possible thresholds
#     mean1 = np.cumsum(hist * bin_centers) / weight1
#     mean2 = (np.cumsum((hist * bin_centers)[::-1]) / weight2[::-1])[::-1]
#     # Clip ends to align class 1 and class 2 variables:
#     # The last value of ``weight1``/``mean1`` should pair with zero values in
#     # ``weight2``/``mean2``, which do not exist.
#     variance12 = weight1[:-1] * weight2[1:] * (mean1[:-1] - mean2[1:]) ** 2
#     idx = np.argmax(variance12)
#     threshold = bin_centers[:-1][idx]
#     return threshold
#
#
# # def calc_kde(xy):
# #     return gaussian_kde(xy)(xy)
#
#
# def plot_frag_qc(
#     x,
#     y,
#     ax,
#     x_thr_min=None,
#     x_thr_max=None,
#     y_thr_min=None,
#     y_thr_max=None,
#     ylab=None,
#     xlab="Number of (unique) fragments",
#     cmap="viridis",
#     density_overlay=False,
#     s=10,
#     marker="+",
#     c="#343434",
#     xlim=None,
#     ylim=None,
#     **kwargs
# ):
#     from scipy.stats import gaussian_kde
#
#     assert all(x.index == y.index)
#     barcodes = x.index.values
#
#     if density_overlay:
#         cores = 8
#
#         x_log = np.log(x)
#
#         # Split input array for KDE [log(x), y] array in
#         # equaly spaced parts (start_offset + n * nbr_cores).
#         kde_parts = [np.vstack([x_log[i::cores], y[i::cores]]) for i in range(cores)]
#
#         # Get nultiprocess context object to spawn processes.
#         # mp_ctx = mp.get_context("spawn")
#
#         # Calculate KDE in parallel.
#         with Pool(processes=cores) as pool:
#             results = pool.map(kde.calc_kde, kde_parts)
#
#         z = np.concatenate(results)
#
#         # now order x and y in the same way that z was ordered, otherwise random z value is assigned to barcode:
#         x_ordered = np.concatenate([x[i::cores] for i in range(cores)])
#         y_ordered = np.concatenate([y[i::cores] for i in range(cores)])
#
#         idx = (
#             z.argsort()
#         )  # order based on z value so that highest value is plotted on top, and not hidden by lower values
#         x, y, z, barcodes = x_ordered[idx], y_ordered[idx], z[idx], barcodes[idx]
#     else:
#         z = c
#
#     sp = ax.scatter(x, y, c=z, s=s, edgecolors=None, marker=marker, cmap=cmap, **kwargs)
#     if ylim is not None:
#         ax.set_ylim(ylim[0], ylim[1])
#     if xlim is not None:
#         ax.set_xlim(xlim[0], xlim[1])
#
#     # Start with keeping all barcodes.
#     barcodes_to_keep = np.full(x.shape[0], True)
#
#     # Filter barcodes out if needed based on thresholds:
#     if x_thr_min is not None:
#         ax.axvline(x=x_thr_min, color="r", linestyle="--")
#
#     if x_thr_max is not None:
#         ax.axvline(x=x_thr_max, color="r", linestyle="--")
#
#     if y_thr_min is not None:
#         ax.axhline(y=y_thr_min, color="r", linestyle="--")
#
#     if y_thr_max is not None:
#         ax.axhline(y=y_thr_max, color="r", linestyle="--")
#
#     ax.set_xscale("log")
#     ax.set_xmargin(0.01)
#     ax.set_ymargin(0.01)
#     ax.set_xlabel(xlab, fontsize=10)
#     ax.set_ylabel(ylab, fontsize=10)
#
# def plot_qc(
#     sample,
#     min_dict,
#     max_dict,
#     metadata_bc_df,
#     include_kde=False,
#     detailed_title=True,
#     s=4,
#     min_x_val=100,
#     min_y_val=1
# ):
#     fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4), dpi=150)
#
#     # calculate thresholds using a double otsu strategy:
#     # first we calculate an otsu threshold using a minimum of 10 fragments
#     # then, this otsu threshold is used as the minimum for the second iteration
#
#     x_arr = np.log10(metadata_bc_df["Unique_nr_frag"])
#     x_threshold_log = threshold_otsu(x_arr, nbins=5000, min_value=np.log10(min_x_val))
#     x_threshold = 10**x_threshold_log
#
#     y_arr = metadata_bc_df["TSS_enrichment"]
#     y_threshold = threshold_otsu(y_arr, nbins=5000, min_value=min_y_val)
#
#     # calculate cells passing filter
#     metadata_bc_df_passing_filters = metadata_bc_df.loc[
#         (metadata_bc_df.Unique_nr_frag > x_threshold)
#         & (metadata_bc_df.TSS_enrichment > y_threshold)
#     ]
#     bc_passing_filters = metadata_bc_df_passing_filters.index
#
#     # plot everything
#     plot_frag_qc(
#         x=metadata_bc_df["Unique_nr_frag"],
#         y=metadata_bc_df["TSS_enrichment"],
#         ylab="TSS Enrichment",
#         s=s,
#         x_thr_min=x_threshold,
#         y_thr_min=y_threshold,
#         xlim=[10, max_dict["Unique_nr_frag"]],
#         ylim=[0, max_dict["TSS_enrichment"]],
#         density_overlay=include_kde,
#         ax=ax1,
#     )
#     plot_frag_qc(
#         x=metadata_bc_df["Unique_nr_frag"],
#         y=metadata_bc_df["FRIP"],
#         x_thr_min=x_threshold,
#         ylab="FRIP",
#         s=s,
#         xlim=[10, max_dict["Unique_nr_frag"]],
#         ylim=[0, 1],
#         density_overlay=include_kde,
#         ax=ax2,
#     )
#     plot_frag_qc(
#         x=metadata_bc_df["Unique_nr_frag"],
#         y=metadata_bc_df["Dupl_rate"],
#         x_thr_min=x_threshold,
#         ylab="Duplicate rate per cell",
#         s=s,
#         xlim=[10, max_dict["Unique_nr_frag"]],
#         ylim=[0, 1],
#         density_overlay=include_kde,
#         ax=ax3,
#     )
#
#     if detailed_title:
#         med_nf = round(
#             metadata_bc_df.loc[bc_passing_filters, "Unique_nr_frag"].median(), 2
#         )
#         med_tss = round(
#             metadata_bc_df.loc[bc_passing_filters, "TSS_enrichment"].median(), 2
#         )
#         med_frip = round(metadata_bc_df.loc[bc_passing_filters, "FRIP"].median(), 2)
#         title = f"{sample}: Kept {len(bc_passing_filters)} cells using Otsu filtering. Median Unique Fragments: {med_nf:.0f}. Median TSS Enrichment: {med_tss:.2f}. Median FRIP: {med_frip:.2f}\nUsed a minimum of {x_threshold:.2f} fragments and TSS enrichment of {y_threshold:.2f})"
#     else:
#         title = sample
#
#     fig.suptitle(title, x=0.5, y=0.95, fontsize=10)
#     return bc_passing_filters, fig
#
#
# ###################
# # Run the loop here
# ###################
#
# metadata_bc_pkl_list = sorted(glob.glob("cistopic_qc_out/*metadata_bc.pkl"))
# metadata_bc_pkl_path_dict = {}
# for metadata_bc_pkl_path in metadata_bc_pkl_list:
#     sample = metadata_bc_pkl_path.split("/")[-1].split("__metadata_bc.pkl")[0]
#     metadata_bc_pkl_path_dict[sample] = metadata_bc_pkl_path
#
# # calculate global maxima to make nice equal plots:
# metadata_bc_df_all = pd.DataFrame()
# for sample in metadata_bc_pkl_path_dict.keys():
#     with open(metadata_bc_pkl_path_dict[sample], "rb") as fh:
#         metadata_bc_df = pickle.load(fh)
#         metadata_bc_df_all = pd.concat([metadata_bc_df_all, metadata_bc_df])
#         print(f"added {sample} metadata_bc_df")
#
# max_dict = {}
# min_dict = {}
# for stat in metadata_bc_df_all.columns:
#     max_dict[stat] = metadata_bc_df_all[stat].max()
#     min_dict[stat] = metadata_bc_df_all[stat].min()
#
# pp.pprint(min_dict)
# pp.pprint(max_dict)
#
# standard_min_x_val = 100
# standard_min_y_val = 1
# min_otsu_frags_dict = {}
# min_otsu_tss_dict = {}
# for metadata_bc_pkl_path in sorted(metadata_bc_pkl_path_dict.keys()):
#     sample = metadata_bc_pkl_path.split("/")[-1].split("__metadata_bc.pkl")[0]
#     tech = sample.split('_')[1]
#     if tech == "ddseq":
#         if "BIO_ddseq_1.FULL" in sample:
#             min_otsu_frags_dict[sample] = 600
#         else:
#             min_otsu_frags_dict[sample] = 300
#     elif tech == "hydrop":
#         min_otsu_frags_dict[sample] = 300
#     else:
#         min_otsu_frags_dict[sample] = standard_min_x_val
#
#     if tech == "s3atac":
#         min_otsu_tss_dict[sample] = 0
#     else:
#         min_otsu_tss_dict[sample] = standard_min_y_val
#
# pp.pprint(min_otsu_frags_dict)
#
# for sample in metadata_bc_pkl_path_dict.keys():
#     pkl_path = f"selected_barcodes/{sample}_bc_passing_filters_otsu.pkl"
#     if os.path.exists(pkl_path):
#         print(f"{pkl_path} bc passing filters exists, skipping...")
#     else:
#         print(f"{pkl_path} bc passing filters does not exist yet, generating...")
#         print(f"\tLoading {metadata_bc_pkl_path_dict[sample]}")
#         with open(metadata_bc_pkl_path_dict[sample], "rb") as fh:
#             metadata_bc_df = pickle.load(fh)
#
#         print(f"\tFiltering cells and generating QC plots.")
#         if not sample in min_otsu_frags_dict.keys():
#             print(f"\t{sample} not in minimum dict! Using standard value of {standard_min_x_val}")
#             min_x_val = standard_min_x_val
#             min_y_val = standard_min_y_val
#         else:
#             min_x_val = min_otsu_frags_dict[sample]
#             min_y_val = min_otsu_tss_dict[sample]
#
#         bc_passing_filters, fig = plot_qc(sample=sample, min_dict=min_dict, max_dict=max_dict, metadata_bc_df=metadata_bc_df, include_kde=kde, min_x_val=min_x_val, min_y_val=min_y_val)
#
#         plt.tight_layout()
#         plt.savefig(f"plots_qc/{sample}_qc_otsu.png", dpi=300, facecolor="white")
#         plt.show()
#         plt.close()
#
#         print(f"\tSaving...")
#         with open(
#             f"selected_barcodes/{sample}_bc_passing_filters_otsu.pkl", "wb"
#         ) as fh:
#             pickle.dump(bc_passing_filters, fh)
#         fh.close()
#
#         fh = open(f"selected_barcodes/{sample}_bc_passing_filters_otsu.txt", "w")
#         for bc in list(bc_passing_filters):
#             fh.write(bc + "\n")
#         fh.close()
#
#         metadata_bc_df.loc[bc_passing_filters].to_csv(f'selected_barcodes/{sample}_metadata_bc_df.tsv', sep='\t')

# %% [markdown]
# Since multiprocessing does not work with jupyter notebooks, run the following code in terminal:

# %% [markdown]
# ```
# mkdir plots_qc
# mkdir selected_barcodes
# SIF=../0_resources/cistopic_image/20220722_pycistopic.sif
# singularity exec \
#     --cleanenv \
#     -H $PWD:/home \
#     $SIF \
#     python ../0_resources/scripts/qc_plots.py
# ```

# %% [markdown]
# And then open the plots:

# %%
metadata_bc_pkl_list = sorted(glob.glob("cistopic_qc_out/*metadata_bc.pkl"))
metadata_bc_pkl_path_dict = {}
for metadata_bc_pkl_path in metadata_bc_pkl_list:
    sample = metadata_bc_pkl_path.split("/")[-1].split("__")[0]
    metadata_bc_pkl_path_dict[sample] = metadata_bc_pkl_path

for sample in metadata_bc_pkl_path_dict.keys():
    if os.path.exists(f"selected_barcodes/{sample}_bc_passing_filters_otsu.pkl"):
        print(f"{sample} bc passing filters exists, printing img and skipping")
        display(Image(f"plots_qc/{sample}_qc_otsu.png"))
    else:
        print(
            f"{sample} bc passing filters does not exist yet, generate using qc_plots.py script!"
        )

# %% [markdown]
# # Write raw barcode file

# %% [markdown]
# Freemuxlet reads barcodes in the bam file. These barcodes (tag: DB) do not contain the `sample` suffix, which is included in the `*_bc_passing_filters_otsu.txt` files:

# %%
# !head selected_barcodes/BIO_ddseq_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# Out:
# AAGGTTCTTTCCTAAGAGACC_CCGCGATCACGCCAATTATTC_CTGCGCCTGTTTAGATTGCCT___BIO_ddseq_1.FULL
# GAGAGGTGACAATATGGTGAA___BIO_ddseq_1.FULL
# CGATTACGCTCCAAGAGCTAA_CTAGAGCACACGCGTACTTTC_GGCGTCCTAACGCCCGTAGCC___BIO_ddseq_1.FULL
# CTAGAGCGGTTAGTGTGGCGC_GCTTTATTTGGACTCGAGGTC_GTTGATGTCATACAGTGGTAG___BIO_ddseq_1.FULL
# CGCGCTTTCTTGTAAGCCGCC_CTTGTCCCGTGATATGATTGT___BIO_ddseq_1.FULL
# AGCCGCCGCACAGCCCATAAT_CGAGTGGTGGTGAATAGTGTT_GAATCAACGAGTGGCAGGCGG___BIO_ddseq_1.FULL
# CACATGATGCGAGCCTCATTT_CAGAGAGTGGTGAAACCTACC_GAATATGTGACCGCTGGTGAA_TCAAGACCGGATCTATTGCCT___BIO_ddseq_1.FULL
# CGAGTGGGAGGACAAGATAGG_CGTGATAATGAATATGCGAGC_TCAAGACGTGTGTCAACTCTT___BIO_ddseq_1.FULL
# CTCTTGCTGCGTTGCGGCTGC_TCGACAGCGGTACGAACGTAA___BIO_ddseq_1.FULL
# CCACTTGCACATGACTAACTC_TATGTGCACGAGAACCAAGCT___BIO_ddseq_1.FULL

# %%
for file in glob.glob("selected_barcodes/*_bc_passing_filters_otsu.txt"):
    print(file)
    sample = file.split("/")[-1].split("_bc_passing_filters_otsu.txt")[0]
    print(sample)
    df = pd.read_csv(file, header=None, index_col=None)

    with open(f"selected_barcodes/{sample}_bc_passing_filters_otsu.RAW.txt", "w") as fp:
        for x in df[0]:
            # write each item on a new line
            fp.write(x.split("___")[0] + "\n")
        print("Done")
# Out:
# selected_barcodes/MDC_mtscatac_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# MDC_mtscatac_1.FIXEDCELLS
# Done
# selected_barcodes/STA_10xv11_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# STA_10xv11_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv11_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv11_1.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xmultiome_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xmultiome_1.FIXEDCELLS
# Done
# selected_barcodes/SAN_10xmultiome_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# SAN_10xmultiome_1.FIXEDCELLS
# Done
# selected_barcodes/VIB_10xmultiome_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_10xmultiome_2.FIXEDCELLS
# Done
# selected_barcodes/STA_10xv11_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# STA_10xv11_1.FIXEDCELLS
# Done
# selected_barcodes/VIB_hydrop_11.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_hydrop_11.FIXEDCELLS
# Done
# selected_barcodes/MDC_mtscatac_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# MDC_mtscatac_2.FIXEDCELLS
# Done
# selected_barcodes/EPF_hydrop_3.FIXEDCELLS_bc_passing_filters_otsu.txt
# EPF_hydrop_3.FIXEDCELLS
# Done
# selected_barcodes/BIO_ddseq_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# BIO_ddseq_2.FIXEDCELLS
# Done
# selected_barcodes/OHS_s3atac_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# OHS_s3atac_1.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv11_3.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv11_3.FIXEDCELLS
# Done
# selected_barcodes/CNA_mtscatac_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_mtscatac_1.FIXEDCELLS
# Done
# selected_barcodes/OHS_s3atac_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# OHS_s3atac_2.FIXEDCELLS
# Done
# selected_barcodes/VIB_10xv2_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_10xv2_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xmultiome_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xmultiome_2.FIXEDCELLS
# Done
# selected_barcodes/VIB_10xv2_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_10xv2_1.FIXEDCELLS
# Done
# selected_barcodes/TXG_10xv2_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# TXG_10xv2_1.FIXEDCELLS
# Done
# selected_barcodes/HAR_ddseq_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# HAR_ddseq_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv11_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv11_2.FIXEDCELLS
# Done
# selected_barcodes/TXG_10xv2_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# TXG_10xv2_2.FIXEDCELLS
# Done
# selected_barcodes/VIB_hydrop_12.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_hydrop_12.FIXEDCELLS
# Done
# selected_barcodes/CNA_ddseq_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_ddseq_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv11_4.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv11_4.FIXEDCELLS
# Done
# selected_barcodes/VIB_10xv1_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_10xv1_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_mtscatac_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_mtscatac_2.FIXEDCELLS
# Done
# selected_barcodes/BIO_ddseq_4.FIXEDCELLS_bc_passing_filters_otsu.txt
# BIO_ddseq_4.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv2_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv2_1.FIXEDCELLS
# Done
# selected_barcodes/SAN_10xmultiome_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# SAN_10xmultiome_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_ddseq_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_ddseq_1.FIXEDCELLS
# Done
# selected_barcodes/VIB_mtscatac_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_mtscatac_2.FIXEDCELLS
# Done
# selected_barcodes/VIB_mtscatac_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_mtscatac_1.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv2_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv2_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_hydrop_3.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_hydrop_3.FIXEDCELLS
# Done
# selected_barcodes/BIO_ddseq_3.FIXEDCELLS_bc_passing_filters_otsu.txt
# BIO_ddseq_3.FIXEDCELLS
# Done
# selected_barcodes/BRO_mtscatac_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# BRO_mtscatac_1.FIXEDCELLS
# Done
# selected_barcodes/EPF_hydrop_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# EPF_hydrop_1.FIXEDCELLS
# Done
# selected_barcodes/CNA_hydrop_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_hydrop_1.FIXEDCELLS
# Done
# selected_barcodes/EPF_hydrop_4.FIXEDCELLS_bc_passing_filters_otsu.txt
# EPF_hydrop_4.FIXEDCELLS
# Done
# selected_barcodes/CNA_hydrop_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_hydrop_2.FIXEDCELLS
# Done
# selected_barcodes/CNA_10xv11_5.FIXEDCELLS_bc_passing_filters_otsu.txt
# CNA_10xv11_5.FIXEDCELLS
# Done
# selected_barcodes/VIB_10xmultiome_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_10xmultiome_1.FIXEDCELLS
# Done
# selected_barcodes/TXG_10xv11_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# TXG_10xv11_1.FIXEDCELLS
# Done
# selected_barcodes/EPF_hydrop_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# EPF_hydrop_2.FIXEDCELLS
# Done
# selected_barcodes/HAR_ddseq_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# HAR_ddseq_1.FIXEDCELLS
# Done
# selected_barcodes/BRO_mtscatac_2.FIXEDCELLS_bc_passing_filters_otsu.txt
# BRO_mtscatac_2.FIXEDCELLS
# Done
# selected_barcodes/VIB_hydrop_22.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_hydrop_22.FIXEDCELLS
# Done
# selected_barcodes/VIB_10xv1_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_10xv1_1.FIXEDCELLS
# Done
# selected_barcodes/BIO_ddseq_1.FIXEDCELLS_bc_passing_filters_otsu.txt
# BIO_ddseq_1.FIXEDCELLS
# Done
# selected_barcodes/VIB_hydrop_21.FIXEDCELLS_bc_passing_filters_otsu.txt
# VIB_hydrop_21.FIXEDCELLS
# Done

# %%
# !head selected_barcodes/BIO_ddseq_1.FIXEDCELLS_bc_passing_filters_otsu.RAW.txt
# Out:
# AAGGTTCTTTCCTAAGAGACC_CCGCGATCACGCCAATTATTC_CTGCGCCTGTTTAGATTGCCT
# GAGAGGTGACAATATGGTGAA
# CGATTACGCTCCAAGAGCTAA_CTAGAGCACACGCGTACTTTC_GGCGTCCTAACGCCCGTAGCC
# CTAGAGCGGTTAGTGTGGCGC_GCTTTATTTGGACTCGAGGTC_GTTGATGTCATACAGTGGTAG
# CGCGCTTTCTTGTAAGCCGCC_CTTGTCCCGTGATATGATTGT
# AGCCGCCGCACAGCCCATAAT_CGAGTGGTGGTGAATAGTGTT_GAATCAACGAGTGGCAGGCGG
# CACATGATGCGAGCCTCATTT_CAGAGAGTGGTGAAACCTACC_GAATATGTGACCGCTGGTGAA_TCAAGACCGGATCTATTGCCT
# CGAGTGGGAGGACAAGATAGG_CGTGATAATGAATATGCGAGC_TCAAGACGTGTGTCAACTCTT
# CTCTTGCTGCGTTGCGGCTGC_TCGACAGCGGTACGAACGTAA
# CCACTTGCACATGACTAACTC_TATGTGCACGAGAACCAAGCT
