# %% [markdown]
# # Generate the main reference (R):

# %%
# RNA-ATAC integration
################################################################################
# https://satijalab.org/seurat/articles/atacseq_integration_vignette.html

library(Seurat)
library(SeuratDisk)
library(Signac)
library(EnsDb.Hsapiens.v86)
library(ggplot2)

################################################################################
################################################################################
# reference data:
################################################################################

f_ref = '/lustre1/project/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/scRNA/cell_type_classification/seurat/reference/pbmc_ssc_mat.rds'
f_meta = '/lustre1/project/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/scRNA/cell_type_classification/seurat/reference/pbmc_ssc_metadata.rds'

pbmc.data <- readRDS(f_ref)
pbmc.metadata <- readRDS(f_meta)

pbmc <- CreateSeuratObject(counts = pbmc.data, meta.data = pbmc.metadata)
pbmc <- subset(pbmc, subset = nFeature_RNA > 200)

pbmc.list <- SplitObject(pbmc, split.by = "Method")
#pbmc.list$bench = qdata

for (i in names(pbmc.list)) {
    pbmc.list[[i]] = NormalizeData(pbmc.list[[i]])
    pbmc.list[[i]] = FindVariableFeatures(pbmc.list[[i]], selection.method = "vst", nfeatures = 2000, verbose = FALSE)
    pbmc.list[[i]] = ScaleData(pbmc.list[[i]])
    pbmc.list[[i]] = RunPCA(pbmc.list[[i]])
    pbmc.list[[i]] = RunUMAP(pbmc.list[[i]], dims = 1:30)
}

##################################################
### integrate reference:

reference.list <- pbmc.list[
    c("10x Chromium (v2) A", "10x Chromium (v2) B", "10x Chromium (v3)", "10x Chromium (v2)")
]
#reference.list$query = qdata
#pbmc.ref = pbmc.list$`10x Chromium (v3)`
pbmc.anchors <- FindIntegrationAnchors(object.list = reference.list, dims = 1:30)

pbmc.integrated <- IntegrateData(anchorset = pbmc.anchors, dims = 1:30)
DefaultAssay(pbmc.integrated) <- "integrated"

pbmc.integrated <- ScaleData(pbmc.integrated, verbose = FALSE)
pbmc.integrated <- RunPCA(pbmc.integrated, npcs = 30, verbose = FALSE)
pbmc.integrated <- RunUMAP(pbmc.integrated, reduction = "pca", dims = 1:30, verbose = FALSE)

##################################################

pbmc.rna = pbmc.list$`10x Chromium (v3)`

saveRDS(pbmc.rna, file='pbmc_RNA_reference_10xv3.rds')

# pbmc.rna <- NormalizeData(pbmc.rna)
# pbmc.rna <- FindVariableFeatures(pbmc.rna)
# pbmc.rna <- ScaleData(pbmc.rna)
# pbmc.rna <- RunPCA(pbmc.rna)
# pbmc.rna <- RunUMAP(pbmc.rna, dims = 1:30)

# %% [markdown]
# Remove megakaryocytes manually

# %%
# RNA-ATAC integration
################################################################################
# https://satijalab.org/seurat/articles/atacseq_integration_vignette.html

library(Seurat)
library(SeuratDisk)
library(Signac)
library(EnsDb.Hsapiens.v86)
library(ggplot2)


################################################################################
# reference data:
################################################################################

f_ref = '../0_resources/seurat_references/pbmc_ssc_mat.rds'
f_meta = '../0_resources/seurat_references/pbmc_ssc_metadata.rds'


pbmc.data <- readRDS(f_ref)
pbmc.metadata <- readRDS(f_meta)

pbmc <- CreateSeuratObject(counts = pbmc.data, meta.data = pbmc.metadata)
pbmc <- subset(pbmc, subset = nFeature_RNA > 200)

pbmc.list <- SplitObject(pbmc, split.by = "Method")
#pbmc.list$bench = qdata

for (i in names(pbmc.list)) {
    pbmc.list[[i]] = NormalizeData(pbmc.list[[i]])
    pbmc.list[[i]] = FindVariableFeatures(pbmc.list[[i]], selection.method = "vst", nfeatures = 2000, verbose = FALSE)
    pbmc.list[[i]] = ScaleData(pbmc.list[[i]])
    pbmc.list[[i]] = RunPCA(pbmc.list[[i]])
    pbmc.list[[i]] = RunUMAP(pbmc.list[[i]], dims = 1:30)
}

##################################################
### integrate reference:

reference.list <- pbmc.list[
    c("10x Chromium (v2) A", "10x Chromium (v2) B", "10x Chromium (v3)", "10x Chromium (v2)")
]
#reference.list$query = qdata
#pbmc.ref = pbmc.list$`10x Chromium (v3)`
pbmc.anchors <- FindIntegrationAnchors(object.list = reference.list, dims = 1:30)

pbmc.integrated <- IntegrateData(anchorset = pbmc.anchors, dims = 1:30)
DefaultAssay(pbmc.integrated) <- "integrated"

pbmc.integrated <- ScaleData(pbmc.integrated, verbose = FALSE)
pbmc.integrated <- RunPCA(pbmc.integrated, npcs = 30, verbose = FALSE)
pbmc.integrated <- RunUMAP(pbmc.integrated, reduction = "pca", dims = 1:30, verbose = FALSE)

##################################################

# pbmc.rna = pbmc.list$`10x Chromium (v3)`

pbmc.rna = readRDS('../0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')

# pbmc.rna <- NormalizeData(pbmc.rna)
# pbmc.rna <- FindVariableFeatures(pbmc.rna)
# pbmc.rna <- ScaleData(pbmc.rna)
# pbmc.rna <- RunPCA(pbmc.rna)
# pbmc.rna <- RunUMAP(pbmc.rna, dims = 1:30)

saveRDS(pbmc, file="../0_resources/seurat_references/pbmc_ref.rds")


# ATAC analysis add gene annotation information
annotations <- GetGRangesFromEnsDb(ensdb = EnsDb.Hsapiens.v86)

# use chr prefix:
ucsc.levels <- str_replace(string=paste("chr",seqlevels(annotations),sep=""), pattern="chrMT", replacement="chrM")
seqlevels(annotations) <- ucsc.levels

genome(annotations) <- "hg38"
saveRDS(annotations, file="../0_resources/seurat_references/granges_annotation.rds")

# %% [markdown]
# # Then, invoke the following R script

# %%
# !cat ../0_resources/scripts/seurat_label_transfer.R
# Out:
# #!/usr/bin/env Rscript
# library(Seurat)
# library(SeuratDisk)
# library(Signac)
# library(EnsDb.Hsapiens.v86)
# library(ggplot2)
# library(stringr)
#
# args = commandArgs(trailingOnly=TRUE)
# sample_id = args[1]
# f_loom = args[2]
# f_frag = args[3]
# f_reference = args[4]
# f_annotation = args[5]
# f_out = args[6]
#
# print(paste0("Processing sample ", args[1]))
#
# # load pbmc object
# # pbmc.integrated <- readRDS("../0_resources/seurat_references/pbmc_integrated.RDS")
# pbmc.rna <- readRDS('../0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')
#
# ################################################################################
# # ATAC
# ################################################################################
#
# ### get data from loom:
# atacloomcon <- Connect(filename = f_loom, mode = "r")
# atacloomcon
# atac_tmp <- as.Seurat(atacloomcon, assay='ATAC')
# atacloomcon$close_all()
#
# # correctly parse regions (default delims are '-','-')
# regions = StringToGRanges(
#     rownames(GetAssayData(atac_tmp, slot = "counts", assay='ATAC')),
#     sep=c(':','-')
#     )
#
# # create chromatin assay
# chromatinassay = CreateChromatinAssay(
#     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
#     # genome='hg38',
#     fragments = f_frag,
#     ranges=regions
#     )
#     #annotation=annotation)
#
# atac <- CreateSeuratObject(counts = chromatinassay, assay='ATAC')
#
# annotations <- readRDS(f_annotation)
# Annotation(atac) <- annotations
#
# # We exclude the first dimension as this is typically correlated with sequencing depth
# atac <- RunTFIDF(atac)
# atac <- FindTopFeatures(atac, min.cutoff = "q0")
# atac <- RunSVD(atac)
# atac <- RunUMAP(atac, reduction = "lsi", dims = 2:30, reduction.name = "umap.atac", reduction.key = "atacUMAP_")
#
# ##################################################
# # Identify RNA-ATAC anchors
#
# # quantify gene activity
# gene.activities <- GeneActivity(atac, features = VariableFeatures(pbmc.rna))
# # gene.activities <- gene.activities[rownames(gene.activities)!="",]
#
# # add gene activities as a new assay
# atac[["ACTIVITY"]] <- CreateAssayObject(counts = gene.activities)
#
# # normalize gene activities
# DefaultAssay(atac) <- "ACTIVITY"
# atac <- NormalizeData(atac)
# atac <- ScaleData(atac, features = rownames(atac))
#
# # Identify anchors
# transfer.anchors <- FindTransferAnchors(reference = pbmc.rna,
#     query = atac,
#     features = VariableFeatures(object = pbmc.rna),
#     reference.assay = "RNA",
#     query.assay = "ACTIVITY",
#     reduction = "cca")
#
# # predict celltype
# celltype.predictions <- TransferData(
#     anchorset = transfer.anchors,
#     refdata = pbmc.rna$CellType,
#     weight.reduction = atac[["lsi"]],
#     dims = 2:30)
#
# pbmc.atac <- AddMetaData(atac, metadata = celltype.predictions)
#
# md = celltype.predictions
# pred_thr = 0.7
#
# tmp = data.frame(
#       composite_sample_id = paste0(rownames(md),'-',sample_id),
#       barcode = rownames(md),
#       sample_id = sample_id,
#       cell_type = md$predicted.id,
#       cell_type_pred_score = md$prediction.score.max
#       )
#
# tmp$cell_type_hiconf_70 = tmp$cell_type
# tmp$cell_type_hiconf_70[tmp$cell_type_pred_score<pred_thr] = 'Unknown'
#
# table(tmp$cell_type)
# table(tmp$cell_type_hiconf_70)
#
# write.table(tmp, file=f_out, sep='\t', row.names=FALSE, quote=FALSE)
# print(paste0('Wrote file ', f_out))

# %% [markdown]
# # Python

# %%
# !cat /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/0_resources/scripts/seurat_label_transfer.R
# Out:
# #!/usr/bin/env Rscript
# library(Seurat)
# library(SeuratDisk)
# library(Signac)
# library(EnsDb.Hsapiens.v86)
# library(ggplot2)
# library(stringr)
#
# args = commandArgs(trailingOnly=TRUE)
# sample_id = args[1]
# f_loom = args[2]
# f_frag = args[3]
# f_reference = args[4]
# f_annotation = args[5]
# f_out = args[6]
#
# print(paste0("Processing sample ", args[1]))
#
# # load pbmc object
# # pbmc.integrated <- readRDS("../0_resources/seurat_references/pbmc_integrated.RDS")
# pbmc.rna <- readRDS('../0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')
#
# ################################################################################
# # ATAC
# ################################################################################
#
# ### get data from loom:
# atacloomcon <- Connect(filename = f_loom, mode = "r")
# atacloomcon
# atac_tmp <- as.Seurat(atacloomcon, assay='ATAC')
# atacloomcon$close_all()
#
# # correctly parse regions (default delims are '-','-')
# regions = StringToGRanges(
#     rownames(GetAssayData(atac_tmp, slot = "counts", assay='ATAC')),
#     sep=c(':','-')
#     )
#
# # create chromatin assay
# chromatinassay = CreateChromatinAssay(
#     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
#     # genome='hg38',
#     fragments = f_frag,
#     ranges=regions
#     )
#     #annotation=annotation)
#
# atac <- CreateSeuratObject(counts = chromatinassay, assay='ATAC')
#
# annotations <- readRDS(f_annotation)
# Annotation(atac) <- annotations
#
# # We exclude the first dimension as this is typically correlated with sequencing depth
# atac <- RunTFIDF(atac)
# atac <- FindTopFeatures(atac, min.cutoff = "q0")
# atac <- RunSVD(atac)
# atac <- RunUMAP(atac, reduction = "lsi", dims = 2:30, reduction.name = "umap.atac", reduction.key = "atacUMAP_")
#
# ##################################################
# # Identify RNA-ATAC anchors
#
# # quantify gene activity
# gene.activities <- GeneActivity(atac, features = VariableFeatures(pbmc.rna))
# # gene.activities <- gene.activities[rownames(gene.activities)!="",]
#
# # add gene activities as a new assay
# atac[["ACTIVITY"]] <- CreateAssayObject(counts = gene.activities)
#
# # normalize gene activities
# DefaultAssay(atac) <- "ACTIVITY"
# atac <- NormalizeData(atac)
# atac <- ScaleData(atac, features = rownames(atac))
#
# # Identify anchors
# transfer.anchors <- FindTransferAnchors(reference = pbmc.rna,
#     query = atac,
#     features = VariableFeatures(object = pbmc.rna),
#     reference.assay = "RNA",
#     query.assay = "ACTIVITY",
#     reduction = "cca")
#
# # predict celltype
# celltype.predictions <- TransferData(
#     anchorset = transfer.anchors,
#     refdata = pbmc.rna$CellType,
#     weight.reduction = atac[["lsi"]],
#     dims = 2:30)
#
# pbmc.atac <- AddMetaData(atac, metadata = celltype.predictions)
#
# md = celltype.predictions
# pred_thr = 0.7
#
# tmp = data.frame(
#       composite_sample_id = paste0(rownames(md),'-',sample_id),
#       barcode = rownames(md),
#       sample_id = sample_id,
#       cell_type = md$predicted.id,
#       cell_type_pred_score = md$prediction.score.max
#       )
#
# tmp$cell_type_hiconf_70 = tmp$cell_type
# tmp$cell_type_hiconf_70[tmp$cell_type_pred_score<pred_thr] = 'Unknown'
#
# table(tmp$cell_type)
# table(tmp$cell_type_hiconf_70)
#
# write.table(tmp, file=f_out, sep='\t', row.names=FALSE, quote=FALSE)
# print(paste0('Wrote file ', f_out))

# %% [markdown]
# # Python

# %%
import glob
import os

# %%
# !pwd
# Out:
# /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/full_2_cistopic

# %%
scrub_name_suffix = "0-4"
frags_path_dict  = {x.split('/')[-1].split(f'.fragments.tsv.gz')[0]:x for x in sorted(glob.glob(f'../1_data_repository/full_fragments/*.fragments.tsv.gz'))}
frags_path_dict
# Out:
# {'BIO_ddseq_1.FULL': '../1_data_repository/full_fragments/BIO_ddseq_1.FULL.fragments.tsv.gz',
#  'BIO_ddseq_2.FULL': '../1_data_repository/full_fragments/BIO_ddseq_2.FULL.fragments.tsv.gz',
#  'BIO_ddseq_3.FULL': '../1_data_repository/full_fragments/BIO_ddseq_3.FULL.fragments.tsv.gz',
#  'BIO_ddseq_4.FULL': '../1_data_repository/full_fragments/BIO_ddseq_4.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_1.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_1.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_2.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_2.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_1.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_1.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_2.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_1.FULL': '../1_data_repository/full_fragments/CNA_10xv11_1.FULL.fragments.tsv.gz',
#  'CNA_10xv11_2.FULL': '../1_data_repository/full_fragments/CNA_10xv11_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_3.FULL': '../1_data_repository/full_fragments/CNA_10xv11_3.FULL.fragments.tsv.gz',
#  'CNA_10xv11_4.FULL': '../1_data_repository/full_fragments/CNA_10xv11_4.FULL.fragments.tsv.gz',
#  'CNA_10xv11_5.FULL': '../1_data_repository/full_fragments/CNA_10xv11_5.FULL.fragments.tsv.gz',
#  'CNA_10xv2_1.FULL': '../1_data_repository/full_fragments/CNA_10xv2_1.FULL.fragments.tsv.gz',
#  'CNA_10xv2_2.FULL': '../1_data_repository/full_fragments/CNA_10xv2_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_1.FULL': '../1_data_repository/full_fragments/CNA_hydrop_1.FULL.fragments.tsv.gz',
#  'CNA_hydrop_2.FULL': '../1_data_repository/full_fragments/CNA_hydrop_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_3.FULL': '../1_data_repository/full_fragments/CNA_hydrop_3.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_1.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_1.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_2.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_1.FULL': '../1_data_repository/full_fragments/EPF_hydrop_1.FULL.fragments.tsv.gz',
#  'EPF_hydrop_2.FULL': '../1_data_repository/full_fragments/EPF_hydrop_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_3.FULL': '../1_data_repository/full_fragments/EPF_hydrop_3.FULL.fragments.tsv.gz',
#  'EPF_hydrop_4.FULL': '../1_data_repository/full_fragments/EPF_hydrop_4.FULL.fragments.tsv.gz',
#  'HAR_ddseq_1.FULL': '../1_data_repository/full_fragments/HAR_ddseq_1.FULL.fragments.tsv.gz',
#  'HAR_ddseq_2.FULL': '../1_data_repository/full_fragments/HAR_ddseq_2.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_1.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_1.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_2.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_2.FULL.fragments.tsv.gz',
#  'OHS_s3atac_1.FULL': '../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz',
#  'OHS_s3atac_2.FULL': '../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_1.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_1.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_2.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_2.FULL.fragments.tsv.gz',
#  'STA_10xv11_1.FULL': '../1_data_repository/full_fragments/STA_10xv11_1.FULL.fragments.tsv.gz',
#  'STA_10xv11_2.FULL': '../1_data_repository/full_fragments/STA_10xv11_2.FULL.fragments.tsv.gz',
#  'TXG_10xv11_1.FULL': '../1_data_repository/full_fragments/TXG_10xv11_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_1.FULL': '../1_data_repository/full_fragments/TXG_10xv2_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_2.FULL': '../1_data_repository/full_fragments/TXG_10xv2_2.FULL.fragments.tsv.gz',
#  'UCS_ddseq_1.FULL': '../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz',
#  'UCS_ddseq_2.FULL': '../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_1.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_1.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_2.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_2.FULL.fragments.tsv.gz',
#  'VIB_10xv1_1.FULL': '../1_data_repository/full_fragments/VIB_10xv1_1.FULL.fragments.tsv.gz',
#  'VIB_10xv1_2.FULL': '../1_data_repository/full_fragments/VIB_10xv1_2.FULL.fragments.tsv.gz',
#  'VIB_10xv2_1.FULL': '../1_data_repository/full_fragments/VIB_10xv2_1.FULL.fragments.tsv.gz',
#  'VIB_10xv2_2.FULL': '../1_data_repository/full_fragments/VIB_10xv2_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_1.FULL': '../1_data_repository/full_fragments/VIB_hydrop_1.FULL.fragments.tsv.gz',
#  'VIB_hydrop_11.FULL': '../1_data_repository/full_fragments/VIB_hydrop_11.FULL.fragments.tsv.gz',
#  'VIB_hydrop_12.FULL': '../1_data_repository/full_fragments/VIB_hydrop_12.FULL.fragments.tsv.gz',
#  'VIB_hydrop_2.FULL': '../1_data_repository/full_fragments/VIB_hydrop_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_21.FULL': '../1_data_repository/full_fragments/VIB_hydrop_21.FULL.fragments.tsv.gz',
#  'VIB_hydrop_22.FULL': '../1_data_repository/full_fragments/VIB_hydrop_22.FULL.fragments.tsv.gz'}

# %%
scrub_name_suffix = "0-4"
frags_path_dict  = {x.split('/')[-1].split(f'.fragments.tsv.gz')[0] :x for x in sorted(glob.glob(f'../1_data_repository/full_fragments/*.fragments.tsv.gz'))}
frags_path_dict
# Out:
# {'BIO_ddseq_1.FULL': '../1_data_repository/full_fragments/BIO_ddseq_1.FULL.fragments.tsv.gz',
#  'BIO_ddseq_2.FULL': '../1_data_repository/full_fragments/BIO_ddseq_2.FULL.fragments.tsv.gz',
#  'BIO_ddseq_3.FULL': '../1_data_repository/full_fragments/BIO_ddseq_3.FULL.fragments.tsv.gz',
#  'BIO_ddseq_4.FULL': '../1_data_repository/full_fragments/BIO_ddseq_4.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_1.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_1.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_2.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_2.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_1.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_1.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_2.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_1.FULL': '../1_data_repository/full_fragments/CNA_10xv11_1.FULL.fragments.tsv.gz',
#  'CNA_10xv11_2.FULL': '../1_data_repository/full_fragments/CNA_10xv11_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_3.FULL': '../1_data_repository/full_fragments/CNA_10xv11_3.FULL.fragments.tsv.gz',
#  'CNA_10xv11_4.FULL': '../1_data_repository/full_fragments/CNA_10xv11_4.FULL.fragments.tsv.gz',
#  'CNA_10xv11_5.FULL': '../1_data_repository/full_fragments/CNA_10xv11_5.FULL.fragments.tsv.gz',
#  'CNA_10xv2_1.FULL': '../1_data_repository/full_fragments/CNA_10xv2_1.FULL.fragments.tsv.gz',
#  'CNA_10xv2_2.FULL': '../1_data_repository/full_fragments/CNA_10xv2_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_1.FULL': '../1_data_repository/full_fragments/CNA_hydrop_1.FULL.fragments.tsv.gz',
#  'CNA_hydrop_2.FULL': '../1_data_repository/full_fragments/CNA_hydrop_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_3.FULL': '../1_data_repository/full_fragments/CNA_hydrop_3.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_1.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_1.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_2.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_1.FULL': '../1_data_repository/full_fragments/EPF_hydrop_1.FULL.fragments.tsv.gz',
#  'EPF_hydrop_2.FULL': '../1_data_repository/full_fragments/EPF_hydrop_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_3.FULL': '../1_data_repository/full_fragments/EPF_hydrop_3.FULL.fragments.tsv.gz',
#  'EPF_hydrop_4.FULL': '../1_data_repository/full_fragments/EPF_hydrop_4.FULL.fragments.tsv.gz',
#  'HAR_ddseq_1.FULL': '../1_data_repository/full_fragments/HAR_ddseq_1.FULL.fragments.tsv.gz',
#  'HAR_ddseq_2.FULL': '../1_data_repository/full_fragments/HAR_ddseq_2.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_1.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_1.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_2.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_2.FULL.fragments.tsv.gz',
#  'OHS_s3atac_1.FULL': '../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz',
#  'OHS_s3atac_2.FULL': '../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_1.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_1.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_2.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_2.FULL.fragments.tsv.gz',
#  'STA_10xv11_1.FULL': '../1_data_repository/full_fragments/STA_10xv11_1.FULL.fragments.tsv.gz',
#  'STA_10xv11_2.FULL': '../1_data_repository/full_fragments/STA_10xv11_2.FULL.fragments.tsv.gz',
#  'TXG_10xv11_1.FULL': '../1_data_repository/full_fragments/TXG_10xv11_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_1.FULL': '../1_data_repository/full_fragments/TXG_10xv2_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_2.FULL': '../1_data_repository/full_fragments/TXG_10xv2_2.FULL.fragments.tsv.gz',
#  'UCS_ddseq_1.FULL': '../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz',
#  'UCS_ddseq_2.FULL': '../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_1.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_1.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_2.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_2.FULL.fragments.tsv.gz',
#  'VIB_10xv1_1.FULL': '../1_data_repository/full_fragments/VIB_10xv1_1.FULL.fragments.tsv.gz',
#  'VIB_10xv1_2.FULL': '../1_data_repository/full_fragments/VIB_10xv1_2.FULL.fragments.tsv.gz',
#  'VIB_10xv2_1.FULL': '../1_data_repository/full_fragments/VIB_10xv2_1.FULL.fragments.tsv.gz',
#  'VIB_10xv2_2.FULL': '../1_data_repository/full_fragments/VIB_10xv2_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_1.FULL': '../1_data_repository/full_fragments/VIB_hydrop_1.FULL.fragments.tsv.gz',
#  'VIB_hydrop_11.FULL': '../1_data_repository/full_fragments/VIB_hydrop_11.FULL.fragments.tsv.gz',
#  'VIB_hydrop_12.FULL': '../1_data_repository/full_fragments/VIB_hydrop_12.FULL.fragments.tsv.gz',
#  'VIB_hydrop_2.FULL': '../1_data_repository/full_fragments/VIB_hydrop_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_21.FULL': '../1_data_repository/full_fragments/VIB_hydrop_21.FULL.fragments.tsv.gz',
#  'VIB_hydrop_22.FULL': '../1_data_repository/full_fragments/VIB_hydrop_22.FULL.fragments.tsv.gz'}

# %%
scrub_name_suffix = "0-4"
loom_path_dict  = {x.split('/')[-1].split(f'__')[0]:x for x in sorted(glob.glob(f'cell_region_looms/*singlets.loom'))}
loom_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'cell_region_looms/BIO_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'BIO_ddseq_2.FULL': 'cell_region_looms/BIO_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'BIO_ddseq_3.FULL': 'cell_region_looms/BIO_ddseq_3.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'BIO_ddseq_4.FULL': 'cell_region_looms/BIO_ddseq_4.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'BRO_mtscatac_1.FULL': 'cell_region_looms/BRO_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'BRO_mtscatac_2.FULL': 'cell_region_looms/BRO_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xmultiome_1.FULL': 'cell_region_looms/CNA_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xmultiome_2.FULL': 'cell_region_looms/CNA_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_1.FULL': 'cell_region_looms/CNA_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_2.FULL': 'cell_region_looms/CNA_10xv11_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_3.FULL': 'cell_region_looms/CNA_10xv11_3.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_4.FULL': 'cell_region_looms/CNA_10xv11_4.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_5.FULL': 'cell_region_looms/CNA_10xv11_5.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv2_1.FULL': 'cell_region_looms/CNA_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv2_2.FULL': 'cell_region_looms/CNA_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_hydrop_1.FULL': 'cell_region_looms/CNA_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_hydrop_2.FULL': 'cell_region_looms/CNA_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_hydrop_3.FULL': 'cell_region_looms/CNA_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_mtscatac_1.FULL': 'cell_region_looms/CNA_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_mtscatac_2.FULL': 'cell_region_looms/CNA_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_1.FULL': 'cell_region_looms/EPF_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_2.FULL': 'cell_region_looms/EPF_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_3.FULL': 'cell_region_looms/EPF_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_4.FULL': 'cell_region_looms/EPF_hydrop_4.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'HAR_ddseq_1.FULL': 'cell_region_looms/HAR_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'HAR_ddseq_2.FULL': 'cell_region_looms/HAR_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'MDC_mtscatac_1.FULL': 'cell_region_looms/MDC_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'MDC_mtscatac_2.FULL': 'cell_region_looms/MDC_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'OHS_s3atac_1.FULL': 'cell_region_looms/OHS_s3atac_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'OHS_s3atac_2.FULL': 'cell_region_looms/OHS_s3atac_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'SAN_10xmultiome_1.FULL': 'cell_region_looms/SAN_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'SAN_10xmultiome_2.FULL': 'cell_region_looms/SAN_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'STA_10xv11_1.FULL': 'cell_region_looms/STA_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'STA_10xv11_2.FULL': 'cell_region_looms/STA_10xv11_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'TXG_10xv11_1.FULL': 'cell_region_looms/TXG_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'TXG_10xv2_1.FULL': 'cell_region_looms/TXG_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'TXG_10xv2_2.FULL': 'cell_region_looms/TXG_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'UCS_ddseq_1.FULL': 'cell_region_looms/UCS_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'UCS_ddseq_2.FULL': 'cell_region_looms/UCS_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xmultiome_1.FULL': 'cell_region_looms/VIB_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xmultiome_2.FULL': 'cell_region_looms/VIB_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv1_1.FULL': 'cell_region_looms/VIB_10xv1_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv1_2.FULL': 'cell_region_looms/VIB_10xv1_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv2_1.FULL': 'cell_region_looms/VIB_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv2_2.FULL': 'cell_region_looms/VIB_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_1.FULL': 'cell_region_looms/VIB_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_11.FULL': 'cell_region_looms/VIB_hydrop_11.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_12.FULL': 'cell_region_looms/VIB_hydrop_12.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_2.FULL': 'cell_region_looms/VIB_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_21.FULL': 'cell_region_looms/VIB_hydrop_21.FULL__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_22.FULL': 'cell_region_looms/VIB_hydrop_22.FULL__cto.scrublet0-4.fmx.singlets.loom'}

# %%
# !cat ../0_resources/scripts/seurat_label_transfer_consensus.R
# Out:
# #!/usr/bin/env Rscript
# library(Seurat)
# library(SeuratDisk)
# library(Signac)
# # library(EnsDb.Hsapiens.v86)
# library(ggplot2)
# library(stringr)
#
# args = commandArgs(trailingOnly=TRUE)
# sample_id = args[1]
# f_loom = args[2]
# f_frag = args[3]
# f_reference = args[4]
# f_annotation = args[5]
# f_out = args[6]
#
# print(paste0("Processing sample ", args[1]))
#
# # load pbmc object
# pbmc.rna <- readRDS("../0_resources/seurat_references/pbmc_integrated.RDS")
# #pbmc.rna <- readRDS('/lustre1/project/stg_00090/scatac_benchmark/0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')
#
# ################################################################################
# # ATAC
# ################################################################################
#
# ### get data from loom:
# atacloomcon <- Connect(filename = f_loom, mode = "r")
# atacloomcon
# atac_tmp <- as.Seurat(atacloomcon, assay='ATAC')
# atacloomcon$close_all()
#
# # subset by removing contig chromosomes
# rawregions = rownames(GetAssayData(atac_tmp, slot = "counts", assay='ATAC'))
# standard_regions = rawregions[!grepl('random|KI|Un', rawregions)]
#
# atac_tmp_data_subset = GetAssayData(atac_tmp[standard_regions], slot = "counts", assay='ATAC')
# atac_tmp <- CreateSeuratObject(atac_tmp_data_subset, assay='ATAC')
#
#
# # subset by removing contig chromosomes
# rawregions = rownames(GetAssayData(atac_tmp, slot = "counts", assay='ATAC'))
# # standard_regions = rawregions[!grepl('random|KIe
# pbmc.rna <- readRDS('../0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')
#
#
#
# # correctly parse regions (default delims are '-','-')
# regions = StringToGRanges(
#     rownames(GetAssayData(atac_tmp, slot = "counts", assay='ATAC')),
#     sep=c(':','-')
#     )
#
# # create chromatin assay
# chromatinassay = CreateChromatinAssay(
#     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
#     # genome='hg38',
#     fragments = f_frag,
#     ranges=regions
#     )
#     #annotation=annotation)
#
# atac <- CreateSeuratObject(counts = chromatinassay, assay='ATAC')
#
# annotations <- readRDS(f_annotation)
# Annotation(atac) <- annotations
#
# # We exclude the first dimension as this is typically correlated with sequencing depth
# atac <- RunTFIDF(atac)
# atac <- FindTopFeatures(atac, min.cutoff = "q0")
# atac <- RunSVD(atac)
# atac <- RunUMAP(atac, reduction = "lsi", dims = 2:30, reduction.name = "umap.atac", reduction.key = "atacUMAP_")
#
# ##################################################
# # Identify RNA-ATAC anchors
#
# # quantify gene activity
# gene.activities <- GeneActivity(atac, features = VariableFeatures(pbmc.rna))
# # gene.activities <- gene.activities[rownames(gene.activities)!="",]
#
# # add gene activities as a new assay
# atac[["ACTIVITY"]] <- CreateAssayObject(counts = gene.activities)
#
# # normalize gene activities
# DefaultAssay(atac) <- "ACTIVITY"
# atac <- NormalizeData(atac)
# atac <- ScaleData(atac, features = rownames(atac))
#
# # Identify anchors
# transfer.anchors <- FindTransferAnchors(reference = pbmc.rna,
#     query = atac,
#     features = VariableFeatures(object = pbmc.rna),
#     reference.assay = "RNA",
#     query.assay = "ACTIVITY",
#     reduction = "cca")
#
# # predict celltype
# celltype.predictions <- TransferData(
#     anchorset = transfer.anchors,
#     refdata = pbmc.rna$CellType,
#     weight.reduction = atac[["lsi"]],
#     dims = 2:30)
#
# pbmc.atac <- AddMetaData(atac, metadata = celltype.predictions)
#
# md = celltype.predictions
# pred_thr = 0.7
#
# tmp = data.frame(
#       composite_sample_id = paste0(rownames(md),'-',sample_id),
#       barcode = rownames(md),
#       sample_id = sample_id,
#       cell_type = md$predicted.id,
#       cell_type_pred_score = md$prediction.score.max
#       )
#
# tmp$cell_type_hiconf_70 = tmp$cell_type
# tmp$cell_type_hiconf_70[tmp$cell_type_pred_score<pred_thr] = 'Unknown'
#
# table(tmp$cell_type)
# table(tmp$cell_type_hiconf_70)
#
# write.table(tmp, file=f_out, sep='\t', row.names=FALSE, quote=FALSE)
# print(paste0('Wrote file ', f_out))

# %%
parallel_filename = "seurat_label_transfer.parallel"
script_path = "../0_resources/scripts/seurat_label_transfer_consensus.R"
img_path = "../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif"
reference_path = "../0_resources/seurat_references/pbmc_ref.rds"
annotation_path = "../0_resources/seurat_references/granges_annotation.rds"
bind_mounts = "/dodrio,/readonly/dodrio,/tmp"
#bind_mounts = "/lustre1,/staging,${VSC_SCRATCH}/tmp:/tmp"

with open(parallel_filename, 'w') as f:
    for sample in loom_path_dict.keys():
        outfile = f"cell_type_classification/{sample}__cell_type_seurat.txt"
        if not os.path.exists(outfile):
            loomfile = loom_path_dict[sample]
            fragfile = frags_path_dict[sample]
            command=f"img_path={img_path} && singularity exec --cleanenv -H $PWD -B {bind_mounts} $img_path Rscript {script_path} {sample} {loomfile} {fragfile} {reference_path} {annotation_path} {outfile}"
            f.write(f"{command}\n")
            print(command)

        else:
            f.write(f"#{outfile} already exists!\n")
            print(f"#{outfile} already exists!")
# Out:
# #cell_type_classification/BIO_ddseq_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BRO_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BRO_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_5.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv2_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/HAR_ddseq_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/HAR_ddseq_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/MDC_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/MDC_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R OHS_s3atac_1.FULL cell_region_looms/OHS_s3atac_1.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_1.FULL__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R OHS_s3atac_2.FULL cell_region_looms/OHS_s3atac_2.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_2.FULL__cell_type_seurat.txt
# #cell_type_classification/SAN_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/SAN_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/STA_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/STA_10xv11_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv2_2.FULL__cell_type_seurat.txt already exists!
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R UCS_ddseq_1.FULL cell_region_looms/UCS_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/UCS_ddseq_1.FULL__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R UCS_ddseq_2.FULL cell_region_looms/UCS_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/UCS_ddseq_2.FULL__cell_type_seurat.txt
# #cell_type_classification/VIB_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv1_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv1_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv2_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_11.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_12.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_21.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_22.FULL__cell_type_seurat.txt already exists!

# %%
parallel_filename = "seurat_label_transfer.parallel"
script_path = "../0_resources/scripts/seurat_label_transfer_consensus.R"
img_path = "../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif"
reference_path = "../0_resources/seurat_references/pbmc_ref.rds"
annotation_path = "../0_resources/seurat_references/granges_annotation.rds"
bind_mounts = "/dodrio,/readonly/dodrio,/tmp"
#bind_mounts = "/lustre1,/staging,${VSC_SCRATCH}/tmp:/tmp"

with open(parallel_filename, 'w') as f:
    for sample in loom_path_dict.keys():
        outfile = f"cell_type_classification/{sample}__cell_type_seurat.txt"
        if not os.path.exists(outfile):
            loomfile = loom_path_dict[sample]
            fragfile = frags_path_dict[sample]
            command=f"Rscript {script_path} {sample} {loomfile} {fragfile} {reference_path} {annotation_path} {outfile}"
            f.write(f"{command}\n")
            print(command)

        else:
            f.write(f"#{outfile} already exists!\n")
            print(f"#{outfile} already exists!")
# Out:
# #cell_type_classification/BIO_ddseq_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BRO_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BRO_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_5.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv2_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/HAR_ddseq_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/HAR_ddseq_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/MDC_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/MDC_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R OHS_s3atac_1.FULL cell_region_looms/OHS_s3atac_1.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_1.FULL__cell_type_seurat.txt
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R OHS_s3atac_2.FULL cell_region_looms/OHS_s3atac_2.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_2.FULL__cell_type_seurat.txt
# #cell_type_classification/SAN_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/SAN_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/STA_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/STA_10xv11_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv2_2.FULL__cell_type_seurat.txt already exists!
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R UCS_ddseq_1.FULL cell_region_looms/UCS_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/UCS_ddseq_1.FULL__cell_type_seurat.txt
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R UCS_ddseq_2.FULL cell_region_looms/UCS_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/UCS_ddseq_2.FULL__cell_type_seurat.txt
# #cell_type_classification/VIB_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv1_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv1_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv2_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_11.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_12.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_21.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_22.FULL__cell_type_seurat.txt already exists!

# %%
parallel_filename = "seurat_label_transfer.parallel"
script_path = "../0_resources/scripts/seurat_label_transfer_consensus.R"
img_path = "../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif"
reference_path = "../0_resources/seurat_references/pbmc_ref.rds"
annotation_path = "../0_resources/seurat_references/granges_annotation.rds"
bind_mounts = "/dodrio,/readonly/dodrio,/tmp"
#bind_mounts = "/lustre1,/staging,${VSC_SCRATCH}/tmp:/tmp"

with open(parallel_filename, 'w') as f:
    for sample in loom_path_dict.keys():
        outfile = f"cell_type_classification/{sample}__cell_type_seurat.txt"
        if not os.path.exists(outfile):
            loomfile = loom_path_dict[sample]
            fragfile = frags_path_dict[sample]
            command=f"Rscript {script_path} {sample} {loomfile} {fragfile} {reference_path} {annotation_path} {outfile}"
            f.write(f"{command}\n")
            print(command)

        else:
            f.write(f"#{outfile} already exists!\n")
            print(f"#{outfile} already exists!")
# Out:
# #cell_type_classification/BIO_ddseq_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BRO_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/BRO_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv11_5.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_10xv2_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_hydrop_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/CNA_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_3.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/EPF_hydrop_4.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/HAR_ddseq_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/HAR_ddseq_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/MDC_mtscatac_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/MDC_mtscatac_2.FULL__cell_type_seurat.txt already exists!
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R OHS_s3atac_1.FULL cell_region_looms/OHS_s3atac_1.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_1.FULL__cell_type_seurat.txt
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R OHS_s3atac_2.FULL cell_region_looms/OHS_s3atac_2.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_2.FULL__cell_type_seurat.txt
# #cell_type_classification/SAN_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/SAN_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/STA_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/STA_10xv11_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv11_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/TXG_10xv2_2.FULL__cell_type_seurat.txt already exists!
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R UCS_ddseq_1.FULL cell_region_looms/UCS_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/UCS_ddseq_1.FULL__cell_type_seurat.txt
# Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R UCS_ddseq_2.FULL cell_region_looms/UCS_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/UCS_ddseq_2.FULL__cell_type_seurat.txt
# #cell_type_classification/VIB_10xmultiome_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xmultiome_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv1_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv1_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv2_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_10xv2_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_1.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_11.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_12.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_2.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_21.FULL__cell_type_seurat.txt already exists!
# #cell_type_classification/VIB_hydrop_22.FULL__cell_type_seurat.txt already exists!

# %% [markdown]
# # Run the Rscript

# %% [markdown]
# ```
# mkdir cell_type_classification
# export OMP_THREAD_LIMIT=80
# cat seurat_label_transfer.parallel | parallel -j 2 --progress
# ```

# %% [markdown]
# # Troubleshooting

# %% [markdown]
# when running
# ```
# > chromatinassay = CreateChromatinAssay(
# +     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
# +     genome='hg38',
# +     fragments = f_frag,
# +     ranges=regions
# +     )
# ```
# i get the error
# ```
# Computing hash
# Checking for 2208 cell barcodes
# Error in CreateFragmentObject(path = fragments, cells = cells, validate.fragments = validate.fragments,  :
#   Not all cells requested could be found in the fragment file.
# In addition: Warning message:
# In CreateChromatinAssay(counts = GetAssayData(atac_tmp, slot = "counts",  :
#   Overlapping ranges supplied. Ranges should be non-overlapping.
# ```
# and `chromatinassay` is empty.

# %%
zcat fragments_postbap/VIB_Hydrop_1.sinto.mm.fragments.tsv.gz | head
# Out:
# chr1	10151	10183	GCGTTGACTTCGTCGACGTA-12	1
# chr1	16228	16272	ATTGTAGAGGTAGGAGTCAA-12	6
# chr1	17490	17527	TTGTACTGCAAGGTGCCAGA-12	3
# chr1	30857	31030	CATGAACGTTGTGACGTGGA-12	1
# chr1	68280	68311	CATTGGTGCAGGCGAGATTC-12	1
# chr1	74871	74900	ATCATCCGTTAATAGGCAGG-11	11
# chr1	79643	79855	GGAGCGGATTCAAGGTCGAT-11	2
# chr1	88228	88302	AAGACCAAGCGCTGATGGTA-12	4
# chr1	89893	89944	TCCGATTCAGCACGTTAAGA-12	3
# chr1	91177	91237	CTCCTCACTACTTGAAGAAG-12	4
#
# gzip: stdout: Broken pipe

# %% [markdown]
# this error doesn't make sense, because the barcodes are present in the fragments file.

# %% [markdown]
# the output of the above code can be read in the cell_type_redictions.ipynb notebook

# %% [markdown]
# it turns out the loom file writing had a bug in it that did not add the `-1?` do the barcode. i fixed this in the loom writing.

# %% [markdown]
# now that this is fixed, i got an error
#
# ```
# > chromatinassay = CreateChromatinAssay(
# +     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
# +     genome='hg38',
# +     fragments = f_frag,
# +     ranges=regions
# +     )
# Computing hash
# Checking for 2208 cell barcodes
# Error in .order_seqlevels(chrom_sizes[, "chrom"]) :
#   !anyNA(m32) is not TRUE
# In addition: Warning message:
# In CreateChromatinAssay(counts = GetAssayData(atac_tmp, slot = "counts",  :
#   Overlapping ranges supplied. Ranges should be non-overlapping.
# ```

# %% [markdown]
# it turns out that this is a known bug (https://github.com/timoast/signac/issues/687) and that commenting out the line `genome='hg38'`
