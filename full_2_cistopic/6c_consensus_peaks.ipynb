# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk, peak_calling
import pyranges as pr
import requests
import os
import pandas as pd
import glob
import pickle

# %%
# %load_ext lab_black

# %%
# get chromosome sizes (hg38)
if not os.path.exists("chromsizes.txt"):
    target_url = (
        "http://hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/hg38.chrom.sizes"
    )
    chromsizes = pd.read_csv(target_url, sep="\t", header=None)
    chromsizes.columns = ["Chromosome", "End"]
    chromsizes["Start"] = [0] * chromsizes.shape[0]
    chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
    chromsizes = pr.PyRanges(chromsizes)
    chromsizes.to_csv("chromsizes.txt")
    chromsizes
else:
    chromsizes = pd.read_csv("chromsizes.txt")

# %%
cto_consensus_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("cistopic_objects/*singlets.model*consensus.pkl"))
}
cto_consensus_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'cistopic_objects/BIO_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'BIO_ddseq_2.FULL': 'cistopic_objects/BIO_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'BIO_ddseq_3.FULL': 'cistopic_objects/BIO_ddseq_3.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'BIO_ddseq_4.FULL': 'cistopic_objects/BIO_ddseq_4.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'BRO_mtscatac_1.FULL': 'cistopic_objects/BRO_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'BRO_mtscatac_2.FULL': 'cistopic_objects/BRO_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xmultiome_1.FULL': 'cistopic_objects/CNA_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'CNA_10xmultiome_2.FULL': 'cistopic_objects/CNA_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_1.FULL': 'cistopic_objects/CNA_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_2.FULL': 'cistopic_objects/CNA_10xv11_2.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_3.FULL': 'cistopic_objects/CNA_10xv11_3.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_4.FULL': 'cistopic_objects/CNA_10xv11_4.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_10xv11_5.FULL': 'cistopic_objects/CNA_10xv11_5.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'CNA_10xv2_1.FULL': 'cistopic_objects/CNA_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'CNA_10xv2_2.FULL': 'cistopic_objects/CNA_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'CNA_hydrop_1.FULL': 'cistopic_objects/CNA_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_hydrop_2.FULL': 'cistopic_objects/CNA_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'CNA_hydrop_3.FULL': 'cistopic_objects/CNA_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'CNA_mtscatac_1.FULL': 'cistopic_objects/CNA_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'CNA_mtscatac_2.FULL': 'cistopic_objects/CNA_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_1.FULL': 'cistopic_objects/EPF_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_2.FULL': 'cistopic_objects/EPF_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_3.FULL': 'cistopic_objects/EPF_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'EPF_hydrop_4.FULL': 'cistopic_objects/EPF_hydrop_4.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'HAR_ddseq_1.FULL': 'cistopic_objects/HAR_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.pkl',
#  'HAR_ddseq_2.FULL': 'cistopic_objects/HAR_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'MDC_mtscatac_1.FULL': 'cistopic_objects/MDC_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'MDC_mtscatac_2.FULL': 'cistopic_objects/MDC_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'OHS_s3atac_1.FULL': 'cistopic_objects/OHS_s3atac_1.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.pkl',
#  'OHS_s3atac_2.FULL': 'cistopic_objects/OHS_s3atac_2.FULL__cto.scrublet0-4.fmx.singlets.model_7topics.dimreduc.consensus.pkl',
#  'SAN_10xmultiome_1.FULL': 'cistopic_objects/SAN_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'SAN_10xmultiome_2.FULL': 'cistopic_objects/SAN_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'STA_10xv11_1.FULL': 'cistopic_objects/STA_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'STA_10xv11_2.FULL': 'cistopic_objects/STA_10xv11_2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'TXG_10xv11_1.FULL': 'cistopic_objects/TXG_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.model_16topics.dimreduc.consensus.pkl',
#  'TXG_10xv2_1.FULL': 'cistopic_objects/TXG_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.model_18topics.dimreduc.consensus.pkl',
#  'TXG_10xv2_2.FULL': 'cistopic_objects/TXG_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.model_16topics.dimreduc.consensus.pkl',
#  'UCS_ddseq_1.FULL': 'cistopic_objects/UCS_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.pkl',
#  'UCS_ddseq_2.FULL': 'cistopic_objects/UCS_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.model_17topics.dimreduc.consensus.pkl',
#  'VIB_10xmultiome_1.FULL': 'cistopic_objects/VIB_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'VIB_10xmultiome_2.FULL': 'cistopic_objects/VIB_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_10xv1_1.FULL': 'cistopic_objects/VIB_10xv1_1.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'VIB_10xv1_2.FULL': 'cistopic_objects/VIB_10xv1_2.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.pkl',
#  'VIB_10xv2_1.FULL': 'cistopic_objects/VIB_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_10xv2_2.FULL': 'cistopic_objects/VIB_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_1.FULL': 'cistopic_objects/VIB_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_11.FULL': 'cistopic_objects/VIB_hydrop_11.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_12.FULL': 'cistopic_objects/VIB_hydrop_12.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_2.FULL': 'cistopic_objects/VIB_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_21.FULL': 'cistopic_objects/VIB_hydrop_21.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.pkl',
#  'VIB_hydrop_22.FULL': 'cistopic_objects/VIB_hydrop_22.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.pkl'}

# %%
fragments_path_dict = {
    x.split("/")[-1].split(f".fragments.tsv.gz")[0]: x
    for x in sorted(glob.glob("../1_data_repository/full_fragments/*.tsv.gz"))
}
fragments_path_dict
# Out:
# {'BIO_ddseq_1.FULL': '../1_data_repository/full_fragments/BIO_ddseq_1.FULL.fragments.tsv.gz',
#  'BIO_ddseq_2.FULL': '../1_data_repository/full_fragments/BIO_ddseq_2.FULL.fragments.tsv.gz',
#  'BIO_ddseq_3.FULL': '../1_data_repository/full_fragments/BIO_ddseq_3.FULL.fragments.tsv.gz',
#  'BIO_ddseq_4.FULL': '../1_data_repository/full_fragments/BIO_ddseq_4.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_1.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_1.FULL.fragments.tsv.gz',
#  'BRO_mtscatac_2.FULL': '../1_data_repository/full_fragments/BRO_mtscatac_2.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_1.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_1.FULL.fragments.tsv.gz',
#  'CNA_10xmultiome_2.FULL': '../1_data_repository/full_fragments/CNA_10xmultiome_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_1.FULL': '../1_data_repository/full_fragments/CNA_10xv11_1.FULL.fragments.tsv.gz',
#  'CNA_10xv11_2.FULL': '../1_data_repository/full_fragments/CNA_10xv11_2.FULL.fragments.tsv.gz',
#  'CNA_10xv11_3.FULL': '../1_data_repository/full_fragments/CNA_10xv11_3.FULL.fragments.tsv.gz',
#  'CNA_10xv11_4.FULL': '../1_data_repository/full_fragments/CNA_10xv11_4.FULL.fragments.tsv.gz',
#  'CNA_10xv11_5.FULL': '../1_data_repository/full_fragments/CNA_10xv11_5.FULL.fragments.tsv.gz',
#  'CNA_10xv2_1.FULL': '../1_data_repository/full_fragments/CNA_10xv2_1.FULL.fragments.tsv.gz',
#  'CNA_10xv2_2.FULL': '../1_data_repository/full_fragments/CNA_10xv2_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_1.FULL': '../1_data_repository/full_fragments/CNA_hydrop_1.FULL.fragments.tsv.gz',
#  'CNA_hydrop_2.FULL': '../1_data_repository/full_fragments/CNA_hydrop_2.FULL.fragments.tsv.gz',
#  'CNA_hydrop_3.FULL': '../1_data_repository/full_fragments/CNA_hydrop_3.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_1.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_1.FULL.fragments.tsv.gz',
#  'CNA_mtscatac_2.FULL': '../1_data_repository/full_fragments/CNA_mtscatac_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_1.FULL': '../1_data_repository/full_fragments/EPF_hydrop_1.FULL.fragments.tsv.gz',
#  'EPF_hydrop_2.FULL': '../1_data_repository/full_fragments/EPF_hydrop_2.FULL.fragments.tsv.gz',
#  'EPF_hydrop_3.FULL': '../1_data_repository/full_fragments/EPF_hydrop_3.FULL.fragments.tsv.gz',
#  'EPF_hydrop_4.FULL': '../1_data_repository/full_fragments/EPF_hydrop_4.FULL.fragments.tsv.gz',
#  'HAR_ddseq_1.FULL': '../1_data_repository/full_fragments/HAR_ddseq_1.FULL.fragments.tsv.gz',
#  'HAR_ddseq_2.FULL': '../1_data_repository/full_fragments/HAR_ddseq_2.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_1.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_1.FULL.fragments.tsv.gz',
#  'MDC_mtscatac_2.FULL': '../1_data_repository/full_fragments/MDC_mtscatac_2.FULL.fragments.tsv.gz',
#  'OHS_s3atac_1.FULL': '../1_data_repository/full_fragments/OHS_s3atac_1.FULL.fragments.tsv.gz',
#  'OHS_s3atac_2.FULL': '../1_data_repository/full_fragments/OHS_s3atac_2.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_1.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_1.FULL.fragments.tsv.gz',
#  'SAN_10xmultiome_2.FULL': '../1_data_repository/full_fragments/SAN_10xmultiome_2.FULL.fragments.tsv.gz',
#  'STA_10xv11_1.FULL': '../1_data_repository/full_fragments/STA_10xv11_1.FULL.fragments.tsv.gz',
#  'STA_10xv11_2.FULL': '../1_data_repository/full_fragments/STA_10xv11_2.FULL.fragments.tsv.gz',
#  'TXG_10xv11_1.FULL': '../1_data_repository/full_fragments/TXG_10xv11_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_1.FULL': '../1_data_repository/full_fragments/TXG_10xv2_1.FULL.fragments.tsv.gz',
#  'TXG_10xv2_2.FULL': '../1_data_repository/full_fragments/TXG_10xv2_2.FULL.fragments.tsv.gz',
#  'UCS_ddseq_1.FULL': '../1_data_repository/full_fragments/UCS_ddseq_1.FULL.fragments.tsv.gz',
#  'UCS_ddseq_2.FULL': '../1_data_repository/full_fragments/UCS_ddseq_2.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_1.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_1.FULL.fragments.tsv.gz',
#  'VIB_10xmultiome_2.FULL': '../1_data_repository/full_fragments/VIB_10xmultiome_2.FULL.fragments.tsv.gz',
#  'VIB_10xv1_1.FULL': '../1_data_repository/full_fragments/VIB_10xv1_1.FULL.fragments.tsv.gz',
#  'VIB_10xv1_2.FULL': '../1_data_repository/full_fragments/VIB_10xv1_2.FULL.fragments.tsv.gz',
#  'VIB_10xv2_1.FULL': '../1_data_repository/full_fragments/VIB_10xv2_1.FULL.fragments.tsv.gz',
#  'VIB_10xv2_2.FULL': '../1_data_repository/full_fragments/VIB_10xv2_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_1.FULL': '../1_data_repository/full_fragments/VIB_hydrop_1.FULL.fragments.tsv.gz',
#  'VIB_hydrop_11.FULL': '../1_data_repository/full_fragments/VIB_hydrop_11.FULL.fragments.tsv.gz',
#  'VIB_hydrop_12.FULL': '../1_data_repository/full_fragments/VIB_hydrop_12.FULL.fragments.tsv.gz',
#  'VIB_hydrop_2.FULL': '../1_data_repository/full_fragments/VIB_hydrop_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_21.FULL': '../1_data_repository/full_fragments/VIB_hydrop_21.FULL.fragments.tsv.gz',
#  'VIB_hydrop_22.FULL': '../1_data_repository/full_fragments/VIB_hydrop_22.FULL.fragments.tsv.gz'}

# %%
import gc
import logging
import os
import re
import subprocess
import sys
from typing import Dict, List, Optional, Union

import numpy as np
import pandas as pd
import pyBigWig
import pyranges as pr
import ray

from pycisTopic.cistopic_class import *
from pycisTopic.utils import *


def export_pseudobulk(
    input_data: Union["CistopicObject", pd.DataFrame, Dict[str, pd.DataFrame]],
    variable: str,
    chromsizes: Union[pd.DataFrame, pr.PyRanges],
    bed_path: str,
    bigwig_path: str,
    path_to_fragments: Optional[Dict[str, str]] = None,
    sample_id_col: Optional[str] = "sample_id",
    n_cpu: Optional[int] = 1,
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
    use_polars: Optional[bool] = True,
    **kwargs
):
    """
    Create pseudobulks as bed and bigwig from single cell fragments file given a barcode annotation.
    Parameters
    ---------
    input_data: CistopicObject or pd.DataFrame
            A :class:`CistopicObject` containing the specified `variable` as a column in :class:`CistopicObject.cell_data` or a cell metadata
            :class:`pd.DataFrame` containing barcode as rows, containing the specified `variable` as a column (additional columns are
            possible) and a `sample_id` column. Index names must contain the BARCODE (e.g. ATGTCGTC-1), additional tags are possible separating with -
            (e.g. ATGCTGTGCG-1-Sample_1). The levels in the sample_id column must agree with the keys in the path_to_fragments dictionary.
            Alternatively, if the cell metadata contains a column named barcode it will be used instead of the index names.
    variable: str
            A character string indicating the column that will be used to create the different group pseudobulk. It must be included in
            the cell metadata provided as input_data.
    chromsizes: pd.DataFrame or pr.PyRanges
            A data frame or :class:`pr.PyRanges` containing size of each chromosome, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed files per group will be saved. If None, files will not be generated.
    bigwig_path: str
            Path to folder where the bigwig files per group will be saved. If None, files will not be generated.
    path_to_fragments: str or dict, optional
            A dictionary of character strings, with sample name as names indicating the path to the fragments file/s from which pseudobulk profiles have to
            be created. If a :class:`CistopicObject` is provided as input it will be ignored, but if a cell metadata :class:`pd.DataFrame` is provided it
            is necessary to provide it. The keys of the dictionary need to match with the sample_id tag added to the index names of the input data frame.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    n_cpu: int, optional
            Number of cores to use. Default: 1.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str, optional
            Pattern to split cell barcode from sample id. Default: ___ .
    use_polars: bool, optional
            Whether to use polars to read fragments files. Default: True.
    **kwargs
            Additional parameters for ray.init()
    Return
    ------
    dict
            A dictionary containing the paths to the newly created bed fragments files per group a dictionary containing the paths to the
            newly created bigwig files per group.
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    # Get fragments file
    if isinstance(input_data, CistopicObject):
        path_to_fragments = input_data.path_to_fragments
        if path_to_fragments is None:
            log.error("No path_to_fragments in this cisTopic object.")
        cell_data = input_data.cell_data
    elif isinstance(input_data, pd.DataFrame):
        if path_to_fragments is None:
            log.error("Please, provide path_to_fragments.")
        cell_data = input_data
    # Check for sample_id column
    try:
        sample_ids = list(set(cell_data[sample_id_col]))
    except ValueError:
        print(
            'Please, include a sample identification column (e.g. "sample_id") in your cell metadata!'
        )

    # Get fragments
    fragments_df_dict = {}
    for sample_id in path_to_fragments.keys():
        if sample_id not in sample_ids:
            log.info(
                "The following path_to_fragments entry is not found in the cell metadata sample_id_col: ",
                sample_id,
                ". It will be ignored.",
            )
        else:
            log.info("Reading fragments from " + path_to_fragments[sample_id])
            fragments_df = read_fragments_from_file(
                path_to_fragments[sample_id], use_polars=use_polars
            ).df
            # Convert to int32 for memory efficiency
            fragments_df.Start = np.int32(fragments_df.Start)
            fragments_df.End = np.int32(fragments_df.End)
            if "Score" in fragments_df:
                fragments_df.Score = np.int32(fragments_df.Score)
            if "barcode" in cell_data:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(cell_data["barcode"].tolist())
                ]
            else:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(
                        prepare_tag_cells(cell_data.index.tolist(), split_pattern)
                    )
                ]
            fragments_df_dict[sample_id] = fragments_df

    # Set groups
    if "barcode" in cell_data:
        cell_data = cell_data.loc[:, [variable, sample_id_col, "barcode"]]
    else:
        cell_data = cell_data.loc[:, [variable, sample_id_col]]
    cell_data[variable] = cell_data[variable].replace(" ", "", regex=True)
    cell_data[variable] = cell_data[variable].replace("[^A-Za-z0-9]+", "_", regex=True)
    groups = sorted(list(set(cell_data[variable])))
    # Check chromosome sizes
    if isinstance(chromsizes, pd.DataFrame):
        chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
        chromsizes = pr.PyRanges(chromsizes)
    # Check that output dir exist and generate output paths
    if isinstance(bed_path, str):
        if not os.path.exists(bed_path):
            os.makedirs(bed_path)
        bed_paths = {
            group: os.path.join(bed_path, str(group) + ".bed.gz") for group in groups
        }
    else:
        bed_paths = {}
    if isinstance(bigwig_path, str):
        if not os.path.exists(bigwig_path):
            os.makedirs(bigwig_path)
        bw_paths = {
            group: os.path.join(bigwig_path, str(group) + ".bw") for group in groups
        }
    else:
        bw_paths = {}
    # Create pseudobulks
    if n_cpu > 1:
        ray.init(num_cpus=n_cpu, **kwargs)
        ray_handle = ray.wait(
            [
                export_pseudobulk_ray.remote(
                    cell_data,
                    group,
                    fragments_df_dict,
                    chromsizes,
                    bigwig_path,
                    bed_path,
                    sample_id_col,
                    normalize_bigwig,
                    remove_duplicates,
                    split_pattern,
                )
                for group in groups
            ],
            num_returns=len(groups),
        )
        ray.shutdown()
    else:
        [
            export_pseudobulk_one_sample(
                cell_data,
                group,
                fragments_df_dict,
                chromsizes,
                bigwig_path,
                bed_path,
                sample_id_col,
                normalize_bigwig,
                remove_duplicates,
                split_pattern,
            )
            for group in groups
        ]

    return bw_paths, bed_paths


def export_pseudobulk_one_sample(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    log.info("Creating pseudobulk for " + str(group))
    group_fragments_list = []
    group_fragments_dict = {}
    for sample_id in fragments_df_dict:
        sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]
        if "barcode" in sample_data:
            sample_data.index = sample_data["barcode"].tolist()
        else:
            sample_data.index = prepare_tag_cells(
                sample_data.index.tolist(), split_pattern
            )
        group_var = sample_data.iloc[:, 0]
        barcodes = group_var[group_var.isin([group])].index.tolist()
        fragments_df = fragments_df_dict[sample_id]
        group_fragments = fragments_df.loc[fragments_df["Name"].isin(barcodes)]
        if len(fragments_df_dict) > 1:
            group_fragments_dict[sample_id] = group_fragments

    if len(fragments_df_dict) > 1:
        group_fragments_list = [
            group_fragments_dict[list(group_fragments_dict.keys())[x]]
            for x in range(len(fragments_df_dict))
        ]
        group_fragments = group_fragments_list[0].append(group_fragments_list[1:])

    group_fragments = group_fragments[
        group_fragments["Chromosome"].isin(chromsizes.Chromosome)
    ]

    del group_fragments_dict
    del group_fragments_list
    del fragments_df
    gc.collect()

    group_pr = pr.PyRanges(group_fragments)
    if isinstance(bigwig_path, str):
        bigwig_path_group = os.path.join(bigwig_path, str(group) + ".bw")
        if remove_duplicates:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
            )
        else:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
                value_col="Score",
            )
    if isinstance(bed_path, str):
        bed_path_group = os.path.join(bed_path, str(group) + ".bed.gz")
        group_pr.to_bed(
            path=bed_path_group, keep=False, compression="infer", chain=False
        )

    log.info(str(group) + " done!")


@ray.remote
def export_pseudobulk_ray(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    export_pseudobulk_one_sample(
        cell_data,
        group,
        fragments_df_dict,
        chromsizes,
        bigwig_path,
        bed_path,
        sample_id_col,
        normalize_bigwig,
        remove_duplicates,
        split_pattern,
    )

# %%
# for sample in ["BRO_mtscatac_1.LIBDS"]:
bw_paths_dict = {}
bed_paths_dict = {}

import ray

if ray.is_initialized():
    print("Shutting down Ray")
    ray.shutdown()

for sample in cto_consensus_path_dict.keys():
    # for sample in ["BRO_mtscatac_1.LIBDS"]:
    bed_path = os.path.join(
        "SCREEN_peaks", f"{sample}__SCREEN_pseudobulk_bed_files"
    )
    bw_path = os.path.join(
        "SCREEN_peaks", f"{sample}__SCREEN_pseudobulk_bw_files"
    )
    if not os.path.exists(bed_path):
        cto_path = cto_consensus_path_dict[sample]
        with open(cto_path, "rb") as f:
            cto = pickle.load(f)

            bw_paths, bed_paths = export_pseudobulk(
                input_data=cto,
                variable="consensus_cell_type",
                sample_id_col="sample_id",
                chromsizes=chromsizes,
                bed_path=bed_path,
                bigwig_path=bw_path,
                path_to_fragments=fragments_path_dict[sample],
                n_cpu=16,
                normalize_bigwig=True,
                remove_duplicates=True,
            )

            if ray.is_initialized():
                print("Shutting down Ray")
                ray.shutdown()
    else:
        print(f"{bed_path} exists, skipping...")
# Out:
# SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_pseudobulk_bed_files exists, skipping...

# %% [markdown]
# # consensus

# %%
cell_data_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("cistopic_objects/*consensus.cell_data.tsv"))
}
cell_data_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'cistopic_objects/BIO_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'BIO_ddseq_2.FULL': 'cistopic_objects/BIO_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.cell_data.tsv',
#  'BIO_ddseq_3.FULL': 'cistopic_objects/BIO_ddseq_3.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'BIO_ddseq_4.FULL': 'cistopic_objects/BIO_ddseq_4.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.cell_data.tsv',
#  'BRO_mtscatac_1.FULL': 'cistopic_objects/BRO_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'BRO_mtscatac_2.FULL': 'cistopic_objects/BRO_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xmultiome_1.FULL': 'cistopic_objects/CNA_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xmultiome_2.FULL': 'cistopic_objects/CNA_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv11_1.FULL': 'cistopic_objects/CNA_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv11_2.FULL': 'cistopic_objects/CNA_10xv11_2.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv11_3.FULL': 'cistopic_objects/CNA_10xv11_3.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv11_4.FULL': 'cistopic_objects/CNA_10xv11_4.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv11_5.FULL': 'cistopic_objects/CNA_10xv11_5.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv2_1.FULL': 'cistopic_objects/CNA_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_10xv2_2.FULL': 'cistopic_objects/CNA_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_hydrop_1.FULL': 'cistopic_objects/CNA_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_hydrop_2.FULL': 'cistopic_objects/CNA_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_hydrop_3.FULL': 'cistopic_objects/CNA_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_mtscatac_1.FULL': 'cistopic_objects/CNA_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'CNA_mtscatac_2.FULL': 'cistopic_objects/CNA_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'EPF_hydrop_1.FULL': 'cistopic_objects/EPF_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.cell_data.tsv',
#  'EPF_hydrop_2.FULL': 'cistopic_objects/EPF_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.cell_data.tsv',
#  'EPF_hydrop_3.FULL': 'cistopic_objects/EPF_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'EPF_hydrop_4.FULL': 'cistopic_objects/EPF_hydrop_4.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'HAR_ddseq_1.FULL': 'cistopic_objects/HAR_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.cell_data.tsv',
#  'HAR_ddseq_2.FULL': 'cistopic_objects/HAR_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'MDC_mtscatac_1.FULL': 'cistopic_objects/MDC_mtscatac_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'MDC_mtscatac_2.FULL': 'cistopic_objects/MDC_mtscatac_2.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'OHS_s3atac_1.FULL': 'cistopic_objects/OHS_s3atac_1.FULL__cto.scrublet0-4.fmx.singlets.model_13topics.dimreduc.consensus.cell_data.tsv',
#  'OHS_s3atac_2.FULL': 'cistopic_objects/OHS_s3atac_2.FULL__cto.scrublet0-4.fmx.singlets.model_7topics.dimreduc.consensus.cell_data.tsv',
#  'SAN_10xmultiome_1.FULL': 'cistopic_objects/SAN_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'SAN_10xmultiome_2.FULL': 'cistopic_objects/SAN_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'STA_10xv11_1.FULL': 'cistopic_objects/STA_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'STA_10xv11_2.FULL': 'cistopic_objects/STA_10xv11_2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'TXG_10xv11_1.FULL': 'cistopic_objects/TXG_10xv11_1.FULL__cto.scrublet0-4.fmx.singlets.model_16topics.dimreduc.consensus.cell_data.tsv',
#  'TXG_10xv2_1.FULL': 'cistopic_objects/TXG_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.model_18topics.dimreduc.consensus.cell_data.tsv',
#  'TXG_10xv2_2.FULL': 'cistopic_objects/TXG_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.model_16topics.dimreduc.consensus.cell_data.tsv',
#  'UCS_ddseq_1.FULL': 'cistopic_objects/UCS_ddseq_1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.consensus.cell_data.tsv',
#  'UCS_ddseq_2.FULL': 'cistopic_objects/UCS_ddseq_2.FULL__cto.scrublet0-4.fmx.singlets.model_17topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_10xmultiome_1.FULL': 'cistopic_objects/VIB_10xmultiome_1.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_10xmultiome_2.FULL': 'cistopic_objects/VIB_10xmultiome_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_10xv1_1.FULL': 'cistopic_objects/VIB_10xv1_1.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_10xv1_2.FULL': 'cistopic_objects/VIB_10xv1_2.FULL__cto.scrublet0-4.fmx.singlets.model_8topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_10xv2_1.FULL': 'cistopic_objects/VIB_10xv2_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_10xv2_2.FULL': 'cistopic_objects/VIB_10xv2_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_hydrop_1.FULL': 'cistopic_objects/VIB_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_hydrop_11.FULL': 'cistopic_objects/VIB_hydrop_11.FULL__cto.scrublet0-4.fmx.singlets.model_11topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_hydrop_12.FULL': 'cistopic_objects/VIB_hydrop_12.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_hydrop_2.FULL': 'cistopic_objects/VIB_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_hydrop_21.FULL': 'cistopic_objects/VIB_hydrop_21.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.consensus.cell_data.tsv',
#  'VIB_hydrop_22.FULL': 'cistopic_objects/VIB_hydrop_22.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.consensus.cell_data.tsv'}

# %%
bw_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("SCREEN_peaks/*_pseudobulk_bw_files"))
}
bw_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_2.FULL': 'SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_3.FULL': 'SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_4.FULL': 'SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_pseudobulk_bw_files',
#  'BRO_mtscatac_1.FULL': 'SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_pseudobulk_bw_files',
#  'BRO_mtscatac_2.FULL': 'SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xmultiome_1.FULL': 'SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xmultiome_2.FULL': 'SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv11_1.FULL': 'SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv11_2.FULL': 'SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv11_3.FULL': 'SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv11_4.FULL': 'SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv11_5.FULL': 'SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv2_1.FULL': 'SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_10xv2_2.FULL': 'SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_hydrop_1.FULL': 'SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_hydrop_2.FULL': 'SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_hydrop_3.FULL': 'SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_mtscatac_1.FULL': 'SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_pseudobulk_bw_files',
#  'CNA_mtscatac_2.FULL': 'SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_pseudobulk_bw_files',
#  'EPF_hydrop_1.FULL': 'SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_pseudobulk_bw_files',
#  'EPF_hydrop_2.FULL': 'SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_pseudobulk_bw_files',
#  'EPF_hydrop_3.FULL': 'SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_pseudobulk_bw_files',
#  'EPF_hydrop_4.FULL': 'SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_pseudobulk_bw_files',
#  'HAR_ddseq_1.FULL': 'SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_pseudobulk_bw_files',
#  'HAR_ddseq_2.FULL': 'SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_pseudobulk_bw_files',
#  'MDC_mtscatac_1.FULL': 'SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_pseudobulk_bw_files',
#  'MDC_mtscatac_2.FULL': 'SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_pseudobulk_bw_files',
#  'OHS_s3atac_1.FULL': 'SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bw_files',
#  'OHS_s3atac_2.FULL': 'SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bw_files',
#  'SAN_10xmultiome_1.FULL': 'SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_pseudobulk_bw_files',
#  'SAN_10xmultiome_2.FULL': 'SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_pseudobulk_bw_files',
#  'STA_10xv11_1.FULL': 'SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_pseudobulk_bw_files',
#  'STA_10xv11_2.FULL': 'SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv11_1.FULL': 'SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv2_1.FULL': 'SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv2_2.FULL': 'SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_pseudobulk_bw_files',
#  'UCS_ddseq_1.FULL': 'SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bw_files',
#  'UCS_ddseq_2.FULL': 'SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_10xmultiome_1.FULL': 'SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_10xmultiome_2.FULL': 'SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_10xv1_1.FULL': 'SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_10xv1_2.FULL': 'SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_10xv2_1.FULL': 'SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_10xv2_2.FULL': 'SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_1.FULL': 'SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_11.FULL': 'SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_12.FULL': 'SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_2.FULL': 'SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_21.FULL': 'SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_22.FULL': 'SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_pseudobulk_bw_files'}

# %%
bed_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("SCREEN_peaks/*_pseudobulk_bed_files"))
}
bed_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_2.FULL': 'SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_3.FULL': 'SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_4.FULL': 'SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_pseudobulk_bed_files',
#  'BRO_mtscatac_1.FULL': 'SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_pseudobulk_bed_files',
#  'BRO_mtscatac_2.FULL': 'SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xmultiome_1.FULL': 'SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xmultiome_2.FULL': 'SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv11_1.FULL': 'SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv11_2.FULL': 'SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv11_3.FULL': 'SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv11_4.FULL': 'SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv11_5.FULL': 'SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv2_1.FULL': 'SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_10xv2_2.FULL': 'SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_hydrop_1.FULL': 'SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_hydrop_2.FULL': 'SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_hydrop_3.FULL': 'SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_mtscatac_1.FULL': 'SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_pseudobulk_bed_files',
#  'CNA_mtscatac_2.FULL': 'SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_pseudobulk_bed_files',
#  'EPF_hydrop_1.FULL': 'SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_pseudobulk_bed_files',
#  'EPF_hydrop_2.FULL': 'SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_pseudobulk_bed_files',
#  'EPF_hydrop_3.FULL': 'SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_pseudobulk_bed_files',
#  'EPF_hydrop_4.FULL': 'SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_pseudobulk_bed_files',
#  'HAR_ddseq_1.FULL': 'SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_pseudobulk_bed_files',
#  'HAR_ddseq_2.FULL': 'SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_pseudobulk_bed_files',
#  'MDC_mtscatac_1.FULL': 'SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_pseudobulk_bed_files',
#  'MDC_mtscatac_2.FULL': 'SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_pseudobulk_bed_files',
#  'OHS_s3atac_1.FULL': 'SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files',
#  'OHS_s3atac_2.FULL': 'SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bed_files',
#  'SAN_10xmultiome_1.FULL': 'SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_pseudobulk_bed_files',
#  'SAN_10xmultiome_2.FULL': 'SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_pseudobulk_bed_files',
#  'STA_10xv11_1.FULL': 'SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_pseudobulk_bed_files',
#  'STA_10xv11_2.FULL': 'SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv11_1.FULL': 'SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv2_1.FULL': 'SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv2_2.FULL': 'SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_pseudobulk_bed_files',
#  'UCS_ddseq_1.FULL': 'SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files',
#  'UCS_ddseq_2.FULL': 'SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_10xmultiome_1.FULL': 'SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_10xmultiome_2.FULL': 'SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_10xv1_1.FULL': 'SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_10xv1_2.FULL': 'SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_10xv2_1.FULL': 'SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_10xv2_2.FULL': 'SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_1.FULL': 'SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_11.FULL': 'SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_12.FULL': 'SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_2.FULL': 'SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_21.FULL': 'SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_22.FULL': 'SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_pseudobulk_bed_files'}

# %%
for sample in bed_path_dict.keys():
    bed_paths = {
        x.split("/")[-1].split("__")[0].split(".bed.gz")[0]: x
        for x in glob.glob(bed_path_dict[sample] + "/*")
    }

# %%
from pycisTopic.pseudobulk_peak_calling import *

# %%
import ray

# %%
narrow_peaks_dict = {}
ray.shutdown()
for sample in bed_path_dict.keys():
    narrow_peaks_dict_path = bed_path_dict[sample].replace(
        "_pseudobulk_bed_files", "_narrow_peaks_dict.pkl"
    )
    peak_path = os.path.join("SCREEN_peaks", f"{sample}__SCREEN_consensus_peaks")
    if not os.path.exists(peak_path):
        os.mkdir(peak_path)

    if not os.path.exists(narrow_peaks_dict_path):
        cell_data = pd.read_csv(cell_data_path_dict[sample])
        cto_celltypes = set(
            [
                x.replace(" ", "").replace("+", "").replace("_", "")
                for x in set(cell_data["consensus_cell_type"].unique())
            ]
        )

        bed_celltypes = set(
            [
                x.split(".")[0].replace("+", "").replace("_", "")
                for x in os.listdir(bed_path_dict[sample])
            ]
        )

        if cto_celltypes == bed_celltypes:
            print(f"Starting {narrow_peaks_dict_path}")
            bed_paths = {
                x.split("/")[-1].split("__")[0].split(".bed.gz")[0]: x
                for x in glob.glob(bed_path_dict[sample] + "/*")
            }
            narrow_peaks_dict = peak_calling(
                macs_path="macs2",
                bed_paths=bed_paths,
                outdir=peak_path,
                genome_size="hs",
                n_cpu=20,
                input_format="BEDPE",
                shift=73,
                ext_size=146,
                keep_dup="all",
                q_value=0.05,
            )
            with open(narrow_peaks_dict_path, "wb") as f:
                pickle.dump(narrow_peaks_dict, f)
        else:
            print(f"{sample} cell types not matching!! Rerun bed file writing.")
            print(f"\t{bed_celltypes}")
            print(f"\t{cto_celltypes}")
    else:
        print(f"{narrow_peaks_dict_path} already exists")
# Out:
# SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# Starting SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-09-26 14:12:00,575	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2444689) 2022-09-26 14:12:28,651 cisTopic     INFO     Calling peaks for CytotoxicTcell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files/CytotoxicTcell.bed.gz --name CytotoxicTcell  --outdir SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2444688) 2022-09-26 14:12:28,654 cisTopic     INFO     Calling peaks for CD14_monocyte with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files/CD14_monocyte.bed.gz --name CD14_monocyte  --outdir SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2444690) 2022-09-26 14:12:28,673 cisTopic     INFO     Calling peaks for Naturalkillercell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files/Naturalkillercell.bed.gz --name Naturalkillercell  --outdir SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2444691) 2022-09-26 14:12:28,679 cisTopic     INFO     Calling peaks for CD4_Tcell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files/CD4_Tcell.bed.gz --name CD4_Tcell  --outdir SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2444692) 2022-09-26 14:12:28,698 cisTopic     INFO     Calling peaks for Bcell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_pseudobulk_bed_files/Bcell.bed.gz --name Bcell  --outdir SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2444690) 2022-09-26 14:15:30,346 cisTopic     INFO     Naturalkillercell done!
# (macs_call_peak_ray pid=2444689) 2022-09-26 14:16:26,039 cisTopic     INFO     CytotoxicTcell done!
# (macs_call_peak_ray pid=2444692) 2022-09-26 14:17:05,330 cisTopic     INFO     Bcell done!
# (macs_call_peak_ray pid=2444691) 2022-09-26 14:19:53,955 cisTopic     INFO     CD4_Tcell done!
# (macs_call_peak_ray pid=2444688) 2022-09-26 14:20:20,526 cisTopic     INFO     CD14_monocyte done!
# Starting SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-09-26 14:20:28,433	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2445776) 2022-09-26 14:20:54,580 cisTopic     INFO     Calling peaks for CD4_Tcell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bed_files/CD4_Tcell.bed.gz --name CD4_Tcell  --outdir SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2445774) 2022-09-26 14:20:54,594 cisTopic     INFO     Calling peaks for CD14_monocyte with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bed_files/CD14_monocyte.bed.gz --name CD14_monocyte  --outdir SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2445772) 2022-09-26 14:20:54,590 cisTopic     INFO     Calling peaks for Naturalkillercell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bed_files/Naturalkillercell.bed.gz --name Naturalkillercell  --outdir SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2445775) 2022-09-26 14:20:54,577 cisTopic     INFO     Calling peaks for Bcell with macs2 callpeak --treatment SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_pseudobulk_bed_files/Bcell.bed.gz --name Bcell  --outdir SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2445772) 2022-09-26 14:21:17,038 cisTopic     INFO     Naturalkillercell done!
# (macs_call_peak_ray pid=2445775) 2022-09-26 14:25:06,611 cisTopic     INFO     Bcell done!
# (macs_call_peak_ray pid=2445774) 2022-09-26 14:31:27,141 cisTopic     INFO     CD14_monocyte done!
# (macs_call_peak_ray pid=2445776) 2022-09-26 14:32:20,177 cisTopic     INFO     CD4_Tcell done!
# SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# Starting SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-09-26 14:32:28,012	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2446976) 2022-09-26 14:32:55,933 cisTopic     INFO     Calling peaks for CytotoxicTcell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files/CytotoxicTcell.bed.gz --name CytotoxicTcell  --outdir SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2446979) 2022-09-26 14:32:55,919 cisTopic     INFO     Calling peaks for CD4_Tcell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files/CD4_Tcell.bed.gz --name CD4_Tcell  --outdir SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2446980) 2022-09-26 14:32:55,923 cisTopic     INFO     Calling peaks for Bcell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files/Bcell.bed.gz --name Bcell  --outdir SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2446977) 2022-09-26 14:32:55,921 cisTopic     INFO     Calling peaks for CD14_monocyte with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files/CD14_monocyte.bed.gz --name CD14_monocyte  --outdir SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2446978) 2022-09-26 14:32:55,924 cisTopic     INFO     Calling peaks for Naturalkillercell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_pseudobulk_bed_files/Naturalkillercell.bed.gz --name Naturalkillercell  --outdir SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2446978) 2022-09-26 14:34:40,105 cisTopic     INFO     Naturalkillercell done!
# (macs_call_peak_ray pid=2446980) 2022-09-26 14:36:10,657 cisTopic     INFO     Bcell done!
# (macs_call_peak_ray pid=2446976) 2022-09-26 14:37:23,839 cisTopic     INFO     CytotoxicTcell done!
# (macs_call_peak_ray pid=2446977) 2022-09-26 14:37:28,934 cisTopic     INFO     CD14_monocyte done!
# (macs_call_peak_ray pid=2446979) 2022-09-26 14:38:04,004 cisTopic     INFO     CD4_Tcell done!
# Starting SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-09-26 14:38:11,564	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2448007) 2022-09-26 14:38:39,414 cisTopic     INFO     Calling peaks for CD14_monocyte with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files/CD14_monocyte.bed.gz --name CD14_monocyte  --outdir SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2448010) 2022-09-26 14:38:39,428 cisTopic     INFO     Calling peaks for CD4_Tcell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files/CD4_Tcell.bed.gz --name CD4_Tcell  --outdir SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2448009) 2022-09-26 14:38:39,427 cisTopic     INFO     Calling peaks for Naturalkillercell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files/Naturalkillercell.bed.gz --name Naturalkillercell  --outdir SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2448008) 2022-09-26 14:38:39,439 cisTopic     INFO     Calling peaks for CytotoxicTcell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files/CytotoxicTcell.bed.gz --name CytotoxicTcell  --outdir SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2448011) 2022-09-26 14:38:39,420 cisTopic     INFO     Calling peaks for Bcell with macs2 callpeak --treatment SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_pseudobulk_bed_files/Bcell.bed.gz --name Bcell  --outdir SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize hs --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2448009) 2022-09-26 14:41:15,615 cisTopic     INFO     Naturalkillercell done!
# (macs_call_peak_ray pid=2448011) 2022-09-26 14:42:01,541 cisTopic     INFO     Bcell done!
# (macs_call_peak_ray pid=2448007) 2022-09-26 14:42:57,767 cisTopic     INFO     CD14_monocyte done!
# (macs_call_peak_ray pid=2448008) 2022-09-26 14:43:10,068 cisTopic     INFO     CytotoxicTcell done!
# (macs_call_peak_ray pid=2448010) 2022-09-26 14:43:43,961 cisTopic     INFO     CD4_Tcell done!
# SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_narrow_peaks_dict.pkl already exists
# SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_narrow_peaks_dict.pkl already exists

# %% [markdown]
# # call consensus peaks

# %%
from pycisTopic.iterative_peak_calling import get_consensus_peaks

# %%
narrow_peaks_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("SCREEN_peaks/*_narrow_peaks_dict.pkl"))
}
narrow_peaks_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_2.FULL': 'SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_3.FULL': 'SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_4.FULL': 'SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BRO_mtscatac_1.FULL': 'SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BRO_mtscatac_2.FULL': 'SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xmultiome_1.FULL': 'SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xmultiome_2.FULL': 'SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv11_1.FULL': 'SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv11_2.FULL': 'SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv11_3.FULL': 'SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv11_4.FULL': 'SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv11_5.FULL': 'SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv2_1.FULL': 'SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_10xv2_2.FULL': 'SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_hydrop_1.FULL': 'SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_hydrop_2.FULL': 'SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_hydrop_3.FULL': 'SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_mtscatac_1.FULL': 'SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'CNA_mtscatac_2.FULL': 'SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'EPF_hydrop_1.FULL': 'SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'EPF_hydrop_2.FULL': 'SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'EPF_hydrop_3.FULL': 'SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'EPF_hydrop_4.FULL': 'SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'HAR_ddseq_1.FULL': 'SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'HAR_ddseq_2.FULL': 'SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'MDC_mtscatac_1.FULL': 'SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'MDC_mtscatac_2.FULL': 'SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'OHS_s3atac_1.FULL': 'SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'OHS_s3atac_2.FULL': 'SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'SAN_10xmultiome_1.FULL': 'SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'SAN_10xmultiome_2.FULL': 'SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'STA_10xv11_1.FULL': 'SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'STA_10xv11_2.FULL': 'SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv11_1.FULL': 'SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv2_1.FULL': 'SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv2_2.FULL': 'SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'UCS_ddseq_1.FULL': 'SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'UCS_ddseq_2.FULL': 'SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_10xmultiome_1.FULL': 'SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_10xmultiome_2.FULL': 'SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_10xv1_1.FULL': 'SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_10xv1_2.FULL': 'SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_10xv2_1.FULL': 'SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_10xv2_2.FULL': 'SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_1.FULL': 'SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_11.FULL': 'SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_12.FULL': 'SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_2.FULL': 'SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_21.FULL': 'SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_22.FULL': 'SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_narrow_peaks_dict.pkl'}

# %%
path_to_blacklist = "../0_resources/regions/hg38-blacklist.v2.bed"

# %%
peak_half_width = 250

# Get consensus peaks
consensus_peaks_dict = {}
for sample in narrow_peaks_path_dict.keys():
    print(sample)
    consensus_out_path = narrow_peaks_path_dict[sample].replace(
        "_narrow_peaks_dict.pkl", "_consensus_peaks.bed"
    )
    if not os.path.exists(consensus_out_path):
        cell_data = pd.read_csv(cell_data_path_dict[sample])
        cto_celltypes = set(
            [
                x.replace(" ", "").replace("+", "").replace("_", "")
                for x in set(cell_data["consensus_cell_type"].unique())
            ]
        )

        with open(narrow_peaks_path_dict[sample], "rb") as f:
            narrow_peaks_dict = pickle.load(f)
        peaks_celltypes = set(
            [
                x.replace(" ", "").replace("+", "").replace("_", "")
                for x in set(narrow_peaks_dict.keys())
            ]
        )

        if cto_celltypes == peaks_celltypes:
            consensus_peaks = get_consensus_peaks(
                narrow_peaks_dict,
                peak_half_width,
                chromsizes=chromsizes,
                path_to_blacklist=path_to_blacklist,
            )

            consensus_peaks.to_bed(
                path=consensus_out_path, keep=True, compression="infer", chain=False
            )
        else:
            print("CELL TYPE SETS NOT MATCHING! Rerun peak calling.")
            print(peaks_celltypes - cto_celltypes)
            print(cto_celltypes - peaks_celltypes)
    else:
        print(f"{consensus_out_path} already exists, skipping...")
# Out:
# BIO_ddseq_1.FULL
# SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# BIO_ddseq_2.FULL
# SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# BIO_ddseq_3.FULL
# SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# BIO_ddseq_4.FULL
# SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# BRO_mtscatac_1.FULL
# SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# BRO_mtscatac_2.FULL
# SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xmultiome_1.FULL
# SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xmultiome_2.FULL
# SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv11_1.FULL
# SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv11_2.FULL
# SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv11_3.FULL
# SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv11_4.FULL
# SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv11_5.FULL
# SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv2_1.FULL
# SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_10xv2_2.FULL
# SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_hydrop_1.FULL
# SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_hydrop_2.FULL
# SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_hydrop_3.FULL
# SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_mtscatac_1.FULL
# SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# CNA_mtscatac_2.FULL
# SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# EPF_hydrop_1.FULL
# SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# EPF_hydrop_2.FULL
# SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# EPF_hydrop_3.FULL
# SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# EPF_hydrop_4.FULL
# SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# HAR_ddseq_1.FULL
# SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# HAR_ddseq_2.FULL
# SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# MDC_mtscatac_1.FULL
# SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# MDC_mtscatac_2.FULL
# SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# OHS_s3atac_1.FULL
# 2022-09-26 14:43:49,010 cisTopic     INFO     Extending and merging peaks per class
# 2022-09-26 14:44:41,076 cisTopic     INFO     Normalizing peak scores
# 2022-09-26 14:44:41,252 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-09-26 14:45:23,329 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# OHS_s3atac_2.FULL
# 2022-09-26 14:45:24,541 cisTopic     INFO     Extending and merging peaks per class
# 2022-09-26 14:46:57,886 cisTopic     INFO     Normalizing peak scores
# 2022-09-26 14:46:58,230 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-09-26 14:48:46,695 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# SAN_10xmultiome_1.FULL
# SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# SAN_10xmultiome_2.FULL
# SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# STA_10xv11_1.FULL
# SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# STA_10xv11_2.FULL
# SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# TXG_10xv11_1.FULL
# SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# TXG_10xv2_1.FULL
# SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# TXG_10xv2_2.FULL
# SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# UCS_ddseq_1.FULL
# 2022-09-26 14:48:48,926 cisTopic     INFO     Extending and merging peaks per class
# 2022-09-26 14:49:27,981 cisTopic     INFO     Normalizing peak scores
# 2022-09-26 14:49:28,125 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-09-26 14:50:00,943 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# ...
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# VIB_10xmultiome_1.FULL
# SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_10xmultiome_2.FULL
# SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_10xv1_1.FULL
# SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_10xv1_2.FULL
# SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_10xv2_1.FULL
# SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_10xv2_2.FULL
# SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_hydrop_1.FULL
# SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_hydrop_11.FULL
# SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_hydrop_12.FULL
# SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_hydrop_2.FULL
# SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_hydrop_21.FULL
# SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_consensus_peaks.bed already exists, skipping...
# VIB_hydrop_22.FULL
# SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_consensus_peaks.bed already exists, skipping...

# %% [markdown]
# # Check % chrM in consensus peaks

# %%
consensus_peaks_path_dict = {x.split('/')[-1].split(f'__')[0]: x for x in sorted(glob.glob("SCREEN_peaks/*consensus_peaks.bed"))}
consensus_peaks_path_dict
# Out:
# {'BIO_ddseq_1.FULL': 'SCREEN_peaks/BIO_ddseq_1.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_2.FULL': 'SCREEN_peaks/BIO_ddseq_2.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_3.FULL': 'SCREEN_peaks/BIO_ddseq_3.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_4.FULL': 'SCREEN_peaks/BIO_ddseq_4.FULL__SCREEN_consensus_peaks.bed',
#  'BRO_mtscatac_1.FULL': 'SCREEN_peaks/BRO_mtscatac_1.FULL__SCREEN_consensus_peaks.bed',
#  'BRO_mtscatac_2.FULL': 'SCREEN_peaks/BRO_mtscatac_2.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xmultiome_1.FULL': 'SCREEN_peaks/CNA_10xmultiome_1.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xmultiome_2.FULL': 'SCREEN_peaks/CNA_10xmultiome_2.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_1.FULL': 'SCREEN_peaks/CNA_10xv11_1.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_2.FULL': 'SCREEN_peaks/CNA_10xv11_2.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_3.FULL': 'SCREEN_peaks/CNA_10xv11_3.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_4.FULL': 'SCREEN_peaks/CNA_10xv11_4.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv11_5.FULL': 'SCREEN_peaks/CNA_10xv11_5.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv2_1.FULL': 'SCREEN_peaks/CNA_10xv2_1.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_10xv2_2.FULL': 'SCREEN_peaks/CNA_10xv2_2.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_hydrop_1.FULL': 'SCREEN_peaks/CNA_hydrop_1.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_hydrop_2.FULL': 'SCREEN_peaks/CNA_hydrop_2.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_hydrop_3.FULL': 'SCREEN_peaks/CNA_hydrop_3.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_mtscatac_1.FULL': 'SCREEN_peaks/CNA_mtscatac_1.FULL__SCREEN_consensus_peaks.bed',
#  'CNA_mtscatac_2.FULL': 'SCREEN_peaks/CNA_mtscatac_2.FULL__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_1.FULL': 'SCREEN_peaks/EPF_hydrop_1.FULL__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_2.FULL': 'SCREEN_peaks/EPF_hydrop_2.FULL__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_3.FULL': 'SCREEN_peaks/EPF_hydrop_3.FULL__SCREEN_consensus_peaks.bed',
#  'EPF_hydrop_4.FULL': 'SCREEN_peaks/EPF_hydrop_4.FULL__SCREEN_consensus_peaks.bed',
#  'HAR_ddseq_1.FULL': 'SCREEN_peaks/HAR_ddseq_1.FULL__SCREEN_consensus_peaks.bed',
#  'HAR_ddseq_2.FULL': 'SCREEN_peaks/HAR_ddseq_2.FULL__SCREEN_consensus_peaks.bed',
#  'MDC_mtscatac_1.FULL': 'SCREEN_peaks/MDC_mtscatac_1.FULL__SCREEN_consensus_peaks.bed',
#  'MDC_mtscatac_2.FULL': 'SCREEN_peaks/MDC_mtscatac_2.FULL__SCREEN_consensus_peaks.bed',
#  'OHS_s3atac_1.FULL': 'SCREEN_peaks/OHS_s3atac_1.FULL__SCREEN_consensus_peaks.bed',
#  'OHS_s3atac_2.FULL': 'SCREEN_peaks/OHS_s3atac_2.FULL__SCREEN_consensus_peaks.bed',
#  'SAN_10xmultiome_1.FULL': 'SCREEN_peaks/SAN_10xmultiome_1.FULL__SCREEN_consensus_peaks.bed',
#  'SAN_10xmultiome_2.FULL': 'SCREEN_peaks/SAN_10xmultiome_2.FULL__SCREEN_consensus_peaks.bed',
#  'STA_10xv11_1.FULL': 'SCREEN_peaks/STA_10xv11_1.FULL__SCREEN_consensus_peaks.bed',
#  'STA_10xv11_2.FULL': 'SCREEN_peaks/STA_10xv11_2.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv11_1.FULL': 'SCREEN_peaks/TXG_10xv11_1.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv2_1.FULL': 'SCREEN_peaks/TXG_10xv2_1.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv2_2.FULL': 'SCREEN_peaks/TXG_10xv2_2.FULL__SCREEN_consensus_peaks.bed',
#  'UCS_ddseq_1.FULL': 'SCREEN_peaks/UCS_ddseq_1.FULL__SCREEN_consensus_peaks.bed',
#  'UCS_ddseq_2.FULL': 'SCREEN_peaks/UCS_ddseq_2.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_10xmultiome_1.FULL': 'SCREEN_peaks/VIB_10xmultiome_1.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_10xmultiome_2.FULL': 'SCREEN_peaks/VIB_10xmultiome_2.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_10xv1_1.FULL': 'SCREEN_peaks/VIB_10xv1_1.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_10xv1_2.FULL': 'SCREEN_peaks/VIB_10xv1_2.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_10xv2_1.FULL': 'SCREEN_peaks/VIB_10xv2_1.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_10xv2_2.FULL': 'SCREEN_peaks/VIB_10xv2_2.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_1.FULL': 'SCREEN_peaks/VIB_hydrop_1.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_11.FULL': 'SCREEN_peaks/VIB_hydrop_11.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_12.FULL': 'SCREEN_peaks/VIB_hydrop_12.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_2.FULL': 'SCREEN_peaks/VIB_hydrop_2.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_21.FULL': 'SCREEN_peaks/VIB_hydrop_21.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_22.FULL': 'SCREEN_peaks/VIB_hydrop_22.FULL__SCREEN_consensus_peaks.bed'}

# %%
for sample, path in consensus_peaks_path_dict.items():
    print(sample)
    peaks_df = pd.read_csv(path, sep='\t', header=None)
    
    chroms_in_df = list(sorted(peaks_df[0].unique()))
    chroms_standard = ["chr" + str(x + 1) for x in range(22)] + ['chrX']
    chroms_nonstandard = list(set(chroms_in_df ) - set(chroms_standard) -  set(['chrM']))
    
    n_standard = peaks_df[0].value_counts()[chroms_standard].sum()
    n_contigs = peaks_df[0].value_counts()[chroms_nonstandard].sum()
    n_chrm = peaks_df[0].value_counts()['chrM'].sum()
    pct_nonstandard = (n_contigs + n_chrm)/len(peaks_df)*100
        
    print(f"\tpeaks on standard chromosomes: {n_standard}")
    print(f"\tpeaks on contigs: {n_contigs}")
    print(f"\tpeaks on chrM: {n_chrm}")
    print(f"\t% peaks non standard chromosomes: {pct_nonstandard}%")
    if 'chrY' in chroms_in_df:
        n_chrY = peaks_df[0].value_counts()['chrY'].sum()
        print(f"\tpeaks on chrY: {n_chrY}")
    else:
        print(f"\tpeaks on chrY: 0")
# Out:
# BIO_ddseq_1.FULL
# 	peaks on standard chromosomes: 165715
# 	peaks on contigs: 242
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.16025930678812636%
# 	peaks on chrY: 0
# BIO_ddseq_2.FULL
# 	peaks on standard chromosomes: 153883
# 	peaks on contigs: 81
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.06688919771927318%
# 	peaks on chrY: 0
# BIO_ddseq_3.FULL
# 	peaks on standard chromosomes: 191169
# 	peaks on contigs: 290
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.1634618397551728%
# 	peaks on chrY: 207
# BIO_ddseq_4.FULL
# 	peaks on standard chromosomes: 174118
# 	peaks on contigs: 264
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.1645595023078467%
# 	peaks on chrY: 191
# BRO_mtscatac_1.FULL
# 	peaks on standard chromosomes: 203455
# 	peaks on contigs: 257
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.136453102835574%
# 	peaks on chrY: 148
# BRO_mtscatac_2.FULL
# 	peaks on standard chromosomes: 202202
# 	peaks on contigs: 251
# 	peaks on chrM: 20
# 	% peaks non standard chromosomes: 0.1338450064946931%
# 	peaks on chrY: 146
# CNA_10xmultiome_1.FULL
# 	peaks on standard chromosomes: 196639
# 	peaks on contigs: 280
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.15334541817092429%
# 	peaks on chrY: 115
# CNA_10xmultiome_2.FULL
# 	peaks on standard chromosomes: 174907
# 	peaks on contigs: 358
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.21735657888731688%
# 	peaks on chrY: 90
# CNA_10xv11_1.FULL
# 	peaks on standard chromosomes: 166939
# 	peaks on contigs: 293
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.18952982254747214%
# 	peaks on chrY: 111
# CNA_10xv11_2.FULL
# 	peaks on standard chromosomes: 160448
# 	peaks on contigs: 284
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.19097384218220273%
# 	peaks on chrY: 111
# CNA_10xv11_3.FULL
# 	peaks on standard chromosomes: 234595
# 	peaks on contigs: 420
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.18890482005114045%
# 	peaks on chrY: 149
# CNA_10xv11_4.FULL
# 	peaks on standard chromosomes: 187553
# 	peaks on contigs: 293
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.16767091787851046%
# 	peaks on chrY: 92
# CNA_10xv11_5.FULL
# 	peaks on standard chromosomes: 170523
# 	peaks on contigs: 340
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.21183837083418675%
# 	peaks on chrY: 97
# CNA_10xv2_1.FULL
# 	peaks on standard chromosomes: 244617
# 	peaks on contigs: 307
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.13513072162254844%
# 	peaks on chrY: 179
# CNA_10xv2_2.FULL
# 	peaks on standard chromosomes: 264416
# 	peaks on contigs: 347
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.13973548450446777%
# 	peaks on chrY: 180
# CNA_hydrop_1.FULL
# 	peaks on standard chromosomes: 86842
# 	peaks on contigs: 265
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.3293966417610669%
# 	peaks on chrY: 74
# CNA_hydrop_2.FULL
# 	peaks on standard chromosomes: 222480
# 	peaks on contigs: 574
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.2671735193387007%
# 	peaks on chrY: 163
# CNA_hydrop_3.FULL
# 	peaks on standard chromosomes: 66251
# 	peaks on contigs: 176
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.2964724295689863%
# 	peaks on chrY: 49
# CNA_mtscatac_1.FULL
# 	peaks on standard chromosomes: 144098
# 	peaks on contigs: 225
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.17180940240810277%
# 	peaks on chrY: 86
# CNA_mtscatac_2.FULL
# 	peaks on standard chromosomes: 151231
# 	peaks on contigs: 209
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.15251350173640912%
# 	peaks on chrY: 74
# EPF_hydrop_1.FULL
# 	peaks on standard chromosomes: 130746
# 	peaks on contigs: 280
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.23044991148281546%
# 	peaks on chrY: 55
# EPF_hydrop_2.FULL
# 	peaks on standard chromosomes: 107130
# 	peaks on contigs: 184
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.1919206976224193%
# 	peaks on chrY: 39
# EPF_hydrop_3.FULL
# 	peaks on standard chromosomes: 131776
# 	peaks on contigs: 347
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.2792387150478641%
# 	peaks on chrY: 61
# EPF_hydrop_4.FULL
# 	peaks on standard chromosomes: 96902
# 	peaks on contigs: 171
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.19877439620989754%
# 	peaks on chrY: 44
# HAR_ddseq_1.FULL
# 	peaks on standard chromosomes: 152046
# 	peaks on contigs: 160
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.12086973658280234%
# 	peaks on chrY: 83
# HAR_ddseq_2.FULL
# 	peaks on standard chromosomes: 162752
# 	peaks on contigs: 208
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.14173257333586936%
# 	peaks on chrY: 103
# MDC_mtscatac_1.FULL
# 	peaks on standard chromosomes: 251451
# 	peaks on contigs: 584
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.24002602596248454%
# 	peaks on chrY: 156
# MDC_mtscatac_2.FULL
# 	peaks on standard chromosomes: 215826
# 	peaks on contigs: 562
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.26985813964234556%
# 	peaks on chrY: 119
# OHS_s3atac_1.FULL
# 	peaks on standard chromosomes: 222028
# 	peaks on contigs: 313
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.15020552072746243%
# 	peaks on chrY: 61
# OHS_s3atac_2.FULL
# 	peaks on standard chromosomes: 506393
# 	peaks on contigs: 1315
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.2633289346700018%
# 	peaks on chrY: 22
# SAN_10xmultiome_1.FULL
# 	peaks on standard chromosomes: 288398
# 	peaks on contigs: 412
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.1506060595569066%
# 	peaks on chrY: 131
# SAN_10xmultiome_2.FULL
# 	peaks on standard chromosomes: 286482
# 	peaks on contigs: 439
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.16100702576112413%
# 	peaks on chrY: 116
# STA_10xv11_1.FULL
# 	peaks on standard chromosomes: 195960
# 	peaks on contigs: 190
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.10857763300760044%
# 	peaks on chrY: 109
# STA_10xv11_2.FULL
# 	peaks on standard chromosomes: 226923
# 	peaks on contigs: 228
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.11048799598545608%
# 	peaks on chrY: 117
# TXG_10xv11_1.FULL
# 	peaks on standard chromosomes: 248577
# 	peaks on contigs: 456
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.19232622382114867%
# 	peaks on chrY: 279
# TXG_10xv2_1.FULL
# 	peaks on standard chromosomes: 347795
# 	peaks on contigs: 526
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.15702958586676313%
# 	peaks on chrY: 380
# TXG_10xv2_2.FULL
# 	peaks on standard chromosomes: 344808
# 	peaks on contigs: 536
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.16214588496907648%
# 	peaks on chrY: 377
# UCS_ddseq_1.FULL
# 	peaks on standard chromosomes: 170853
# 	peaks on contigs: 281
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.17644824866349215%
# 	peaks on chrY: 76
# UCS_ddseq_2.FULL
# 	peaks on standard chromosomes: 199578
# 	peaks on contigs: 370
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.1960294044106616%
# 	peaks on chrY: 122
# VIB_10xmultiome_1.FULL
# 	peaks on standard chromosomes: 122710
# 	peaks on contigs: 106
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.10501550810410375%
# 	peaks on chrY: 62
# VIB_10xmultiome_2.FULL
# 	peaks on standard chromosomes: 167153
# 	peaks on contigs: 166
# 	peaks on chrM: 25
# 	% peaks non standard chromosomes: 0.11413615068362176%
# 	peaks on chrY: 97
# VIB_10xv1_1.FULL
# 	peaks on standard chromosomes: 165105
# 	peaks on contigs: 195
# 	peaks on chrM: 21
# 	% peaks non standard chromosomes: 0.1306549077249714%
# 	peaks on chrY: 114
# VIB_10xv1_2.FULL
# 	peaks on standard chromosomes: 210226
# 	peaks on contigs: 380
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.19133167797406814%
# 	peaks on chrY: 91
# VIB_10xv2_1.FULL
# 	peaks on standard chromosomes: 229427
# 	peaks on contigs: 220
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.10623892437443125%
# 	peaks on chrY: 138
# VIB_10xv2_2.FULL
# 	peaks on standard chromosomes: 259038
# 	peaks on contigs: 252
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.10604944603625735%
# 	peaks on chrY: 165
# VIB_hydrop_1.FULL
# 	peaks on standard chromosomes: 113523
# 	peaks on contigs: 113
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.11965616449203319%
# 	peaks on chrY: 56
# VIB_hydrop_11.FULL
# 	peaks on standard chromosomes: 110395
# 	peaks on contigs: 127
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.13569134741507982%
# 	peaks on chrY: 59
# VIB_hydrop_12.FULL
# 	peaks on standard chromosomes: 79118
# 	peaks on contigs: 75
# 	peaks on chrM: 22
# 	% peaks non standard chromosomes: 0.12245155589219213%
# 	peaks on chrY: 38
# VIB_hydrop_2.FULL
# 	peaks on standard chromosomes: 127542
# 	peaks on contigs: 125
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.11590570913932179%
# 	peaks on chrY: 58
# VIB_hydrop_21.FULL
# 	peaks on standard chromosomes: 99146
# 	peaks on contigs: 97
# 	peaks on chrM: 23
# 	% peaks non standard chromosomes: 0.12088731287651362%
# 	peaks on chrY: 46
# VIB_hydrop_22.FULL
# 	peaks on standard chromosomes: 94547
# 	peaks on contigs: 76
# 	peaks on chrM: 24
# 	% peaks non standard chromosomes: 0.10565575242744091%
# 	peaks on chrY: 35
