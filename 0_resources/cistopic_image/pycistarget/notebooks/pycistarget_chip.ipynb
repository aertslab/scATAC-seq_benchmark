# %%
# For installation
pip install /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/

# %%
# %matplotlib inline
import pycistarget
pycistarget.__version__
# Out:
# '0.1.dev47+g689662b'

# %% [markdown]
# <a class="anchor" id="top"></a>
# # PycisTarget on mouse liver ChIP-seq data
#
# * [0. Getting your input region sets](#1)
# * [1. Homer](#2)
#     * [A. Running Homer](#3)
#     * [B. Exploring Homer results](#4)
# * [2. cisTarget](#5)
#     * [A. Creating cisTarget databases](#6)
#     * [B. Running cisTarget](#7)
#     * [C. Exploring cisTarget results](#8)
# * [3. Differential Motif Enrichment (DEM)](#9)
#     * [A. Creating DEM databases](#10)
#     * [B. Running DEM](#11)
#     * [C. Exploring DEM results](#12)
#     * [D. Advanced usage](#13)
#         * [1. Thresholding on the mean foreground signal](#14)
#         * [2. Using a fixed threshold for the motif hits](#15)
#         * [3. Using a shuffled background](#16)
#         * [4. Specifying contrasts](#17)

# %% [markdown]
# **pycisTarget** is a python module that allows to perform motif enrichment analysis and derive genome-wide cistromes implementing **cisTarget** (Herrmann et al., 2012; Imrichova et al., 2015). In addition, *de novo* cistromes can also be derived (via **Homer** (Heinz et al., 2010)) and pycisTarget also includes a novel approach to derive differentially enriched motifs and cistromes between one or more groups of regions, named **Differentially Enriched Motifs (DEM)**.

# %% [markdown]
# <a class="anchor" id="1"></a>
# ## 0. Getting your input region sets

# %% [markdown]
# **pycisTarget** uses as input a dictionary containing the region set name as label and regions (as pyranges) as values. In this tutorial we will use 4 region sets, which correspond to the top 5K ChIP-seq peaks of Hnf4a, Foxa1, Cebpa and Onecut1 in the mouse liver. We can easily read the data in the correct format using list comprehensension.

# %%
import pyranges as pr
import os
path_to_region_sets = '/staging/leuven/stg_00002/lcb/cbravo/Liver/Multiome/pycistopic/GEMSTAT/ChIP/All_summits'
region_sets_files = ['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K.bed', 'Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K.bed', 'Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K.bed', 'Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K.bed']
region_sets = {x.replace('.bed', ''):pr.read_bed(os.path.join(path_to_region_sets, x)) for x in region_sets_files}

# %% [markdown]
# Apart from the cisTarget method, pycisTarget includes wrapper functions to use Homer (for *de novo* motif enrichment) and a new implementation relying in statistical testing between sets of regions using Cluster-Buster scores (DEM). We will first describe how to perform motif enrichment and form cistromes using Homer.

# %% [markdown]
# <a class="anchor" id="2"></a>
# ## 1. Homer

# %% [markdown]
# First we need to load the functions needed for Homer:

# %%
# Load homer functions
from pycistarget.motif_enrichment_homer import *

# %% [markdown]
# <a class="anchor" id="3"></a>
# #### A. Running Homer

# %% [markdown]
# For running Homer there are some relevant parameters:
# - **homer_path**: Path to the executable Homer files. Homer has to be also accessible in the python paths too.
# - **region_sets**: The input sets of regions
# - **outdir**: Output directory
# - **genome**: Genome assembly (equivalent to the genome parameter in Homer). Several species and genomes are supported, including human (hg18, hg19, hg38) and mouse (mm8, mm9, mm10), among others. Alternatively, it can be a path to custom genome fasta files.
# - **size**: Fragment size to use for motif finding (by default, 'given', which is the whole region).
# - **mask**: Whether to mask repeat regions
# - **denovo**: Whether to perform de novo motif discovery. This will increase the running time considerably. If running de novo motif enrichment, you can use meme with a motif collection of interest to identify potential TFs linked to de novo motifs. If False, Homer will only be run for known motifs.
# - **length**: Motif length for the de novo motif discovery.
# - **n_cpu**: Number of cores to use
# - **meme_path**:  Path to the executable MEME files. MEME has to be also accessible in the python paths too.
# - **meme_collection_path** : Path to the motif collection in meme format. We recommend to use the cisTarget motif collection.
# - **cistrome_annotation** : Annotations to assign motifs to TFs (direct, and/or by motif similarity or orthology)

# %%
# Set correct path to run HOMER
import os
os.putenv('HOMER_HOME','/data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a')
os.environ["PATH"] += os.pathsep + '/data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a/bin:'
homer_path='/data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a/bin/'
# Choose the output directory for the results
outdir='/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/'
# Select your genome
genome='mm10'
# Set correct path to MEME for de novo motif annotation
os.putenv('MEME_HOME','/data/leuven/software/biomed/haswell_centos7/2018a/software/MEME/5.1.1-foss-2018a-Perl-5.28.1-Python-3.6.4')
os.environ["PATH"] += os.pathsep + '/data/leuven/software/biomed/haswell_centos7/2018a/software/MEME/5.1.1-foss-2018a-Perl-5.28.1-Python-3.6.4/bin:'
meme_collection_path = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/ctx_v9_motif_collection.meme'
meme_path='/data/leuven/software/biomed/haswell_centos7/2018a/software/MEME/5.1.1-foss-2018a-Perl-5.28.1-Python-3.6.4/bin/'
# Run
homer_dict=run_homer(homer_path,
                     region_sets,
                     outdir,
                     'mm10',
                     size='given',
                     mask=True,
                     denovo=True,
                     length='8,10,12',
                     n_cpu=4,
                     meme_path = meme_path,
                     meme_collection_path = meme_collection_path,
                     cistrome_annotation = ['Direct_annot', 'Motif_similarity_annot', 'Orthology_annot', 'Motif_similarity_and_Orthology_annot'],
                     _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-21 16:31:31,863 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-05-21 16:32:07,912	ERROR services.py:1276 -- Failed to start the dashboard: Failed to start the dashboard. The last 10 lines of /scratch/leuven/313/vsc31305/ray_spill/session_2021-05-21_16-31-36_998091_12802/logs/dashboard.log:
# 2021-05-21 16:31:54,846	INFO dashboard.py:92 -- Setup static dir for dashboard: /user/leuven/313/vsc31305/.local/lib/python3.7/site-packages/ray/new_dashboard/client/build
# 2021-05-21 16:31:54,887	INFO head.py:162 -- Connect to GCS at b'10.118.230.159:33619'
# 2021-05-21 16:31:54,908	INFO utils.py:202 -- Get all modules by type: DashboardHeadModule
# (pid=12165) 2021-05-21 16:32:25,143 Homer        INFO     Running Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=12165) 2021-05-21 16:32:25,169 Homer        INFO     Running Homer for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K with /data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a/bin/findMotifsGenome.pl /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/regions_bed/Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K.bed mm10 /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K -preparsedDir /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K -size given -len 8,10,12 -mask -keepFiles
# (pid=12163) 2021-05-21 16:32:25,160 Homer        INFO     Running Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=12163) 2021-05-21 16:32:25,169 Homer        INFO     Running Homer for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K with /data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a/bin/findMotifsGenome.pl /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/regions_bed/Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K.bed mm10 /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K -preparsedDir /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K -size given -len 8,10,12 -mask -keepFiles
# (pid=12164) 2021-05-21 16:32:25,143 Homer        INFO     Running Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=12164) 2021-05-21 16:32:25,169 Homer        INFO     Running Homer for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K with /data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a/bin/findMotifsGenome.pl /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/regions_bed/Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K.bed mm10 /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K -preparsedDir /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K -size given -len 8,10,12 -mask -keepFiles
# (pid=12166) 2021-05-21 16:32:25,182 Homer        INFO     Running Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=12166) 2021-05-21 16:32:25,183 Homer        INFO     Running Homer for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K with /data/leuven/software/biomed/haswell_centos7/2018a/software/HOMER/4.10.4-foss-2018a/bin/findMotifsGenome.pl /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/regions_bed/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K.bed mm10 /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K -preparsedDir /staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K -size given -len 8,10,12 -mask -keepFiles
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error
# (raylet) : Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12163) 2021-05-21 17:42:35,710 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=12163) 2021-05-21 17:42:37,073 Homer        INFO     Annotating motifs for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=12163) 2021-05-21 17:42:37,075 Homer        INFO     Annotating known motifs
# (pid=12163) b'Skipping line 310: expected 12 fields, saw 13\n'
# (pid=12163) 2021-05-21 17:43:06,130 Homer        INFO     Comparing de novo motifs with given motif collection with tomtom
# (raylet) cut: write error: Broken pipe
# (pid=12164) 2021-05-21 17:43:15,678 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=12164) 2021-05-21 17:43:16,095 Homer        INFO     Annotating motifs for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=12164) 2021-05-21 17:43:16,096 Homer        INFO     Annotating known motifs
# (pid=12164) b'Skipping line 310: expected 12 fields, saw 13\n'
# (pid=12164) 2021-05-21 17:43:25,846 Homer        INFO     Comparing de novo motifs with given motif collection with tomtom
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12165) 2021-05-21 17:45:43,442 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=12165) 2021-05-21 17:45:44,655 Homer        INFO     Annotating motifs for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=12165) 2021-05-21 17:45:44,657 Homer        INFO     Annotating known motifs
# (pid=12165) b'Skipping line 310: expected 12 fields, saw 13\n'
# (pid=12165) 2021-05-21 17:46:01,956 Homer        INFO     Comparing de novo motifs with given motif collection with tomtom
# (pid=12166) 2021-05-21 17:46:22,825 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=12166) 2021-05-21 17:46:23,038 Homer        INFO     Annotating motifs for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=12166) 2021-05-21 17:46:23,038 Homer        INFO     Annotating known motifs
# (pid=12166) b'Skipping line 310: expected 12 fields, saw 13\n'
# (pid=12166) 2021-05-21 17:46:56,667 Homer        INFO     Comparing de novo motifs with given motif collection with tomtom
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12164) 2021-05-21 18:01:52,520 Homer        INFO     Finding motif hits for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=12164) 2021-05-21 18:01:52,522 Homer        INFO     Retrieving enriched regions per known motif
# (raylet) cut: write error: Broken pipe
# (pid=12163) 2021-05-21 18:02:38,037 Homer        INFO     Finding motif hits for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=12163) 2021-05-21 18:02:38,038 Homer        INFO     Retrieving enriched regions per known motif
# (raylet) cut: write error: Broken pipe
# (pid=12164) 2021-05-21 18:03:16,611 Homer        INFO     Retrieving enriched regions per de novo motif
# (raylet) cut: write error: Broken pipe
# (pid=12164) 2021-05-21 18:03:51,871 Homer        INFO     Getting cistromes for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=12164) 2021-05-21 18:03:53,970 Homer        INFO     Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K done!
# (raylet) cut: write error: Broken pipe
# (pid=12163) 2021-05-21 18:04:17,076 Homer        INFO     Retrieving enriched regions per de novo motif
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error
# (raylet) : Broken pipe
# (pid=12163) 2021-05-21 18:04:53,143 Homer        INFO     Getting cistromes for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (raylet) cut: write error: Broken pipe
# (pid=12163) 2021-05-21 18:04:55,294 Homer        INFO     Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K done!
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12165) 2021-05-21 18:07:16,943 Homer        INFO     Finding motif hits for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=12165) 2021-05-21 18:07:16,947 Homer        INFO     Retrieving enriched regions per known motif
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12165) 2021-05-21 18:08:34,283 Homer        INFO     Retrieving enriched regions per de novo motif
# (pid=12166) 2021-05-21 18:08:36,668 Homer        INFO     Finding motif hits for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=12166) 2021-05-21 18:08:36,669 Homer        INFO     Retrieving enriched regions per known motif
# (raylet) cut: write error: Broken pipe
# (pid=12165) 2021-05-21 18:09:07,412 Homer        INFO     Getting cistromes for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=12165) 2021-05-21 18:09:09,586 Homer        INFO     Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K done!
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12166) 2021-05-21 18:10:23,813 Homer        INFO     Retrieving enriched regions per de novo motif
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=12166) 2021-05-21 18:11:00,941 Homer        INFO     Getting cistromes for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=12166) 2021-05-21 18:11:03,760 Homer        INFO     Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K done!

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Homer_dict.pkl', 'wb') as f:
  pickle.dump(homer_dict, f)

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="4"></a>
# ### B. Exploring Homer results

# %% [markdown]
# We can load the results for exploration.

# %%
# Load
import pickle
infile = open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Homer_dict.pkl', 'rb')
homer_dict = pickle.load(infile)
infile.close()

# %% [markdown]
# To visualize motif enrichment results, we can use the `homer_results()` function:

# %%
homer_results(homer_dict, 'Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K', results='known')
# Out:
# <HTML><HEAD><TITLE>/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K - Homer Known Motif Enrichment Results</TITLE></HEAD>
# <BODY>
# <H1>Homer Known Motif Enrichment Results (/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K)</H1>
# <A HREF="homerResults.html">Homer <i>de novo</i> Motif Results</A><BR/>
# <A HREF="geneOntology.html">Gene Ontology Enrichment Results</A><BR/>
# <A HREF="knownResults.txt">Known Motif Enrichment Results (txt file)</A><BR/>
# Total Target Sequences = 4595, Total Background Sequences = 44689</BR>
# <TABLE border="1" cellpading="0" cellspacing="0">
# <TR><TD>Rank</TD><TD>Motif</TD><TD>Name</TD><TD>P-value</TD><TD>log P-pvalue</TD><TD>q-value (Benjamini)</TD><TD># Target Sequences with Motif</TD><TD>% of Targets Sequences with Motif</TD><TD># Background Sequences with Motif</TD><TD>% of Background Sequences with Motif</TD><TD>Motif File</TD>
# <TD>SVG</TD></TR>
# <TR><TD>1</TD><TD>
# <svg width="255" height="50">
#  <g font-family="Arial" font-weight="bold" font-size="66.5">
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.026,1,49)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.061,0,47.7)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.102,0,44.65)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.811,2,39.55)">A</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,27,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.001,25,48.95)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.003,25,48.9)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.995,26,48.75)">T</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,52,49)">A</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,50,48.95)">C</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.026,50,48.9)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.972,51,47.6)">T</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,75,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.100,76,48.95)">T</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.104,77,43.95)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.795,75,38.75)">G</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.055,100,49)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.076,102,46.25)">A</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.244,101,42.45)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.625,100,30.25)">C</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.061,125,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.104,126,45.95)">T</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.192,127,40.75)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.643,125,31.15)">G</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.003,150,49)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.102,152,48.85)">A</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.138,151,43.75)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.757,150,36.85)">C</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.001,175,49)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,176,48.95)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.027,175,48.9)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.971,177,47.55)">A</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,200,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,201,48.95)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.005,200,48.9)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.993,202,48.65)">A</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.037,227,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.143,225,47.15)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.157,226,40)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.663,225,32.15)">C</text>
#
#  </g>
# </svg>
#
# </TD><TD>CEBP(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512)/Homer</TD><TD>1e-1324</TD><TD>-3.049e+03</TD><TD>0.0000</TD><TD>2719.0</TD><TD>59.17%</TD><TD>5054.3</TD><TD>11.31%</TD><TD><A target="_blank" HREF="knownResults//known1.motif">motif file (matrix)</A></TD>
# <TD><A HREF="knownResults//known1.logo.svg">svg</A></TD>
# </TR>
# <TR><TD>2</TD><TD>
# <svg width="255" height="50">
#  <g font-family="Arial" font-weight="bold" font-size="66.5">
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.050,1,49)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.147,0,46.5)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.352,2,39.15)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.451,0,21.55)">G</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.011,25,49)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.020,27,48.45)">A</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.031,25,47.45)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.938,26,45.9)">T</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.022,50,49)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.029,52,47.9)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.148,50,46.45)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.801,51,39.05)">T</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.024,75,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.032,76,47.8)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.228,75,46.2)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.716,77,34.8)">A</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.024,102,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.051,100,47.8)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.142,100,45.25)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.783,101,38.15)">T</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.031,125,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.042,126,47.45)">T</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.247,127,45.35)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.680,125,33)">G</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.027,150,49)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.053,152,47.65)">A</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.416,150,45)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.504,151,24.2)">T</text>
#
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.016,176,49)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.024,175,48.2)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.074,175,47)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix

# %%
homer_results(homer_dict, 'Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K', results='denovo')
# Out:
# <HTML><HEAD><TITLE>/media/data/users/cbravo/pyCistrome/tutorial/Homer/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K/ - Homer de novo Motif Results</TITLE></HEAD>
# <BODY>
# <H1>Homer <i>de novo</i> Motif Results (/media/data/users/cbravo/pyCistrome/tutorial/Homer/Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K/)</H1>
# <A HREF="knownResults.html">Known Motif Enrichment Results</A><BR/>
# <A HREF="geneOntology.html">Gene Ontology Enrichment Results</A><BR/>
# If Homer is having trouble matching a motif to a known motif, try copy/pasting the matrix file into
# <A HREF="http://www.benoslab.pitt.edu/stamp/">STAMP</A><BR/>
# More information on motif finding results: <A HREF="http://biowhat.ucsd.edu/homer/">HOMER</A>
#  | <A HREF="http://biowhat.ucsd.edu/homer/motif/index.html">Description of Results</A>
#  | <A HREF="http://biowhat.ucsd.edu/homer/motif/practicalTips.html">Tips</A>
# <BR/>
# Total target sequences = 4595<BR/>
# Total background sequences = 44753<BR/>
# <FONT color="red">* - possible false positive</FONT><BR/>
# <TABLE border="1" cellpading="0" cellspacing="0">
# <TR><TD>Rank</TD><TD>Motif</TD><TD>P-value</TD><TD>log P-pvalue</TD><TD>% of Targets</TD><TD>% of Background</TD>
# <TD>STD(Bg STD)</TD>
# <TD>Best Match/Details</TD><TD>Motif File</TD></TR>
# <TR><TD>1
# </TD><TD><svg width="305" height="50">
#  <g font-family="Arial" font-weight="bold" font-size="66.5">
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.116,1,49)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.228,0,43.2)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.324,2,31.8)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.331,0,15.6)">G</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,27,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.001,25,48.95)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.008,25,48.9)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.990,26,48.5)">T</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,52,49)">A</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,50,48.95)">C</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.401,50,48.9)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.597,51,28.85)">T</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.010,75,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.290,76,48.5)">T</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.321,77,34)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.379,75,17.95)">G</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.172,102,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.206,100,40.4)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.256,101,30.1)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.365,100,17.3)">C</text>
#
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.152,126,49)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.208,125,41.4)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.247,127,31)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.394,125,18.65)">G</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.005,150,49)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.291,152,48.75)">A</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.309,151,34.2)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.396,150,18.75)">C</text>
#
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.001,175,49)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,176,48.95)">T</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.397,175,48.9)">C</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.601,177,29.05)">A</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,200,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,201,48.95)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.004,200,48.9)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.994,202,48.7)">A</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.136,227,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.255,225,42.2)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.296,225,29.45)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.313,226,14.65)">T</text>
#
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.237,251,49)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.239,250,37.15)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.243,252,25.2)">A</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.280,250,13.05)">C</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.226,277,49)">A</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.242,276,37.7)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.257,275,25.6)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.274,275,12.75)">C</text>
#
#  </g>
# </svg>
# </TD><TD>1e-1782</TD><TD>-4.104e+03</TD><TD>65.31%</TD><TD>10.04%</TD><TD>55.6bp (153.5bp)</TD><TD>NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer(0.919)<BR/><A target="_blank" HREF="homerResults/motif1.info.html">More Information</A> | <A target="blank" HREF="homerResults/motif1.similar.html">Similar Motifs Found</A></TD><TD><A target="_blank" HREF="homerResults/motif1.motif">motif file (matrix)</A></TD></TR>
# <TR><TD>2
# </TD><TD><svg width="205" height="50">
#  <g font-family="Arial" font-weight="bold" font-size="66.5">
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,0,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,1,48.95)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.181,0,48.9)">G</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.817,2,39.85)">A</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,27,49)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.001,25,48.95)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.011,25,48.9)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.987,26,48.35)">T</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,52,49)">A</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,50,48.95)">C</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.001,50,48.9)">G</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.997,51,48.85)">T</text>
#
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.001,75,49)">C</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,76,48.95)">T</text>
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.097,77,48.9)">A</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.901,75,44.05)">G</text>
#
#   <text fill="#00BB00" x="0" y="0"  transform="matrix(0.53,0,0,0.001,102,49)">A</text>
#   <text fill="#DD0000" x="0" y="0"  transform="matrix(0.65,0,0,0.001,101,48.95)">T</text>
#   <text fill="#F9A500" x="0" y="0"  transform="matrix(0.55,0,0,0.016,100,48.9)">G</text>
#   <text fill="#0000EE" x="0" y="0"  transform="matrix(0.59,0,0,0.982,100,48.1)">C</text>
#
#   <text fill="#DD0000" x="0" y

# %% [markdown]
# You can also access the regions enriched for each motif (use known_motif_hits for known motifs; and denovo_motif_hits for de novo motifs):

# %%
homer_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].known_motif_hits['CEBP(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512)/Homer'][0:10]
# Out:
# ['chr18:60495354-60495855',
#  'chr11:19018746-19019247',
#  'chr1:161070421-161070922',
#  'chr1:82238130-82238631',
#  'chr13:73626916-73627417',
#  'chr10:37275799-37276300',
#  'chr7:89423090-89423591',
#  'chr2:167687611-167688112',
#  'chr13:52981068-52981569',
#  'chr15:96735639-96736140']

# %% [markdown]
# To access cistromes (use known_cistromes for cistromes based on known motifs; and denovo_cistromes for cistromes based on de novo motifs):

# %%
homer_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].known_cistromes['Cebpa'][0:10]
# Out:
# ['chr18:60495354-60495855',
#  'chr11:19018746-19019247',
#  'chr1:161070421-161070922',
#  'chr1:82238130-82238631',
#  'chr13:73626916-73627417',
#  'chr10:37275799-37276300',
#  'chr7:89423090-89423591',
#  'chr2:167687611-167688112',
#  'chr13:52981068-52981569',
#  'chr15:96735639-96736140']

# %% [markdown]
# You can easily export cistromes to a bed file:

# %%
from pycistarget.utils import *
cebpa_cistrome_pr = pr.PyRanges(region_names_to_coordinates(homer_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].known_cistromes['Cebpa']))
cebpa_cistrome_pr.to_bed(path='/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/Homer/cebpa_cistrome_example.bed')

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="5"></a>
# ## 2. cisTarget

# %% [markdown]
# <a class="anchor" id="6"></a>
# #### A. Creating cisTarget databases

# %% [markdown]
# To run **cisTarget** you will need to provide a **ranking database** (that is, a feather file with a dataframe with motifs as rows, genomic regions as columns and their ranked position [based on cis-regulatory module (CRM) score (Frith et al., 2003)] as values). We provide those databases for human (hg38, hg19), mouse (mm10, mm9) and fly (dm3, dm6) at https://resources.aertslab.org/cistarget/.
#
# In addition, **if you want to use other regions or genomes to build your databases**, we provide a step-by-step tutorial and scripts at https://github.com/aertslab/create_cisTarget_databases. Below you can find the basic steps to do so:

# %%
# %%bash
# #### Variables
# region_bed = 'PATH_TO_BED_FILE_WITH_GENOMIC_REGIONS_FOR_DATABASE'
# region_fasta = 'PATH_TO_FASTA_FILE_WITH_GENOMIC_REGIONS_FOR_DATABASE'
# database_suffix = 'SUFFIX_FOR_DATABASE_FILE'
# #### Get fasta sequences
# module load BEDTools # In our system, load BEDTools
# bedtools getfasta -fi /staging/leuven/stg_00002/lcb/resources/mouse/mm10/mm10.fa -bed ${region_bed} > ${region_fasta}
# #### Activate environment
# my_conda_initialize # In our system, initialize conda
# conda activate /staging/leuven/stg_00002/lcb/ghuls/software/miniconda3/envs/create_cistarget_databases
# #### Set ${create_cistarget_databases_dir} to https://github.com/aertslab/create_cisTarget_databases
# create_cistarget_databases_dir='/staging/leuven/stg_00002/lcb/ghuls/software/create_cisTarget_databases'
# #### Score the motifs in 10 chunks
# for current_part in {1..10} ; do ${create_cistarget_databases_dir}/create_cistarget_motif_databases.py
# -f ${region_fasta}
# -M /staging/leuven/stg_00002/lcb/icistarget/data/motifCollection/v9/singletons/
# -m /staging/leuven/stg_00002/lcb/icistarget/data/motifCollection/v9/motifs.txt
# -p ${current_part} 10
# -o ${database_suffix}
# -t 20
# done
# #### Merge scores
# ${create_cistarget_databases_dir}/combine_partial_regions_or_genes_vs_motifs_or_tracks_cistarget_dbs.py -i ${database_suffix} ${output_dir}
# #### Remove chunks
# rm ${database_suffix}*part*
# #### Create rankings
# motifs_vs_regions_scores_feather = 'PATH_TO_MOTIFS_VS_REGIONS_SCORES_DATABASE'
# ${create_cistarget_databases_dir}/convert_motifs_or_tracks_vs_regions_or_genes_scores_to_rankings_cistarget_dbs.py -i ${motifs_vs_regions_scores_feather} -s 555

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="7"></a>
# #### B. Running cisTarget

# %% [markdown]
# For running cisTarget there are some relevant parameters:
# - **ctx_db**: Path to the cisTarget database to use, or a preloaded cisTargetDatabase object (using the same region sets to be analyzed)
# - **region_sets**: The input sets of regions
# - **specie**: Specie to which region coordinates and database belong to. To annotate motifs to TFs using cisTarget annotations, possible values are 'mus_musculus', 'homo_sapiens' or 'drosophila_melanogaster'. If any other value, motifs will not be annotated to a TF unless providing a customized annotation.
# - **fraction_overlap**: Minimum overlap fraction (in any direction) to map input regions to regions in the database. Default: 0.4.
# - **auc_threshold**: Threshold to calculate the AUC. For human and mouse we recommend to set it to 0.005 (default), for fly to 0.01.
# - **nes_threshold**: NES threshold to calculate the motif significant. Default: 3.0
# - **rank_threshold**: Percentage of regions to use as maximum rank to take into account for the region enrichment recovery curve. By default, we use 5% of the total number of regions in the database.
# - **annotation**: Annotation to use to form the cistromes. Default: ['Direct_annot', 'Motif_similarity_annot', 'Orthology_annot', 'Motif_similarity_and_Orthology_annot']
# - **n_cpu**: Number of cpus to use during calculations.

# %%
# Load cistarget functions
from pycistarget.motif_enrichment_cistarget import *

# %%
# Run
cistarget_dict = run_cistarget(ctx_db = '/staging/leuven/stg_00002/icistarget-data/make_rankings/v9/CTX_mm10/CTX_mm10_SCREEN3_1kb_bg_with_mask/CTX_mm10_SCREEN3_1kb_bg_with_mask.regions_vs_motifs.rankings.feather',
                                                      region_sets = region_sets,
                                                      specie = 'mus_musculus',
                                                      auc_threshold = 0.005,
                                                      nes_threshold = 3.0,
                                                      rank_threshold = 0.05,
                                                      annotation = ['Direct_annot', 'Motif_similarity_annot', 'Orthology_annot', 'Motif_similarity_and_Orthology_annot'],
                                                      n_cpu = 4,
                                                      _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-21 15:56:46,117 cisTarget    INFO     Reading cisTarget database
# 2021-05-21 16:04:29,659	ERROR services.py:1276 -- Failed to start the dashboard: Failed to start the dashboard. The last 10 lines of /scratch/leuven/313/vsc31305/ray_spill/session_2021-05-21_16-04-02_048332_31050/logs/dashboard.log:
# 2021-05-21 16:04:20,268	INFO dashboard.py:92 -- Setup static dir for dashboard: /user/leuven/313/vsc31305/.local/lib/python3.7/site-packages/ray/new_dashboard/client/build
# 2021-05-21 16:04:20,669	INFO head.py:162 -- Connect to GCS at b'10.118.230.159:41212'
# 2021-05-21 16:04:20,727	INFO utils.py:202 -- Get all modules by type: DashboardHeadModule
# (pid=7422) 2021-05-21 16:04:52,480 cisTarget    INFO     Running cisTarget for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=7422) 2021-05-21 16:04:52,480 cisTarget    INFO     Running cisTarget for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=7421) 2021-05-21 16:04:52,480 cisTarget    INFO     Running cisTarget for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=7421) 2021-05-21 16:04:52,480 cisTarget    INFO     Running cisTarget for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=7420) 2021-05-21 16:04:52,498 cisTarget    INFO     Running cisTarget for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=7420) 2021-05-21 16:04:52,498 cisTarget    INFO     Running cisTarget for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=7419) 2021-05-21 16:04:52,480 cisTarget    INFO     Running cisTarget for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=7419) 2021-05-21 16:04:52,480 cisTarget    INFO     Running cisTarget for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=7421) 2021-05-21 16:07:06,446 cisTarget    INFO     Annotating motifs for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=7421) 2021-05-21 16:07:06,446 cisTarget    INFO     Annotating motifs for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=7419) 2021-05-21 16:07:06,946 cisTarget    INFO     Annotating motifs for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=7419) 2021-05-21 16:07:06,946 cisTarget    INFO     Annotating motifs for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=7420) 2021-05-21 16:07:09,965 cisTarget    INFO     Annotating motifs for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=7420) 2021-05-21 16:07:09,965 cisTarget    INFO     Annotating motifs for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=7421) 2021-05-21 16:07:10,386 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7421) 2021-05-21 16:07:10,386 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7419) 2021-05-21 16:07:10,385 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7419) 2021-05-21 16:07:10,385 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7420) 2021-05-21 16:07:13,391 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7420) 2021-05-21 16:07:13,391 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7419) 2021-05-21 16:07:15,275 cisTarget    INFO     Getting cistromes for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=7419) 2021-05-21 16:07:15,275 cisTarget    INFO     Getting cistromes for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=7422) 2021-05-21 16:07:16,032 cisTarget    INFO     Annotating motifs for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=7422) 2021-05-21 16:07:16,032 cisTarget    INFO     Annotating motifs for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=7421) 2021-05-21 16:07:16,055 cisTarget    INFO     Getting cistromes for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=7421) 2021-05-21 16:07:16,055 cisTarget    INFO     Getting cistromes for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=7420) 2021-05-21 16:07:16,220 cisTarget    INFO     Getting cistromes for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=7420) 2021-05-21 16:07:16,220 cisTarget    INFO     Getting cistromes for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=7422) 2021-05-21 16:07:19,809 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7422) 2021-05-21 16:07:19,809 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=7422) 2021-05-21 16:07:25,934 cisTarget    INFO     Getting cistromes for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=7422) 2021-05-21 16:07:25,934 cisTarget    INFO     Getting cistromes for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-21 16:07:47,191 cisTarget    INFO     Done!

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/cisTarget/cisTarget_dict.pkl', 'wb') as f:
  pickle.dump(cistarget_dict, f)

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="8"></a>
# #### C. Exploring cisTarget results

# %% [markdown]
# We can load the results for exploration.

# %%
# Load
import pickle
infile = open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/cisTarget/cisTarget_dict.pkl', 'rb')
cistarget_dict = pickle.load(infile)
infile.close()

# %% [markdown]
# To visualize motif enrichment results, we can use the `cisTarget_results()` function:

# %%
cistarget_results(cistarget_dict, name='Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Region_set</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">NES</th>
#       <th style="min-width: 80px;">AUC</th>
#       <th style="min-width: 80px;">Rank_at_max</th>
#       <th style="min-width: 80px;">Motif_hits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>cisbp__M5317</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5317.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>18.341869</td>
#       <td>0.091825</td>
#       <td>60113.0</td>
#       <td>2446</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPE_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPE_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>18.218210</td>
#       <td>0.091232</td>
#       <td>60594.0</td>
#       <td>2443</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07414</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07414.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpa, Cebpb</td>
#       <td>Cebpd, Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>Atf3, Bmyc, Hlf, Myc, Nfil3</td>
#       <td>18.055576</td>
#       <td>0.090453</td>
#       <td>60353.0</td>
#       <td>2606</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5314</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5314.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>17.952745</td>
#       <td>0.089960</td>
#       <td>60640.0</td>
#       <td>2417</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPB_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPB_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>17.655014</td>
#       <td>0.088534</td>
#       <td>60617.0</td>
#       <td>2389</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPD_NRTTGCGYAAYN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPD_NRTTGCGYAAYN_eDBD.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Dbp, Ep300, Hlf, Ppargc1a, Tef</td>
#       <td>17.425034</td>
#       <td>0.087432</td>
#       <td>60524.0</td>
#       <td>2314</td>
#     </tr>
#     <tr>
#       <th>hocomoco__CEBPB_MOUSE.H11MO.0.A</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/hocomoco__CEBPB_MOUSE.H11MO.0.A.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpa, Cebpb</td>
#       <td>Cebpd, Cebpe, Cebpg</td>
#       <td>NaN</td>
#       <td>Ep300</td>
#       <td>17.383533</td>
#       <td>0.087233</td>
#       <td>60630.0</td>
#       <td>2604</td>
#     </tr>
#     <tr>
#       <th>cisbp__M0315</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M0315.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpa, Cebpb</td>
#       <td>Cebpd, Cebpe, Cebpg, Hlf</td>
#       <td>NaN</td>
#       <td>Ep300, Nfil3, Ppargc1a</td>
#       <td>17.377502</td>
#       <td>0.087204</td>
#       <td>60187.0</td>
#       <td>2617</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M08910</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M08910.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Dbp, Ep300, Hlf, Ppargc1a, Tef</td>
#       <td>17.132434</td>
#       <td>0.086030</td>
#       <td>60626.0</td>
#       <td>2477</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5316</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5316.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>17.111585</td>
#       <td>0.085930</td>
#       <td>60530.0</td>
#       <td>2392</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPD_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPD_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>16.836237</td>
#       <td>0.084610</td>
#       <td>59032.0</td>
#       <td>2129</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPD_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPD_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>16.802178</td>
#       <td>0.084447</td>
#       <td>60619.0</td>
#       <td>2370</td>
#     </tr>
#     <tr>
#       <th>hocomoco__CEBPB_HUMAN.H11MO.0.A</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/hocomoco__CEBPB_HUMAN.H11MO.0.A.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpa</td>
#       <td>Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpb</td>
#       <td>Ep300</td>
#       <td>16.784994</td>
#       <td>0.084365</td>
#       <td>60580.0</td>
#       <td>2591</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5995</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5995.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>16.557772</td>
#       <td>0.083276</td>
#       <td>60599.0</td>
#       <td>2354</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPG_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPG_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpb, Cebpd, Dbp</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>16.526107</td>
#       <td>0.083125</td>
#       <td>60466.0</td>
#       <td>2429</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5315</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5315.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>16.522240</td>
#       <td>0.083106</td>
#       <td>60632.0</td>
#       <td>2338</td>

# %% [markdown]
# This table can also be easily exported to a html file:

# %%
out_file = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/cisTarget/Cebpa_motif_enricment.html'
cistarget_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].motif_enrichment.to_html(open(out_file, 'w'), escape=False, col_space=80)

# %% [markdown]
# You can also access the regions enriched for each motif. You will find to entries in motif_hits (similarly for cistromes); in 'Region_set' you will find the coordinates as in the input regions, in 'Database' you will find the coordinates as in the database:

# %%
cistarget_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].motif_hits['Region_set']['cisbp__M5317'][0:10]
# Out:
# ['chr15:85231705-85232206',
#  'chr12:83543908-83544409',
#  'chr15:81523371-81523872',
#  'chr1:138606672-138607173',
#  'chr17:87263386-87263887',
#  'chr15:77196848-77197349',
#  'chr15:25914953-25915454',
#  'chr2:73046931-73047432',
#  'chr1:31093894-31094395',
#  'chr9:50834945-50835446']

# %% [markdown]
# To access cistromes (only available if motifs have been annotated):

# %%
cistarget_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].cistromes['Region_set']['Cebpa'][0:10]
# Out:
# ['chr15:85231705-85232206',
#  'chr11:75472531-75473032',
#  'chr12:83543908-83544409',
#  'chr15:81523371-81523872',
#  'chr5:147726931-147727432',
#  'chr1:60859768-60860269',
#  'chr1:138606672-138607173',
#  'chr17:87263386-87263887',
#  'chr9:14398068-14398569',
#  'chr15:77196848-77197349']

# %% [markdown]
# You can easily export cistromes to a bed file:

# %%
from pycistarget.utils import *
cebpa_cistrome = cistarget_dict['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].cistromes['Region_set']['Cebpa']
cebpa_cistrome_pr = pr.PyRanges(region_names_to_coordinates(cebpa_cistrome))
cebpa_cistrome_pr.to_bed(path='/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/cisTarget/cebpa_cistrome_example.bed')

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="9"></a>
# # 3. DEM

# %% [markdown]
# <a class="anchor" id="10"></a>
# #### A. Creating your DEM databases

# %% [markdown]
# To run **DEM** you will need to provide a **CRM scores database** (that is, a feather file with a dataframe with motifs as rows, genomic regions as columns and their cis-regulatory module (CRM) score (Frith et al., 2003) as values). We provide those databases for human (hg38, hg19), mouse (mm10, mm9) and fly (dm3, dm6) at https://resources.aertslab.org/cistarget/.
#
# In addition, **if you want to use other regions or genomes to build your databases**, we provide a step-by-step tutorial and scripts at https://github.com/aertslab/create_cisTarget_databases. The steps are the same as for creating a cisTarget database, without running the last step for ranking the regions. Below you can find the basic steps to do so:

# %%
# %%bash
# #### Variables
# region_bed = 'PATH_TO_BED_FILE_WITH_GENOMIC_REGIONS_FOR_DATABASE'
# region_fasta = 'PATH_TO_FASTA_FILE_WITH_GENOMIC_REGIONS_FOR_DATABASE'
# database_suffix = 'SUFFIX_FOR_DATABASE_FILE'
# #### Get fasta sequences
# module load BEDTools # In our system, load BEDTools
# bedtools getfasta -fi /staging/leuven/stg_00002/lcb/resources/mouse/mm10/mm10.fa -bed ${region_bed} > ${region_fasta}
# #### Activate environment
# my_conda_initialize # In our system, initialize conda
# conda activate /staging/leuven/stg_00002/lcb/ghuls/software/miniconda3/envs/create_cistarget_databases
# #### Set ${create_cistarget_databases_dir} to https://github.com/aertslab/create_cisTarget_databases
# create_cistarget_databases_dir='/staging/leuven/stg_00002/lcb/ghuls/software/create_cisTarget_databases'
# #### Score the motifs in 10 chunks
# for current_part in {1..10} ; do ${create_cistarget_databases_dir}/create_cistarget_motif_databases.py
# -f ${region_fasta}
# -M /staging/leuven/stg_00002/lcb/icistarget/data/motifCollection/v9/singletons/
# -m /staging/leuven/stg_00002/lcb/icistarget/data/motifCollection/v9/motifs.txt
# -p ${current_part} 10
# -o ${database_suffix}
# -t 20
# done
# #### Merge scores
# ${create_cistarget_databases_dir}/combine_partial_regions_or_genes_vs_motifs_or_tracks_cistarget_dbs.py -i ${database_suffix} ${output_dir}
# #### Remove chunks
# rm ${database_suffix}*part*

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="11"></a>
# #### B. Running DEM

# %% [markdown]
# For running DEM there are some relevant parameters:
# - **dem_db**: Path to the DEM database to use, or a preloaded DEMDatabase object (using the same region sets to be analyzed)
# - **region_sets**: The input sets of regions
# - **specie**: Specie to which region coordinates and database belong to. To annotate motifs to TFs using cisTarget annotations, possible values are 'mus_musculus', 'homo_sapiens' or 'drosophila_melanogaster'. If any other value, motifs will not be annotated to a TF unless providing a customized annotation.
# - **contrasts**: Type of contrast to perform. If 'Other', background regions will be taken from other region sets; if 'Shuffle' the background will consist of the scores on shuffled input sequences. You can also provide a list specifying the specific contrasts to make. We will show some examples of these modalities below. When using 'Shuffle', the cluster-buster path, the genome fasta and the path to the folder with the motifs to score (cluster-buster format) has to be provided.
# - **fraction_overlap**: Minimum overlap fraction (in any direction) to map input regions to regions in the database. Default: 0.4.
# - **max_bg_regions**: Maximum number of background regions to use. Default: None (all regions).
# - **adjpval_thr**: Maximum adjusted p-value to select motifs. Default: 0.05
# - **log2fc_thr**: Minimum LogFC between the regions set and te background to consider the motif as differentially enriched. Default: 1.
# - **mean_fg_thr**: Minimum mean CRM value in the foreground (region set) to consider the motif differentially enriched. Default: 0
# - **motif_hit_thr**: Minimum CRM value to consider a region a motif hit. If None (default), an optimal threshold will be calculated per motif by comparing foreground and background.
# - **annotation**: Annotation to use to form the cistromes. Here we will only use the direct annotation as example. Default: ['Direct_annot', 'Motif_similarity_annot', 'Orthology_annot', 'Motif_similarity_and_Orthology_annot']
# - **n_cpu**: Number of cpus to use during calculations.

# %%
# Load DEM functions
from pycistarget.motif_enrichment_dem import *

# %%
DEM_dict = DEM(dem_db = '/staging/leuven/stg_00002/icistarget-data/make_rankings/v9/CTX_mm10/CTX_mm10_SCREEN3_1kb_bg_with_mask/CTX_mm10_SCREEN3_1kb_bg_with_mask.regions_vs_motifs.scores.feather',
    region_sets = region_sets,
    specie = 'mus_musculus',
    contrasts = 'Other',
    name = 'DEM',
    fraction_overlap = 0.4,
    max_bg_regions = 500,
    adjpval_thr = 0.05,
    log2fc_thr = 1,
    mean_fg_thr = 0,
    motif_hit_thr = None,
    cluster_buster_path = None,
    path_to_genome_fasta = None,
    path_to_motifs = None,
    annotation = ['Direct_annot'],
    n_cpu = 4,
    tmp_dir = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tmp',
    _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-20 14:50:06,004 DEM          INFO     Reading DEM database
# 2021-05-20 14:55:31,347 DEM          INFO     Creating contrast groups
# 2021-05-20 14:55:34,272	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=22837) 2021-05-20 14:55:44,096 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=22837) 2021-05-20 14:55:44,096 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=22836) 2021-05-20 14:55:45,161 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=22836) 2021-05-20 14:55:45,161 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=22834) 2021-05-20 14:55:45,297 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=22834) 2021-05-20 14:55:45,297 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=22835) 2021-05-20 14:55:45,610 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=22835) 2021-05-20 14:55:45,610 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=22837) 2021-05-20 14:56:02,210 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22837) 2021-05-20 14:56:02,210 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22835) 2021-05-20 14:56:05,688 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22835) 2021-05-20 14:56:05,688 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22836) 2021-05-20 14:56:05,926 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22836) 2021-05-20 14:56:05,926 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22834) 2021-05-20 14:56:06,066 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=22834) 2021-05-20 14:56:06,066 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 14:57:00,359 DEM          INFO     Forming cistromes
# 2021-05-20 14:57:00,710 DEM          INFO     Done!

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/DEM_dict_B.pkl', 'wb') as f:
  pickle.dump(DEM_dict, f)

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="12"></a>
# #### C. Exploring DEM results

# %% [markdown]
# We can load the results for exploration.

# %%
# Load
import pickle
infile = open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/DEM_dict_B.pkl', 'rb')
DEM_dict = pickle.load(infile)
infile.close()

# %% [markdown]
# To visualize motif enrichment results, we can use the `DEM_results()` function:

# %%
DEM_dict.DEM_results('Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Contrast</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">Log2FC</th>
#       <th style="min-width: 80px;">Adjusted_pval</th>
#       <th style="min-width: 80px;">Mean_fg</th>
#       <th style="min-width: 80px;">Mean_bg</th>
#       <th style="min-width: 80px;">Motif_hit_thr</th>
#       <th style="min-width: 80px;">Number_of_regions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>taipale_tf_pairs__FLI1_CEBPD_RNCGGANNTTGCGCAAN_CAP</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_tf_pairs__FLI1_CEBPD_RNCGGANNTTGCGCAAN_CAP.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Cebpd, Fli1</td>
#       <td>NaN</td>
#       <td>2.627919</td>
#       <td>0.008487</td>
#       <td>0.314952</td>
#       <td>0.050952</td>
#       <td>1.1000</td>
#       <td>428.0</td>
#     </tr>
#     <tr>
#       <th>taipale_tf_pairs__ATF4_TEF_RNMTGATGCAATN_CAP</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_tf_pairs__ATF4_TEF_RNMTGATGCAATN_CAP.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Atf4, Tef</td>
#       <td>NaN</td>
#       <td>2.449714</td>
#       <td>0.000787</td>
#       <td>0.455437</td>
#       <td>0.083366</td>
#       <td>2.3800</td>
#       <td>363.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPG_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.435591</td>
#       <td>0.0</td>
#       <td>1.327401</td>
#       <td>0.245367</td>
#       <td>2.1100</td>
#       <td>1413.0</td>
#     </tr>
#     <tr>
#       <th>taipale__Atf4_DBD_NGGATGATGCAATM_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__Atf4_DBD_NGGATGATGCAATM_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Atf4</td>
#       <td>Cebpg, Ddit3</td>
#       <td>NaN</td>
#       <td>Cebpb, Ep300, Jun</td>
#       <td>2.367688</td>
#       <td>0.003386</td>
#       <td>0.378252</td>
#       <td>0.073289</td>
#       <td>2.9200</td>
#       <td>249.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp, Hlf</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Nfil3, Ppargc1a, Tef</td>
#       <td>2.333029</td>
#       <td>0.0</td>
#       <td>1.289099</td>
#       <td>0.255844</td>
#       <td>1.6100</td>
#       <td>1610.0</td>
#     </tr>
#     <tr>
#       <th>taipale_tf_pairs__TEAD4_CEBPD_NTTRCGYAANNNNNNRGWATGY_CAP</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_tf_pairs__TEAD4_CEBPD_NTTRCGYAANNNNNNRGWATGY_CAP.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Cebpd, Tead4</td>
#       <td>NaN</td>
#       <td>2.332689</td>
#       <td>0.000001</td>
#       <td>0.400207</td>
#       <td>0.079447</td>
#       <td>0.6470</td>
#       <td>767.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5318</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5318.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.330356</td>
#       <td>0.0</td>
#       <td>1.42071</td>
#       <td>0.282487</td>
#       <td>2.2000</td>
#       <td>1478.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M09010</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M09010.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Atf2, Cebpa, Cebpb, Cebpg, Nfil3</td>
#       <td>Dbp, Hlf, Tef</td>
#       <td>Cebpe, Crebl2</td>
#       <td>2.293414</td>
#       <td>0.0</td>
#       <td>0.655187</td>
#       <td>0.133653</td>
#       <td>1.0000</td>
#       <td>1067.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPG_full_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_full_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.279199</td>
#       <td>0.0</td>
#       <td>1.511894</td>
#       <td>0.311468</td>
#       <td>1.1200</td>
#       <td>2187.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__TEF_NRTTAYGTAAYN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__TEF_NRTTAYGTAAYN_eDBD.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Atf2, Atf4, Cebpa, Creb1, Dbp, Hlf, Nfil3</td>
#       <td>Tef</td>
#       <td>Cebpb, Cebpd, Cebpe, Cebpg, Creb5, Crem, Jdp2, Xbp1</td>
#       <td>2.266265</td>
#       <td>0.0</td>
#       <td>0.664474</td>
#       <td>0.138122</td>
#       <td>2.3300</td>
#       <td>665.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5988</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5988.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Atf4</td>
#       <td>Cebpg, Ddit3</td>
#       <td>NaN</td>
#       <td>Cebpb, Ep300, Jun</td>
#       <td>2.192377</td>
#       <td>0.000001</td>
#       <td>0.51717</td>
#       <td>0.113152</td>
#       <td>3.0400</td>
#       <td>330.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5319</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5319.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.174326</td>
#       <td>0.0</td>
#       <td>1.573493</td>
#       <td>0.3486</td>
#       <td>0.7790</td>
#       <td>2613.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpb, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Dbp, Ep300, Hlf, Ppargc1a, Tef</td>
#       <td>2.171451</td>
#       <td>0.0</td>
#       <td>1.662524</td>
#       <td>0.369059</td>
#       <td>2.6200</td>
#       <td>1480.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Dbp</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>2.165566</td>
#       <td>0.0</td>
#       <td>1.46913</td>
#       <td>0.327461</td>
#       <td>2.4500</td>
#       <td>1381.0</td>

# %% [markdown]
# This table can also be easily exported to a html file:

# %%
out_file = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/Cebpa_motif_enricment.html'
DEM_dict.motif_enrichment['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'].to_html(open(out_file, 'w'), escape=False, col_space=80)

# %% [markdown]
# You can also access the regions enriched for each motif. You will find to entries in motif_hits (similarly for cistromes); in 'Region_set' you will find the coordinates as in the input regions, in 'Database' you will find the coordinates as in the database:

# %%
DEM_dict.motif_hits['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['taipale__CEBPG_DBD_NTTRCGCAAY'][0:10]
# Out:
# ['chr3:104601631-104602132',
#  'chr4:48132714-48133215',
#  'chr5:37960182-37960683',
#  'chr14:12104181-12104682',
#  'chr3:118477970-118478471',
#  'chr8:11088866-11089367',
#  'chr7:66311206-66311707',
#  'chr13:55361124-55361625',
#  'chr8:22878215-22878716',
#  'chr15:36394865-36395366']

# %% [markdown]
# To access cistromes (only available if motifs have been annotated):

# %%
DEM_dict.cistromes['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['Cebpa'][0:10]
# Out:
# ['chr10:128964974-128965475',
#  'chr14:55560165-55560666',
#  'chr3:104601631-104602132',
#  'chr4:156124035-156124536',
#  'chr2:168003318-168003819',
#  'chr5:87147990-87148491',
#  'chr11:90240601-90241102',
#  'chr18:51130579-51131080',
#  'chr4:48132714-48133215',
#  'chr9:75764709-75765210']

# %% [markdown]
# What is the length of this cistrome? We will compare how this changes with different settings below:

# %%
len(DEM_dict.cistromes['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['Cebpa'])
# Out:
# 3819

# %% [markdown]
# You can easily export cistromes to a bed file:

# %%
from pycistarget.utils import *
cebpa_cistrome = DEM_dict.cistromes['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['Cebpa']
cebpa_cistrome_pr = pr.PyRanges(region_names_to_coordinates(cebpa_cistrome))
cebpa_cistrome_pr.to_bed(path='/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/cebpa_cistrome_example.bed')

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="13"></a>
# #### D. Advanced usage

# %% [markdown]
# <a class="anchor" id="14"></a>
# ##### 1. Thresholding on the mean foreground signal

# %% [markdown]
# Above you may have noticed some motifs with high LogFC values, but low signal in both foreground and background. To avoid them, you can set a threshold on the mean CRM value in the foreground with `mean_fg_thr`. Here we will set it to 1:

# %%
DEM_dict = DEM(dem_db = '/staging/leuven/stg_00002/icistarget-data/make_rankings/v9/CTX_mm10/CTX_mm10_SCREEN3_1kb_bg_with_mask/CTX_mm10_SCREEN3_1kb_bg_with_mask.regions_vs_motifs.scores.feather',
    region_sets = region_sets,
    specie = 'mus_musculus',
    contrasts = 'Other',
    name = 'DEM',
    fraction_overlap = 0.4,
    max_bg_regions = 500,
    adjpval_thr = 0.05,
    log2fc_thr = 1,
    mean_fg_thr = 1,
    motif_hit_thr = None,
    n_cpu = 4,
    cluster_buster_path = None,
    path_to_genome_fasta = None,
    path_to_motifs = None,
    annotation = ['Direct_annot'],
    tmp_dir = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tmp',
    _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-20 15:02:37,680 DEM          INFO     Reading DEM database
# 2021-05-20 15:03:45,343 DEM          INFO     Creating contrast groups
# 2021-05-20 15:03:48,130	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=27254) 2021-05-20 15:03:57,085 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=27254) 2021-05-20 15:03:57,085 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=27254) 2021-05-20 15:03:57,085 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=27253) 2021-05-20 15:03:58,535 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=27253) 2021-05-20 15:03:58,535 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=27253) 2021-05-20 15:03:58,535 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=27252) 2021-05-20 15:03:58,555 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=27252) 2021-05-20 15:03:58,555 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=27252) 2021-05-20 15:03:58,555 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=27255) 2021-05-20 15:03:58,625 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=27255) 2021-05-20 15:03:58,625 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=27255) 2021-05-20 15:03:58,625 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=27254) 2021-05-20 15:04:11,979 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27254) 2021-05-20 15:04:11,979 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27254) 2021-05-20 15:04:11,979 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27252) 2021-05-20 15:04:15,301 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27252) 2021-05-20 15:04:15,301 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27252) 2021-05-20 15:04:15,301 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27253) 2021-05-20 15:04:15,594 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27253) 2021-05-20 15:04:15,594 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27253) 2021-05-20 15:04:15,594 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27255) 2021-05-20 15:04:15,849 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27255) 2021-05-20 15:04:15,849 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=27255) 2021-05-20 15:04:15,849 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 15:04:50,815 DEM          INFO     Forming cistromes
# 2021-05-20 15:04:51,010 DEM          INFO     Done!

# %% [markdown]
# You will observe now that these motifs are gone:

# %%
DEM_dict.DEM_results('Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Contrast</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">Log2FC</th>
#       <th style="min-width: 80px;">Adjusted_pval</th>
#       <th style="min-width: 80px;">Mean_fg</th>
#       <th style="min-width: 80px;">Mean_bg</th>
#       <th style="min-width: 80px;">Motif_hit_thr</th>
#       <th style="min-width: 80px;">Number_of_regions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>taipale__CEBPG_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.435591</td>
#       <td>0.0</td>
#       <td>1.327401</td>
#       <td>0.245367</td>
#       <td>2.110</td>
#       <td>1413.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp, Hlf</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Nfil3, Ppargc1a, Tef</td>
#       <td>2.333029</td>
#       <td>0.0</td>
#       <td>1.289099</td>
#       <td>0.255844</td>
#       <td>1.610</td>
#       <td>1610.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5318</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5318.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.330356</td>
#       <td>0.0</td>
#       <td>1.42071</td>
#       <td>0.282487</td>
#       <td>2.200</td>
#       <td>1478.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPG_full_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_full_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.279199</td>
#       <td>0.0</td>
#       <td>1.511894</td>
#       <td>0.311468</td>
#       <td>1.120</td>
#       <td>2187.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5319</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5319.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.174326</td>
#       <td>0.0</td>
#       <td>1.573493</td>
#       <td>0.3486</td>
#       <td>0.779</td>
#       <td>2613.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpb, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Dbp, Ep300, Hlf, Ppargc1a, Tef</td>
#       <td>2.171451</td>
#       <td>0.0</td>
#       <td>1.662524</td>
#       <td>0.369059</td>
#       <td>2.620</td>
#       <td>1480.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Dbp</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>2.165566</td>
#       <td>0.0</td>
#       <td>1.46913</td>
#       <td>0.327461</td>
#       <td>2.450</td>
#       <td>1381.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07413</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07413.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>NaN</td>
#       <td>Cebpe, Ep300</td>
#       <td>2.109829</td>
#       <td>0.0</td>
#       <td>1.89574</td>
#       <td>0.439195</td>
#       <td>1.490</td>
#       <td>2463.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07080</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07080.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpb</td>
#       <td>Bmyc, Ep300, Myc</td>
#       <td>2.082265</td>
#       <td>0.0</td>
#       <td>2.516838</td>
#       <td>0.594335</td>
#       <td>2.160</td>
#       <td>2582.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07689</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07689.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp, Hlf</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Nfil3, Ppargc1a, Tef</td>
#       <td>2.079418</td>
#       <td>0.0</td>
#       <td>1.738856</td>
#       <td>0.41143</td>
#       <td>2.520</td>
#       <td>1561.0</td>
#     </tr>
#     <tr>
#       <th>taipale__Cebpb_DBD_NTTRCGCAAY_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__Cebpb_DBD_NTTRCGCAAY_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300</td>
#       <td>2.077897</td>
#       <td>0.0</td>
#       <td>1.843061</td>
#       <td>0.436547</td>
#       <td>1.500</td>
#       <td>2391.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPD_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPD_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>2.040281</td>
#       <td>0.0</td>
#       <td>1.875253</td>
#       <td>0.455905</td>
#       <td>1.940</td>
#       <td>2050.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPB_full_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPB_full_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>2.026426</td>
#       <td>0.0</td>
#       <td>1.932452</td>
#       <td>0.474344</td>
#       <td>1.660</td>
#       <td>2347.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5995</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5995.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>2.01841</td>
#       <td>0.0</td>
#       <td>1.89166</td>
#       <td>0.466919</td>
#       <td>1.580</td>
#       <td>2370.0</td>
#     </tr>
#     <tr>
#       <th>factorbook__CEBPB</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/factorbook__CEBPB.png" width="200" ></td>
#       <td>Cebpa_ERR235722

# %% [markdown]
# Let's check the length of the cistrome:

# %%
len(DEM_dict.cistromes['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['Cebpa'])
# Out:
# 3819

# %% [markdown]
# And save this object:

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/DEM_dict_D1.pkl', 'wb') as f:
  pickle.dump(DEM_dict, f)

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="15"></a>
# ##### 2. Using a fixed threshold for the motif hits

# %% [markdown]
# You may have also noticed that cistromes are larger compared to Homer or cisTarget, and this will largely depend on your background (cistromes will be formed by those regions that are more enriched for that motif compared to that background). You can also set a fixed threshold to consider a motif a hit with `motif_hit_thr`. Here we will set it to 3.

# %%
DEM_dict = DEM(dem_db = '/staging/leuven/stg_00002/icistarget-data/make_rankings/v9/CTX_mm10/CTX_mm10_SCREEN3_1kb_bg_with_mask/CTX_mm10_SCREEN3_1kb_bg_with_mask.regions_vs_motifs.scores.feather',
    region_sets = region_sets,
    specie = 'mus_musculus',
    contrasts = 'Other',
    name = 'DEM',
    fraction_overlap = 0.4,
    max_bg_regions = 500,
    adjpval_thr = 0.05,
    log2fc_thr = 1,
    mean_fg_thr = 1,
    motif_hit_thr = 3,
    n_cpu = 4,
    cluster_buster_path = None,
    path_to_genome_fasta = None,
    path_to_motifs = None,
    annotation = ['Direct_annot'],
    tmp_dir = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tmp',
    _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-20 15:06:10,529 DEM          INFO     Reading DEM database
# 2021-05-20 15:07:15,600 DEM          INFO     Creating contrast groups
# 2021-05-20 15:07:18,434	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=29491) 2021-05-20 15:07:27,651 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=29491) 2021-05-20 15:07:27,651 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=29491) 2021-05-20 15:07:27,651 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=29491) 2021-05-20 15:07:27,651 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=29493) 2021-05-20 15:07:29,285 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=29493) 2021-05-20 15:07:29,285 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=29493) 2021-05-20 15:07:29,285 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=29493) 2021-05-20 15:07:29,285 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=29494) 2021-05-20 15:07:29,491 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=29494) 2021-05-20 15:07:29,491 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=29494) 2021-05-20 15:07:29,491 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=29494) 2021-05-20 15:07:29,491 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=29492) 2021-05-20 15:07:30,134 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=29492) 2021-05-20 15:07:30,134 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=29492) 2021-05-20 15:07:30,134 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=29492) 2021-05-20 15:07:30,134 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=29491) 2021-05-20 15:07:42,074 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29491) 2021-05-20 15:07:42,074 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29491) 2021-05-20 15:07:42,074 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29491) 2021-05-20 15:07:42,074 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29493) 2021-05-20 15:07:45,507 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29493) 2021-05-20 15:07:45,507 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29493) 2021-05-20 15:07:45,507 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29493) 2021-05-20 15:07:45,507 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29494) 2021-05-20 15:07:46,234 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29494) 2021-05-20 15:07:46,234 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29494) 2021-05-20 15:07:46,234 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29494) 2021-05-20 15:07:46,234 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29492) 2021-05-20 15:07:47,143 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29492) 2021-05-20 15:07:47,143 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29492) 2021-05-20 15:07:47,143 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=29492) 2021-05-20 15:07:47,143 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-05-20 15:08:23,063 DEM          INFO     Forming cistromes
# 2021-05-20 15:08:23,250 DEM          INFO     Done!

# %% [markdown]
# You will notice now that the number of motif hits per motif is generally lower.

# %%
DEM_dict.DEM_results('Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Contrast</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">Log2FC</th>
#       <th style="min-width: 80px;">Adjusted_pval</th>
#       <th style="min-width: 80px;">Mean_fg</th>
#       <th style="min-width: 80px;">Mean_bg</th>
#       <th style="min-width: 80px;">Motif_hit_thr</th>
#       <th style="min-width: 80px;">Number_of_regions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>taipale__CEBPG_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.435591</td>
#       <td>0.0</td>
#       <td>1.327401</td>
#       <td>0.245367</td>
#       <td>3.0</td>
#       <td>1006.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp, Hlf</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Nfil3, Ppargc1a, Tef</td>
#       <td>2.333029</td>
#       <td>0.0</td>
#       <td>1.289099</td>
#       <td>0.255844</td>
#       <td>3.0</td>
#       <td>977.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5318</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5318.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.330356</td>
#       <td>0.0</td>
#       <td>1.42071</td>
#       <td>0.282487</td>
#       <td>3.0</td>
#       <td>1098.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPG_full_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_full_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.279199</td>
#       <td>0.0</td>
#       <td>1.511894</td>
#       <td>0.311468</td>
#       <td>3.0</td>
#       <td>1163.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5319</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5319.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.174326</td>
#       <td>0.0</td>
#       <td>1.573493</td>
#       <td>0.3486</td>
#       <td>3.0</td>
#       <td>1172.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpb, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Dbp, Ep300, Hlf, Ppargc1a, Tef</td>
#       <td>2.171451</td>
#       <td>0.0</td>
#       <td>1.662524</td>
#       <td>0.369059</td>
#       <td>3.0</td>
#       <td>1274.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Dbp</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>2.165566</td>
#       <td>0.0</td>
#       <td>1.46913</td>
#       <td>0.327461</td>
#       <td>3.0</td>
#       <td>1158.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07413</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07413.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>NaN</td>
#       <td>Cebpe, Ep300</td>
#       <td>2.109829</td>
#       <td>0.0</td>
#       <td>1.89574</td>
#       <td>0.439195</td>
#       <td>3.0</td>
#       <td>1386.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07080</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07080.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpb</td>
#       <td>Bmyc, Ep300, Myc</td>
#       <td>2.082265</td>
#       <td>0.0</td>
#       <td>2.516838</td>
#       <td>0.594335</td>
#       <td>3.0</td>
#       <td>2052.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07689</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07689.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp, Hlf</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Nfil3, Ppargc1a, Tef</td>
#       <td>2.079418</td>
#       <td>0.0</td>
#       <td>1.738856</td>
#       <td>0.41143</td>
#       <td>3.0</td>
#       <td>1304.0</td>
#     </tr>
#     <tr>
#       <th>taipale__Cebpb_DBD_NTTRCGCAAY_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__Cebpb_DBD_NTTRCGCAAY_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300</td>
#       <td>2.077897</td>
#       <td>0.0</td>
#       <td>1.843061</td>
#       <td>0.436547</td>
#       <td>3.0</td>
#       <td>1383.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPD_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPD_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>2.040281</td>
#       <td>0.0</td>
#       <td>1.875253</td>
#       <td>0.455905</td>
#       <td>3.0</td>
#       <td>1339.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPB_full_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPB_full_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>2.026426</td>
#       <td>0.0</td>
#       <td>1.932452</td>
#       <td>0.474344</td>
#       <td>3.0</td>
#       <td>1459.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5995</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5995.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpe</td>
#       <td>Ep300, Ppargc1a</td>
#       <td>2.01841</td>
#       <td>0.0</td>
#       <td>1.89166</td>
#       <td>0.466919</td>
#       <td>3.0</td>
#       <td>1417.0</td>
#     </tr>
#     <tr>
#       <th>factorbook__CEBPB</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/factorbook__CEBPB.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_exten

# %% [markdown]
# The length of the cistromes is lower too:

# %%
len(DEM_dict.cistromes['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['Cebpa'])
# Out:
# 3465

# %% [markdown]
# Let's save this object:

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/DEM_dict_D2.pkl', 'wb') as f:
  pickle.dump(DEM_dict, f)

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="16"></a>
# ##### 3. Using a shuffled background

# %% [markdown]
# It is possible that you don't have a background (for example, if you only have a ChIP-seq experiment). You can also use shuffled regions (from your input) as background by setting `contrasts` to 'Shuffle'. You will need to have Cluster-Buster installed to use this option.

# %%
os.putenv('CBUST_HOME','/data/leuven/software/biomed/haswell_centos7/2018a/software/Cluster-Buster/20180705-GCCcore-6.4.0')
os.environ["PATH"] += os.pathsep + '/data/leuven/software/biomed/haswell_centos7/2018a/software/Cluster-Buster/20180705-GCCcore-6.4.0/bin:'
DEM_dict = DEM(dem_db = '/staging/leuven/stg_00002/icistarget-data/make_rankings/v9/CTX_mm10/CTX_mm10_SCREEN3_1kb_bg_with_mask/CTX_mm10_SCREEN3_1kb_bg_with_mask.regions_vs_motifs.scores.feather',
    region_sets = region_sets,
    specie = 'mus_musculus',
    contrasts = 'Shuffle',
    name = 'DEM',
    max_bg_regions = 100,
    adjpval_thr = 0.05,
    log2fc_thr = 1,
    mean_fg_thr = 2.5, #You may need to increase the detection threshold here, otherwise you may see a lot of G repeats
    n_cpu = 4,
    fraction_overlap = 0.4,
    cluster_buster_path = '/data/leuven/software/biomed/haswell_centos7/2018a/software/Cluster-Buster/20180705-GCCcore-6.4.0/bin/cbust',
    path_to_genome_fasta = '/staging/leuven/res_00001/genomes/mus_musculus/mm10_ucsc/fasta/mm10.fa',
    path_to_motifs = '/staging/leuven/stg_00002/lcb/icistarget/data/motifCollection/v9/singletons/',
    tmp_dir = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tmp',
    _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-20 15:47:08,935 DEM          INFO     Reading DEM database
# 2021-05-20 15:48:23,826 DEM          INFO     Creating contrast groups
# 2021-05-20 15:48:23,831 DEM          INFO     Generating and scoring shuffled background
# 2021-05-20 15:48:24,004 Cluster-Buster INFO     Scoring sequences
# 2021-05-20 15:48:27,052	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 15:51:16,809 Cluster-Buster INFO     Done!
# 2021-05-20 15:51:17,184 DEM          INFO     Generating and scoring shuffled background
# 2021-05-20 15:51:17,364 Cluster-Buster INFO     Scoring sequences
# 2021-05-20 15:51:20,443	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 15:54:12,203 Cluster-Buster INFO     Done!
# 2021-05-20 15:54:12,474 DEM          INFO     Generating and scoring shuffled background
# 2021-05-20 15:54:12,635 Cluster-Buster INFO     Scoring sequences
# 2021-05-20 15:54:15,775	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 15:57:05,877 Cluster-Buster INFO     Done!
# 2021-05-20 15:57:06,199 DEM          INFO     Generating and scoring shuffled background
# 2021-05-20 15:57:06,350 Cluster-Buster INFO     Scoring sequences
# 2021-05-20 15:57:09,364	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 15:59:56,516 Cluster-Buster INFO     Done!
# 2021-05-20 15:59:59,941	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23920) 2021-05-20 16:00:08,922 DEM          INFO     Computing DEM for Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23921) 2021-05-20 16:00:10,159 DEM          INFO     Computing DEM for Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23923) 2021-05-20 16:00:12,013 DEM          INFO     Computing DEM for Foxa1_ERR235786_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (pid=23922) 2021-05-20 16:00:12,645 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23920) 2021-05-20 16:00:23,040 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23921) 2021-05-20 16:00:26,569 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23923) 2021-05-20 16:00:28,546 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=23922) 2021-05-20 16:00:29,923 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# (raylet) cut: write error: Broken pipe
# 2021-05-20 16:01:11,481 DEM          INFO     Forming cistromes
# 2021-05-20 16:01:14,332 DEM          INFO     Done!

# %% [markdown]
# Let's see the results now:

# %%
DEM_dict.DEM_results('Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Contrast</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">Log2FC</th>
#       <th style="min-width: 80px;">Adjusted_pval</th>
#       <th style="min-width: 80px;">Mean_fg</th>
#       <th style="min-width: 80px;">Mean_bg</th>
#       <th style="min-width: 80px;">Motif_hit_thr</th>
#       <th style="min-width: 80px;">Number_of_regions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000EHE_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000EHE_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg, Ddit3</td>
#       <td>Cebpb</td>
#       <td>Dbp, Ep300</td>
#       <td>3.109886</td>
#       <td>0.0</td>
#       <td>2.555773</td>
#       <td>0.296042</td>
#       <td>1.290</td>
#       <td>3020.0</td>
#     </tr>
#     <tr>
#       <th>factorbook__CEBPB</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/factorbook__CEBPB.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Atf4, Cebpa, Cebpd, Cebpg, Dbp</td>
#       <td>Cebpb</td>
#       <td>Cebpe, Ep300, Hlf</td>
#       <td>3.105516</td>
#       <td>0.0</td>
#       <td>2.632374</td>
#       <td>0.30584</td>
#       <td>3.030</td>
#       <td>2225.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000BRQ_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000BRQ_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>Cebpb</td>
#       <td>Ep300</td>
#       <td>3.085453</td>
#       <td>0.0</td>
#       <td>2.872691</td>
#       <td>0.338435</td>
#       <td>2.480</td>
#       <td>2856.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000BQI_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000BQI_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg, Ddit3</td>
#       <td>Cebpb</td>
#       <td>NaN</td>
#       <td>2.994965</td>
#       <td>0.0</td>
#       <td>2.675362</td>
#       <td>0.335589</td>
#       <td>2.980</td>
#       <td>2360.0</td>
#     </tr>
#     <tr>
#       <th>hocomoco__CEBPB_HUMAN.H11MO.0.A</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/hocomoco__CEBPB_HUMAN.H11MO.0.A.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpa</td>
#       <td>Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpb</td>
#       <td>Ep300</td>
#       <td>2.985242</td>
#       <td>0.0</td>
#       <td>2.938602</td>
#       <td>0.371102</td>
#       <td>1.400</td>
#       <td>3337.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07080</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07080.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpb</td>
#       <td>Bmyc, Ep300, Myc</td>
#       <td>2.982557</td>
#       <td>0.0</td>
#       <td>2.516838</td>
#       <td>0.318432</td>
#       <td>0.816</td>
#       <td>3237.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000DYI_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000DYI_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg, Dbp</td>
#       <td>Cebpb, Ep300</td>
#       <td>Jun</td>
#       <td>2.930386</td>
#       <td>0.0</td>
#       <td>2.601177</td>
#       <td>0.341221</td>
#       <td>2.340</td>
#       <td>2661.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000EDA_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000EDA_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Atf4, Cebpa, Cebpd, Cebpe, Cebpg, Dbp, Ddit3, Nfil3</td>
#       <td>Cebpb, Ep300</td>
#       <td>NaN</td>
#       <td>2.92885</td>
#       <td>0.0</td>
#       <td>3.012026</td>
#       <td>0.395537</td>
#       <td>1.300</td>
#       <td>3504.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000EEE_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000EEE_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpb, Ep300</td>
#       <td>Atf4</td>
#       <td>2.915596</td>
#       <td>0.0</td>
#       <td>2.600302</td>
#       <td>0.344621</td>
#       <td>0.965</td>
#       <td>3193.0</td>
#     </tr>
#     <tr>
#       <th>jaspar__MA0102.3</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/jaspar__MA0102.3.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpd, Cebpe, Cebpg</td>
#       <td>Cebpa</td>
#       <td>Ep300</td>
#       <td>2.912782</td>
#       <td>0.0</td>
#       <td>2.79246</td>
#       <td>0.370811</td>
#       <td>1.300</td>
#       <td>3250.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000EFM_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000EFM_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpe, Cebpg, Dbp</td>
#       <td>Cebpb, Ep300</td>
#       <td>Atf4, Jun</td>
#       <td>2.890924</td>
#       <td>0.0</td>
#       <td>2.759995</td>
#       <td>0.372095</td>
#       <td>2.660</td>
#       <td>2629.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000EEX_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000EEX_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Ddit3</td>
#       <td>Cebpb</td>
#       <td>Ep300</td>
#       <td>2.797833</td>
#       <td>0.0</td>
#       <td>2.87718</td>
#       <td>0.413747</td>
#       <td>2.230</td>
#       <td>2902.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M4606</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M4606.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Dbp, Ddit3</td>
#       <td>Cebpb, Ep300</td>
#       <td>Atf4, Cebpe, Hlf, Ppargc1a</td>
#       <td>2.791954</td>
#       <td>0.0</td>
#       <td>2.664852</td>
#       <td>0.384779</td>
#       <td>1.090</td>
#       <td>3308.0</td>
#     </tr>
#     <tr>
#       <th>hocomoco__CEBPB_MOUSE.H11MO.0.A</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/hocomoco__CEBPB_MOUSE.H11MO.0.A.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpa, Cebpb</td>
#       <td>Cebpd, Cebpe, Cebpg</td>
#       <td>NaN</td>
#       <td>Ep300</td>
#       <td>2.786502</td>
#       <td>0.0</td>
#       <td>3.081223</td>
#       <td>0.446583</td>
#       <td>1.350</td>
#       <td>3525.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M4529</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M4529.png" width="20

# %% [markdown]
# The length of the cistromes is lower too:

# %%
len(DEM_dict.cistromes['Region_set']['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K']['Cebpa'])
# Out:
# 4037

# %% [markdown]
# Let's save this object:

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/DEM_dict_D3.pkl', 'wb') as f:
  pickle.dump(DEM_dict, f)

# %% [markdown]
# [[Back to top]](#top)

# %% [markdown]
# <a class="anchor" id="17"></a>
# ##### 4. Specifying contrasts

# %% [markdown]
# Finally it is possible that you want to make specific contrast between region sets. You can do this by passing a list to contrast (each slot will be a contrast, first slot with it will be the foreground and second the background). For example, here we will perform two contrasts: 1) Cebpa versus Onecut and 2) Cebpa versus Onecut and Hnf4a.

# %%
DEM_dict = DEM(dem_db = '/staging/leuven/stg_00002/icistarget-data/make_rankings/v9/CTX_mm10/CTX_mm10_SCREEN3_1kb_bg_with_mask/CTX_mm10_SCREEN3_1kb_bg_with_mask.regions_vs_motifs.scores.feather',
    region_sets = region_sets,
    specie = 'mus_musculus',
    contrasts = [[['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'], ['Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K']], [['Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K'], ['Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K', 'Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K']]],
    name = 'DEM',
    fraction_overlap = 0.4,
    max_bg_regions = 500,
    adjpval_thr = 0.05,
    log2fc_thr = 1,
    mean_fg_thr = 1,
    motif_hit_thr = 3,
    n_cpu = 4,
    cluster_buster_path = None,
    path_to_genome_fasta = None,
    path_to_motifs = None,
    annotation = ['Direct_annot'],
    tmp_dir = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tmp',
    _temp_dir='/scratch/leuven/313/vsc31305/ray_spill')
# Out:
# 2021-05-20 17:45:35,805 DEM          INFO     Reading DEM database
# 2021-05-20 17:50:54,828 DEM          INFO     Creating contrast groups
# 2021-05-20 17:51:11,304	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=24771) 2021-05-20 17:51:28,026 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K_Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=24771) 2021-05-20 17:51:28,026 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K_Hnf4a_ERR235763_summits_order_by_score_extended_250bp_top5K
# (pid=24772) 2021-05-20 17:51:28,189 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=24772) 2021-05-20 17:51:28,189 DEM          INFO     Computing DEM for Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K
# (pid=24771) 2021-05-20 17:51:44,966 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=24771) 2021-05-20 17:51:44,966 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=24772) 2021-05-20 17:51:45,054 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=24772) 2021-05-20 17:51:45,054 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-05-20 17:52:21,729 DEM          INFO     Forming cistromes
# 2021-05-20 17:52:21,841 DEM          INFO     Done!

# %% [markdown]
# Let's see the results now comparing with Onecut:

# %%
DEM_dict.DEM_results('Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Contrast</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">Log2FC</th>
#       <th style="min-width: 80px;">Adjusted_pval</th>
#       <th style="min-width: 80px;">Mean_fg</th>
#       <th style="min-width: 80px;">Mean_bg</th>
#       <th style="min-width: 80px;">Motif_hit_thr</th>
#       <th style="min-width: 80px;">Number_of_regions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD_meth_repr.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp, Hlf</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Nfil3, Ppargc1a, Tef</td>
#       <td>2.260583</td>
#       <td>0.0</td>
#       <td>1.289099</td>
#       <td>0.269019</td>
#       <td>3.0</td>
#       <td>977.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPB_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Dbp</td>
#       <td>Cebpb, Cebpe</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>2.152441</td>
#       <td>0.0</td>
#       <td>1.46913</td>
#       <td>0.330454</td>
#       <td>3.0</td>
#       <td>1158.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPE_NRTTGCGYAAYN_eDBD.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpb, Cebpg</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Dbp, Ep300, Hlf, Ppargc1a, Tef</td>
#       <td>2.150738</td>
#       <td>0.0</td>
#       <td>1.662524</td>
#       <td>0.374396</td>
#       <td>3.0</td>
#       <td>1274.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPG_DBD_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_DBD_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.076253</td>
#       <td>0.0</td>
#       <td>1.327401</td>
#       <td>0.314766</td>
#       <td>3.0</td>
#       <td>1006.0</td>
#     </tr>
#     <tr>
#       <th>taipale__CEBPG_full_NTTRCGCAAY</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale__CEBPG_full_NTTRCGCAAY.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>2.06123</td>
#       <td>0.0</td>
#       <td>1.511894</td>
#       <td>0.362267</td>
#       <td>3.0</td>
#       <td>1163.0</td>
#     </tr>
#     <tr>
#       <th>taipale_cyt_meth__CEBPD_NRTTGCGYAAYN_eDBD_meth</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/taipale_cyt_meth__CEBPD_NRTTGCGYAAYN_eDBD_meth.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpg, Dbp</td>
#       <td>Cebpd, Cebpe</td>
#       <td>Ep300, Hlf, Nfil3, Tef</td>
#       <td>2.030317</td>
#       <td>0.0</td>
#       <td>1.776707</td>
#       <td>0.43494</td>
#       <td>3.0</td>
#       <td>1417.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5275</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5275.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpb, Cebpd, Cebpg, Tef</td>
#       <td>NaN</td>
#       <td>Cebpe</td>
#       <td>2.006358</td>
#       <td>0.0</td>
#       <td>1.396739</td>
#       <td>0.347649</td>
#       <td>3.0</td>
#       <td>988.0</td>
#     </tr>
#     <tr>
#       <th>transfac_pro__M07413</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/transfac_pro__M07413.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd, Cebpg</td>
#       <td>NaN</td>
#       <td>Cebpe, Ep300</td>
#       <td>2.00377</td>
#       <td>0.0</td>
#       <td>1.89574</td>
#       <td>0.472698</td>
#       <td>3.0</td>
#       <td>1386.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5319</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5319.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>1.994111</td>
#       <td>0.0</td>
#       <td>1.573493</td>
#       <td>0.394982</td>
#       <td>3.0</td>
#       <td>1172.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M5318</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M5318.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpb</td>
#       <td>Cebpa, Cebpd</td>
#       <td>Cebpe, Cebpg</td>
#       <td>Ep300</td>
#       <td>1.98843</td>
#       <td>0.0</td>
#       <td>1.42071</td>
#       <td>0.358037</td>
#       <td>3.0</td>
#       <td>1098.0</td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__CEBPB__ENCSR000EBV_1__m1</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/dbcorrdb__CEBPB__ENCSR000EBV_1__m1.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>Cebpg</td>
#       <td>Cebpa, Cebpd, Cebpe, Ddit3</td>
#       <td>Cebpb</td>
#       <td>Ep300</td>
#       <td>1.982228</td>
#       <td>0.0</td>
#       <td>2.440383</td>
#       <td>0.617658</td>
#       <td>3.0</td>
#       <td>2178.0</td>
#     </tr>
#     <tr>
#       <th>factorbook__CEBPB</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/factorbook__CEBPB.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Atf4, Cebpa, Cebpd, Cebpg, Dbp</td>
#       <td>Cebpb</td>
#       <td>Cebpe, Ep300, Hlf</td>
#       <td>1.974533</td>
#       <td>0.0</td>
#       <td>2.632374</td>
#       <td>0.669814</td>
#       <td>3.0</td>
#       <td>2241.0</td>
#     </tr>
#     <tr>
#       <th>cisbp__M4606</th>
#       <td><img src="https://motifcollections.aertslab.org/v9/logos/cisbp__M4606.png" width="200" ></td>
#       <td>Cebpa_ERR235722_summits_order_by_score_extended_250bp_top5K_VS_Onecut1_ERR235752_summits_order_by_score_extended_250bp_top5K</td>
#       <td>NaN</td>
#       <td>Cebpa, Cebpd, Cebpg, Dbp, Ddit3</td>
#       <td>Cebpb, Ep300</td>
#       <td>A

# %% [markdown]
# Let's save this object:

# %%
# Save
import pickle
with open('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/pycistarget/tutorial/DEM/DEM_dict_D4.pkl', 'wb') as f:
  pickle.dump(DEM_dict, f)

# %% [markdown]
# [[Back to top]](#top)
