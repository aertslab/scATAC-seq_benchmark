# %% [markdown]
# # Generate the main reference (R):

# %%
# RNA-ATAC integration
################################################################################
# https://satijalab.org/seurat/articles/atacseq_integration_vignette.html

library(Seurat)
library(SeuratDisk)
library(Signac)
library(ggplot2)
library(stringr)


f_ref = '../0_resources/seurat_references/pbmc_ssc_mat.rds'
f_meta = '../0_resources/seurat_references/pbmc_ssc_metadata.rds'

pbmc.data <- readRDS(f_ref)
pbmc.metadata <- readRDS(f_meta)

pbmc <- CreateSeuratObject(counts = pbmc.data, meta.data = pbmc.metadata)
pbmc <- subset(pbmc, subset = nFeature_RNA > 200)

pbmc.list <- SplitObject(pbmc, split.by = "Method")

for (i in names(pbmc.list)) {
    pbmc.list[[i]] = NormalizeData(pbmc.list[[i]])
    pbmc.list[[i]] = FindVariableFeatures(pbmc.list[[i]], selection.method = "vst", nfeatures = 2000, verbose = FALSE)
    pbmc.list[[i]] = ScaleData(pbmc.list[[i]])
    pbmc.list[[i]] = RunPCA(pbmc.list[[i]])
    pbmc.list[[i]] = RunUMAP(pbmc.list[[i]], dims = 1:30)
}

reference.list <- pbmc.list[
    c("10x Chromium (v2) A", "10x Chromium (v2) B", "10x Chromium (v3)", "10x Chromium (v2)")
]

pbmc.anchors <- FindIntegrationAnchors(object.list = reference.list, dims = 1:30)

pbmc.integrated <- IntegrateData(anchorset = pbmc.anchors, dims = 1:30)
DefaultAssay(pbmc.integrated) <- "integrated"

pbmc.integrated <- ScaleData(pbmc.integrated, verbose = FALSE)
pbmc.integrated <- RunPCA(pbmc.integrated, npcs = 30, verbose = FALSE)
pbmc.integrated <- RunUMAP(pbmc.integrated, reduction = "pca", dims = 1:30, verbose = FALSE)
pbmc.rna <- readRDS('../0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')

# save
# saveRDS(pbmc, file="../0_resources/seurat_references/pbmc_ref.rds")

# ATAC analysis add gene annotation information
annotations <- GetGRangesFromEnsDb(ensdb = EnsDb.Hsapiens.v86)

# use chr prefix:
ucsc.levels <- str_replace(string=paste("chr",seqlevels(annotations),sep=""), pattern="chrMT", replacement="chrM")
seqlevels(annotations) <- ucsc.levels

genome(annotations) <- "hg38"
saveRDS(annotations, file="../0_resources/seurat_references/granges_annotation.rds")
# Out:
#   Input In [4]
#     for (i in names(pbmc.list)) {
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Then, invoke the following R script

# %%
# !cat ../0_resources/scripts/seurat_label_transfer.R
# Out:
# #!/usr/bin/env Rscript
# library(Seurat)
# library(SeuratDisk)
# library(Signac)
# library(EnsDb.Hsapiens.v86)
# library(ggplot2)
# library(stringr)
#
# args = commandArgs(trailingOnly=TRUE)
# sample_id = args[1]
# f_loom = args[2]
# f_frag = args[3]
# f_reference = args[4]
# f_annotation = args[5]
# f_out = args[6]
#
# print(paste0("Processing sample ", args[1]))
#
# # load pbmc object
# # pbmc.integrated <- readRDS("../0_resources/seurat_references/pbmc_integrated.RDS")
# pbmc.rna <- readRDS('../0_resources/seurat_references/pbmc_ssc_mat__integrated.rds')
#
# ################################################################################
# # ATAC
# ################################################################################
#
# ### get data from loom:
# atacloomcon <- Connect(filename = f_loom, mode = "r")
# atacloomcon
# atac_tmp <- as.Seurat(atacloomcon, assay='ATAC')
# atacloomcon$close_all()
#
# # correctly parse regions (default delims are '-','-')
# regions = StringToGRanges(
#     rownames(GetAssayData(atac_tmp, slot = "counts", assay='ATAC')),
#     sep=c(':','-')
#     )
#
# # create chromatin assay
# chromatinassay = CreateChromatinAssay(
#     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
#     # genome='hg38',
#     fragments = f_frag,
#     ranges=regions
#     )
#     #annotation=annotation)
#
# atac <- CreateSeuratObject(counts = chromatinassay, assay='ATAC')
#
# annotations <- readRDS(f_annotation)
# Annotation(atac) <- annotations
#
# # We exclude the first dimension as this is typically correlated with sequencing depth
# atac <- RunTFIDF(atac)
# atac <- FindTopFeatures(atac, min.cutoff = "q0")
# atac <- RunSVD(atac)
# atac <- RunUMAP(atac, reduction = "lsi", dims = 2:30, reduction.name = "umap.atac", reduction.key = "atacUMAP_")
#
# ##################################################
# # Identify RNA-ATAC anchors
#
# # quantify gene activity
# gene.activities <- GeneActivity(atac, features = VariableFeatures(pbmc.rna))
# # gene.activities <- gene.activities[rownames(gene.activities)!="",]
#
# # add gene activities as a new assay
# atac[["ACTIVITY"]] <- CreateAssayObject(counts = gene.activities)
#
# # normalize gene activities
# DefaultAssay(atac) <- "ACTIVITY"
# atac <- NormalizeData(atac)
# atac <- ScaleData(atac, features = rownames(atac))
#
# # Identify anchors
# transfer.anchors <- FindTransferAnchors(reference = pbmc.rna,
#     query = atac,
#     features = VariableFeatures(object = pbmc.rna),
#     reference.assay = "RNA",
#     query.assay = "ACTIVITY",
#     reduction = "cca")
#
# # predict celltype
# celltype.predictions <- TransferData(
#     anchorset = transfer.anchors,
#     refdata = pbmc.rna$CellType,
#     weight.reduction = atac[["lsi"]],
#     dims = 2:30)
#
# pbmc.atac <- AddMetaData(atac, metadata = celltype.predictions)
#
# md = celltype.predictions
# pred_thr = 0.7
#
# tmp = data.frame(
#       composite_sample_id = paste0(rownames(md),'-',sample_id),
#       barcode = rownames(md),
#       sample_id = sample_id,
#       cell_type = md$predicted.id,
#       cell_type_pred_score = md$prediction.score.max
#       )
#
# tmp$cell_type_hiconf_70 = tmp$cell_type
# tmp$cell_type_hiconf_70[tmp$cell_type_pred_score<pred_thr] = 'Unknown'
#
# table(tmp$cell_type)
# table(tmp$cell_type_hiconf_70)
#
# write.table(tmp, file=f_out, sep='\t', row.names=FALSE, quote=FALSE)
# print(paste0('Wrote file ', f_out))

# %% [markdown]
# ## We write a .parallel file

# %%
import glob
import os

# %%
# !pwd
# Out:
# /dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/fixedcells_2_cistopic

# %%
scrub_name_suffix = "0-4"
loom_path_dict  = {x.split('/')[-1].split(f'__')[0]:x for x in sorted(glob.glob(f'cell_region_looms/*singlets.loom'))}
loom_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'BIO_ddseq_2.FIXEDCELLS': 'cell_region_looms/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'BIO_ddseq_3.FIXEDCELLS': 'cell_region_looms/BIO_ddseq_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'BIO_ddseq_4.FIXEDCELLS': 'cell_region_looms/BIO_ddseq_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'BRO_mtscatac_1.FIXEDCELLS': 'cell_region_looms/BRO_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'BRO_mtscatac_2.FIXEDCELLS': 'cell_region_looms/BRO_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xmultiome_1.FIXEDCELLS': 'cell_region_looms/CNA_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xmultiome_2.FIXEDCELLS': 'cell_region_looms/CNA_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_1.FIXEDCELLS': 'cell_region_looms/CNA_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_2.FIXEDCELLS': 'cell_region_looms/CNA_10xv11_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_3.FIXEDCELLS': 'cell_region_looms/CNA_10xv11_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_4.FIXEDCELLS': 'cell_region_looms/CNA_10xv11_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv11_5.FIXEDCELLS': 'cell_region_looms/CNA_10xv11_5.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv2_1.FIXEDCELLS': 'cell_region_looms/CNA_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_10xv2_2.FIXEDCELLS': 'cell_region_looms/CNA_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_hydrop_1.FIXEDCELLS': 'cell_region_looms/CNA_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_hydrop_2.FIXEDCELLS': 'cell_region_looms/CNA_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_hydrop_3.FIXEDCELLS': 'cell_region_looms/CNA_hydrop_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_mtscatac_1.FIXEDCELLS': 'cell_region_looms/CNA_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'CNA_mtscatac_2.FIXEDCELLS': 'cell_region_looms/CNA_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_1.FIXEDCELLS': 'cell_region_looms/EPF_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_2.FIXEDCELLS': 'cell_region_looms/EPF_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_3.FIXEDCELLS': 'cell_region_looms/EPF_hydrop_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'EPF_hydrop_4.FIXEDCELLS': 'cell_region_looms/EPF_hydrop_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'HAR_ddseq_1.FIXEDCELLS': 'cell_region_looms/HAR_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'HAR_ddseq_2.FIXEDCELLS': 'cell_region_looms/HAR_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'MDC_mtscatac_1.FIXEDCELLS': 'cell_region_looms/MDC_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'MDC_mtscatac_2.FIXEDCELLS': 'cell_region_looms/MDC_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'OHS_s3atac_1.FIXEDCELLS': 'cell_region_looms/OHS_s3atac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'OHS_s3atac_2.FIXEDCELLS': 'cell_region_looms/OHS_s3atac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'SAN_10xmultiome_1.FIXEDCELLS': 'cell_region_looms/SAN_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'SAN_10xmultiome_2.FIXEDCELLS': 'cell_region_looms/SAN_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'STA_10xv11_1.FIXEDCELLS': 'cell_region_looms/STA_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'STA_10xv11_2.FIXEDCELLS': 'cell_region_looms/STA_10xv11_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'TXG_10xv11_1.FIXEDCELLS': 'cell_region_looms/TXG_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'TXG_10xv2_1.FIXEDCELLS': 'cell_region_looms/TXG_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'TXG_10xv2_2.FIXEDCELLS': 'cell_region_looms/TXG_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xmultiome_1.FIXEDCELLS': 'cell_region_looms/VIB_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xmultiome_2.FIXEDCELLS': 'cell_region_looms/VIB_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv1_1.FIXEDCELLS': 'cell_region_looms/VIB_10xv1_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv1_2.FIXEDCELLS': 'cell_region_looms/VIB_10xv1_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv2_1.FIXEDCELLS': 'cell_region_looms/VIB_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_10xv2_2.FIXEDCELLS': 'cell_region_looms/VIB_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_1.FIXEDCELLS': 'cell_region_looms/VIB_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom',
#  'VIB_hydrop_2.FIXEDCELLS': 'cell_region_looms/VIB_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom'}

# %%
scrub_name_suffix = "0-4"
frags_path_dict  = {x.split('/')[-1].split(f'.fragments.tsv.gz')[0] :x for x in sorted(glob.glob(f'../1_data_repository/fixedcells_fragments/*.fragments.tsv.gz'))}
frags_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS.fragments.tsv.gz',
#  'BIO_ddseq_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_2.FIXEDCELLS.fragments.tsv.gz',
#  'BIO_ddseq_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_3.FIXEDCELLS.fragments.tsv.gz',
#  'BIO_ddseq_4.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BIO_ddseq_4.FIXEDCELLS.fragments.tsv.gz',
#  'BRO_mtscatac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BRO_mtscatac_1.FIXEDCELLS.fragments.tsv.gz',
#  'BRO_mtscatac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/BRO_mtscatac_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xmultiome_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xmultiome_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_3.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_4.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_4.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv11_5.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv11_5.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv2_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv2_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_10xv2_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_10xv2_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_hydrop_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_hydrop_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_hydrop_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_hydrop_2.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_hydrop_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_hydrop_3.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_mtscatac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_mtscatac_1.FIXEDCELLS.fragments.tsv.gz',
#  'CNA_mtscatac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/CNA_mtscatac_2.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_1.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_2.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_3.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_3.FIXEDCELLS.fragments.tsv.gz',
#  'EPF_hydrop_4.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/EPF_hydrop_4.FIXEDCELLS.fragments.tsv.gz',
#  'HAR_ddseq_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/HAR_ddseq_1.FIXEDCELLS.fragments.tsv.gz',
#  'HAR_ddseq_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/HAR_ddseq_2.FIXEDCELLS.fragments.tsv.gz',
#  'MDC_mtscatac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/MDC_mtscatac_1.FIXEDCELLS.fragments.tsv.gz',
#  'MDC_mtscatac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/MDC_mtscatac_2.FIXEDCELLS.fragments.tsv.gz',
#  'OHS_s3atac_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/OHS_s3atac_1.FIXEDCELLS.fragments.tsv.gz',
#  'OHS_s3atac_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/OHS_s3atac_2.FIXEDCELLS.fragments.tsv.gz',
#  'SAN_10xmultiome_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/SAN_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz',
#  'SAN_10xmultiome_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/SAN_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz',
#  'STA_10xv11_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/STA_10xv11_1.FIXEDCELLS.fragments.tsv.gz',
#  'STA_10xv11_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/STA_10xv11_2.FIXEDCELLS.fragments.tsv.gz',
#  'TXG_10xv11_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/TXG_10xv11_1.FIXEDCELLS.fragments.tsv.gz',
#  'TXG_10xv2_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/TXG_10xv2_1.FIXEDCELLS.fragments.tsv.gz',
#  'TXG_10xv2_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/TXG_10xv2_2.FIXEDCELLS.fragments.tsv.gz',
#  'UCS_ddseq_1.LIBDS': '../1_data_repository/fixedcells_fragments/UCS_ddseq_1.LIBDS.fragments.tsv.gz',
#  'UCS_ddseq_2.LIBDS': '../1_data_repository/fixedcells_fragments/UCS_ddseq_2.LIBDS.fragments.tsv.gz',
#  'VIB_10xmultiome_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xmultiome_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv1_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv1_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv1_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv1_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv2_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv2_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_10xv2_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_10xv2_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_1.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_1.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_11.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_11.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_12.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_12.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_2.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_2.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_21.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_21.FIXEDCELLS.fragments.tsv.gz',
#  'VIB_hydrop_22.FIXEDCELLS': '../1_data_repository/fixedcells_fragments/VIB_hydrop_22.FIXEDCELLS.fragments.tsv.gz'}

# %%
parallel_filename = "seurat_label_transfer.parallel"
script_path = "../0_resources/scripts/seurat_label_transfer.R"
img_path = "../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif"
reference_path = "../0_resources/seurat_references/pbmc_ref.rds"
annotation_path = "../0_resources/seurat_references/granges_annotation.rds"
bind_mounts = "/dodrio,/readonly/dodrio,/tmp"
#bind_mounts = "/lustre1,/staging,${VSC_SCRATCH}/tmp:/tmp"

with open(parallel_filename, 'w') as f:
    for sample in loom_path_dict.keys():
        outfile = f"cell_type_classification/{sample}__cell_type_seurat.txt"
        if not os.path.exists(outfile):
            loomfile = loom_path_dict[sample]
            fragfile = frags_path_dict[sample]
            command=f"img_path={img_path} && singularity exec --cleanenv -H $PWD -B {bind_mounts} $img_path Rscript {script_path} {sample} {loomfile} {fragfile} {reference_path} {annotation_path} {outfile}"
            f.write(f"{command}\n")
            print(command)

        else:
            f.write(f"#{outfile} already exists!\n")
            print(f"#{outfile} already exists!")
# Out:
# #cell_type_classification/BIO_ddseq_1.FIXEDCELLS__cell_type_seurat.txt already exists!
# #cell_type_classification/BIO_ddseq_2.FIXEDCELLS__cell_type_seurat.txt already exists!
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R BIO_ddseq_3.FIXEDCELLS cell_region_looms/BIO_ddseq_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_3.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_3.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R BIO_ddseq_4.FIXEDCELLS cell_region_looms/BIO_ddseq_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_4.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_4.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R BRO_mtscatac_1.FIXEDCELLS cell_region_looms/BRO_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/BRO_mtscatac_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BRO_mtscatac_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R BRO_mtscatac_2.FIXEDCELLS cell_region_looms/BRO_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/BRO_mtscatac_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BRO_mtscatac_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xmultiome_1.FIXEDCELLS cell_region_looms/CNA_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xmultiome_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xmultiome_2.FIXEDCELLS cell_region_looms/CNA_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xmultiome_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv11_1.FIXEDCELLS cell_region_looms/CNA_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv11_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv11_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv11_2.FIXEDCELLS cell_region_looms/CNA_10xv11_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv11_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv11_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv11_3.FIXEDCELLS cell_region_looms/CNA_10xv11_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv11_3.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv11_3.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv11_4.FIXEDCELLS cell_region_looms/CNA_10xv11_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv11_4.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv11_4.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv11_5.FIXEDCELLS cell_region_looms/CNA_10xv11_5.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv11_5.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv11_5.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv2_1.FIXEDCELLS cell_region_looms/CNA_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv2_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv2_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_10xv2_2.FIXEDCELLS cell_region_looms/CNA_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_10xv2_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_10xv2_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_hydrop_1.FIXEDCELLS cell_region_looms/CNA_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_hydrop_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_hydrop_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_hydrop_2.FIXEDCELLS cell_region_looms/CNA_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_hydrop_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_hydrop_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_hydrop_3.FIXEDCELLS cell_region_looms/CNA_hydrop_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_hydrop_3.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_hydrop_3.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_mtscatac_1.FIXEDCELLS cell_region_looms/CNA_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_mtscatac_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_mtscatac_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R CNA_mtscatac_2.FIXEDCELLS cell_region_looms/CNA_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/CNA_mtscatac_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/CNA_mtscatac_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R EPF_hydrop_1.FIXEDCELLS cell_region_looms/EPF_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/EPF_hydrop_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/EPF_hydrop_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R EPF_hydrop_2.FIXEDCELLS cell_region_looms/EPF_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/EPF_hydrop_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/EPF_hydrop_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R EPF_hydrop_3.FIXEDCELLS cell_region_looms/EPF_hydrop_3.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/EPF_hydrop_3.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/EPF_hydrop_3.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R EPF_hydrop_4.FIXEDCELLS cell_region_looms/EPF_hydrop_4.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/EPF_hydrop_4.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/EPF_hydrop_4.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R HAR_ddseq_1.FIXEDCELLS cell_region_looms/HAR_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/HAR_ddseq_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/HAR_ddseq_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R HAR_ddseq_2.FIXEDCELLS cell_region_looms/HAR_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/HAR_ddseq_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/HAR_ddseq_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R MDC_mtscatac_1.FIXEDCELLS cell_region_looms/MDC_mtscatac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/MDC_mtscatac_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/MDC_mtscatac_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R MDC_mtscatac_2.FIXEDCELLS cell_region_looms/MDC_mtscatac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/MDC_mtscatac_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/MDC_mtscatac_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R OHS_s3atac_1.FIXEDCELLS cell_region_looms/OHS_s3atac_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/OHS_s3atac_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R OHS_s3atac_2.FIXEDCELLS cell_region_looms/OHS_s3atac_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/OHS_s3atac_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/OHS_s3atac_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R SAN_10xmultiome_1.FIXEDCELLS cell_region_looms/SAN_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/SAN_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/SAN_10xmultiome_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R SAN_10xmultiome_2.FIXEDCELLS cell_region_looms/SAN_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/SAN_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/SAN_10xmultiome_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R STA_10xv11_1.FIXEDCELLS cell_region_looms/STA_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/STA_10xv11_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/STA_10xv11_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R STA_10xv11_2.FIXEDCELLS cell_region_looms/STA_10xv11_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/STA_10xv11_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/STA_10xv11_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R TXG_10xv11_1.FIXEDCELLS cell_region_looms/TXG_10xv11_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/TXG_10xv11_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/TXG_10xv11_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R TXG_10xv2_1.FIXEDCELLS cell_region_looms/TXG_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/TXG_10xv2_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/TXG_10xv2_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R TXG_10xv2_2.FIXEDCELLS cell_region_looms/TXG_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/TXG_10xv2_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/TXG_10xv2_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_10xmultiome_1.FIXEDCELLS cell_region_looms/VIB_10xmultiome_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_10xmultiome_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_10xmultiome_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_10xmultiome_2.FIXEDCELLS cell_region_looms/VIB_10xmultiome_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_10xmultiome_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_10xmultiome_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_10xv1_1.FIXEDCELLS cell_region_looms/VIB_10xv1_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_10xv1_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_10xv1_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_10xv1_2.FIXEDCELLS cell_region_looms/VIB_10xv1_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_10xv1_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_10xv1_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_10xv2_1.FIXEDCELLS cell_region_looms/VIB_10xv2_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_10xv2_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_10xv2_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_10xv2_2.FIXEDCELLS cell_region_looms/VIB_10xv2_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_10xv2_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_10xv2_2.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_hydrop_1.FIXEDCELLS cell_region_looms/VIB_hydrop_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_hydrop_1.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_hydrop_1.FIXEDCELLS__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer.R VIB_hydrop_2.FIXEDCELLS cell_region_looms/VIB_hydrop_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.loom ../1_data_repository/fixedcells_fragments/VIB_hydrop_2.FIXEDCELLS.fragments.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/VIB_hydrop_2.FIXEDCELLS__cell_type_seurat.txt

# %% [markdown]
# # Subsets

# %%
scrub_name_suffix = "0-4"
loom_path_dict  = {x.split('/')[-1].split(f'__')[0] + '_' + x.split('/')[-1].split(f'_')[-1].split('.')[0]  :x for x in sorted(glob.glob(f'cell_region_looms/*subset*.loom'))}
loom_path_dict
# Out:
# {'BIO_ddseq_1.FIXEDCELLS_subset0': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset0.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset1': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset1.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset10': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset10.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset11': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset11.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset12': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset12.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset13': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset13.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset14': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset14.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset15': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset15.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset16': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset16.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset17': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset17.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset18': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset18.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset19': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset19.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset2': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset2.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset20': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset20.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset21': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset21.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset22': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset22.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset23': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset23.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset24': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset24.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset25': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset25.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset26': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset26.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset27': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset27.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset28': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset28.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset29': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset29.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset3': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset3.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset30': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset30.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset31': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset31.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset32': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset32.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset33': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset33.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset34': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset34.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset35': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset35.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset36': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset36.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset37': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset37.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset38': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset38.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset39': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset39.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset4': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset4.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset40': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset40.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset41': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset41.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset42': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset42.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset43': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset43.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset44': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset44.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset45': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset45.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset46': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset46.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset47': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset47.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset48': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset48.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset49': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset49.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset5': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset5.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset50': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset50.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset51': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset51.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset52': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset52.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset53': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset53.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset54': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset54.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset55': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset55.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset56': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset56.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset57': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset57.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset58': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset58.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset59': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset59.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset6': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset6.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset60': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset60.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset61': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset61.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset62': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset62.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset63': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset63.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset64': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset64.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset65': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset65.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset66': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset66.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset67': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset67.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset68': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset68.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset69': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset69.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset7': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset7.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset70': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset70.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset71': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset71.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset72': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset72.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset73': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset73.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset74': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset74.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset75': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset75.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset76': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset76.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset77': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset77.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset78': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset78.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset79': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset79.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset8': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset8.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset80': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset80.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset81': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset81.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset82': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset82.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset83': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset83.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset84': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset84.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset85': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset85.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset86': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset86.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset87': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset87.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset88': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset88.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset89': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset89.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset9': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset9.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset90': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset90.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset91': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset91.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset92': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset92.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset93': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset93.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset94': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset94.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset95': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset95.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset96': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset96.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset97': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset97.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset98': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset98.loom',
#  'BIO_ddseq_1.FIXEDCELLS_subset99': 'cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset99.loom',
#  'BIO_ddseq_2.FIXEDCELLS_subset0': 'cell_region_looms/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset0.loom',
#  'BIO_ddseq_2.FIXEDCELLS_subset1': 'cell_region_looms/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset1.loom',
#  'BIO_ddseq_2.FIXEDCELLS_subset2': 'cell_region_looms/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset2.loom'}

# %%
loom_path_dict.pop('BIO_ddseq_2.FIXEDCELLS_subset0')
loom_path_dict.pop('BIO_ddseq_2.FIXEDCELLS_subset1')
loom_path_dict.pop('BIO_ddseq_2.FIXEDCELLS_subset2')
# Out:
# 'cell_region_looms/BIO_ddseq_2.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset2.loom'

# %%
scrub_name_suffix = "0-4"
frags_path_dict  = {x.split('/')[-1].split(f'.fragments.filteredchroms.tsv.gz')[0] :x for x in sorted(glob.glob(f'../1_data_repository/fixedcells_fragments/*.fragments.filteredchroms.tsv.gz'))}
frags_path_dict_subset  = {x: frags_path_dict[x] for x in loom_path_dict.keys()}
frags_path_dict_subset
# Out:
# {'BIO_ddseq_1.FIXEDCELLS_subset0': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset0.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset1': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset1.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset10': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset10.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset11': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset11.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset12': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset12.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset13': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset13.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset14': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset14.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset15': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset15.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset16': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset16.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset17': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset17.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset18': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset18.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset19': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset19.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset2': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset2.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset20': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset20.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset21': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset21.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset22': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset22.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset23': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset23.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset24': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset24.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset25': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset25.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset26': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset26.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset27': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset27.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset28': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset28.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset29': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset29.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset3': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset3.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset30': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset30.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset31': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset31.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset32': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset32.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset33': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset33.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset34': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset34.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset35': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset35.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset36': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset36.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset37': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset37.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset38': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset38.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset39': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset39.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset4': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset4.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset40': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset40.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset41': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset41.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset42': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset42.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset43': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset43.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset44': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset44.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset45': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset45.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset46': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset46.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset47': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset47.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset48': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset48.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset49': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset49.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset5': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset5.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset50': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset50.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset51': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset51.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset52': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset52.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset53': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset53.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset54': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset54.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset55': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset55.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset56': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset56.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset57': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset57.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset58': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset58.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset59': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset59.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset6': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset6.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset60': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset60.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset61': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset61.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset62': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset62.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset63': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset63.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset64': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset64.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset65': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset65.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset66': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset66.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset67': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset67.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset68': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset68.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset69': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset69.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset7': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset7.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset70': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset70.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset71': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset71.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset72': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset72.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset73': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset73.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset74': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset74.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset75': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset75.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset76': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset76.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset77': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset77.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset78': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset78.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset79': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset79.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset8': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset8.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset80': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset80.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset81': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset81.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset82': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset82.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset83': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset83.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset84': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset84.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset85': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset85.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset86': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset86.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset87': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset87.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset88': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset88.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset89': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset89.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset9': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset9.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset90': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset90.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset91': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset91.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset92': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset92.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset93': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset93.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset94': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset94.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset95': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset95.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset96': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset96.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset97': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset97.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset98': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset98.fragments.filteredchroms.tsv.gz',
#  'BIO_ddseq_1.FIXEDCELLS_subset99': '../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset99.fragments.filteredchroms.tsv.gz'}

# %%
parallel_filename = "seurat_label_transfer.subsets.parallel"
script_path = "../0_resources/scripts/seurat_label_transfer_consensus.R"
img_path = "../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif"
reference_path = "../0_resources/seurat_references/pbmc_ref.rds"
annotation_path = "../0_resources/seurat_references/granges_annotation.rds"
bind_mounts = "/dodrio,/readonly/dodrio,/tmp"
#bind_mounts = "/lustre1,/staging,${VSC_SCRATCH}/tmp:/tmp"

with open(parallel_filename, 'w') as f:
    for sample in loom_path_dict.keys():
        outfile = f"cell_type_classification/{sample}__cell_type_seurat.txt"
        if not os.path.exists(outfile):
            loomfile = loom_path_dict[sample]
            fragfile = frags_path_dict_subset[sample]
            command=f"img_path={img_path} && singularity exec --cleanenv -H $PWD -B {bind_mounts} $img_path Rscript {script_path} {sample} {loomfile} {fragfile} {reference_path} {annotation_path} {outfile}"
            f.write(f"{command}\n")
            print(command)

        else:
            f.write(f"#{outfile} already exists!\n")
            print(f"#{outfile} already exists!")
# Out:
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset0 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset0.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset0.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset0__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset1 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset1.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset1.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset1__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset10 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset10.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset10.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset10__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset11 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset11.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset11.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset11__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset12 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset12.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset12.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset12__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset13 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset13.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset13.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset13__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset14 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset14.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset14.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset14__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset15 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset15.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset15.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset15__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset16 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset16.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset16.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset16__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset17 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset17.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset17.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset17__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset18 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset18.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset18.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset18__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset19 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset19.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset19.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset19__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset2 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset2.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset2.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset2__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset20 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset20.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset20.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset20__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset21 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset21.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset21.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset21__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset22 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset22.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset22.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset22__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset23 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset23.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset23.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset23__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset24 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset24.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset24.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset24__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset25 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset25.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset25.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset25__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset26 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset26.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset26.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset26__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset27 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset27.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset27.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset27__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset28 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset28.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset28.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset28__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset29 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset29.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset29.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset29__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset3 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset3.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset3.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset3__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset30 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset30.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset30.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset30__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset31 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset31.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset31.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset31__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset32 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset32.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset32.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset32__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset33 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset33.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset33.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset33__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset34 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset34.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset34.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset34__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset35 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset35.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset35.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset35__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset36 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset36.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset36.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset36__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset37 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset37.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset37.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset37__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset38 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset38.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset38.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset38__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset39 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset39.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset39.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset39__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset4 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset4.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset4.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset4__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset40 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset40.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset40.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset40__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset41 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset41.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset41.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset41__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset42 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset42.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset42.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset42__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset43 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset43.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset43.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset43__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset44 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset44.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset44.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset44__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset45 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset45.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset45.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset45__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset46 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset46.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset46.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset46__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset47 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset47.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset47.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset47__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset48 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset48.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset48.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset48__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset49 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset49.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset49.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset49__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset5 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset5.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset5.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset5__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset50 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset50.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset50.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset50__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset51 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset51.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset51.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset51__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset52 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset52.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset52.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset52__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset53 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset53.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset53.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset53__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset54 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset54.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset54.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset54__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset55 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset55.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset55.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset55__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset56 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset56.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset56.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset56__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset57 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset57.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset57.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset57__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset58 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset58.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset58.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset58__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset59 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset59.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset59.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset59__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset6 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset6.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset6.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset6__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset60 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset60.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset60.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset60__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset61 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset61.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset61.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset61__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset62 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset62.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset62.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset62__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset63 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset63.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset63.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset63__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset64 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset64.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset64.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset64__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset65 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset65.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset65.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset65__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset66 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset66.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset66.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset66__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset67 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset67.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset67.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset67__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset68 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset68.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset68.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset68__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset69 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset69.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset69.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset69__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset7 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset7.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset7.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset7__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset70 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset70.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset70.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset70__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset71 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset71.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset71.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset71__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset72 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset72.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset72.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset72__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset73 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset73.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset73.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset73__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset74 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset74.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset74.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset74__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset75 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset75.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset75.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset75__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset76 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset76.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset76.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset76__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset77 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset77.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset77.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset77__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset78 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset78.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset78.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset78__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset79 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset79.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset79.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset79__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset8 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset8.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset8.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset8__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset80 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset80.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset80.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset80__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset81 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset81.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset81.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset81__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset82 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset82.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset82.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset82__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset83 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset83.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset83.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset83__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset84 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset84.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset84.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset84__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset85 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset85.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset85.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset85__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset86 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset86.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset86.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset86__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset87 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset87.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset87.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset87__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset88 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset88.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset88.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset88__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset89 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset89.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset89.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset89__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset9 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset9.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset9.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset9__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset90 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset90.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset90.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset90__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset91 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset91.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset91.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset91__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset92 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset92.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset92.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset92__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset93 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset93.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset93.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset93__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset94 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset94.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset94.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset94__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset95 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset95.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset95.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset95__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset96 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset96.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset96.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset96__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset97 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset97.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset97.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset97__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset98 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset98.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset98.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset98__cell_type_seurat.txt
# img_path=../0_resources/vsn_cache/cflerin-seurat-4.0.3-plus.sif && singularity exec --cleanenv -H $PWD -B /dodrio,/readonly/dodrio,/tmp $img_path Rscript ../0_resources/scripts/seurat_label_transfer_consensus.R BIO_ddseq_1.FIXEDCELLS_subset99 cell_region_looms/BIO_ddseq_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets_subset99.loom ../1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS_subset99.fragments.filteredchroms.tsv.gz ../0_resources/seurat_references/pbmc_ref.rds ../0_resources/seurat_references/granges_annotation.rds cell_type_classification/BIO_ddseq_1.FIXEDCELLS_subset99__cell_type_seurat.txt

# %% [markdown]
# # Run the Rscript

# %% [markdown]
# ```
# mkdir cell_type_classification
# export OMP_THREAD_LIMIT=6
# cat seurat_label_transfer.subsets.parallel | parallel -j 1 --progress
# ```

# %%
kill $(jobs -p)

# %% [markdown]
# # Troubleshooting

# %% [markdown]
# when running
# ```
# > chromatinassay = CreateChromatinAssay(
# +     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
# +     genome='hg38',
# +     fragments = f_frag,
# +     ranges=regions
# +     )
# ```
# i get the error
# ```
# Computing hash
# Checking for 2208 cell barcodes
# Error in CreateFragmentObject(path = fragments, cells = cells, validate.fragments = validate.fragments,  :
#   Not all cells requested could be found in the fragment file.
# In addition: Warning message:
# In CreateChromatinAssay(counts = GetAssayData(atac_tmp, slot = "counts",  :
#   Overlapping ranges supplied. Ranges should be non-overlapping.
# ```
# and `chromatinassay` is empty.

# %%
zcat fragments_postbap/VIB_Hydrop_1.sinto.mm.fragments.tsv.gz | head
# Out:
# chr1	10151	10183	GCGTTGACTTCGTCGACGTA-12	1
# chr1	16228	16272	ATTGTAGAGGTAGGAGTCAA-12	6
# chr1	17490	17527	TTGTACTGCAAGGTGCCAGA-12	3
# chr1	30857	31030	CATGAACGTTGTGACGTGGA-12	1
# chr1	68280	68311	CATTGGTGCAGGCGAGATTC-12	1
# chr1	74871	74900	ATCATCCGTTAATAGGCAGG-11	11
# chr1	79643	79855	GGAGCGGATTCAAGGTCGAT-11	2
# chr1	88228	88302	AAGACCAAGCGCTGATGGTA-12	4
# chr1	89893	89944	TCCGATTCAGCACGTTAAGA-12	3
# chr1	91177	91237	CTCCTCACTACTTGAAGAAG-12	4
#
# gzip: stdout: Broken pipe

# %% [markdown]
# this error doesn't make sense, because the barcodes are present in the fragments file.

# %% [markdown]
# the output of the above code can be read in the cell_type_redictions.ipynb notebook

# %% [markdown]
# it turns out the loom file writing had a bug in it that did not add the `-1?` do the barcode. i fixed this in the loom writing.

# %% [markdown]
# now that this is fixed, i got an error
#
# ```
# > chromatinassay = CreateChromatinAssay(
# +     counts=GetAssayData(atac_tmp, slot = "counts", assay='ATAC'),
# +     genome='hg38',
# +     fragments = f_frag,
# +     ranges=regions
# +     )
# Computing hash
# Checking for 2208 cell barcodes
# Error in .order_seqlevels(chrom_sizes[, "chrom"]) :
#   !anyNA(m32) is not TRUE
# In addition: Warning message:
# In CreateChromatinAssay(counts = GetAssayData(atac_tmp, slot = "counts",  :
#   Overlapping ranges supplied. Ranges should be non-overlapping.
# ```

# %% [markdown]
# it turns out that this is a known bug (https://github.com/timoast/signac/issues/687) and that commenting out the line `genome='hg38'`
