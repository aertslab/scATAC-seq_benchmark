# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk, peak_calling
import pyranges as pr
import requests
import os
import pandas as pd
import glob
import pickle

# %%
# %load_ext lab_black

# %%
# get chromosome sizes (hg38)
if not os.path.exists("chromsizes.txt"):
    target_url = (
        "http://hgdownload.cse.ucsc.edu/goldenPath/mm10/bigZips/mm10.chrom.sizes"
    )
    chromsizes = pd.read_csv(target_url, sep="\t", header=None)
    chromsizes.columns = ["Chromosome", "End"]
    chromsizes["Start"] = [0] * chromsizes.shape[0]
    chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
    chromsizes = pr.PyRanges(chromsizes)
    chromsizes.to_csv("chromsizes.txt")
    chromsizes
else:
    chromsizes = pd.read_csv("chromsizes.txt")

# %%
cto_consensus_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("cistopic_objects/*singlets.model*dimreduc.pkl"))
}
cto_consensus_path_dict
# Out:
# {'BIO_ddseq_m1c1.FULL': 'cistopic_objects/BIO_ddseq_m1c1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.pkl',
#  'BIO_ddseq_m1c2.FULL': 'cistopic_objects/BIO_ddseq_m1c2.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.pkl',
#  'BIO_ddseq_m1c3.FULL': 'cistopic_objects/BIO_ddseq_m1c3.FULL__cto.scrublet0-4.fmx.singlets.model_15topics.dimreduc.pkl',
#  'BIO_ddseq_m1c4.FULL': 'cistopic_objects/BIO_ddseq_m1c4.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.pkl',
#  'BIO_ddseq_m1c5.FULL': 'cistopic_objects/BIO_ddseq_m1c5.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.pkl',
#  'BIO_ddseq_m1c6.FULL': 'cistopic_objects/BIO_ddseq_m1c6.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.pkl',
#  'BIO_ddseq_m1c7.FULL': 'cistopic_objects/BIO_ddseq_m1c7.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.pkl',
#  'BIO_ddseq_m1c8.FULL': 'cistopic_objects/BIO_ddseq_m1c8.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.pkl',
#  'BIO_ddseq_m2c1.FULL': 'cistopic_objects/BIO_ddseq_m2c1.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.pkl',
#  'BIO_ddseq_m2c2.FULL': 'cistopic_objects/BIO_ddseq_m2c2.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.pkl',
#  'BIO_ddseq_m2c3.FULL': 'cistopic_objects/BIO_ddseq_m2c3.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.pkl',
#  'BIO_ddseq_m2c4.FULL': 'cistopic_objects/BIO_ddseq_m2c4.FULL__cto.scrublet0-4.fmx.singlets.model_10topics.dimreduc.pkl',
#  'OHS_s3atac_mouse.FULL': 'cistopic_objects/OHS_s3atac_mouse.FULL__cto.scrublet0-4.fmx.singlets.model_9topics.dimreduc.pkl',
#  'TXG_10xmultiome_e18mousebrainfresh.FULL': 'cistopic_objects/TXG_10xmultiome_e18mousebrainfresh.FULL__cto.scrublet0-4.fmx.singlets.model_18topics.dimreduc.pkl',
#  'TXG_10xv11_adultmousecortexchromiumx.FULL': 'cistopic_objects/TXG_10xv11_adultmousecortexchromiumx.FULL__cto.scrublet0-4.fmx.singlets.model_18topics.dimreduc.pkl',
#  'TXG_10xv1_adultmousefresh.FULL': 'cistopic_objects/TXG_10xv1_adultmousefresh.FULL__cto.scrublet0-4.fmx.singlets.model_20topics.dimreduc.pkl',
#  'TXG_10xv2_adultmousecortex.FULL': 'cistopic_objects/TXG_10xv2_adultmousecortex.FULL__cto.scrublet0-4.fmx.singlets.model_18topics.dimreduc.pkl',
#  'TXG_10xv2_adultmousecortexchromiumx.FULL': 'cistopic_objects/TXG_10xv2_adultmousecortexchromiumx.FULL__cto.scrublet0-4.fmx.singlets.model_15topics.dimreduc.pkl',
#  'VIB_hydrop_1.FULL': 'cistopic_objects/VIB_hydrop_1.FULL__cto.scrublet0-4.fmx.singlets.model_19topics.dimreduc.pkl',
#  'VIB_hydrop_2.FULL': 'cistopic_objects/VIB_hydrop_2.FULL__cto.scrublet0-4.fmx.singlets.model_14topics.dimreduc.pkl',
#  'VIB_hydrop_3.FULL': 'cistopic_objects/VIB_hydrop_3.FULL__cto.scrublet0-4.fmx.singlets.model_14topics.dimreduc.pkl',
#  'VIB_hydrop_4.FULL': 'cistopic_objects/VIB_hydrop_4.FULL__cto.scrublet0-4.fmx.singlets.model_15topics.dimreduc.pkl',
#  'VIB_hydrop_5.FULL': 'cistopic_objects/VIB_hydrop_5.FULL__cto.scrublet0-4.fmx.singlets.model_12topics.dimreduc.pkl'}

# %%
filenames = sorted(
    glob.glob("../1_data_repository/publicdata_full_fragments_vsn/*.fragments.tsv.gz")
)
fragments_path_dict = {}
for filename in filenames:
    sample = filename.split("/")[-1].split(".fragments.tsv.gz")[0]
    fragments_path_dict[sample] = filename
fragments_path_dict
# Out:
# {'BIO_ddseq_m1c1.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c1.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c2.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c2.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c3.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c3.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c4.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c4.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c5.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c5.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c6.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c6.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c7.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c7.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m1c8.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m1c8.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m2c1.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m2c1.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m2c2.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m2c2.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m2c3.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m2c3.FULL.fragments.tsv.gz',
#  'BIO_ddseq_m2c4.FULL': '../1_data_repository/publicdata_full_fragments_vsn/BIO_ddseq_m2c4.FULL.fragments.tsv.gz',
#  'OHS_s3atac_mouse.FULL': '../1_data_repository/publicdata_full_fragments_vsn/OHS_s3atac_mouse.FULL.fragments.tsv.gz',
#  'TXG_10xmultiome_e18mousebrainfresh.FULL': '../1_data_repository/publicdata_full_fragments_vsn/TXG_10xmultiome_e18mousebrainfresh.FULL.fragments.tsv.gz',
#  'TXG_10xv11_adultmousecortexchromiumx.FULL': '../1_data_repository/publicdata_full_fragments_vsn/TXG_10xv11_adultmousecortexchromiumx.FULL.fragments.tsv.gz',
#  'TXG_10xv1_adultmousefresh.FULL': '../1_data_repository/publicdata_full_fragments_vsn/TXG_10xv1_adultmousefresh.FULL.fragments.tsv.gz',
#  'TXG_10xv2_adultmousecortex.FULL': '../1_data_repository/publicdata_full_fragments_vsn/TXG_10xv2_adultmousecortex.FULL.fragments.tsv.gz',
#  'TXG_10xv2_adultmousecortexchromiumx.FULL': '../1_data_repository/publicdata_full_fragments_vsn/TXG_10xv2_adultmousecortexchromiumx.FULL.fragments.tsv.gz',
#  'VIB_hydrop_1.FULL': '../1_data_repository/publicdata_full_fragments_vsn/VIB_hydrop_1.FULL.fragments.tsv.gz',
#  'VIB_hydrop_2.FULL': '../1_data_repository/publicdata_full_fragments_vsn/VIB_hydrop_2.FULL.fragments.tsv.gz',
#  'VIB_hydrop_3.FULL': '../1_data_repository/publicdata_full_fragments_vsn/VIB_hydrop_3.FULL.fragments.tsv.gz',
#  'VIB_hydrop_4.FULL': '../1_data_repository/publicdata_full_fragments_vsn/VIB_hydrop_4.FULL.fragments.tsv.gz',
#  'VIB_hydrop_5.FULL': '../1_data_repository/publicdata_full_fragments_vsn/VIB_hydrop_5.FULL.fragments.tsv.gz'}

# %%
import gc
import logging
import os
import re
import subprocess
import sys
from typing import Dict, List, Optional, Union

import numpy as np
import pandas as pd
import pyBigWig
import pyranges as pr
import ray

from pycisTopic.cistopic_class import *
from pycisTopic.utils import *


def export_pseudobulk(
    input_data: Union["CistopicObject", pd.DataFrame, Dict[str, pd.DataFrame]],
    variable: str,
    chromsizes: Union[pd.DataFrame, pr.PyRanges],
    bed_path: str,
    bigwig_path: str,
    path_to_fragments: Optional[Dict[str, str]] = None,
    sample_id_col: Optional[str] = "sample_id",
    n_cpu: Optional[int] = 1,
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
    use_polars: Optional[bool] = True,
    **kwargs
):
    """
    Create pseudobulks as bed and bigwig from single cell fragments file given a barcode annotation.
    Parameters
    ---------
    input_data: CistopicObject or pd.DataFrame
            A :class:`CistopicObject` containing the specified `variable` as a column in :class:`CistopicObject.cell_data` or a cell metadata
            :class:`pd.DataFrame` containing barcode as rows, containing the specified `variable` as a column (additional columns are
            possible) and a `sample_id` column. Index names must contain the BARCODE (e.g. ATGTCGTC-1), additional tags are possible separating with -
            (e.g. ATGCTGTGCG-1-Sample_1). The levels in the sample_id column must agree with the keys in the path_to_fragments dictionary.
            Alternatively, if the cell metadata contains a column named barcode it will be used instead of the index names.
    variable: str
            A character string indicating the column that will be used to create the different group pseudobulk. It must be included in
            the cell metadata provided as input_data.
    chromsizes: pd.DataFrame or pr.PyRanges
            A data frame or :class:`pr.PyRanges` containing size of each chromosome, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed files per group will be saved. If None, files will not be generated.
    bigwig_path: str
            Path to folder where the bigwig files per group will be saved. If None, files will not be generated.
    path_to_fragments: str or dict, optional
            A dictionary of character strings, with sample name as names indicating the path to the fragments file/s from which pseudobulk profiles have to
            be created. If a :class:`CistopicObject` is provided as input it will be ignored, but if a cell metadata :class:`pd.DataFrame` is provided it
            is necessary to provide it. The keys of the dictionary need to match with the sample_id tag added to the index names of the input data frame.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    n_cpu: int, optional
            Number of cores to use. Default: 1.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str, optional
            Pattern to split cell barcode from sample id. Default: ___ .
    use_polars: bool, optional
            Whether to use polars to read fragments files. Default: True.
    **kwargs
            Additional parameters for ray.init()
    Return
    ------
    dict
            A dictionary containing the paths to the newly created bed fragments files per group a dictionary containing the paths to the
            newly created bigwig files per group.
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    # Get fragments file
    if isinstance(input_data, CistopicObject):
        path_to_fragments = input_data.path_to_fragments
        if path_to_fragments is None:
            log.error("No path_to_fragments in this cisTopic object.")
        cell_data = input_data.cell_data
    elif isinstance(input_data, pd.DataFrame):
        if path_to_fragments is None:
            log.error("Please, provide path_to_fragments.")
        cell_data = input_data
    # Check for sample_id column
    try:
        sample_ids = list(set(cell_data[sample_id_col]))
    except ValueError:
        print(
            'Please, include a sample identification column (e.g. "sample_id") in your cell metadata!'
        )

    # Get fragments
    fragments_df_dict = {}
    for sample_id in path_to_fragments.keys():
        if sample_id not in sample_ids:
            log.info(
                "The following path_to_fragments entry is not found in the cell metadata sample_id_col: ",
                sample_id,
                ". It will be ignored.",
            )
        else:
            log.info("Reading fragments from " + path_to_fragments[sample_id])
            fragments_df = read_fragments_from_file(
                path_to_fragments[sample_id], use_polars=use_polars
            ).df
            # Convert to int32 for memory efficiency
            fragments_df.Start = np.int32(fragments_df.Start)
            fragments_df.End = np.int32(fragments_df.End)
            if "Score" in fragments_df:
                fragments_df.Score = np.int32(fragments_df.Score)
            if "barcode" in cell_data:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(cell_data["barcode"].tolist())
                ]
            else:
                fragments_df = fragments_df.loc[
                    fragments_df["Name"].isin(
                        prepare_tag_cells(cell_data.index.tolist(), split_pattern)
                    )
                ]
            fragments_df_dict[sample_id] = fragments_df

    # Set groups
    if "barcode" in cell_data:
        cell_data = cell_data.loc[:, [variable, sample_id_col, "barcode"]]
    else:
        cell_data = cell_data.loc[:, [variable, sample_id_col]]
    cell_data[variable] = cell_data[variable].replace(" ", "", regex=True)
    cell_data[variable] = cell_data[variable].replace("[^A-Za-z0-9]+", "_", regex=True)
    groups = sorted(list(set(cell_data[variable])))
    # Check chromosome sizes
    if isinstance(chromsizes, pd.DataFrame):
        chromsizes = chromsizes.loc[:, ["Chromosome", "Start", "End"]]
        chromsizes = pr.PyRanges(chromsizes)
    # Check that output dir exist and generate output paths
    if isinstance(bed_path, str):
        if not os.path.exists(bed_path):
            os.makedirs(bed_path)
        bed_paths = {
            group: os.path.join(bed_path, str(group) + ".bed.gz") for group in groups
        }
    else:
        bed_paths = {}
    if isinstance(bigwig_path, str):
        if not os.path.exists(bigwig_path):
            os.makedirs(bigwig_path)
        bw_paths = {
            group: os.path.join(bigwig_path, str(group) + ".bw") for group in groups
        }
    else:
        bw_paths = {}
    # Create pseudobulks
    if n_cpu > 1:
        ray.init(num_cpus=n_cpu, **kwargs)
        ray_handle = ray.wait(
            [
                export_pseudobulk_ray.remote(
                    cell_data,
                    group,
                    fragments_df_dict,
                    chromsizes,
                    bigwig_path,
                    bed_path,
                    sample_id_col,
                    normalize_bigwig,
                    remove_duplicates,
                    split_pattern,
                )
                for group in groups
            ],
            num_returns=len(groups),
        )
        ray.shutdown()
    else:
        [
            export_pseudobulk_one_sample(
                cell_data,
                group,
                fragments_df_dict,
                chromsizes,
                bigwig_path,
                bed_path,
                sample_id_col,
                normalize_bigwig,
                remove_duplicates,
                split_pattern,
            )
            for group in groups
        ]

    return bw_paths, bed_paths


def export_pseudobulk_one_sample(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    # Create logger
    level = logging.INFO
    log_format = "%(asctime)s %(name)-12s %(levelname)-8s %(message)s"
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=log_format, handlers=handlers)
    log = logging.getLogger("cisTopic")

    log.info("Creating pseudobulk for " + str(group))
    group_fragments_list = []
    group_fragments_dict = {}
    for sample_id in fragments_df_dict:
        sample_data = cell_data[cell_data.loc[:, sample_id_col].isin([sample_id])]
        if "barcode" in sample_data:
            sample_data.index = sample_data["barcode"].tolist()
        else:
            sample_data.index = prepare_tag_cells(
                sample_data.index.tolist(), split_pattern
            )
        group_var = sample_data.iloc[:, 0]
        barcodes = group_var[group_var.isin([group])].index.tolist()
        fragments_df = fragments_df_dict[sample_id]
        group_fragments = fragments_df.loc[fragments_df["Name"].isin(barcodes)]
        if len(fragments_df_dict) > 1:
            group_fragments_dict[sample_id] = group_fragments

    if len(fragments_df_dict) > 1:
        group_fragments_list = [
            group_fragments_dict[list(group_fragments_dict.keys())[x]]
            for x in range(len(fragments_df_dict))
        ]
        group_fragments = group_fragments_list[0].append(group_fragments_list[1:])

    group_fragments = group_fragments[
        group_fragments["Chromosome"].isin(chromsizes.Chromosome)
    ]

    del group_fragments_dict
    del group_fragments_list
    del fragments_df
    gc.collect()

    group_pr = pr.PyRanges(group_fragments)
    if isinstance(bigwig_path, str):
        bigwig_path_group = os.path.join(bigwig_path, str(group) + ".bw")
        if remove_duplicates:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
            )
        else:
            group_pr.to_bigwig(
                path=bigwig_path_group,
                chromosome_sizes=chromsizes,
                rpm=normalize_bigwig,
                value_col="Score",
            )
    if isinstance(bed_path, str):
        bed_path_group = os.path.join(bed_path, str(group) + ".bed.gz")
        group_pr.to_bed(
            path=bed_path_group, keep=False, compression="infer", chain=False
        )

    log.info(str(group) + " done!")


@ray.remote
def export_pseudobulk_ray(
    cell_data: pd.DataFrame,
    group: str,
    fragments_df_dict: Dict[str, pd.DataFrame],
    chromsizes: pr.PyRanges,
    bigwig_path: str,
    bed_path: str,
    sample_id_col: Optional[str] = "sample_id",
    normalize_bigwig: Optional[bool] = True,
    remove_duplicates: Optional[bool] = True,
    split_pattern: Optional[str] = "___",
):
    """
    Create pseudobulk as bed and bigwig from single cell fragments file given a barcode annotation and a group.
    Parameters
    ---------
    cell_data: pd.DataFrame
            A cell metadata :class:`pd.Dataframe` containing barcodes, their annotation and their sample of origin.
    group: str
            A character string indicating the group for which pseudobulks will be created.
    fragments_df_dict: dict
            A dictionary containing data frames as values with 'Chromosome', 'Start', 'End', 'Name', and 'Score' as columns; and sample label
            as keys. 'Score' indicates the number of times that a fragments is found assigned to that barcode.
    chromsizes: pr.PyRanges
            A :class:`pr.PyRanges` containing size of each column, containing 'Chromosome', 'Start' and 'End' columns.
    bed_path: str
            Path to folder where the fragments bed file will be saved.
    bigwig_path: str
            Path to folder where the bigwig file will be saved.
    sample_id_col: str, optional
            Name of the column containing the sample name per barcode in the input :class:`CistopicObject.cell_data` or class:`pd.DataFrame`. Default: 'sample_id'.
    normalize_bigwig: bool, optional
            Whether bigwig files should be CPM normalized. Default: True.
    remove_duplicates: bool, optional
            Whether duplicates should be removed before converting the data to bigwig.
    split_pattern: str
            Pattern to split cell barcode from sample id. Default: ___ .
    """
    export_pseudobulk_one_sample(
        cell_data,
        group,
        fragments_df_dict,
        chromsizes,
        bigwig_path,
        bed_path,
        sample_id_col,
        normalize_bigwig,
        remove_duplicates,
        split_pattern,
    )

# %%
sample = "OHS_s3atac_mouse.FULL"
cto_path = cto_consensus_path_dict[sample]
with open(cto_path, "rb") as f:
    cto = pickle.load(f)

# %%
# for sample in ["BRO_mtscatac_1.LIBDS"]:
bw_paths_dict = {}
bed_paths_dict = {}

import ray

if ray.is_initialized():
    print("Shutting down Ray")
    ray.shutdown()

for sample in cto_consensus_path_dict.keys():
    # for sample in ["BRO_mtscatac_1.LIBDS"]:
    bed_path = os.path.join(
        "final_consensus_peaks", f"{sample}__SCREEN_pseudobulk_bed_files"
    )
    bw_path = os.path.join(
        "final_consensus_peaks", f"{sample}__SCREEN_pseudobulk_bw_files"
    )
    if not os.path.exists(bed_path):
        cto_path = cto_consensus_path_dict[sample]
        with open(cto_path, "rb") as f:
            cto = pickle.load(f)

        cto.cell_data["sample_id_fixed"] = [
            x.replace(".fragments.tsv.gz", "") for x in cto.cell_data["sample_id"]
        ]
        if sample == "OHS_s3atac_mouse.FULL":
            cto.cell_data["sample_id_fixed"] = "OHS_s3atac_mouse.FULL"

        bw_paths, bed_paths = export_pseudobulk(
            input_data=cto,
            variable="pycisTopic_leiden_10_0.4",
            sample_id_col="sample_id_fixed",
            chromsizes=chromsizes,
            bed_path=bed_path,
            bigwig_path=bw_path,
            path_to_fragments=fragments_path_dict[sample],
            n_cpu=16,
            normalize_bigwig=True,
            remove_duplicates=True,
        )

        if ray.is_initialized():
            print("Shutting down Ray")
            ray.shutdown()
    else:
        print(f"{bed_path} exists, skipping...")
# Out:
# final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m2c2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m2c3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/BIO_ddseq_m2c4.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/OHS_s3atac_mouse.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/TXG_10xmultiome_e18mousebrainfresh.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/TXG_10xv11_adultmousecortexchromiumx.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/TXG_10xv1_adultmousefresh.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/TXG_10xv2_adultmousecortex.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/TXG_10xv2_adultmousecortexchromiumx.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/VIB_hydrop_1.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/VIB_hydrop_2.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/VIB_hydrop_3.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files exists, skipping...
# final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files exists, skipping...

# %% [markdown]
# # consensus

# %%
bw_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("final_consensus_peaks/*_pseudobulk_bw_files"))
}
bw_path_dict
# Out:
# {'BIO_ddseq_m1c1.FULL': 'final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c2.FULL': 'final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c3.FULL': 'final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c4.FULL': 'final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c5.FULL': 'final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c6.FULL': 'final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c7.FULL': 'final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m1c8.FULL': 'final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m2c1.FULL': 'final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m2c2.FULL': 'final_consensus_peaks/BIO_ddseq_m2c2.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m2c3.FULL': 'final_consensus_peaks/BIO_ddseq_m2c3.FULL__SCREEN_pseudobulk_bw_files',
#  'BIO_ddseq_m2c4.FULL': 'final_consensus_peaks/BIO_ddseq_m2c4.FULL__SCREEN_pseudobulk_bw_files',
#  'OHS_s3atac_mouse.FULL': 'final_consensus_peaks/OHS_s3atac_mouse.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xmultiome_e18mousebrainfresh.FULL': 'final_consensus_peaks/TXG_10xmultiome_e18mousebrainfresh.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv11_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv11_adultmousecortexchromiumx.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv1_adultmousefresh.FULL': 'final_consensus_peaks/TXG_10xv1_adultmousefresh.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv2_adultmousecortex.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortex.FULL__SCREEN_pseudobulk_bw_files',
#  'TXG_10xv2_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortexchromiumx.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_1.FULL': 'final_consensus_peaks/VIB_hydrop_1.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_2.FULL': 'final_consensus_peaks/VIB_hydrop_2.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_3.FULL': 'final_consensus_peaks/VIB_hydrop_3.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_4.FULL': 'final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bw_files',
#  'VIB_hydrop_5.FULL': 'final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bw_files'}

# %%
bed_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("final_consensus_peaks/*_pseudobulk_bed_files"))
}
bed_path_dict
# Out:
# {'BIO_ddseq_m1c1.FULL': 'final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c2.FULL': 'final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c3.FULL': 'final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c4.FULL': 'final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c5.FULL': 'final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c6.FULL': 'final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c7.FULL': 'final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m1c8.FULL': 'final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m2c1.FULL': 'final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m2c2.FULL': 'final_consensus_peaks/BIO_ddseq_m2c2.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m2c3.FULL': 'final_consensus_peaks/BIO_ddseq_m2c3.FULL__SCREEN_pseudobulk_bed_files',
#  'BIO_ddseq_m2c4.FULL': 'final_consensus_peaks/BIO_ddseq_m2c4.FULL__SCREEN_pseudobulk_bed_files',
#  'OHS_s3atac_mouse.FULL': 'final_consensus_peaks/OHS_s3atac_mouse.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xmultiome_e18mousebrainfresh.FULL': 'final_consensus_peaks/TXG_10xmultiome_e18mousebrainfresh.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv11_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv11_adultmousecortexchromiumx.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv1_adultmousefresh.FULL': 'final_consensus_peaks/TXG_10xv1_adultmousefresh.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv2_adultmousecortex.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortex.FULL__SCREEN_pseudobulk_bed_files',
#  'TXG_10xv2_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortexchromiumx.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_1.FULL': 'final_consensus_peaks/VIB_hydrop_1.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_2.FULL': 'final_consensus_peaks/VIB_hydrop_2.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_3.FULL': 'final_consensus_peaks/VIB_hydrop_3.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_4.FULL': 'final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files',
#  'VIB_hydrop_5.FULL': 'final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files'}

# %%
for sample in bed_path_dict.keys():
    bed_paths = {
        x.split("/")[-1].split("__")[0].split(".bed.gz")[0]: x
        for x in glob.glob(bed_path_dict[sample] + "/*")
    }

# %%
from pycisTopic.pseudobulk_peak_calling import *

# %%
import ray

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
cto_path = cto_consensus_path_dict[sample]
with open(cto_path, "rb") as f:
    cto = pickle.load(f)

# %%
cto.cell_data["pycisTopic_leiden_10_0.4"].unique()
# Out:
# array(['2', '3', '4', '0', '10', '9', '8', '7', '6', '12', '1', '11',
#        '13', '5', '15', '14', '16'], dtype=object)

# %%
narrow_peaks_dict = {}
ray.shutdown()
for sample in bed_path_dict.keys():
    narrow_peaks_dict_path = bed_path_dict[sample].replace(
        "_pseudobulk_bed_files", "_narrow_peaks_dict.pkl"
    )
    peak_path = os.path.join(
        "final_consensus_peaks", f"{sample}__SCREEN_consensus_peaks"
    )
    if not os.path.exists(peak_path):
        os.mkdir(peak_path)

    if not os.path.exists(narrow_peaks_dict_path):
        cto_path = cto_consensus_path_dict[sample]
        with open(cto_path, "rb") as f:
            cto = pickle.load(f)

        cto_celltypes = set(cto.cell_data["pycisTopic_leiden_10_0.4"].unique())
        bed_celltypes = set(
            [
                x.split(".")[0].replace("+", "").replace("_", "")
                for x in os.listdir(bed_path_dict[sample])
            ]
        )

        if cto_celltypes == bed_celltypes:
            print(f"Starting {narrow_peaks_dict_path}")
            bed_paths = {
                x.split("/")[-1].split("__")[0].split(".bed.gz")[0]: x
                for x in glob.glob(bed_path_dict[sample] + "/*")
            }
            narrow_peaks_dict = peak_calling(
                macs_path="macs2",
                bed_paths=bed_paths,
                outdir=peak_path,
                genome_size="mm",
                n_cpu=20,
                input_format="BEDPE",
                shift=73,
                ext_size=146,
                keep_dup="all",
                q_value=0.05,
            )
            with open(narrow_peaks_dict_path, "wb") as f:
                pickle.dump(narrow_peaks_dict, f)
        else:
            print(f"{sample} cell types not matching!! Rerun bed file writing.")
            print(f"\t{bed_celltypes}")
            print(f"\t{cto_celltypes}")
    else:
        print(f"{narrow_peaks_dict_path} already exists")
# Out:
# Starting final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 14:59:17,267	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2856476) 2022-11-04 14:59:22,856 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856473) 2022-11-04 14:59:22,822 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856481) 2022-11-04 14:59:22,855 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856483) 2022-11-04 14:59:22,823 cisTopic     INFO     Calling peaks for 11 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/11.bed.gz --name 11  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856478) 2022-11-04 14:59:22,839 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856467) 2022-11-04 14:59:22,941 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856482) 2022-11-04 14:59:22,947 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856475) 2022-11-04 14:59:22,958 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856484) 2022-11-04 14:59:22,915 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856471) 2022-11-04 14:59:22,964 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856485) 2022-11-04 14:59:23,008 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856472) 2022-11-04 14:59:23,006 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2856483) 2022-11-04 14:59:46,042 cisTopic     INFO     11 done!
# (macs_call_peak_ray pid=2856482) 2022-11-04 14:59:49,025 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2856478) 2022-11-04 14:59:49,599 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2856484) 2022-11-04 14:59:52,169 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2856467) 2022-11-04 14:59:52,396 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2856476) 2022-11-04 14:59:54,331 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2856485) 2022-11-04 14:59:58,288 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2856471) 2022-11-04 15:00:10,305 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2856473) 2022-11-04 15:00:20,068 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2856475) 2022-11-04 15:00:49,486 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2856481) 2022-11-04 15:01:02,488 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2856472) 2022-11-04 15:01:31,207 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:01:38,759	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2857513) 2022-11-04 15:01:44,079 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857520) 2022-11-04 15:01:44,049 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857519) 2022-11-04 15:01:44,098 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857511) 2022-11-04 15:01:44,129 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857517) 2022-11-04 15:01:44,124 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857516) 2022-11-04 15:01:44,210 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857509) 2022-11-04 15:01:44,214 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857508) 2022-11-04 15:01:44,218 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857512) 2022-11-04 15:01:44,241 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857514) 2022-11-04 15:01:44,247 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857515) 2022-11-04 15:01:44,256 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2857508) 2022-11-04 15:01:47,779 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2857520) 2022-11-04 15:01:57,647 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2857509) 2022-11-04 15:02:07,245 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2857515) 2022-11-04 15:02:08,229 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2857511) 2022-11-04 15:02:08,963 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2857512) 2022-11-04 15:02:12,341 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2857517) 2022-11-04 15:02:45,801 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2857514) 2022-11-04 15:02:48,956 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2857519) 2022-11-04 15:03:28,545 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2857513) 2022-11-04 15:03:37,314 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2857516) 2022-11-04 15:04:01,851 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:04:08,937	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2858622) 2022-11-04 15:04:14,228 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858618) 2022-11-04 15:04:14,327 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858612) 2022-11-04 15:04:14,328 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858607) 2022-11-04 15:04:14,332 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858625) 2022-11-04 15:04:14,376 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858617) 2022-11-04 15:04:14,394 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858611) 2022-11-04 15:04:14,416 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858608) 2022-11-04 15:04:14,483 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858616) 2022-11-04 15:04:14,452 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858620) 2022-11-04 15:04:14,501 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858609) 2022-11-04 15:04:14,683 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2858625) 2022-11-04 15:04:34,900 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2858612) 2022-11-04 15:04:59,681 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2858618) 2022-11-04 15:04:59,838 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2858620) 2022-11-04 15:04:59,965 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2858617) 2022-11-04 15:05:03,515 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2858616) 2022-11-04 15:05:04,038 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2858608) 2022-11-04 15:05:39,567 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2858611) 2022-11-04 15:05:40,424 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2858607) 2022-11-04 15:06:00,126 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2858609) 2022-11-04 15:06:02,915 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2858622) 2022-11-04 15:06:03,870 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:06:11,461	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2859602) 2022-11-04 15:06:16,531 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859614) 2022-11-04 15:06:16,548 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859615) 2022-11-04 15:06:16,566 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859608) 2022-11-04 15:06:16,574 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859616) 2022-11-04 15:06:16,652 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859601) 2022-11-04 15:06:16,676 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859607) 2022-11-04 15:06:16,747 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859617) 2022-11-04 15:06:16,736 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859612) 2022-11-04 15:06:16,800 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859609) 2022-11-04 15:06:16,823 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2859607) 2022-11-04 15:06:22,770 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2859601) 2022-11-04 15:06:40,112 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2859609) 2022-11-04 15:06:41,453 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2859617) 2022-11-04 15:06:43,458 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2859602) 2022-11-04 15:06:44,664 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2859612) 2022-11-04 15:07:13,370 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2859608) 2022-11-04 15:07:14,785 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2859614) 2022-11-04 15:07:40,516 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2859615) 2022-11-04 15:08:02,665 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2859616) 2022-11-04 15:08:52,615 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:09:00,183	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2860692) 2022-11-04 15:09:06,268 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860686) 2022-11-04 15:09:06,241 cisTopic     INFO     Calling peaks for 14 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/14.bed.gz --name 14  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860684) 2022-11-04 15:09:06,319 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860691) 2022-11-04 15:09:06,364 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860693) 2022-11-04 15:09:06,363 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860687) 2022-11-04 15:09:06,430 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860688) 2022-11-04 15:09:06,474 cisTopic     INFO     Calling peaks for 12 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/12.bed.gz --name 12  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860690) 2022-11-04 15:09:06,484 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860701) 2022-11-04 15:09:06,547 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860682) 2022-11-04 15:09:06,514 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860699) 2022-11-04 15:09:06,506 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860700) 2022-11-04 15:09:06,529 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860685) 2022-11-04 15:09:06,512 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860683) 2022-11-04 15:09:06,628 cisTopic     INFO     Calling peaks for 13 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/13.bed.gz --name 13  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860698) 2022-11-04 15:09:06,694 cisTopic     INFO     Calling peaks for 11 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_pseudobulk_bed_files/11.bed.gz --name 11  --outdir final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2860686) 2022-11-04 15:09:13,808 cisTopic     INFO     14 done!
# (macs_call_peak_ray pid=2860698) 2022-11-04 15:09:22,936 cisTopic     INFO     11 done!
# (macs_call_peak_ray pid=2860683) 2022-11-04 15:09:24,962 cisTopic     INFO     13 done!
# (macs_call_peak_ray pid=2860692) 2022-11-04 15:09:39,115 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2860688) 2022-11-04 15:09:42,112 cisTopic     INFO     12 done!
# (macs_call_peak_ray pid=2860691) 2022-11-04 15:09:44,983 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2860699) 2022-11-04 15:09:45,210 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2860685) 2022-11-04 15:09:47,228 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2860700) 2022-11-04 15:09:53,394 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2860687) 2022-11-04 15:10:22,296 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2860682) 2022-11-04 15:10:42,673 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2860684) 2022-11-04 15:10:43,830 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2860701) 2022-11-04 15:10:52,331 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2860693) 2022-11-04 15:11:04,282 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2860690) 2022-11-04 15:11:43,351 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:11:50,754	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2861806) 2022-11-04 15:11:55,942 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861809) 2022-11-04 15:11:55,950 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861804) 2022-11-04 15:11:55,952 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861811) 2022-11-04 15:11:55,939 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861799) 2022-11-04 15:11:56,087 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861800) 2022-11-04 15:11:56,128 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861810) 2022-11-04 15:11:56,108 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861814) 2022-11-04 15:11:56,183 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861803) 2022-11-04 15:11:56,205 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861801) 2022-11-04 15:11:56,243 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2861809) 2022-11-04 15:12:22,270 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2861804) 2022-11-04 15:12:22,676 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2861800) 2022-11-04 15:12:26,947 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2861810) 2022-11-04 15:12:36,556 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2861814) 2022-11-04 15:12:37,846 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2861801) 2022-11-04 15:12:49,881 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2861806) 2022-11-04 15:13:08,069 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2861811) 2022-11-04 15:13:33,772 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2861803) 2022-11-04 15:13:36,461 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2861799) 2022-11-04 15:14:05,571 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:14:12,868	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2862847) 2022-11-04 15:14:17,976 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862841) 2022-11-04 15:14:17,992 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862849) 2022-11-04 15:14:18,012 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862848) 2022-11-04 15:14:18,031 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862855) 2022-11-04 15:14:18,091 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862854) 2022-11-04 15:14:18,153 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862846) 2022-11-04 15:14:18,164 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862840) 2022-11-04 15:14:18,184 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862844) 2022-11-04 15:14:18,225 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862852) 2022-11-04 15:14:18,292 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2862844) 2022-11-04 15:14:39,714 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2862854) 2022-11-04 15:14:43,321 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2862848) 2022-11-04 15:14:44,397 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2862846) 2022-11-04 15:14:45,273 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2862841) 2022-11-04 15:14:56,857 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2862847) 2022-11-04 15:15:06,414 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2862849) 2022-11-04 15:15:27,217 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2862855) 2022-11-04 15:15:37,766 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2862840) 2022-11-04 15:15:43,863 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2862852) 2022-11-04 15:16:12,597 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:16:19,699	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2863837) 2022-11-04 15:16:25,248 cisTopic     INFO     Calling peaks for 11 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/11.bed.gz --name 11  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863842) 2022-11-04 15:16:25,298 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863839) 2022-11-04 15:16:25,313 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863856) 2022-11-04 15:16:25,306 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863855) 2022-11-04 15:16:25,319 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863841) 2022-11-04 15:16:25,350 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863847) 2022-11-04 15:16:25,367 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863838) 2022-11-04 15:16:25,428 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863850) 2022-11-04 15:16:25,431 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863848) 2022-11-04 15:16:25,488 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863853) 2022-11-04 15:16:25,482 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863852) 2022-11-04 15:16:25,543 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2863837) 2022-11-04 15:16:48,217 cisTopic     INFO     11 done!
# (macs_call_peak_ray pid=2863853) 2022-11-04 15:16:54,234 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2863838) 2022-11-04 15:16:56,479 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2863850) 2022-11-04 15:16:57,020 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2863847) 2022-11-04 15:16:59,350 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2863839) 2022-11-04 15:17:17,937 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2863841) 2022-11-04 15:17:39,853 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2863842) 2022-11-04 15:17:41,781 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2863848) 2022-11-04 15:17:44,120 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2863856) 2022-11-04 15:17:45,805 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2863852) 2022-11-04 15:17:49,322 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2863855) 2022-11-04 15:18:14,800 cisTopic     INFO     0 done!
# Starting final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:18:22,079	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2864830) 2022-11-04 15:18:27,340 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# ...
# (macs_call_peak_ray pid=2878536) 2022-11-04 15:46:44,637 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878528) 2022-11-04 15:46:50,341 cisTopic     INFO     26 done!
# (macs_call_peak_ray pid=2878528) 2022-11-04 15:46:50,381 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878521) 2022-11-04 15:46:50,568 cisTopic     INFO     27 done!
# (macs_call_peak_ray pid=2878521) 2022-11-04 15:46:50,596 cisTopic     INFO     Calling peaks for 11 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/11.bed.gz --name 11  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878527) 2022-11-04 15:46:50,901 cisTopic     INFO     28 done!
# (macs_call_peak_ray pid=2878527) 2022-11-04 15:46:50,933 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878534) 2022-11-04 15:46:51,365 cisTopic     INFO     21 done!
# (macs_call_peak_ray pid=2878534) 2022-11-04 15:46:51,394 cisTopic     INFO     Calling peaks for 16 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/16.bed.gz --name 16  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878520) 2022-11-04 15:46:52,087 cisTopic     INFO     24 done!
# (macs_call_peak_ray pid=2878520) 2022-11-04 15:46:52,115 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878529) 2022-11-04 15:46:52,410 cisTopic     INFO     19 done!
# (macs_call_peak_ray pid=2878529) 2022-11-04 15:46:52,426 cisTopic     INFO     Calling peaks for 13 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/13.bed.gz --name 13  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878530) 2022-11-04 15:46:52,546 cisTopic     INFO     18 done!
# (macs_call_peak_ray pid=2878530) 2022-11-04 15:46:52,576 cisTopic     INFO     Calling peaks for 17 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/17.bed.gz --name 17  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878525) 2022-11-04 15:46:54,402 cisTopic     INFO     29 done!
# (macs_call_peak_ray pid=2878525) 2022-11-04 15:46:54,439 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878533) 2022-11-04 15:46:55,563 cisTopic     INFO     23 done!
# (macs_call_peak_ray pid=2878533) 2022-11-04 15:46:55,592 cisTopic     INFO     Calling peaks for 14 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/14.bed.gz --name 14  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878516) 2022-11-04 15:46:55,649 cisTopic     INFO     15 done!
# (macs_call_peak_ray pid=2878516) 2022-11-04 15:46:55,692 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2878526) 2022-11-04 15:46:57,086 cisTopic     INFO     25 done!
# (macs_call_peak_ray pid=2878535) 2022-11-04 15:46:58,121 cisTopic     INFO     12 done!
# (macs_call_peak_ray pid=2878523) 2022-11-04 15:46:58,897 cisTopic     INFO     20 done!
# (macs_call_peak_ray pid=2878530) 2022-11-04 15:47:00,040 cisTopic     INFO     17 done!
# (macs_call_peak_ray pid=2878529) 2022-11-04 15:47:02,680 cisTopic     INFO     13 done!
# (macs_call_peak_ray pid=2878528) 2022-11-04 15:47:04,530 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2878533) 2022-11-04 15:47:05,604 cisTopic     INFO     14 done!
# (macs_call_peak_ray pid=2878517) 2022-11-04 15:47:06,730 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2878534) 2022-11-04 15:47:07,295 cisTopic     INFO     16 done!
# (macs_call_peak_ray pid=2878519) 2022-11-04 15:47:08,461 cisTopic     INFO     22 done!
# (macs_call_peak_ray pid=2878532) 2022-11-04 15:47:08,957 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2878536) 2022-11-04 15:47:09,407 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2878520) 2022-11-04 15:47:09,567 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2878525) 2022-11-04 15:47:09,860 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2878521) 2022-11-04 15:47:10,101 cisTopic     INFO     11 done!
# (macs_call_peak_ray pid=2878516) 2022-11-04 15:47:12,618 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2878524) 2022-11-04 15:47:16,573 cisTopic     INFO     0 done!
# (macs_call_peak_ray pid=2878522) 2022-11-04 15:47:20,561 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2878527) 2022-11-04 15:47:28,678 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2878518) 2022-11-04 15:47:47,794 cisTopic     INFO     1 done!
# Starting final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_narrow_peaks_dict.pkl
# 2022-11-04 15:47:54,671	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (macs_call_peak_ray pid=2879545) 2022-11-04 15:48:01,076 cisTopic     INFO     Calling peaks for 16 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/16.bed.gz --name 16  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879557) 2022-11-04 15:48:01,147 cisTopic     INFO     Calling peaks for 5 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/5.bed.gz --name 5  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879554) 2022-11-04 15:48:01,192 cisTopic     INFO     Calling peaks for 10 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/10.bed.gz --name 10  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879542) 2022-11-04 15:48:01,166 cisTopic     INFO     Calling peaks for 1 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/1.bed.gz --name 1  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879548) 2022-11-04 15:48:01,190 cisTopic     INFO     Calling peaks for 12 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/12.bed.gz --name 12  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879547) 2022-11-04 15:48:01,263 cisTopic     INFO     Calling peaks for 11 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/11.bed.gz --name 11  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879550) 2022-11-04 15:48:01,382 cisTopic     INFO     Calling peaks for 2 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/2.bed.gz --name 2  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879537) 2022-11-04 15:48:01,369 cisTopic     INFO     Calling peaks for 15 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/15.bed.gz --name 15  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879543) 2022-11-04 15:48:01,415 cisTopic     INFO     Calling peaks for 14 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/14.bed.gz --name 14  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879544) 2022-11-04 15:48:01,468 cisTopic     INFO     Calling peaks for 13 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/13.bed.gz --name 13  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879549) 2022-11-04 15:48:01,413 cisTopic     INFO     Calling peaks for 9 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/9.bed.gz --name 9  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879538) 2022-11-04 15:48:01,483 cisTopic     INFO     Calling peaks for 0 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/0.bed.gz --name 0  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879536) 2022-11-04 15:48:01,492 cisTopic     INFO     Calling peaks for 3 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/3.bed.gz --name 3  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879546) 2022-11-04 15:48:01,511 cisTopic     INFO     Calling peaks for 8 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/8.bed.gz --name 8  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879540) 2022-11-04 15:48:01,500 cisTopic     INFO     Calling peaks for 6 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/6.bed.gz --name 6  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879553) 2022-11-04 15:48:01,530 cisTopic     INFO     Calling peaks for 7 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/7.bed.gz --name 7  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879551) 2022-11-04 15:48:01,519 cisTopic     INFO     Calling peaks for 4 with macs2 callpeak --treatment final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_pseudobulk_bed_files/4.bed.gz --name 4  --outdir final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks --format BEDPE --gsize mm --qvalue 0.05 --nomodel --shift 73 --extsize 146 --keep-dup all --call-summits --nolambda
# (macs_call_peak_ray pid=2879537) 2022-11-04 15:48:07,675 cisTopic     INFO     15 done!
# (macs_call_peak_ray pid=2879557) 2022-11-04 15:48:07,956 cisTopic     INFO     5 done!
# (macs_call_peak_ray pid=2879545) 2022-11-04 15:48:08,078 cisTopic     INFO     16 done!
# (macs_call_peak_ray pid=2879543) 2022-11-04 15:48:09,980 cisTopic     INFO     14 done!
# (macs_call_peak_ray pid=2879548) 2022-11-04 15:48:11,172 cisTopic     INFO     12 done!
# (macs_call_peak_ray pid=2879553) 2022-11-04 15:48:12,839 cisTopic     INFO     7 done!
# (macs_call_peak_ray pid=2879554) 2022-11-04 15:48:16,568 cisTopic     INFO     10 done!
# (macs_call_peak_ray pid=2879544) 2022-11-04 15:48:18,182 cisTopic     INFO     13 done!
# (macs_call_peak_ray pid=2879549) 2022-11-04 15:48:18,155 cisTopic     INFO     9 done!
# (macs_call_peak_ray pid=2879536) 2022-11-04 15:48:19,219 cisTopic     INFO     3 done!
# (macs_call_peak_ray pid=2879546) 2022-11-04 15:48:19,619 cisTopic     INFO     8 done!
# (macs_call_peak_ray pid=2879547) 2022-11-04 15:48:20,331 cisTopic     INFO     11 done!
# (macs_call_peak_ray pid=2879550) 2022-11-04 15:48:25,115 cisTopic     INFO     2 done!
# (macs_call_peak_ray pid=2879551) 2022-11-04 15:48:26,878 cisTopic     INFO     4 done!
# (macs_call_peak_ray pid=2879540) 2022-11-04 15:48:29,428 cisTopic     INFO     6 done!
# (macs_call_peak_ray pid=2879542) 2022-11-04 15:48:30,939 cisTopic     INFO     1 done!
# (macs_call_peak_ray pid=2879538) 2022-11-04 15:48:55,721 cisTopic     INFO     0 done!

# %% [markdown]
# # call consensus peaks

# %%
from pycisTopic.iterative_peak_calling import get_consensus_peaks

# %%
narrow_peaks_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("final_consensus_peaks/*_narrow_peaks_dict.pkl"))
}
narrow_peaks_path_dict
# Out:
# {'BIO_ddseq_m1c1.FULL': 'final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c2.FULL': 'final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c3.FULL': 'final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c4.FULL': 'final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c5.FULL': 'final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c6.FULL': 'final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c7.FULL': 'final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m1c8.FULL': 'final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m2c1.FULL': 'final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m2c2.FULL': 'final_consensus_peaks/BIO_ddseq_m2c2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m2c3.FULL': 'final_consensus_peaks/BIO_ddseq_m2c3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'BIO_ddseq_m2c4.FULL': 'final_consensus_peaks/BIO_ddseq_m2c4.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'OHS_s3atac_mouse.FULL': 'final_consensus_peaks/OHS_s3atac_mouse.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xmultiome_e18mousebrainfresh.FULL': 'final_consensus_peaks/TXG_10xmultiome_e18mousebrainfresh.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv11_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv11_adultmousecortexchromiumx.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv1_adultmousefresh.FULL': 'final_consensus_peaks/TXG_10xv1_adultmousefresh.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv2_adultmousecortex.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortex.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'TXG_10xv2_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortexchromiumx.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_1.FULL': 'final_consensus_peaks/VIB_hydrop_1.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_2.FULL': 'final_consensus_peaks/VIB_hydrop_2.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_3.FULL': 'final_consensus_peaks/VIB_hydrop_3.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_4.FULL': 'final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_narrow_peaks_dict.pkl',
#  'VIB_hydrop_5.FULL': 'final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_narrow_peaks_dict.pkl'}

# %%
path_to_blacklist = "../0_resources/regions/hg38-blacklist.v2.bed"

# %%
peak_half_width = 250

# Get consensus peaks
consensus_peaks_dict = {}
for sample in narrow_peaks_path_dict.keys():
    print(sample)
    consensus_out_path = narrow_peaks_path_dict[sample].replace(
        "_narrow_peaks_dict.pkl", "_consensus_peaks.bed"
    )
    if not os.path.exists(consensus_out_path):
        cto_path = cto_consensus_path_dict[sample]
        with open(cto_path, "rb") as f:
            cto = pickle.load(f)

        cto_celltypes = set(cto.cell_data["pycisTopic_leiden_10_0.4"].unique())

        with open(narrow_peaks_path_dict[sample], "rb") as f:
            narrow_peaks_dict = pickle.load(f)
        peaks_celltypes = set(
            [
                x.replace(" ", "").replace("+", "").replace("_", "")
                for x in set(narrow_peaks_dict.keys())
            ]
        )

        if cto_celltypes == peaks_celltypes:
            consensus_peaks = get_consensus_peaks(
                narrow_peaks_dict,
                peak_half_width,
                chromsizes=chromsizes,
                path_to_blacklist=path_to_blacklist,
            )

            consensus_peaks.to_bed(
                path=consensus_out_path, keep=True, compression="infer", chain=False
            )
        else:
            print("CELL TYPE SETS NOT MATCHING! Rerun peak calling.")
            print(peaks_celltypes - cto_celltypes)
            print(cto_celltypes - peaks_celltypes)
    else:
        print(f"{consensus_out_path} already exists, skipping...")
# Out:
# BIO_ddseq_m1c1.FULL
# 2022-11-04 15:49:00,066 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 15:50:23,829 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 15:50:24,234 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 15:51:39,804 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c2.FULL
# 2022-11-04 15:51:42,132 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 15:53:14,562 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 15:53:14,945 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 15:54:32,105 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c3.FULL
# 2022-11-04 15:54:34,444 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 15:56:14,059 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 15:56:14,499 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 15:57:36,596 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c4.FULL
# 2022-11-04 15:57:38,904 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 15:59:08,127 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 15:59:08,509 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:00:24,706 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c5.FULL
# 2022-11-04 16:00:27,080 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:02:27,791 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:02:28,340 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:04:00,788 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c6.FULL
# 2022-11-04 16:04:03,359 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:05:34,990 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:05:35,413 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:06:55,459 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c7.FULL
# 2022-11-04 16:06:57,738 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:08:16,856 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:08:17,274 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:09:27,517 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m1c8.FULL
# 2022-11-04 16:09:30,076 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:11:05,394 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:11:05,863 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:12:25,080 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# BIO_ddseq_m2c1.FULL
# 2022-11-04 16:12:27,573 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:13:41,273 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:13:41,593 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:14:45,137 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# ...
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:45:08,487 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# VIB_hydrop_4.FULL
# 2022-11-04 16:45:11,187 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:46:12,444 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:46:12,827 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:47:21,042 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# VIB_hydrop_5.FULL
# 2022-11-04 16:47:23,453 cisTopic     INFO     Extending and merging peaks per class
# 2022-11-04 16:48:10,465 cisTopic     INFO     Normalizing peak scores
# 2022-11-04 16:48:10,769 cisTopic     INFO     Merging peaks
# Warning! Start and End columns now have different dtypes: int64 and int32
# 2022-11-04 16:49:03,603 cisTopic     INFO     Done!
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)
# /opt/venv/lib/python3.8/site-packages/pyranges/out.py:37: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   return pd.concat([outdf, df.get(noncanonical)], axis=1)

# %% [markdown]
# # Check % chrM in consensus peaks

# %%
consensus_peaks_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob("final_consensus_peaks/*consensus_peaks.bed"))
}
consensus_peaks_path_dict
# Out:
# {'BIO_ddseq_m1c1.FULL': 'final_consensus_peaks/BIO_ddseq_m1c1.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c2.FULL': 'final_consensus_peaks/BIO_ddseq_m1c2.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c3.FULL': 'final_consensus_peaks/BIO_ddseq_m1c3.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c4.FULL': 'final_consensus_peaks/BIO_ddseq_m1c4.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c5.FULL': 'final_consensus_peaks/BIO_ddseq_m1c5.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c6.FULL': 'final_consensus_peaks/BIO_ddseq_m1c6.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c7.FULL': 'final_consensus_peaks/BIO_ddseq_m1c7.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m1c8.FULL': 'final_consensus_peaks/BIO_ddseq_m1c8.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m2c1.FULL': 'final_consensus_peaks/BIO_ddseq_m2c1.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m2c2.FULL': 'final_consensus_peaks/BIO_ddseq_m2c2.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m2c3.FULL': 'final_consensus_peaks/BIO_ddseq_m2c3.FULL__SCREEN_consensus_peaks.bed',
#  'BIO_ddseq_m2c4.FULL': 'final_consensus_peaks/BIO_ddseq_m2c4.FULL__SCREEN_consensus_peaks.bed',
#  'OHS_s3atac_mouse.FULL': 'final_consensus_peaks/OHS_s3atac_mouse.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xmultiome_e18mousebrainfresh.FULL': 'final_consensus_peaks/TXG_10xmultiome_e18mousebrainfresh.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv11_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv11_adultmousecortexchromiumx.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv1_adultmousefresh.FULL': 'final_consensus_peaks/TXG_10xv1_adultmousefresh.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv2_adultmousecortex.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortex.FULL__SCREEN_consensus_peaks.bed',
#  'TXG_10xv2_adultmousecortexchromiumx.FULL': 'final_consensus_peaks/TXG_10xv2_adultmousecortexchromiumx.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_1.FULL': 'final_consensus_peaks/VIB_hydrop_1.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_2.FULL': 'final_consensus_peaks/VIB_hydrop_2.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_3.FULL': 'final_consensus_peaks/VIB_hydrop_3.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_4.FULL': 'final_consensus_peaks/VIB_hydrop_4.FULL__SCREEN_consensus_peaks.bed',
#  'VIB_hydrop_5.FULL': 'final_consensus_peaks/VIB_hydrop_5.FULL__SCREEN_consensus_peaks.bed'}

# %%
for sample, path in consensus_peaks_path_dict.items():
    print(sample)
    peaks_df = pd.read_csv(path, sep='\t', header=None)
    
    chroms_in_df = list(sorted(peaks_df[0].unique()))
    chroms_standard = ["chr" + str(x + 1) for x in range(22)] + ['chrX']
    chroms_nonstandard = list(set(chroms_in_df ) - set(chroms_standard) -  set(['chrM']))
    
    n_standard = peaks_df[0].value_counts()[chroms_standard].sum()
    n_contigs = peaks_df[0].value_counts()[chroms_nonstandard].sum()
    n_chrm = peaks_df[0].value_counts()['chrM'].sum()
    pct_nonstandard = (n_contigs + n_chrm)/len(peaks_df)*100
        
    print(f"\tpeaks on standard chromosomes: {n_standard}")
    print(f"\tpeaks on contigs: {n_contigs}")
    print(f"\tpeaks on chrM: {n_chrm}")
    print(f"\t% peaks non standard chromosomes: {pct_nonstandard}%")
    if 'chrY' in chroms_in_df:
        n_chrY = peaks_df[0].value_counts()['chrY'].sum()
        print(f"\tpeaks on chrY: {n_chrY}")
    else:
        print(f"\tpeaks on chrY: 0")
# Out:
# BIO_ddseq_m1c1.FULL
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 9
#       6 chroms_standard = ["chr" + str(x + 1) for x in range(22)] + ['chrX']
#       7 chroms_nonstandard = list(set(chroms_in_df ) - set(chroms_standard) -  set(['chrM']))
# ----> 9 n_standard = peaks_df[0].value_counts()[chroms_standard].sum()
#      10 n_contigs = peaks_df[0].value_counts()[chroms_nonstandard].sum()
#      11 n_chrm = peaks_df[0].value_counts()['chrM'].sum()
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/series.py:1008, in Series.__getitem__(self, key)
#    1005     key = np.asarray(key, dtype=bool)
#    1006     return self._get_values(key)
# -> 1008 return self._get_with(key)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/series.py:1048, in Series._get_with(self, key)
#    1045         return self.iloc[key]
#    1047 # handle the dup indexing case GH#4246
# -> 1048 return self.loc[key]
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1302, in _LocIndexer._getitem_axis(self, key, axis)
#    1299     if hasattr(key, "ndim") and key.ndim > 1:
#    1300         raise ValueError("Cannot index with multidimensional key")
# -> 1302     return self._getitem_iterable(key, axis=axis)
#    1304 # nested tuple slicing
#    1305 if is_nested_tuple(key, labels):
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1240, in _LocIndexer._getitem_iterable(self, key, axis)
#    1237 self._validate_key(key, axis)
#    1239 # A collection of keys
# -> 1240 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1241 return self.obj._reindex_with_indexers(
#    1242     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1243 )
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1433, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1430 ax = self.obj._get_axis(axis)
#    1431 axis_name = self.obj._get_axis_name(axis)
# -> 1433 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1435 return keyarr, indexer
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['chr20', 'chr21', 'chr22'] not in index"
