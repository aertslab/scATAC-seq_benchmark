# %%
id=_atac_v1_adult_brain_fresh_5k_S1
samplename=TXG_10xv1_adultmousebrainfresh
ls all/*$id*

cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &
# Out:
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L001_R1_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L001_R2_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L001_R3_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L002_R1_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L002_R2_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L002_R3_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L003_R1_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L003_R2_001.fastq.gz
# all/TXG_10xv1__atac_v1_adult_brain_fresh_5k_S1_L003_R3_001.fastq.gz
# [1] 1397326
# [2] 1397327
# [3] 1397328

# %%
jobs
# Out:
# [1]   Running                 cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
# [2]-  Running                 cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
# [3]+  Running                 cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &

# %%
id=_8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller
samplename=TXG_10xv2_adultmousecortexchromiumclassic
ls all/*$id*

cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &
# Out:
# [1]   Done                    cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz
# [2]-  Done                    cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz
# [3]+  Done                    cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller_S6_L003_R1_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller_S6_L003_R2_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller_S6_L003_R3_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller_S6_L004_R1_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller_S6_L004_R2_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_Controller_S6_L004_R3_001.fastq.gz
# [1] 1397687
# [2] 1397688
# [3] 1397689

# %%
8k_mouse_cortex_ATACv2_nextgem_Chromium_X
# Out:
# [1]   Running                 cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
# [2]-  Running                 cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
# [3]+  Running                 cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &

# %%
id=8k_mouse_cortex_ATACv2_nextgem_Chromium_X
samplename=TXG_10xv2_adultmousecortexchromiumx
ls all/*$id*

cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &
# Out:
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_X_S5_L003_R1_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_X_S5_L003_R2_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_X_S5_L003_R3_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_X_S5_L004_R1_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_X_S5_L004_R2_001.fastq.gz
# all/TXG_10xv2__8k_mouse_cortex_ATACv2_nextgem_Chromium_X_S5_L004_R3_001.fastq.gz
# [4] 1397706
# [5] 1397707
# [6] 1397708

# %%
id=8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X
samplename=TXG_10xv11_adultmousecortexchromiumx
ls all/*$id*

cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &
# Out:
# [2]   Done                    cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz
# [5]-  Done                    cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz
# all/TXG_10xv11__8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X_S4_L003_R1_001.fastq.gz
# all/TXG_10xv11__8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X_S4_L003_R2_001.fastq.gz
# all/TXG_10xv11__8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X_S4_L003_R3_001.fastq.gz
# all/TXG_10xv11__8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X_S4_L004_R1_001.fastq.gz
# all/TXG_10xv11__8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X_S4_L004_R2_001.fastq.gz
# all/TXG_10xv11__8k_mouse_cortex_ATACv1-1_nextgem_Chromium_X_S4_L004_R3_001.fastq.gz
# [7] 1397779
# [8] 1397780
# [9] 1397781

# %%
id=e18_mouse_brain_fresh_5k
samplename=TXG_10xmultiome_e18mousebrainfresh
ls all/*$id*

cat all/*$id*R1*.fastq.gz > all_merged/${samplename}__R1.FULL.fastq.gz &
cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz &
cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz &
# Out:
# [3]   Done                    cat all/*$id*R3*.fastq.gz > all_merged/${samplename}__R3.FULL.fastq.gz
# [8]-  Done                    cat all/*$id*R2*.fastq.gz > all_merged/${samplename}__R2.FULL.fastq.gz
# all/TXG_multiome__e18_mouse_brain_fresh_5k_S1_L001_R1_001.fastq.gz
# all/TXG_multiome__e18_mouse_brain_fresh_5k_S1_L001_R2_001.fastq.gz
# all/TXG_multiome__e18_mouse_brain_fresh_5k_S1_L001_R3_001.fastq.gz
# all/TXG_multiome__e18_mouse_brain_fresh_5k_S1_L002_R1_001.fastq.gz
# all/TXG_multiome__e18_mouse_brain_fresh_5k_S1_L002_R2_001.fastq.gz
# all/TXG_multiome__e18_mouse_brain_fresh_5k_S1_L002_R3_001.fastq.gz
# [10] 1397870
# [11] 1397871
# [12] 1397872

# %%
ls all_merged
# Out:
# BIO_ddseq_SRR8310661__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310661__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310662__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310662__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310663__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310663__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310664__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310664__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310665__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310665__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310666__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310666__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310667__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310667__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310668__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310668__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310669__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310669__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310670__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310670__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310671__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310671__R2.FULL.fastq.gz
# BIO_ddseq_SRR8310672__R1.FULL.fastq.gz
# BIO_ddseq_SRR8310672__R2.FULL.fastq.gz
# ...

# %%
for file in all_merged/*.fastq.gz
do
    echo $file
    filename=`basename $file`
    zcat $file | head -n 4000 | gzip > all_mini/${filename/FULL/MINI}
done
# Out:
# all_merged/BIO_ddseq_SRR8310661__R1.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310661__R2.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310662__R1.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310662__R2.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310663__R1.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310663__R2.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310664__R1.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310664__R2.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310665__R1.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310665__R2.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310666__R1.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# all_merged/BIO_ddseq_SRR8310666__R2.FULL.fastq.gz
#
# gzip: stdout: Broken pipe
# ...
