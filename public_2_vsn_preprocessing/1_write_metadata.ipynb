# %% [markdown]
# Writing a metadata file for the vsn preprocessing pipeline (https://vsn-pipelines.readthedocs.io/en/latest/scatac-seq.html)

# %%
import os
import glob
import pandas as pd

# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
filepaths = sorted(
    glob.glob(
        "/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/[!BIO]*.fastq.gz"
    )
)
filenames = [x.split("/")[-1] for x in filepaths]
filenames

df_raw_filenames = pd.DataFrame(filepaths, columns=["filename"])

df_raw_filenames["sample_name"] = [
    x.split("/")[-1].split(".")[0].split("__")[0] for x in df_raw_filenames["filename"]
]

df_raw_filenames["read"] = [x.split("_R")[1][0] for x in df_raw_filenames["filename"]]

df_raw_filenames

samples_df = pd.pivot(
    df_raw_filenames, values="filename", index="sample_name", columns="read"
)

samples_df["sample_name"] = samples_df.index + ".FULL"

samples_df.columns = [
    "fastq_PE1_path",
    "fastq_barcode_path",
    "fastq_PE2_path",
    "sample_name",
]

# %%
df_raw_filenames
# Out:
#                                              filename  \
# 0   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 1   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 2   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 3   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 4   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 5   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 6   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 7   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 8   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 9   /lustre1/project/stg_00090/scatac_benchmark/1_...
# 10  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 11  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 12  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 13  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 14  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 15  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 16  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 17  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 18  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 19  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 20  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 21  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 22  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 23  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 24  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 25  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 26  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 27  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 28  /lustre1/project/stg_00090/scatac_benchmark/1_...
# 29  /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                              sample_name read
# 0     TXG_10xmultiome_e18mousebrainfresh    1
# 1     TXG_10xmultiome_e18mousebrainfresh    2
# 2     TXG_10xmultiome_e18mousebrainfresh    3
# 3   TXG_10xv11_adultmousecortexchromiumx    1
# 4   TXG_10xv11_adultmousecortexchromiumx    2
# 5   TXG_10xv11_adultmousecortexchromiumx    3
# 6              TXG_10xv1_adultmousefresh    1
# 7              TXG_10xv1_adultmousefresh    2
# 8              TXG_10xv1_adultmousefresh    3
# 9             TXG_10xv2_adultmousecortex    1
# 10            TXG_10xv2_adultmousecortex    2
# 11            TXG_10xv2_adultmousecortex    3
# 12   TXG_10xv2_adultmousecortexchromiumx    1
# 13   TXG_10xv2_adultmousecortexchromiumx    2
# 14   TXG_10xv2_adultmousecortexchromiumx    3
# 15                          VIB_hydrop_1    1
# 16                          VIB_hydrop_1    2
# 17                          VIB_hydrop_1    3
# 18                          VIB_hydrop_2    1
# 19                          VIB_hydrop_2    2
# 20                          VIB_hydrop_2    3
# 21                          VIB_hydrop_3    1
# 22                          VIB_hydrop_3    2
# 23                          VIB_hydrop_3    3
# 24                          VIB_hydrop_4    1
# 25                          VIB_hydrop_4    2
# 26                          VIB_hydrop_4    3
# 27                          VIB_hydrop_5    1
# 28                          VIB_hydrop_5    2
# 29                          VIB_hydrop_5    3

# %%
tech_dict = {
    "TXG_10xmultiome_e18mousebrainfresh.FULL": "multiome",
    "TXG_10xv11_adultmousecortexchromiumx.FULL": "atac_revcomp",
    "TXG_10xv1_adultmousefresh.FULL": "revcomp",
    "TXG_10xv2_adultmousecortex.FULL": "atac_revcomp",
    "TXG_10xv2_adultmousecortexchromiumx.FULL": "atac_revcomp",
    "VIB_hydrop_1.FULL": "hydrop_3x96",
    "VIB_hydrop_2.FULL": "hydrop_3x96",
    "VIB_hydrop_3.FULL": "hydrop_3x96",
    "VIB_hydrop_4.FULL": "hydrop_3x96",
    "VIB_hydrop_5.FULL": "hydrop_3x96",
}

# %%
samples_df["technology"] = [tech_dict[x] for x in samples_df["sample_name"]]

# %%
samples_df
# Out:
#                                                                          fastq_PE1_path  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh    /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv11_adultmousecortexchromiumx  /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv1_adultmousefresh             /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortex            /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortexchromiumx   /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_1                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_2                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_3                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_4                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_5                          /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                                                                      fastq_barcode_path  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh    /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv11_adultmousecortexchromiumx  /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv1_adultmousefresh             /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortex            /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortexchromiumx   /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_1                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_2                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_3                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_4                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_5                          /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                                                                          fastq_PE2_path  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh    /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv11_adultmousecortexchromiumx  /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv1_adultmousefresh             /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortex            /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortexchromiumx   /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_1                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_2                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_3                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_4                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_5                          /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                                                                     sample_name  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh      TXG_10xmultiome_e18mousebrainfresh.FULL
# TXG_10xv11_adultmousecortexchromiumx  TXG_10xv11_adultmousecortexchromiumx.FULL
# TXG_10xv1_adultmousefresh                        TXG_10xv1_adultmousefresh.FULL
# TXG_10xv2_adultmousecortex                      TXG_10xv2_adultmousecortex.FULL
# TXG_10xv2_adultmousecortexchromiumx    TXG_10xv2_adultmousecortexchromiumx.FULL
# VIB_hydrop_1                                                  VIB_hydrop_1.FULL
# VIB_hydrop_2                                                  VIB_hydrop_2.FULL
# VIB_hydrop_3                                                  VIB_hydrop_3.FULL
# VIB_hydrop_4                                                  VIB_hydrop_4.FULL
# VIB_hydrop_5                                                  VIB_hydrop_5.FULL
#
#                                         technology
# sample_name
# TXG_10xmultiome_e18mousebrainfresh        multiome
# TXG_10xv11_adultmousecortexchromiumx  atac_revcomp
# TXG_10xv1_adultmousefresh                  revcomp
# TXG_10xv2_adultmousecortex            atac_revcomp
# TXG_10xv2_adultmousecortexchromiumx   atac_revcomp
# VIB_hydrop_1                           hydrop_3x96
# VIB_hydrop_2                           hydrop_3x96
# VIB_hydrop_3                           hydrop_3x96
# VIB_hydrop_4                           hydrop_3x96
# VIB_hydrop_5                           hydrop_3x96

# %%
filepaths = sorted(
    glob.glob(
        "/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO*.fastq.gz"
    )
)
filenames = [x.split("/")[-1] for x in filepaths]
filenames

df_raw_filenames = pd.DataFrame(filepaths, columns=["filename"])

df_raw_filenames["sample_name"] = [
    x.split("/")[-1].split(".")[0].split("__")[0] for x in df_raw_filenames["filename"]
]

df_raw_filenames["read"] = [x.split("_R")[1][0] for x in df_raw_filenames["filename"]]

df_raw_filenames

samples_df_biorad = pd.pivot(
    df_raw_filenames, values="filename", index="sample_name", columns="read"
)

samples_df_biorad["sample_name"] = samples_df_biorad.index + ".FULL"

samples_df_biorad.columns = [
    "fastq_PE1_path",
    "fastq_PE2_path",
    "sample_name",
]

# %%
samples_df_biorad["technology"] = "biorad"

# %%
filepaths = sorted(
    glob.glob(
        "/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/OHS*.fastq.gz"
    )
)
filenames = [x.split("/")[-1] for x in filepaths]
filenames

df_raw_filenames = pd.DataFrame(filepaths, columns=["filename"])

df_raw_filenames["sample_name"] = [
    x.split("/")[-1].split(".")[0].split("__")[0] for x in df_raw_filenames["filename"]
]

df_raw_filenames["read"] = [x.split("_R")[1][0] for x in df_raw_filenames["filename"]]

df_raw_filenames

samples_df_s3 = pd.pivot(
    df_raw_filenames, values="filename", index="sample_name", columns="read"
)

samples_df_s3["sample_name"] = samples_df_s3.index + ".FULL"

samples_df_s3.columns = [
    "fastq_PE1_path",
    "fastq_barcode_path",
    "fastq_PE2_path",
    "sample_name",
]
samples_df_s3["technology"] = "s3atac"

# %%
samples_df_merged = pd.concat([samples_df, samples_df_biorad, samples_df_s3])

# %%
samples_df_merged
# Out:
#                                                                          fastq_PE1_path  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh    /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv11_adultmousecortexchromiumx  /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv1_adultmousefresh             /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortex            /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortexchromiumx   /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_1                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_2                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_3                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_4                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_5                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c1                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c2                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c3                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c4                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c5                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c6                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c7                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c8                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c1                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c2                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c3                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c4                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# OHS_s3atac_s3ATAC_Mouse               /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                                                                      fastq_barcode_path  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh    /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv11_adultmousecortexchromiumx  /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv1_adultmousefresh             /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortex            /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortexchromiumx   /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_1                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_2                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_3                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_4                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_5                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c1                                                                      NaN
# BIO_ddseq_m1c2                                                                      NaN
# BIO_ddseq_m1c3                                                                      NaN
# BIO_ddseq_m1c4                                                                      NaN
# BIO_ddseq_m1c5                                                                      NaN
# BIO_ddseq_m1c6                                                                      NaN
# BIO_ddseq_m1c7                                                                      NaN
# BIO_ddseq_m1c8                                                                      NaN
# BIO_ddseq_m2c1                                                                      NaN
# BIO_ddseq_m2c2                                                                      NaN
# BIO_ddseq_m2c3                                                                      NaN
# BIO_ddseq_m2c4                                                                      NaN
# OHS_s3atac_s3ATAC_Mouse               /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                                                                          fastq_PE2_path  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh    /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv11_adultmousecortexchromiumx  /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv1_adultmousefresh             /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortex            /lustre1/project/stg_00090/scatac_benchmark/1_...
# TXG_10xv2_adultmousecortexchromiumx   /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_1                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_2                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_3                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_4                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# VIB_hydrop_5                          /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c1                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c2                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c3                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c4                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c5                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c6                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c7                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m1c8                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c1                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c2                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c3                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# BIO_ddseq_m2c4                        /lustre1/project/stg_00090/scatac_benchmark/1_...
# OHS_s3atac_s3ATAC_Mouse               /lustre1/project/stg_00090/scatac_benchmark/1_...
#
#                                                                     sample_name  \
# sample_name
# TXG_10xmultiome_e18mousebrainfresh      TXG_10xmultiome_e18mousebrainfresh.FULL
# TXG_10xv11_adultmousecortexchromiumx  TXG_10xv11_adultmousecortexchromiumx.FULL
# TXG_10xv1_adultmousefresh                        TXG_10xv1_adultmousefresh.FULL
# TXG_10xv2_adultmousecortex                      TXG_10xv2_adultmousecortex.FULL
# TXG_10xv2_adultmousecortexchromiumx    TXG_10xv2_adultmousecortexchromiumx.FULL
# VIB_hydrop_1                                                  VIB_hydrop_1.FULL
# VIB_hydrop_2                                                  VIB_hydrop_2.FULL
# VIB_hydrop_3                                                  VIB_hydrop_3.FULL
# VIB_hydrop_4                                                  VIB_hydrop_4.FULL
# VIB_hydrop_5                                                  VIB_hydrop_5.FULL
# BIO_ddseq_m1c1                                              BIO_ddseq_m1c1.FULL
# BIO_ddseq_m1c2                                              BIO_ddseq_m1c2.FULL
# BIO_ddseq_m1c3                                              BIO_ddseq_m1c3.FULL
# BIO_ddseq_m1c4                                              BIO_ddseq_m1c4.FULL
# BIO_ddseq_m1c5                                              BIO_ddseq_m1c5.FULL
# BIO_ddseq_m1c6                                              BIO_ddseq_m1c6.FULL
# BIO_ddseq_m1c7                                              BIO_ddseq_m1c7.FULL
# BIO_ddseq_m1c8                                              BIO_ddseq_m1c8.FULL
# BIO_ddseq_m2c1                                              BIO_ddseq_m2c1.FULL
# BIO_ddseq_m2c2                                              BIO_ddseq_m2c2.FULL
# BIO_ddseq_m2c3                                              BIO_ddseq_m2c3.FULL
# BIO_ddseq_m2c4                                              BIO_ddseq_m2c4.FULL
# OHS_s3atac_s3ATAC_Mouse                            OHS_s3atac_s3ATAC_Mouse.FULL
#
#                                         technology
# sample_name
# TXG_10xmultiome_e18mousebrainfresh        multiome
# TXG_10xv11_adultmousecortexchromiumx  atac_revcomp
# TXG_10xv1_adultmousefresh                  revcomp
# TXG_10xv2_adultmousecortex            atac_revcomp
# TXG_10xv2_adultmousecortexchromiumx   atac_revcomp
# VIB_hydrop_1                           hydrop_3x96
# VIB_hydrop_2                           hydrop_3x96
# VIB_hydrop_3                           hydrop_3x96
# VIB_hydrop_4                           hydrop_3x96
# VIB_hydrop_5                           hydrop_3x96
# BIO_ddseq_m1c1                              biorad
# BIO_ddseq_m1c2                              biorad
# BIO_ddseq_m1c3                              biorad
# BIO_ddseq_m1c4                              biorad
# BIO_ddseq_m1c5                              biorad
# BIO_ddseq_m1c6                              biorad
# BIO_ddseq_m1c7                              biorad
# BIO_ddseq_m1c8                              biorad
# BIO_ddseq_m2c1                              biorad
# BIO_ddseq_m2c2                              biorad
# BIO_ddseq_m2c3                              biorad
# BIO_ddseq_m2c4                              biorad
# OHS_s3atac_s3ATAC_Mouse                     s3atac

# %%
samples_df_merged = samples_df_merged[
    [
        "sample_name",
        "technology",
        "fastq_PE1_path",
        "fastq_barcode_path",
        "fastq_PE2_path",
    ]
]

# %%
samples_df_merged.to_csv("metadata.tsv", sep="\t", index=False)

# %%
# !cat metadata.tsv
# Out:
# sample_name	technology	fastq_PE1_path	fastq_barcode_path	fastq_PE2_path
# TXG_10xmultiome_e18mousebrainfresh.FULL	multiome	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xmultiome_e18mousebrainfresh__R1.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xmultiome_e18mousebrainfresh__R2.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xmultiome_e18mousebrainfresh__R3.FULL.fastq.gz
# TXG_10xv11_adultmousecortexchromiumx.FULL	atac_revcomp	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv11_adultmousecortexchromiumx__R1.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv11_adultmousecortexchromiumx__R2.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv11_adultmousecortexchromiumx__R3.FULL.fastq.gz
# TXG_10xv1_adultmousefresh.FULL	revcomp	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv1_adultmousefresh__R1.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv1_adultmousefresh__R2.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv1_adultmousefresh__R3.FULL.fastq.gz
# TXG_10xv2_adultmousecortex.FULL	atac_revcomp	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv2_adultmousecortex__R1.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv2_adultmousecortex__R2.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv2_adultmousecortex__R3.FULL.fastq.gz
# TXG_10xv2_adultmousecortexchromiumx.FULL	atac_revcomp	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv2_adultmousecortexchromiumx__R1.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv2_adultmousecortexchromiumx__R2.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/TXG_10xv2_adultmousecortexchromiumx__R3.FULL.fastq.gz
# VIB_hydrop_1.FULL	hydrop_3x96	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_1__R1.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_1__R2.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_1__R3.fastq.gz
# VIB_hydrop_2.FULL	hydrop_3x96	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_2__R1.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_2__R2.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_2__R3.fastq.gz
# VIB_hydrop_3.FULL	hydrop_3x96	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_3__R1.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_3__R2.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_3__R3.fastq.gz
# VIB_hydrop_4.FULL	hydrop_3x96	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_4__R1.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_4__R2.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_4__R3.fastq.gz
# VIB_hydrop_5.FULL	hydrop_3x96	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_5__R1.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_5__R2.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/VIB_hydrop_5__R3.fastq.gz
# BIO_ddseq_m1c1.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c1__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c1__R2.FULL.fastq.gz
# BIO_ddseq_m1c2.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c2__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c2__R2.FULL.fastq.gz
# BIO_ddseq_m1c3.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c3__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c3__R2.FULL.fastq.gz
# BIO_ddseq_m1c4.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c4__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c4__R2.FULL.fastq.gz
# BIO_ddseq_m1c5.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c5__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c5__R2.FULL.fastq.gz
# BIO_ddseq_m1c6.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c6__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c6__R2.FULL.fastq.gz
# BIO_ddseq_m1c7.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c7__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c7__R2.FULL.fastq.gz
# BIO_ddseq_m1c8.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c8__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m1c8__R2.FULL.fastq.gz
# BIO_ddseq_m2c1.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c1__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c1__R2.FULL.fastq.gz
# BIO_ddseq_m2c2.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c2__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c2__R2.FULL.fastq.gz
# BIO_ddseq_m2c3.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c3__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c3__R2.FULL.fastq.gz
# BIO_ddseq_m2c4.FULL	biorad	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c4__R1.FULL.fastq.gz		/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/BIO_ddseq_m2c4__R2.FULL.fastq.gz
# OHS_s3atac_s3ATAC_Mouse.FULL	s3atac	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/OHS_s3atac_s3ATAC_Mouse__R1.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/OHS_s3atac_s3ATAC_Mouse__R2.FULL.fastq.gz	/lustre1/project/stg_00090/scatac_benchmark/1_data_repository/publicdata_full_fastq/all_merged/OHS_s3atac_s3ATAC_Mouse__R3.FULL.fastq.gz
