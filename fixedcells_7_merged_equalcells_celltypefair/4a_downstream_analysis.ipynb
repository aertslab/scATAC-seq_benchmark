# %% [markdown]
# # pycisTopic analysis
#
# Full dataset, using consensus peak regions.

# %%
import pycisTopic

# %load_ext nb_black
import warnings

warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import pickle
import pandas as pd
import os

# %%
# !pwd
# Out:
# /lustre1/project/stg_00090/scatac_benchmark/fixedcells_7_merged_equalcells_celltypefair

# %%
wdir = "/lustre1/project/stg_00090/scatac_benchmark/fixedcells_7_merged_equalcells_celltypefair"
os.chdir(wdir)

# %%
# create output directory:
f_final_dir = os.path.join(wdir, "downstream_analysis")
if not os.path.exists(f_final_dir):
    os.makedirs(f_final_dir)

# %%
import glob

# %% [markdown]
# ## Save/load cisTopic objects

# %%
cto_consensus_paths = sorted(glob.glob(f"cistopic_objects/*topics.pkl"))
cistopic_obj_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x for x in cto_consensus_paths
}
cistopic_obj_path_dict
# Out:
# {'master_celltypefair_1.FIXEDCELLS': 'cistopic_objects/master_celltypefair_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_28topics.pkl'}

# %% [markdown]
# ## Topic binarization & QC

# %%
from pycisTopic.topic_binarization import binarize_topics
from pycisTopic.topic_qc import compute_topic_metrics, plot_topic_qc
from pycisTopic.utils import fig2img
import matplotlib.pyplot as plt
from pycisTopic.topic_qc import topic_annotation
from pycisTopic.diff_features import (
    impute_accessibility,
    normalize_scores,
    find_highly_variable_features,
    find_diff_features,
)
from pycisTopic.clust_vis import plot_imputed_features
import numpy as np
import copy

# %% [markdown]
# ### Binarize the topic-region distributions

# %%
for sample in cistopic_obj_path_dict.keys():
    # for sample  in ['SAN_10xmultiome_1.FIXEDCELLS']:
    path = cistopic_obj_path_dict[sample]
    if not os.path.exists(f"downstream_analysis/DARs/{sample}"):
        if os.path.isfile(path):
            print(f"Loading {path}")
            with open(path, "rb") as f:
                cto = pickle.load(f)

            cto.cell_names = cto.cell_data.index
            if [x.split("-")[0] for x in cto.selected_model.cell_topic.columns] == [
                x.split("___")[0] for x in list(cto.cell_names)
            ]:
                cto.selected_model.cell_topic.columns = list(cto.cell_names)

            region_bin_topics = binarize_topics(
                cto,
                method="otsu",
                ntop=3000,
                plot=True,
                num_columns=6,
                save=f"plots_qc/{sample}__topic_region_binarized.png",
            )

            with open(
                f"downstream_analysis/binarized_topics/{sample}__topic_region_binarized.pkl",
                "wb",
            ) as f:
                pickle.dump(region_bin_topics, f, protocol=4)

            binarized_cell_topics = binarize_topics(
                cto,
                target="cell",
                method="li",
                plot=True,
                num_columns=5,
                nbins=100,
                save=f"plots_qc/{sample}__cells_topic_binarized.png",
            )

            with open(
                f"downstream_analysis/binarized_topics/{sample}__cells_topic_binarized.pkl",
                "wb",
            ) as f:
                pickle.dump(region_bin_topics, f, protocol=4)

            topic_qc_metrics = compute_topic_metrics(cto)

            with open(
                f"downstream_analysis/binarized_topics/{sample}__topic_qc.pkl", "wb"
            ) as f:
                pickle.dump(topic_qc_metrics, f, protocol=4)

            fig_dict = {
                "CoherenceVSAssignments": plot_topic_qc(
                    topic_qc_metrics,
                    var_x="Coherence",
                    var_y="Log10_Assignments",
                    var_color="Gini_index",
                    plot=False,
                    return_fig=True,
                ),
                "AssignmentsVSCells_in_bin": plot_topic_qc(
                    topic_qc_metrics,
                    var_x="Log10_Assignments",
                    var_y="Cells_in_binarized_topic",
                    var_color="Gini_index",
                    plot=False,
                    return_fig=True,
                ),
                "CoherenceVSCells_in_bin": plot_topic_qc(
                    topic_qc_metrics,
                    var_x="Coherence",
                    var_y="Cells_in_binarized_topic",
                    var_color="Gini_index",
                    plot=False,
                    return_fig=True,
                ),
                "CoherenceVSRegions_in_bin": plot_topic_qc(
                    topic_qc_metrics,
                    var_x="Coherence",
                    var_y="Regions_in_binarized_topic",
                    var_color="Gini_index",
                    plot=False,
                    return_fig=True,
                ),
                "CoherenceVSMarginal_dist": plot_topic_qc(
                    topic_qc_metrics,
                    var_x="Coherence",
                    var_y="Marginal_topic_dist",
                    var_color="Gini_index",
                    plot=False,
                    return_fig=True,
                ),
                "CoherenceVSGini_index": plot_topic_qc(
                    topic_qc_metrics,
                    var_x="Coherence",
                    var_y="Gini_index",
                    var_color="Gini_index",
                    plot=False,
                    return_fig=True,
                ),
            }

            fig = plt.figure(figsize=(40, 43))
            i = 1
            for fig_ in fig_dict.keys():
                plt.subplot(2, 3, i)
                img = fig2img(
                    fig_dict[fig_]
                )  # To convert figures to png to plot together, see .utils.py. This converts the figure to png.
                plt.imshow(img)
                plt.axis("off")
                i += 1
            plt.subplots_adjust(wspace=0, hspace=-0.70)
            # plt.tight_layout()
            plt.show()
            plt.savefig(
                f"plots_qc/{sample}__topic_qc_metrics.png", facecolor="white", dpi=150
            )

            topic_annot = topic_annotation(
                cto,
                annot_var="harmony_consensus_cell_type__mega",
                binarized_cell_topic=binarized_cell_topics,
                general_topic_thr=0.2,
            )
            topic_qc_metrics = pd.concat(
                [
                    topic_annot[
                        [
                            "harmony_consensus_cell_type__mega",
                            "Ratio_cells_in_topic",
                            "Ratio_group_in_population",
                        ]
                    ],
                    topic_qc_metrics,
                ],
                axis=1,
            )

            imputed_acc_obj = impute_accessibility(
                cto, selected_cells=None, selected_regions=None, scale_factor=10**6
            )

            normalized_imputed_acc_obj = normalize_scores(
                imputed_acc_obj, scale_factor=10**4
            )

            with open(
                f"downstream_analysis/imputed_acc_objs/{sample}__imputed_acc_obs.pkl",
                "wb",
            ) as f:
                pickle.dump(normalized_imputed_acc_obj, f, protocol=4)

            variable_regions = find_highly_variable_features(
                normalized_imputed_acc_obj,
                min_disp=0.05,
                min_mean=0.0125,
                max_mean=3,
                max_disp=np.inf,
                n_bins=20,
                n_top_features=None,
                plot=True,
                save=f"plots_qc/{sample}__HVR.png",
            )

            print(f"Found {len(variable_regions)} variable regions")
            with open(f"downstream_analysis/HVRs/{sample}__HVRs.bed", "w") as f:
                for line in [
                    x.replace(":", "\t").replace("-", "\t") for x in variable_regions
                ]:
                    f.write(f"{line}\n")

            with open(f"downstream_analysis/HVRs/{sample}__HVRs.pkl", "wb") as f:
                pickle.dump(variable_regions, f, protocol=4)

            if not os.path.exists(f"downstream_analysis/DARs/{sample}"):
                os.mkdir(f"downstream_analysis/DARs/{sample}")

            markers_dict = find_diff_features(
                cto,
                normalized_imputed_acc_obj,
                variable="harmony_consensus_cell_type__mega",
                var_features=variable_regions,
                contrasts=None,
                adjpval_thr=0.05,
                log2fc_thr=np.log2(1.5),
                n_cpu=16,
            )
            with open(
                f"downstream_analysis/DARs/{sample}/{sample}__DARs_dict.pkl", "wb"
            ) as f:
                pickle.dump(markers_dict, f, protocol=4)

            for cell_type in markers_dict.keys():
                markers = markers_dict[cell_type].index.tolist()
                df = pd.DataFrame(markers)
                if len(df) == 0:
                    print(f"no DARs found for {cell_type} in {sample}")
                else:
                    df[[0, 1]] = df[0].str.split(":", expand=True)
                    df[[1, 2]] = df[1].str.split("-", expand=True)
                    df[3] = markers_dict[cell_type].index.tolist()
                    df[3] = cell_type.replace(" ", "_")  # + '_' + df[3].astype(str)
                    score = markers_dict[cell_type]["Log2FC"]
                    score = score.reset_index(drop=True)
                    df[4] = score
                    df[5] = "."
                    pval = markers_dict[cell_type]["Adjusted_pval"]
                    pval = pval.reset_index(drop=True)
                    df[6] = pval
                    name = cell_type.replace(" ", "_")
                    # name = name.replace('/', '-')
                    if not os.path.exists(f"downstream_analysis/DARs/{sample}"):
                        os.mkdir(f"downstream_analysis/DARs/{sample}")

                    df.to_csv(
                        f'downstream_analysis/DARs/{sample}/{sample}__{cell_type.replace(" ", "_")}__DARs.bed',
                        sep="\t",
                        header=False,
                        index=False,
                    )
                    df[0:2000].to_csv(
                        f'downstream_analysis/DARs/{sample}/{sample}__{cell_type.replace(" ", "_")}__DARs.TOP2k.bed',
                        sep="\t",
                        header=False,
                        index=False,
                    )

        else:
            print(f"{path} does not exist!")
    else:
        print(f"downstream_analysis/DARs/{sample} already exists!")
# Out:
# downstream_analysis/DARs/master_celltypefair_1.FIXEDCELLS already exists!

# %% [markdown]
# # Calculate DARs between male and female

# %%
normalized_imputed_acc_obj_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(
        glob.glob(f"downstream_analysis/imputed_acc_objs/*imputed_acc_obs.pkl")
    )
}
normalized_imputed_acc_obj_path_dict
# Out:
# {'master_celltypefair_1.FIXEDCELLS': 'downstream_analysis/imputed_acc_objs/master_celltypefair_1.FIXEDCELLS__imputed_acc_obs.pkl'}

# %%
hvr_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x
    for x in sorted(glob.glob(f"downstream_analysis/HVRs/*bed"))
}
hvr_path_dict
# Out:
# {'master_celltypefair_1.FIXEDCELLS': 'downstream_analysis/HVRs/master_celltypefair_1.FIXEDCELLS__HVRs.bed'}

# %%
cto_consensus_paths = sorted(glob.glob(f"cistopic_objects/*topics.pkl"))
cistopic_obj_path_dict = {
    x.split("/")[-1].split(f"__")[0]: x for x in cto_consensus_paths
}
cistopic_obj_path_dict
# Out:
# {'master_celltypefair_1.FIXEDCELLS': 'cistopic_objects/master_celltypefair_1.FIXEDCELLS__cto.scrublet0-4.fmx.singlets.model_28topics.pkl'}

# %%
sample = "master_celltypefair_1.FIXEDCELLS"
with open(
    cistopic_obj_path_dict[sample],
    "rb",
) as f:
    cto = pickle.load(f)

# %%
acc_path = normalized_imputed_acc_obj_path_dict[sample]

if os.path.isfile(acc_path):
    print(f"Loading {acc_path}")
    with open(acc_path, "rb") as f:
        normalized_imputed_acc_obj = pickle.load(f)

hvr_pkl_path = f"downstream_analysis/HVRs/{sample}__HVRs.pkl"

if os.path.exists(hvr_pkl_path):
    print(f"Loading {hvr_pkl_path}")
    with open(hvr_pkl_path, "rb") as f:
        variable_regions = pickle.load(f)
else:
    print("HVRs do not exist!")

cto.cell_data["fmx_sample_harmony_consensus_cell_type__mega"] = (
    cto.cell_data["fmx_sample"] + "_" + cto.cell_data["harmony_consensus_cell_type__mega"]
)

contrasts = []
for cell_type in cto.cell_data["harmony_consensus_cell_type__mega"].unique():
    print(cell_type)
    ct_a = "sampleA_" + cell_type
    ct_b = "sampleB_" + cell_type
    contrast = [[[ct_a], [ct_b]], [[ct_b], [ct_a]]]
    contrasts = contrasts + contrast

markers_dict = find_diff_features(
    cto,
    normalized_imputed_acc_obj,
    variable="fmx_sample_harmony_consensus_cell_type__mega",
    var_features=variable_regions,
    contrasts=contrasts,
    adjpval_thr=0.05,
    log2fc_thr=np.log2(1.2),
    n_cpu=10,
)

if not os.path.exists(f"harmony_consensus_cell_type__mega_male_female_DARs/{sample}"):
    os.mkdir(f"harmony_consensus_cell_type__mega_male_female_DARs/{sample}")

with open(
    f"harmony_consensus_cell_type__mega_male_female_DARs/{sample}/{sample}__DARs_dict_1-2xfoldchange.pkl",
    "wb",
) as f:
    pickle.dump(markers_dict, f, protocol=4)

for contrast in markers_dict.keys():
    markers = markers_dict[contrast].index.tolist()
    df = pd.DataFrame(markers)
    if len(df) == 0:
        print(f"no DARs found for {contrast} in {sample}")
    else:
        df[[0, 1]] = df[0].str.split(":", expand=True)
        df[[1, 2]] = df[1].str.split("-", expand=True)
        df[3] = markers_dict[contrast].index.tolist()
        df[3] = contrast.replace(" ", "_")  # + '_' + df[3].astype(str)
        score = markers_dict[contrast]["Log2FC"]
        score = score.reset_index(drop=True)
        df[4] = score
        df[5] = "."
        pval = markers_dict[contrast]["Adjusted_pval"]
        pval = pval.reset_index(drop=True)
        df[6] = pval
        name = contrast.replace(" ", "_")

        df.to_csv(
            f'harmony_consensus_cell_type__mega_male_female_DARs/{sample}/{sample}__{contrast.replace(" ", "_")}__1-2xfoldchange_DARs.bed',
            sep="\t",
            header=False,
            index=False,
        )

# %%
if not os.path.exists(f"harmony_consensus_cell_type__mega_male_female_DARs/{sample}"):
    os.mkdir(f"harmony_consensus_cell_type__mega_male_female_DARs/{sample}")

with open(
    f"harmony_consensus_cell_type__mega_male_female_DARs/{sample}/{sample}__DARs_dict_1-2xfoldchange.pkl",
    "wb",
) as f:
    pickle.dump(markers_dict, f, protocol=4)

for contrast in markers_dict.keys():
    markers = markers_dict[contrast].index.tolist()
    df = pd.DataFrame(markers)
    if len(df) == 0:
        print(f"no DARs found for {contrast} in {sample}")
    else:
        df[[0, 1]] = df[0].str.split(":", expand=True)
        df[[1, 2]] = df[1].str.split("-", expand=True)
        df[3] = markers_dict[contrast].index.tolist()
        df[3] = contrast.replace(" ", "_")  # + '_' + df[3].astype(str)
        score = markers_dict[contrast]["Log2FC"]
        score = score.reset_index(drop=True)
        df[4] = score
        df[5] = "."
        pval = markers_dict[contrast]["Adjusted_pval"]
        pval = pval.reset_index(drop=True)
        df[6] = pval
        name = contrast.replace(" ", "_")

        df.to_csv(
            f'harmony_consensus_cell_type__mega_male_female_DARs/{sample}/{sample}__{contrast.replace(" ", "_")}__1-2xfoldchange_DARs.bed',
            sep="\t",
            header=False,
            index=False,
        )
# Out:
# no DARs found for sampleA_Natural killer cell_VS_sampleB_Natural killer cell in master_celltypefair_1.FIXEDCELLS
# no DARs found for sampleB_Natural killer cell_VS_sampleA_Natural killer cell in master_celltypefair_1.FIXEDCELLS
# no DARs found for sampleA_CD16+ monocyte_VS_sampleB_CD16+ monocyte in master_celltypefair_1.FIXEDCELLS
# no DARs found for sampleA_Dendritic cell_VS_sampleB_Dendritic cell in master_celltypefair_1.FIXEDCELLS
# no DARs found for sampleB_Dendritic cell_VS_sampleA_Dendritic cell in master_celltypefair_1.FIXEDCELLS

# %% [markdown]
# ## Calculate DARs for each technology here

# %%
acc_path = normalized_imputed_acc_obj_path_dict[sample]

if os.path.isfile(acc_path):
    print(f"Loading {acc_path}")
    with open(acc_path, "rb") as f:
        normalized_imputed_acc_obj = pickle.load(f)

hvr_pkl_path = f"downstream_analysis/HVRs/{sample}__HVRs.pkl"

if os.path.exists(hvr_pkl_path):
    print(f"Loading {hvr_pkl_path}")
    with open(hvr_pkl_path, "rb") as f:
        variable_regions = pickle.load(f)
else:
    print("HVRs do not exist!")
# Out:
# Loading downstream_analysis/imputed_acc_objs/master_celltypefair_1.FIXEDCELLS__imputed_acc_obs.pkl
# Loading downstream_analysis/HVRs/master_celltypefair_1.FIXEDCELLS__HVRs.pkl

# %%
cto.cell_data["harmony_consensus_cell_type__mega_bytech"] = cto.cell_data["harmony_consensus_cell_type__mega"]  + '__' +  cto.cell_data["tech"]

# %%
cto.cell_data["harmony_consensus_cell_type__mega_bytech"]
# Out:
# GAAGCAGCGGAATGATGCTCGTTCCAAT___OHS_s3atac_1.FIXEDCELLS    Cytotoxic T cell__s3atac
# AGGCAGAATGGTATTATTGGTCACGA___OHS_s3atac_2.FIXEDCELLS      Cytotoxic T cell__s3atac
# ATTGAGGAGCCAAGGCAAAGTACTCC___OHS_s3atac_2.FIXEDCELLS      Cytotoxic T cell__s3atac
# CTCTCTACTGAACGGCGTATCTGCCA___OHS_s3atac_2.FIXEDCELLS      Cytotoxic T cell__s3atac
# GAAGAGTATTGGCATAACCGCGCCGATC___OHS_s3atac_1.FIXEDCELLS    Cytotoxic T cell__s3atac
#                                                                     ...
# TGATGCACAAGATTAG___VIB_10xv1_2.FIXEDCELLS                    Dendritic cell__10xv1
# AAAGGATTCCACACCT___VIB_10xv1_2.FIXEDCELLS                    Dendritic cell__10xv1
# TGAGCCGGTTTGACCA___VIB_10xv1_2.FIXEDCELLS                    Dendritic cell__10xv1
# AGACAAAGTCACAGGA___VIB_10xv1_2.FIXEDCELLS                    Dendritic cell__10xv1
# CACCTGTTCTCTATTG___VIB_10xv1_2.FIXEDCELLS                    Dendritic cell__10xv1
# Name: harmony_consensus_cell_type__mega_bytech, Length: 35456, dtype: object

# %%
list(set(cto.cell_data[cto.cell_data["tech"] == tech]["harmony_consensus_cell_type__mega_bytech"].unique()) - set([cell_type]))
# Out:
# ['B cell__10xv1',
#  'CD16+ monocyte__10xv1',
#  'Cytotoxic T cell__10xv1',
#  'Natural killer cell__10xv1',
#  'CD14+ monocyte__10xv1',
#  'CD4+ T cell__10xv1']

# %%
contrasts = []
for tech in cto.cell_data["tech"].unique():
    print(tech)
    for cell_type in cto.cell_data[cto.cell_data["tech"] == tech]["harmony_consensus_cell_type__mega_bytech"].unique():
        print("\t" + cell_type)
        contrast_fg = cell_type
        contrast_bg = list(set(cto.cell_data[cto.cell_data["tech"] == tech]["harmony_consensus_cell_type__mega_bytech"].unique()) - set([cell_type]))
        contrast = [[[contrast_fg], contrast_bg]]
        contrasts = contrasts + contrast
# Out:
# s3atac
# 	Cytotoxic T cell__s3atac
# 	CD4+ T cell__s3atac
# 	Natural killer cell__s3atac
# 	CD14+ monocyte__s3atac
# 	B cell__s3atac
# 	CD16+ monocyte__s3atac
# 	Dendritic cell__s3atac
# 10xmultiome
# 	Cytotoxic T cell__10xmultiome
# 	CD4+ T cell__10xmultiome
# 	Natural killer cell__10xmultiome
# 	CD14+ monocyte__10xmultiome
# 	B cell__10xmultiome
# 	CD16+ monocyte__10xmultiome
# 	Dendritic cell__10xmultiome
# 10xv11
# 	Cytotoxic T cell__10xv11
# 	CD4+ T cell__10xv11
# 	Natural killer cell__10xv11
# 	CD14+ monocyte__10xv11
# 	B cell__10xv11
# 	CD16+ monocyte__10xv11
# 	Dendritic cell__10xv11
# hydrop
# 	Cytotoxic T cell__hydrop
# 	CD4+ T cell__hydrop
# 	Natural killer cell__hydrop
# 	CD14+ monocyte__hydrop
# 	B cell__hydrop
# 	CD16+ monocyte__hydrop
# 	Dendritic cell__hydrop
# 10xv2
# 	Cytotoxic T cell__10xv2
# 	CD4+ T cell__10xv2
# 	Natural killer cell__10xv2
# 	CD14+ monocyte__10xv2
# 	B cell__10xv2
# 	CD16+ monocyte__10xv2
# 	Dendritic cell__10xv2
# ddseq
# 	Cytotoxic T cell__ddseq
# 	CD4+ T cell__ddseq
# 	Natural killer cell__ddseq
# 	CD14+ monocyte__ddseq
# 	B cell__ddseq
# 	CD16+ monocyte__ddseq
# 	Dendritic cell__ddseq
# mtscatac
# 	Cytotoxic T cell__mtscatac
# 	CD4+ T cell__mtscatac
# 	Natural killer cell__mtscatac
# 	CD14+ monocyte__mtscatac
# 	B cell__mtscatac
# 	CD16+ monocyte__mtscatac
# 	Dendritic cell__mtscatac
# 10xv1
# 	Cytotoxic T cell__10xv1
# 	CD4+ T cell__10xv1
# 	Natural killer cell__10xv1
# 	CD14+ monocyte__10xv1
# 	B cell__10xv1
# 	CD16+ monocyte__10xv1
# 	Dendritic cell__10xv1

# %%
markers_dict = find_diff_features(
    cto,
    normalized_imputed_acc_obj,
    variable="harmony_consensus_cell_type__mega_bytech",
    var_features=variable_regions,
    contrasts=contrasts,
    adjpval_thr=0.05,
    log2fc_thr=np.log2(1.2),
    n_cpu=10,
)
# Out:
# 2023-01-30 14:11:30,563	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# (markers_ray pid=1306574) 2023-01-30 14:11:36,846 cisTopic     INFO     Formatting data for Cytotoxic T cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306578) 2023-01-30 14:11:39,164 cisTopic     INFO     Formatting data for CD4+ T cell__s3atac_VS_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306570) 2023-01-30 14:11:41,544 cisTopic     INFO     Formatting data for Natural killer cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306574) 2023-01-30 14:11:42,739 cisTopic     INFO     Computing p-value for Cytotoxic T cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306576) 2023-01-30 14:11:43,976 cisTopic     INFO     Formatting data for CD14+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306578) 2023-01-30 14:11:45,252 cisTopic     INFO     Computing p-value for CD4+ T cell__s3atac_VS_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306569) 2023-01-30 14:11:46,273 cisTopic     INFO     Formatting data for B cell__s3atac_VS_CD4+ T cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306570) 2023-01-30 14:11:48,541 cisTopic     INFO     Computing p-value for Natural killer cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306573) 2023-01-30 14:11:48,685 cisTopic     INFO     Formatting data for CD16+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac
# (markers_ray pid=1306576) 2023-01-30 14:11:50,761 cisTopic     INFO     Computing p-value for CD14+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306571) 2023-01-30 14:11:51,011 cisTopic     INFO     Formatting data for Dendritic cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306569) 2023-01-30 14:11:52,881 cisTopic     INFO     Computing p-value for B cell__s3atac_VS_CD4+ T cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306575) 2023-01-30 14:11:53,471 cisTopic     INFO     Formatting data for Cytotoxic T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306572) 2023-01-30 14:11:55,806 cisTopic     INFO     Formatting data for CD4+ T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306573) 2023-01-30 14:11:55,929 cisTopic     INFO     Computing p-value for CD16+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac
# (markers_ray pid=1306571) 2023-01-30 14:11:58,802 cisTopic     INFO     Computing p-value for Dendritic cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306575) 2023-01-30 14:12:00,835 cisTopic     INFO     Computing p-value for Cytotoxic T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306572) 2023-01-30 14:12:03,563 cisTopic     INFO     Computing p-value for CD4+ T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (raylet) Spilled 14148 MiB, 2 objects, write throughput 824 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# (raylet) Spilled 28297 MiB, 3 objects, write throughput 1542 MiB/s.
# (raylet) Spilled 42445 MiB, 5 objects, write throughput 2024 MiB/s.
# (raylet) Spilled 56594 MiB, 7 objects, write throughput 2468 MiB/s.
# (markers_ray pid=1306574) 2023-01-30 14:12:21,699 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306574) 2023-01-30 14:12:23,327 cisTopic     INFO     Cytotoxic T cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac done!
# (markers_ray pid=1306574) 2023-01-30 14:12:23,423 cisTopic     INFO     Formatting data for Natural killer cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306578) 2023-01-30 14:12:24,681 cisTopic     INFO     Computing log2FC for CD4+ T cell__s3atac_VS_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306578) 2023-01-30 14:12:26,317 cisTopic     INFO     CD4+ T cell__s3atac_VS_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac done!
# (markers_ray pid=1306578) 2023-01-30 14:12:26,458 cisTopic     INFO     Formatting data for CD14+ monocyte__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306570) 2023-01-30 14:12:27,321 cisTopic     INFO     Computing log2FC for Natural killer cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306570) 2023-01-30 14:12:28,860 cisTopic     INFO     Natural killer cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac done!
# (markers_ray pid=1306570) 2023-01-30 14:12:28,967 cisTopic     INFO     Formatting data for B cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306576) 2023-01-30 14:12:29,724 cisTopic     INFO     Computing log2FC for CD14+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306574) 2023-01-30 14:12:30,508 cisTopic     INFO     Computing p-value for Natural killer cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306576) 2023-01-30 14:12:31,282 cisTopic     INFO     CD14+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD16+ monocyte__s3atac done!
# (markers_ray pid=1306576) 2023-01-30 14:12:31,471 cisTopic     INFO     Formatting data for CD16+ monocyte__10xmultiome_VS_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306569) 2023-01-30 14:12:32,024 cisTopic     INFO     Computing log2FC for B cell__s3atac_VS_CD4+ T cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306569) 2023-01-30 14:12:33,651 cisTopic     INFO     B cell__s3atac_VS_CD4+ T cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac done!
# (markers_ray pid=1306578) 2023-01-30 14:12:34,679 cisTopic     INFO     Computing p-value for CD14+ monocyte__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306573) 2023-01-30 14:12:34,928 cisTopic     INFO     Computing log2FC for CD16+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac
# (markers_ray pid=1306573) 2023-01-30 14:12:36,600 cisTopic     INFO     CD16+ monocyte__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac done!
# (markers_ray pid=1306575) 2023-01-30 14:12:36,605 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306570) 2023-01-30 14:12:37,291 cisTopic     INFO     Computing p-value for B cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306571) 2023-01-30 14:12:37,641 cisTopic     INFO     Computing log2FC for Dendritic cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac
# (markers_ray pid=1306575) 2023-01-30 14:12:38,223 cisTopic     INFO     Cytotoxic T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Dendritic cell__10xmultiome done!
# (markers_ray pid=1306571) 2023-01-30 14:12:39,284 cisTopic     INFO     Dendritic cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Cytotoxic T cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac done!
# (markers_ray pid=1306572) 2023-01-30 14:12:39,226 cisTopic     INFO     Computing log2FC for CD4+ T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306576) 2023-01-30 14:12:39,856 cisTopic     INFO     Computing p-value for CD16+ monocyte__10xmultiome_VS_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306572) 2023-01-30 14:12:40,810 cisTopic     INFO     CD4+ T cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome done!
# (raylet) Spilled 70744 MiB, 11 objects, write throughput 1832 MiB/s.
# (raylet) Spilled 84893 MiB, 14 objects, write throughput 2065 MiB/s.
# (raylet) Spilled 141492 MiB, 26 objects, write throughput 2498 MiB/s.
# (markers_ray pid=1306572) 2023-01-30 14:13:01,538 cisTopic     INFO     Formatting data for Dendritic cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome
# (markers_ray pid=1306571) 2023-01-30 14:13:01,866 cisTopic     INFO     Formatting data for Cytotoxic T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11
# (markers_ray pid=1306575) 2023-01-30 14:13:02,219 cisTopic     INFO     Formatting data for CD4+ T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306573) 2023-01-30 14:13:02,554 cisTopic     INFO     Formatting data for Natural killer cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306569) 2023-01-30 14:13:02,916 cisTopic     INFO     Formatting data for CD14+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306574) 2023-01-30 14:13:05,986 cisTopic     INFO     Computing log2FC for Natural killer cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306574) 2023-01-30 14:13:07,534 cisTopic     INFO     Natural killer cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome done!
# (markers_ray pid=1306574) 2023-01-30 14:13:07,666 cisTopic     INFO     Formatting data for B cell__10xv11_VS_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306578) 2023-01-30 14:13:10,057 cisTopic     INFO     Computing log2FC for CD14+ monocyte__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306571) 2023-01-30 14:13:10,532 cisTopic     INFO     Computing p-value for Cytotoxic T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11
# (markers_ray pid=1306575) 2023-01-30 14:13:11,548 cisTopic     INFO     Computing p-value for CD4+ T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306578) 2023-01-30 14:13:11,721 cisTopic     INFO     CD14+ monocyte__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome done!
# (markers_ray pid=1306569) 2023-01-30 14:13:12,111 cisTopic     INFO     Computing p-value for CD14+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306570) 2023-01-30 14:13:12,348 cisTopic     INFO     Computing log2FC for B cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306573) 2023-01-30 14:13:12,539 cisTopic     INFO     Computing p-value for Natural killer cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306572) 2023-01-30 14:13:13,697 cisTopic     INFO     Computing p-value for Dendritic cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome
# (markers_ray pid=1306570) 2023-01-30 14:13:14,020 cisTopic     INFO     B cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome done!
# (markers_ray pid=1306574) 2023-01-30 14:13:15,405 cisTopic     INFO     Computing p-value for B cell__10xv11_VS_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306576) 2023-01-30 14:13:15,843 cisTopic     INFO     Computing log2FC for CD16+ monocyte__10xmultiome_VS_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome
# (markers_ray pid=1306576) 2023-01-30 14:13:17,387 cisTopic     INFO     CD16+ monocyte__10xmultiome_VS_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome_Dendritic cell__10xmultiome done!
# (markers_ray pid=1306578) 2023-01-30 14:13:42,782 cisTopic     INFO     Formatting data for CD16+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306576) 2023-01-30 14:13:42,789 cisTopic     INFO     Formatting data for Cytotoxic T cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306570) 2023-01-30 14:13:42,804 cisTopic     INFO     Formatting data for Dendritic cell__10xv11_VS_B cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306571) 2023-01-30 14:13:46,756 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11
# (markers_ray pid=1306575) 2023-01-30 14:13:47,952 cisTopic     INFO     Computing log2FC for CD4+ T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306569) 2023-01-30 14:13:48,029 cisTopic     INFO     Computing log2FC for CD14+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306571) 2023-01-30 14:13:48,323 cisTopic     INFO     Cytotoxic T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11 done!
# (markers_ray pid=1306573) 2023-01-30 14:13:48,725 cisTopic     INFO     Computing log2FC for Natural killer cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306572) 2023-01-30 14:13:49,334 cisTopic     INFO     Computing log2FC for Dendritic cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome
# (markers_ray pid=1306575) 2023-01-30 14:13:49,642 cisTopic     INFO     CD4+ T cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11 done!
# (markers_ray pid=1306569) 2023-01-30 14:13:49,724 cisTopic     INFO     CD14+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11 done!
# (raylet) Spilled 297129 MiB, 45 objects, write throughput 2788 MiB/s.
# (markers_ray pid=1306576) 2023-01-30 14:13:50,257 cisTopic     INFO     Computing p-value for Cytotoxic T cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306573) 2023-01-30 14:13:50,399 cisTopic     INFO     Natural killer cell__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Cytotoxic T cell__10xv11 done!
# (markers_ray pid=1306572) 2023-01-30 14:13:51,053 cisTopic     INFO     Dendritic cell__10xmultiome_VS_CD16+ monocyte__10xmultiome_B cell__10xmultiome_CD4+ T cell__10xmultiome_CD14+ monocyte__10xmultiome_Natural killer cell__10xmultiome_Cytotoxic T cell__10xmultiome done!
# (markers_ray pid=1306574) 2023-01-30 14:13:51,513 cisTopic     INFO     Computing log2FC for B cell__10xv11_VS_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306578) 2023-01-30 14:13:51,730 cisTopic     INFO     Computing p-value for CD16+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306570) 2023-01-30 14:13:51,723 cisTopic     INFO     Computing p-value for Dendritic cell__10xv11_VS_B cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306574) 2023-01-30 14:13:53,136 cisTopic     INFO     B cell__10xv11_VS_Dendritic cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11 done!
# (markers_ray pid=1306573) 2023-01-30 14:14:15,575 cisTopic     INFO     Formatting data for Natural killer cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop
# (markers_ray pid=1306571) 2023-01-30 14:14:15,576 cisTopic     INFO     Formatting data for B cell__hydrop_VS_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306575) 2023-01-30 14:14:15,580 cisTopic     INFO     Formatting data for CD14+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306572) 2023-01-30 14:14:15,575 cisTopic     INFO     Formatting data for CD4+ T cell__hydrop_VS_B cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306569) 2023-01-30 14:14:15,859 cisTopic     INFO     Formatting data for Dendritic cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306574) 2023-01-30 14:14:16,198 cisTopic     INFO     Formatting data for Cytotoxic T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306574) 2023-01-30 14:14:24,264 cisTopic     INFO     Computing p-value for Cytotoxic T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306572) 2023-01-30 14:14:24,347 cisTopic     INFO     Computing p-value for CD4+ T cell__hydrop_VS_B cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306575) 2023-01-30 14:14:24,468 cisTopic     INFO     Computing p-value for CD14+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306571) 2023-01-30 14:14:24,671 cisTopic     INFO     Computing p-value for B cell__hydrop_VS_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306573) 2023-01-30 14:14:25,617 cisTopic     INFO     Computing p-value for Natural killer cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop
# (markers_ray pid=1306569) 2023-01-30 14:14:25,831 cisTopic     INFO     Computing p-value for Dendritic cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306576) 2023-01-30 14:14:27,279 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306570) 2023-01-30 14:14:27,800 cisTopic     INFO     Computing log2FC for Dendritic cell__10xv11_VS_B cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306578) 2023-01-30 14:14:28,696 cisTopic     INFO     Computing log2FC for CD16+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11
# (markers_ray pid=1306576) 2023-01-30 14:14:28,855 cisTopic     INFO     Cytotoxic T cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop done!
# (markers_ray pid=1306570) 2023-01-30 14:14:29,425 cisTopic     INFO     Dendritic cell__10xv11_VS_B cell__10xv11_CD16+ monocyte__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11 done!
# (markers_ray pid=1306578) 2023-01-30 14:14:30,417 cisTopic     INFO     CD16+ monocyte__10xv11_VS_B cell__10xv11_Dendritic cell__10xv11_CD4+ T cell__10xv11_CD14+ monocyte__10xv11_Natural killer cell__10xv11_Cytotoxic T cell__10xv11 done!
# (markers_ray pid=1306578) 2023-01-30 14:14:37,224 cisTopic     INFO     Formatting data for B cell__10xv2_VS_Natural killer cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306570) 2023-01-30 14:14:37,224 cisTopic     INFO     Formatting data for CD16+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306576) 2023-01-30 14:14:37,219 cisTopic     INFO     Formatting data for CD14+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306576) 2023-01-30 14:14:44,373 cisTopic     INFO     Computing p-value for CD14+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306578) 2023-01-30 14:14:45,469 cisTopic     INFO     Computing p-value for B cell__10xv2_VS_Natural killer cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306570) 2023-01-30 14:14:45,696 cisTopic     INFO     Computing p-value for CD16+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306574) 2023-01-30 14:15:00,116 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306575) 2023-01-30 14:15:00,456 cisTopic     INFO     Computing log2FC for CD14+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306571) 2023-01-30 14:15:01,128 cisTopic     INFO     Computing log2FC for B cell__hydrop_VS_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306572) 2023-01-30 14:15:01,491 cisTopic     INFO     Computing log2FC for CD4+ T cell__hydrop_VS_B cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306574) 2023-01-30 14:15:01,731 cisTopic     INFO     Cytotoxic T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2 done!
# (markers_ray pid=1306573) 2023-01-30 14:15:01,921 cisTopic     INFO     Computing log2FC for Natural killer cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop
# (markers_ray pid=1306575) 2023-01-30 14:15:02,114 cisTopic     INFO     CD14+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop done!
# (markers_ray pid=1306569) 2023-01-30 14:15:02,581 cisTopic     INFO     Computing log2FC for Dendritic cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306571) 2023-01-30 14:15:02,757 cisTopic     INFO     B cell__hydrop_VS_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop done!
# (markers_ray pid=1306572) 2023-01-30 14:15:03,114 cisTopic     INFO     CD4+ T cell__hydrop_VS_B cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop done!
# (markers_ray pid=1306573) 2023-01-30 14:15:03,549 cisTopic     INFO     Natural killer cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Dendritic cell__hydrop done!
# (markers_ray pid=1306574) 2023-01-30 14:15:03,901 cisTopic     INFO     Formatting data for CD4+ T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306573) 2023-01-30 14:15:03,903 cisTopic     INFO     Formatting data for CD16+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306571) 2023-01-30 14:15:03,903 cisTopic     INFO     Formatting data for CD4+ T cell__ddseq_VS_Cytotoxic T cell__ddseq_B cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306569) 2023-01-30 14:15:04,326 cisTopic     INFO     Dendritic cell__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_CD16+ monocyte__hydrop_Natural killer cell__hydrop done!
# (markers_ray pid=1306572) 2023-01-30 14:15:04,250 cisTopic     INFO     Formatting data for Natural killer cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306569) 2023-01-30 14:15:04,700 cisTopic     INFO     Formatting data for CD14+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306575) 2023-01-30 14:15:05,069 cisTopic     INFO     Formatting data for B cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306571) 2023-01-30 14:15:11,766 cisTopic     INFO     Computing p-value for CD4+ T cell__ddseq_VS_Cytotoxic T cell__ddseq_B cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306574) 2023-01-30 14:15:12,284 cisTopic     INFO     Computing p-value for CD4+ T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306569) 2023-01-30 14:15:13,393 cisTopic     INFO     Computing p-value for CD14+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306575) 2023-01-30 14:15:13,478 cisTopic     INFO     Computing p-value for B cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306573) 2023-01-30 14:15:13,625 cisTopic     INFO     Computing p-value for CD16+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306572) 2023-01-30 14:15:14,088 cisTopic     INFO     Computing p-value for Natural killer cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306576) 2023-01-30 14:15:19,860 cisTopic     INFO     Computing log2FC for CD14+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (raylet) Spilled 537676 MiB, 101 objects, write throughput 2738 MiB/s.
# (markers_ray pid=1306578) 2023-01-30 14:15:21,140 cisTopic     INFO     Computing log2FC for B cell__10xv2_VS_Natural killer cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306576) 2023-01-30 14:15:21,511 cisTopic     INFO     CD14+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2 done!
# (markers_ray pid=1306570) 2023-01-30 14:15:21,829 cisTopic     INFO     Computing log2FC for CD16+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306578) 2023-01-30 14:15:22,793 cisTopic     INFO     B cell__10xv2_VS_Natural killer cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2 done!
# (markers_ray pid=1306570) 2023-01-30 14:15:23,505 cisTopic     INFO     CD16+ monocyte__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_Dendritic cell__10xv2 done!
# (markers_ray pid=1306578) 2023-01-30 14:15:29,680 cisTopic     INFO     Formatting data for Dendritic cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2
# (markers_ray pid=1306570) 2023-01-30 14:15:29,681 cisTopic     INFO     Formatting data for Natural killer cell__10xv2_VS_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306576) 2023-01-30 14:15:29,700 cisTopic     INFO     Formatting data for Cytotoxic T cell__ddseq_VS_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306576) 2023-01-30 14:15:35,975 cisTopic     INFO     Computing p-value for Cytotoxic T cell__ddseq_VS_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306570) 2023-01-30 14:15:36,309 cisTopic     INFO     Computing p-value for Natural killer cell__10xv2_VS_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306578) 2023-01-30 14:15:36,925 cisTopic     INFO     Computing p-value for Dendritic cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2
# (markers_ray pid=1306571) 2023-01-30 14:15:46,291 cisTopic     INFO     Computing log2FC for CD4+ T cell__ddseq_VS_Cytotoxic T cell__ddseq_B cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306571) 2023-01-30 14:15:47,853 cisTopic     INFO     CD4+ T cell__ddseq_VS_Cytotoxic T cell__ddseq_B cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq done!
# (markers_ray pid=1306574) 2023-01-30 14:15:47,953 cisTopic     INFO     Computing log2FC for CD4+ T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306569) 2023-01-30 14:15:48,466 cisTopic     INFO     Computing log2FC for CD14+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306575) 2023-01-30 14:15:48,556 cisTopic     INFO     Computing log2FC for B cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306572) 2023-01-30 14:15:49,247 cisTopic     INFO     Computing log2FC for Natural killer cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306574) 2023-01-30 14:15:49,586 cisTopic     INFO     CD4+ T cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2 done!
# (markers_ray pid=1306573) 2023-01-30 14:15:49,782 cisTopic     INFO     Computing log2FC for CD16+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop
# (markers_ray pid=1306569) 2023-01-30 14:15:50,136 cisTopic     INFO     CD14+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq done!
# (markers_ray pid=1306575) 2023-01-30 14:15:50,232 cisTopic     INFO     B cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq done!
# (markers_ray pid=1306572) 2023-01-30 14:15:50,851 cisTopic     INFO     Natural killer cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq done!
# (markers_ray pid=1306573) 2023-01-30 14:15:51,418 cisTopic     INFO     CD16+ monocyte__hydrop_VS_B cell__hydrop_CD4+ T cell__hydrop_CD14+ monocyte__hydrop_Cytotoxic T cell__hydrop_Dendritic cell__hydrop_Natural killer cell__hydrop done!
# (markers_ray pid=1306576) 2023-01-30 14:16:10,674 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__ddseq_VS_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306570) 2023-01-30 14:16:11,611 cisTopic     INFO     Computing log2FC for Natural killer cell__10xv2_VS_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2
# (markers_ray pid=1306578) 2023-01-30 14:16:12,237 cisTopic     INFO     Computing log2FC for Dendritic cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2
# (markers_ray pid=1306576) 2023-01-30 14:16:12,250 cisTopic     INFO     Cytotoxic T cell__ddseq_VS_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq_CD16+ monocyte__ddseq done!
# (markers_ray pid=1306570) 2023-01-30 14:16:13,236 cisTopic     INFO     Natural killer cell__10xv2_VS_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2_Dendritic cell__10xv2 done!
# (markers_ray pid=1306578) 2023-01-30 14:16:13,913 cisTopic     INFO     Dendritic cell__10xv2_VS_Natural killer cell__10xv2_B cell__10xv2_CD4+ T cell__10xv2_Cytotoxic T cell__10xv2_CD14+ monocyte__10xv2_CD16+ monocyte__10xv2 done!
# (markers_ray pid=1306578) 2023-01-30 14:17:08,872 cisTopic     INFO     Formatting data for CD16+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq
# (markers_ray pid=1306570) 2023-01-30 14:17:09,162 cisTopic     INFO     Formatting data for Dendritic cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306576) 2023-01-30 14:17:09,516 cisTopic     INFO     Formatting data for Cytotoxic T cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306573) 2023-01-30 14:17:09,860 cisTopic     INFO     Formatting data for CD4+ T cell__mtscatac_VS_CD14+ monocyte__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306572) 2023-01-30 14:17:10,241 cisTopic     INFO     Formatting data for Natural killer cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306575) 2023-01-30 14:17:10,624 cisTopic     INFO     Formatting data for CD14+ monocyte__mtscatac_VS_Natural killer cell__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306569) 2023-01-30 14:17:10,992 cisTopic     INFO     Formatting data for B cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac
# (markers_ray pid=1306574) 2023-01-30 14:17:11,367 cisTopic     INFO     Formatting data for CD16+ monocyte__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_B cell__mtscatac
# (markers_ray pid=1306571) 2023-01-30 14:17:11,786 cisTopic     INFO     Formatting data for Dendritic cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306576) 2023-01-30 14:17:18,600 cisTopic     INFO     Computing p-value for Cytotoxic T cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306573) 2023-01-30 14:17:20,518 cisTopic     INFO     Computing p-value for CD4+ T cell__mtscatac_VS_CD14+ monocyte__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306570) 2023-01-30 14:17:20,628 cisTopic     INFO     Computing p-value for Dendritic cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306575) 2023-01-30 14:17:20,888 cisTopic     INFO     Computing p-value for CD14+ monocyte__mtscatac_VS_Natural killer cell__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306572) 2023-01-30 14:17:21,559 cisTopic     INFO     Computing p-value for Natural killer cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306569) 2023-01-30 14:17:21,740 cisTopic     INFO     Computing p-value for B cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac
# (markers_ray pid=1306574) 2023-01-30 14:17:22,733 cisTopic     INFO     Computing p-value for CD16+ monocyte__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_B cell__mtscatac
# (markers_ray pid=1306571) 2023-01-30 14:17:22,784 cisTopic     INFO     Computing p-value for Dendritic cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306578) 2023-01-30 14:17:23,568 cisTopic     INFO     Computing p-value for CD16+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq
# (markers_ray pid=1306570) 2023-01-30 14:17:55,377 cisTopic     INFO     Computing log2FC for Dendritic cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_CD16+ monocyte__ddseq
# (markers_ray pid=1306576) 2023-01-30 14:17:55,571 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306570) 2023-01-30 14:17:56,935 cisTopic     INFO     Dendritic cell__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_CD16+ monocyte__ddseq done!
# (markers_ray pid=1306573) 2023-01-30 14:17:56,965 cisTopic     INFO     Computing log2FC for CD4+ T cell__mtscatac_VS_CD14+ monocyte__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306576) 2023-01-30 14:17:57,116 cisTopic     INFO     Cytotoxic T cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac done!
# (markers_ray pid=1306575) 2023-01-30 14:17:57,468 cisTopic     INFO     Computing log2FC for CD14+ monocyte__mtscatac_VS_Natural killer cell__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306573) 2023-01-30 14:17:58,504 cisTopic     INFO     CD4+ T cell__mtscatac_VS_CD14+ monocyte__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac done!
# (markers_ray pid=1306578) 2023-01-30 14:17:58,621 cisTopic     INFO     Computing log2FC for CD16+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq
# (markers_ray pid=1306569) 2023-01-30 14:17:58,621 cisTopic     INFO     Computing log2FC for B cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac
# (markers_ray pid=1306572) 2023-01-30 14:17:58,789 cisTopic     INFO     Computing log2FC for Natural killer cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306575) 2023-01-30 14:17:59,129 cisTopic     INFO     CD14+ monocyte__mtscatac_VS_Natural killer cell__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac done!
# (markers_ray pid=1306571) 2023-01-30 14:17:59,207 cisTopic     INFO     Computing log2FC for Dendritic cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac
# (markers_ray pid=1306574) 2023-01-30 14:17:59,442 cisTopic     INFO     Computing log2FC for CD16+ monocyte__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_B cell__mtscatac
# (markers_ray pid=1306578) 2023-01-30 14:18:00,313 cisTopic     INFO     CD16+ monocyte__ddseq_VS_Cytotoxic T cell__ddseq_CD4+ T cell__ddseq_Natural killer cell__ddseq_B cell__ddseq_CD14+ monocyte__ddseq_Dendritic cell__ddseq done!
# (markers_ray pid=1306569) 2023-01-30 14:18:00,271 cisTopic     INFO     B cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac done!
# (markers_ray pid=1306572) 2023-01-30 14:18:00,505 cisTopic     INFO     Natural killer cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac done!
# (markers_ray pid=1306571) 2023-01-30 14:18:00,856 cisTopic     INFO     Dendritic cell__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_CD16+ monocyte__mtscatac_B cell__mtscatac done!
# (markers_ray pid=1306574) 2023-01-30 14:18:01,090 cisTopic     INFO     CD16+ monocyte__mtscatac_VS_CD14+ monocyte__mtscatac_CD4+ T cell__mtscatac_Natural killer cell__mtscatac_Cytotoxic T cell__mtscatac_Dendritic cell__mtscatac_B cell__mtscatac done!
# (markers_ray pid=1306578) 2023-01-30 14:18:10,677 cisTopic     INFO     Formatting data for CD4+ T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:18:10,691 cisTopic     INFO     Formatting data for CD14+ monocyte__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306569) 2023-01-30 14:18:10,681 cisTopic     INFO     Formatting data for Natural killer cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306572) 2023-01-30 14:18:10,690 cisTopic     INFO     Formatting data for Cytotoxic T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306572) 2023-01-30 14:18:16,320 cisTopic     INFO     Computing p-value for Cytotoxic T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306578) 2023-01-30 14:18:16,838 cisTopic     INFO     Computing p-value for CD4+ T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:18:16,882 cisTopic     INFO     Computing p-value for CD14+ monocyte__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306569) 2023-01-30 14:18:17,733 cisTopic     INFO     Computing p-value for Natural killer cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306572) 2023-01-30 14:18:51,305 cisTopic     INFO     Computing log2FC for Cytotoxic T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:18:51,935 cisTopic     INFO     Computing log2FC for CD14+ monocyte__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306578) 2023-01-30 14:18:52,761 cisTopic     INFO     Computing log2FC for CD4+ T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1
# (markers_ray pid=1306572) 2023-01-30 14:18:52,966 cisTopic     INFO     Cytotoxic T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1 done!
# (markers_ray pid=1306569) 2023-01-30 14:18:53,011 cisTopic     INFO     Computing log2FC for Natural killer cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:18:53,604 cisTopic     INFO     CD14+ monocyte__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD4+ T cell__10xv1 done!
# (markers_ray pid=1306578) 2023-01-30 14:18:54,434 cisTopic     INFO     CD4+ T cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1 done!
# (markers_ray pid=1306569) 2023-01-30 14:18:54,667 cisTopic     INFO     Natural killer cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1 done!
# (markers_ray pid=1306569) 2023-01-30 14:19:29,465 cisTopic     INFO     Formatting data for B cell__10xv1_VS_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306578) 2023-01-30 14:19:29,845 cisTopic     INFO     Formatting data for CD16+ monocyte__10xv1_VS_B cell__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:19:30,177 cisTopic     INFO     Formatting data for Dendritic cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:19:46,374 cisTopic     INFO     Computing p-value for Dendritic cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306578) 2023-01-30 14:19:46,537 cisTopic     INFO     Computing p-value for CD16+ monocyte__10xv1_VS_B cell__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306569) 2023-01-30 14:19:47,134 cisTopic     INFO     Computing p-value for B cell__10xv1_VS_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:20:23,082 cisTopic     INFO     Computing log2FC for Dendritic cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306578) 2023-01-30 14:20:23,187 cisTopic     INFO     Computing log2FC for CD16+ monocyte__10xv1_VS_B cell__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306569) 2023-01-30 14:20:24,010 cisTopic     INFO     Computing log2FC for B cell__10xv1_VS_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1
# (markers_ray pid=1306576) 2023-01-30 14:20:24,827 cisTopic     INFO     Dendritic cell__10xv1_VS_B cell__10xv1_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1 done!
# (markers_ray pid=1306578) 2023-01-30 14:20:24,957 cisTopic     INFO     CD16+ monocyte__10xv1_VS_B cell__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1 done!
# (markers_ray pid=1306569) 2023-01-30 14:20:25,749 cisTopic     INFO     B cell__10xv1_VS_CD16+ monocyte__10xv1_Cytotoxic T cell__10xv1_Dendritic cell__10xv1_Natural killer cell__10xv1_CD14+ monocyte__10xv1_CD4+ T cell__10xv1 done!

# %%
if not os.path.exists(f"harmony_consensus_cell_type__mega_dars_bytech/{sample}"):
    os.mkdir(f"harmony_consensus_cell_type__mega_dars_bytech/{sample}")

with open(
    f"harmony_consensus_cell_type__mega_dars_bytech/{sample}/{sample}__DARs_dict_1-2xfoldchange.pkl",
    "wb",
) as f:
    pickle.dump(markers_dict, f, protocol=4)

# %%
markers_dict["Cytotoxic T cell__s3atac_VS_CD4+ T cell__s3atac_B cell__s3atac_Natural killer cell__s3atac_Dendritic cell__s3atac_CD14+ monocyte__s3atac_CD16+ monocyte__s3atac"].index.tolist()
# Out:
# ['chr1:160738300-160738800',
#  'chrX:107480215-107480715',
#  'chr1:26384028-26384528',
#  'chr2:144328951-144329451',
#  'chr19:5086203-5086703',
#  'chr16:15389801-15390301',
#  'chr1:91753815-91754315',
#  'chr1:18828143-18828643',
#  'chr16:82452186-82452686',
#  'chr22:21780254-21780754',
#  'chr8:58961776-58962276',
#  'chr1:227816992-227817492',
#  'chr17:30655938-30656438',
#  'chr7:3119560-3120060',
#  'chr1:235885848-235886348',
#  'chr4:230967-231467',
#  'chr11:36408389-36408889',
#  'chr17:79556257-79556757',
#  'chr16:31414645-31415145',
#  'chr20:35080132-35080632',
#  'chr15:49036812-49037312',
#  'chr2:159145665-159146165',
#  'chr6:45895539-45896039',
#  'chr11:76495033-76495533',
#  'chr1:235697461-235697961',
#  'chr2:88269676-88270176',
#  'chr12:10307574-10308074',
#  'chr2:113679433-113679933',
#  'chr16:89020264-89020764',
#  'chr20:51409301-51409801',
#  'chr6:144304428-144304928',
#  'chr12:10602582-10603082',
#  'chr3:106033652-106034152',
#  'chr9:6439216-6439716',
#  'chr10:72941683-72942183',
#  'chr8:101967771-101968271',
#  'chr12:68163496-68163996',
#  'chr13:29529698-29530198',
#  'chr6:30568245-30568745',
#  'chr3:17075299-17075799',
#  'chr6:101845605-101846105',
#  'chr21:46052613-46053113',
#  'chr16:53537568-53538068',
#  'chr3:39222474-39222974',
#  'chr20:51554408-51554908',
#  'chr15:60860117-60860617',
#  'chr20:23415937-23416437',
#  'chr6:15993780-15994280',
#  'chr4:36192876-36193376',
#  'chr2:27572408-27572908',
#  'chr7:6032113-6032613',
#  'chr4:25687661-25688161',
#  'chr7:65233667-65234167',
#  'chr7:121360506-121361006',
#  'chr2:201656069-201656569',
#  'chr18:74995996-74996496',
#  'chr1:151436964-151437464',
#  'chr14:71697993-71698493',
#  'chr7:7942654-7943154',
#  'chr18:12920601-12921101',
#  'chr22:48185485-48185985',
#  'chr22:22735201-22735701',
#  'chr16:23483500-23484000',
#  'chr2:88638713-88639213',
#  'chr22:22737537-22738037',
#  'chr11:113859789-113860289',
#  'chr3:125822100-125822600',
#  'chr18:80172000-80172500',
#  'chr5:102853561-102854061',
#  'chr2:46144368-46144868',
#  'chr2:175208022-175208522',
#  'chrX:149858531-149859031',
#  'chr2:7438825-7439325',
#  'chr10:77279231-77279731',
#  'chr3:177683572-177684072',
#  'chr7:37657821-37658321',
#  'chr12:10453144-10453644',
#  'chr7:38217778-38218278',
#  'chr2:54041129-54041629',
#  'chr17:44438603-44439103',
#  'chr22:31524069-31524569',
#  'chr15:72805419-72805919',
#  'chr12:91852047-91852547',
#  'chr1:158978661-158979161',
#  'chr13:20669144-20669644',
#  'chr1:203756008-203756508',
#  'chr5:155767413-155767913',
#  'chr13:66162437-66162937',
#  'chr1:157628692-157629192',
#  'chr5:148853828-148854328',
#  'chr9:87276116-87276616',
#  'chr1:59125066-59125566',
#  'chr14:67875145-67875645',
#  'chr1:53135693-53136193',
#  'chr5:126816522-126817022',
#  'chr5:155773640-155774140',
#  'chr20:36563989-36564489',
#  'chr1:11062877-11063377',
#  'chr7:98514356-98514856',
#  'chr12:7755658-7756158',
#  'chr7:6241585-6242085',
#  'chr17:35889672-35890172',
#  'chrX:13716407-13716907',
#  'chr1:157696891-157697391',
#  'chr1:53575033-53575533',
#  'chr5:176723340-176723840',
#  'chr18:77220692-77221192',
#  'chr8:142838238-142838738',
#  'chr2:7437077-7437577',
#  'chrX:13483723-13484223',
#  'chr18:12929649-12930149',
#  'chr1:7915802-7916302',
#  'chr9:74322827-74323327',
#  'chr7:38245517-38246017',
#  'chr15:56174566-56175066',
#  'chrX:107454262-107454762',
#  'chr14:97393283-97393783',
#  'chr1:198558332-198558832',
#  'chr5:148839915-148840415',
#  'chr2:69685641-69686141',
#  'chr10:8360257-8360757',
#  'chr10:32983140-32983640',
#  'chr6:5522145-5522645',
#  'chr3:59235506-59236006',
#  'chr3:45958363-45958863',
#  'chr12:122161664-122162164',
#  'chr4:8046876-8047376',
#  'chr4:26723171-26723671',
#  'chr12:128570165-128570665',
#  'chrX:41695454-41695954',
#  'chr6:150310416-150310916',
#  'chr7:150999466-150999966',
#  'chr1:168576260-168576760',
#  'chrX:139739074-139739574',
#  'chr8:29990382-29990882',
#  'chr9:128511968-128512468',
#  'chr17:35529821-35530321',
#  'chr15:59384447-59384947',
#  'chr2:27685006-27685506',
#  'chr20:51386553-51387053',
#  'chr11:116953500-116954000',
#  'chr22:39115983-39116483',
#  'chr21:44626182-44626682',
#  'chr5:40338432-40338932',
#  'chr5:146765043-146765543',
#  'chr8:73346383-73346883',
#  'chr3:114323743-114324243',
#  'chr3:88018944-88019444',
#  'chr13:50422051-50422551',
#  'chr21:31011373-31011873',
#  'chr16:87754487-87754987',
#  'chr2:8346224-8346724',
#  'chr4:36278741-36279241',
#  'chr2:27638033-27638533',
#  'chr20:2637169-2637669',
#  'chr13:23321083-23321583',
#  'chr17:57982352-57982852',
#  'chr1:24498552-24499052',
#  'chr2:234272423-234272923',
#  'chr17:49338830-49339330',
#  'chr17:35891215-35891715',
#  'chr11:113868070-113868570',
#  'chr12:111971764-111972264',
#  'chr10:17511306-17511806',
#  'chr18:44805593-44806093',
#  'chr1:202201137-202201637',
#  'chr1:184380390-184380890',
#  'chr9:87276692-87277192',
#  'chr1:168543856-168544356',
#  'chr5:143120911-143121411',
#  'chr2:48362459-48362959',
#  'chr10:70985841-70986341',
#  'chr1:158924701-158925201',
#  'chr8:134324751-134325251',
#  'chr15:40743177-40743677',
#  'chr3:66353906-66354406',
#  'chr22:26628694-26629194',
#  'chr3:196144684-196145184',
#  'chr3:73029178-73029678',
#  'chr17:3788137-3788637',
#  'chr7:55309594-55310094',
#  'chr1:206944677-206945177',
#  'chr19:7692808-7693308',
#  'chr1:160879031-160879531',
#  'chr12:10279853-10280353',
#  'chr17:35889126-35889626',
#  'chr2:112920862-112921362',
#  'chr4:36281324-36281824',
#  'chr1:168392112-168392612',
#  'chr3:46269481-46269981',
#  'chr17:35879395-35879895',
#  'chr7:38220411-38220911',
#  'chr11:119440719-119441219',
#  'chr3:15467168-15467668',
#  'chr1:162548117-162548617',
#  'chr2:317902-318402',
#  'chr1:35115767-35116267',
#  'chr17:66713417-66713917',
#  'chr3:123492122-123492622',
#  'chr14:97432543-97433043',
#  'chr17:48265323-48265823',
#  'chr8:58790762-58791262',
#  'chr13:44112603-44113103',
#  'chr1:228748485-228748985',
#  'chr5:180367236-180367736',
#  'chrX:124641908-124642408',
#  'chr3:153242824-153243324',
#  'chr6:105648238-105648738',
#  'chr7:35652083-35652583',
#  'chr6:46325665-46326165',
#  'chr6:109706470-109706970',
#  'chr10:27224907-27225407',
#  'chr4:38003038-38003538',
#  'chr18:22260318-22260818',
#  'chr6:150311501-150312001',
#  'chr11:11987569-11988069',
#  'chr17:8388200-8388700',
#  'chr1:220056338-220056838',
#  'chr1:10498119-10498619',
#  'chr11:14435625-14436125',
#  'chr14:52155047-52155547',
#  'chr18:61948949-61949449',
#  'chr3:66297896-66298396',
#  'chr9:131833028-131833528',
#  'chr11:113862394-113862894',
#  'chr20:36564747-36565247',
#  'chr13:23321584-23322084',
#  'chr8:79692945-79693445',
#  'chr13:113876549-113877049',
#  'chr5:5486079-5486579',
#  'chr15:38576782-38577282',
#  'chr15:58650066-58650566',
#  'chr7:38242735-38243235',
#  'chr9:85717202-85717702',
#  'chr22:38104616-38105116',
#  'chr9:92440414-92440914',
#  'chr7:70669784-70670284',
#  'chr13:48526283-48526783',
#  'chr4:6179293-6179793',
#  'chr22:39116600-39117100',
#  'chr3:178348872-178349372',
#  'chr8:102095527-102096027',
#  'chr19:7691418-7691918',
#  'chr1:59316767-59317267',
#  'chr2:144598644-144599144',
#  'chr2:9655414-9655914',
#  'chr8:97847078-97847578',
#  'chr12:121551727-121552227',
#  'chr10:7030161-7030661',
#  'chr8:52764243-52764743',
#  'chr8:125125466-125125966',
#  'chr1:15919266-15919766',
#  'chr19:51386787-51387287',
#  'chr2:8588429-8588929',
#  'chr5:180720375-180720875',
#  'chr5:73120308-73120808',
#  'chr9:106310764-106311264',
#  'chr2:128382136-128382636',
#  'chr2:36798661-36799161',
#  'chr12:52559339-52559839',
#  'chr3:15500218-15500718',
#  'chr9:134649085-134649585',
#  'chr10:6491528-6492028',
#  'chr3:196357823-196358323',
#  'chr13:44352055-44352555',
#  'chr5:40480325-40480825',
#  'chr1:203756554-203757054',
#  'chr20:56433725-56434225',
#  'chr12:9009962-9010462',
#  'chr1:39328263-39328763',
#  'chr19:38928330-38928830',
#  'chrX:40663296-40663796',
#  'chr8:66589569-66590069',
#  'chr14:91047093-91047593',
#  'chr6:138944272-138944772',
#  'chr12:22410133-22410633',
#  'chr2:135954184-135954684',
#  'chr20:51667003-51667503',
#  'chr17:47810077-47810577',
#  'chr7:29156771-29157271',
#  'chr19:39299339-39299839',
#  'chr16:87979853-87980353',
#  'chr6:46174809-46175309',
#  'chr11:2217076-2217576',
#  'chr6:33645449-33645949',
#  'chr17:47762678-47763178',
#  'chr3:141403546-141404046',
#  'chr9:4344938-4345438',
#  'chr9:4653988-4654488',
#  'chr15:65512801-65513301',
#  'chr6:5869592-5870092',
#  'chr3:106068710-106069210',
#  'chr7:21383163-21383663',
#  'chr6:40477281-40477781',
#  'chr7:159174924-159175424',
#  'chr2:190695645-190696145',
#  'chr16:82945641-82946141',
#  'chr8:66446015-66446515',
#  'chr3:125670941-125671441',
#  'chr6:117615963-117616463',
#  'chr5:40361371-40361871',
#  'chr10:29657615-29658115',
#  'chr6:15628698-15629198',
#  'chr1:231919743-231920243',
#  'chr1:3787241-3787741',
#  'chr16:74888158-74888658',
#  'chr17:1890711-1891211',
#  'chr13:41811498-41811998',
#  'chr3:27900266-27900766',
#  'chr2:169683468-169683968',
#  'chr12:52558820-52559320',
#  'chr9:124873574-124874074',
#  'chr6:53634234-53634734',
#  'chr22:24409914-24410414',
#  'chr2:241762259-241762759',
#  'chr12:68225574-68226074',
#  'chr11:66272535-66273035',
#  'chr19:14676751-14677251',
#  'chr1:91875986-91876486',
#  'chr1:26790444-26790944',
#  'chr6:83308791-83309291',
#  'chr5:55023902-55024402',
#  'chr13:114268111-114268611',
#  'chr7:70679591-70680091',
#  'chr22:20122948-20123448',
#  'chr7:1961827-1962327',
#  'chr11:63950966-63951466',
#  'chr18:22408049-22408549',
#  'chr14:101712763-101713263',
#  'chr14:99396133-99396633',
#  'chr15:72964491-72964991',
#  'chr10:27225606-27226106',
#  'chr5:127785056-127785556',
#  'chr1:36606853-36607353',
#  'chr15:91491110-91491610',
#  'chr14:54669772-54670272',
#  'chr6:135537958-135538458',
#  'chr2:60948853-60949353',
#  'chr20:57605075-57605575',
#  'chr3:27905585-27906085',
#  'chr1:15252897-15253397',
#  'chr2:85684799-85685299',
#  'chr11:14393803-14394303',
#  'chr7:8198237-8198737',
#  'chr13:27559671-27560171',
#  'chr16:31421555-31422055',
#  'chr12:52555544-52556044',
#  'chr6:137269259-137269759',
#  'chr3:114315778-114316278',
#  'chr21:34801053-34801553',
#  'chr11:122850098-122850598',
#  'chr17:47829327-47829827',
#  'chr15:50751321-50751821',
#  'chr17:12982345-12982845',
#  'chr18:69895512-69896012',
#  'chr19:19010539-19011039',
#  'chr2:12855452-12855952',
#  'chr19:13887455-13887955',
#  'chr4:6198166-6198666',
#  'chr19:52778715-52779215',
#  'chr8:17962922-17963422',
#  'chr2:102264667-102265167',
#  'chr15:65761117-65761617',
#  'chr8:102097018-102097518',
#  'chr16:9082357-9082857',
#  'chr22:43085977-43086477',
#  'chr6:1770290-1770790',
#  'chr2:109205374-109205874',
#  'chr11:134349414-134349914',
#  'chr4:36189306-36189806',
#  'chr6:144197838-144198338',
#  'chr2:96161725-96162225',
#  'chr1:25064461-25064961',
#  'chr18:3511866-3512366',
#  'chr6:111714303-111714803',
#  'chr4:7324619-7325119',
#  'chr4:183321111-183321611',
#  'chr5:148855611-148856111',
#  'chr17:17363536-17364036',
#  'chr17:69602959-69603459',
#  'chr2:105072000-105072500',
#  'chr2:88239655-88240155',
#  'chr16:23482728-23483228',
#  'chr5:143693733-143694233',
#  'chr12:68119713-68120213',
#  'chr22:22756694-22757194',
#  'chr1:92365665-92366165',
#  'chr3:69282076-69282576',
#  'chr15:60540226-60540726',
#  'chr1:28365882-28366382',
#  'chr2:68379332-68379832',
#  'chr10:70610922-70611422',
#  'chr6:35191828-35192328',
#  'chr18:45785132-45785632',
#  'chr5:91390313-91390813',
#  'chr1:7929692-7930192',
#  'chr8:29050084-29050584',
#  'chr20:52031762-52032262',
#  'chrY:7280306-7280806',
#  'chr10:73758862-73759362',
#  'chr3:105828676-105829176',
#  'chr5:72194754-72195254',
#  'chr17:42361800-42362300',
#  'chr5:150046010-150046510',
#  'chr2:419901-420401',
#  'chr4:2470716-2471216',
#  'chr17:10077835-10078335',
#  'chr15:72809295-72809795',
#  'chr14:77738453-77738953',
#  'chr4:6221757-6222257',
#  'chr13:50427471-50427971',
#  'chr18:23563529-23564029',
#  'chr2:24739268-24739768',
#  'chr7:6240912-6241412',
#  'chr11:387211-387711',
#  'chr14:44928698-44929198',
#  'chr2:169682914-169683414',
#  'chr15:63763413-63763913',
#  'chr11:19280951-19281451',
#  'chr1:221829575-221830075',
#  'chr12:10397334-10397834',
#  'chr18:22342787-22343287',
#  'chr2:241869216-241869716',
#  'chrX:13719124-13719624',
#  'chr16:67289679-67290179',
#  'chr10:50527424-50527924',
#  'chr16:68752588-68753088',
#  'chr3:45963999-45964499',
#  'chr9:132451198-132451698',
#  'chr2:61663014-61663514',
#  'chr2:9663134-9663634',
#  'chr2:100218504-100219004',
#  'chr8:127625149-127625649',
#  'chr19:7692274-7692774',
#  'chr1:168833652-168834152',
#  'chr10:123772118-123772618',
#  'chr10:70610339-70610839',
#  'chr3:141017520-141018020',
#  'chr12:109062631-109063131',
#  'chr16:50722041-50722541',
#  'chr19:7690727-7691227',
#  'chr9:91693902-91694402',
#  'chr5:132664060-132664560',
#  'chr14:106736853-106737353',
#  'chr12:128745958-128746458',
#  'chr1:160756333-160756833',
#  'chr12:54432775-54433275',
#  'chr11:14784140-14784640',
#  'chr13:50255572-50256072',
#  'chr1:50450928-50451428',
#  'chr6:4607466-4607966',
#  'chr5:159933566-159934066',
#  'chr1:157723079-157723579',
#  'chr6:17664255-17664755',
#  'chr12:31722018-31722518',
#  'chr9:96203788-96204288',
#  'chr6:46175438-46175938',
#  'chr1:232528705-232529205',
#  'chr1:110982283-110982783',
#  'chr18:22344270-22344770',
#  'chr1:53410047-53410547',
#  'chr8:127732418-127732918',
#  'chr15:60740528-60741028',
#  'chr7:129554134-129554634',
#  'chr1:237789580-237790080',
#  'chr16:85518488-85518988',
#  'chr5:171985046-171985546',
#  'chr17:77692484-77692984',
#  'chr17:35897919-35898419',
#  'chr2:12219693-12220193',
#  'chr8:134278218-134278718',
#  'chr1:67323054-67323554',
#  'chr9:126982171-126982671',
#  'chr4:121706614-121707114',
#  'chr20:20603368-20603868',
#  'chr4:1087274-1087774',
#  'chr9:91211722-91212222',
#  'chr6:116136894-116137394',
#  'chr1:91732379-91732879',
#  'chr20:52054077-52054577',
#  'chr9:121732805-121733305',
#  'chr12:89477510-89478010',
#  'chr2:156480283-156480783',
#  'chr3:46107745-46108245',
#  'chr18:45938387-45938887',
#  'chr11:115256728-115257228',
#  'chr2:69469299-69469799',
#  'chr2:234077599-234078099',
#  'chr16:81522767-81523267',
#  'chr17:10081500-10082000',
#  'chr22:21763146-21763646',
#  'chr10:122544472-122544972',
#  'chr6:45584034-45584534',
#  'chr17:47740959-47741459',
#  'chr2:191127183-191127683',
#  'chr1:55128673-55129173',
#  'chr22:45254904-45255404',
#  'chr11:86802518-86803018',
#  'chr13:102721662-102722162',
#  'chr22:42828350-42828850',
#  'chr12:10285888-10286388',
#  'chr18:23570832-23571332',
#  'chr1:53600425-53600925',
#  'chr1:160751503-160752003',
#  'chr13:80386006-80386506',
#  'chr10:113005274-113005774',
#  'chr3:18527649-18528149',
#  'chr2:239609633-239610133',
#  'chr9:91253420-91253920',
#  'chr19:52542947-52543447',
#  'chr21:33227807-33228307',
#  'chr17:4045313-4045813',
#  'chr6:52176525-52177025',
#  'chr18:22465944-22466444',
#  'chr11:76200090-76200590',
#  'chr2:33275649-33276149',
#  'chr17:58387671-58388171',
#  'chr17:35878244-35878744',
#  'chr11:11995569-11996069',
#  'chr11:130340630-130341130',
#  'chr3:46102369-46102869',
#  'chr14:24609725-24610225',
#  'chrUn_GL000219v1:45822-46322',
#  'chr4:71107752-71108252',
#  'chr3:188553598-188554098',
#  'chr17:33233562-33234062',
#  'chr2:62332917-62333417',
#  'chr22:49784962-49785462',
#  'chr1:55138677-55139177',
#  'chr1:185241106-185241606',
#  'chr17:36107582-36108082',
#  'chr19:10006221-10006721',
#  'chr22:46370326-46370826',
#  'chr17:47741735-47742235',
#  'chr1:67294821-67295321',
#  'chr14:81485274-81485774',
#  'chr12:122166590-122167090',
#  'chr16:66874713-66875213',
#  'chr13:113875824-113876324',
#  'chrX:107451647-107452147',
#  'chr1:145718969-145719469',
#  'chr15:65857699-65858199',
#  'chr16:89026045-89026545',
#  'chr6:40477785-40478285',
#  'chr12:96473301-96473801',
#  'chr2:189791584-189792084',
#  'chr2:62208722-62209222',
#  'chr22:37994011-37994511',
#  'chr6:150310990-150311490',
#  'chr17:71921746-71922246',
#  'chr17:14559650-14560150',
#  'chr14:65637709-65638209',
#  'chr12:132818322-132818822',
#  'chr2:28547849-28548349',
#  'chr3:144128196-144128696',
#  'chr11:36558107-36558607',
#  'chr3:43014871-43015371',
#  'chr7:128320298-128320798',
#  'chr15:29031683-29032183',
#  'chr20:33372305-33372805',
#  'chr2:216349822-216350322',
#  'chr20:34369220-34369720',
#  'chr12:68080574-68081074',
#  'chr1:168410320-168410820',
#  'chr14:62097720-62098220',
#  'chr5:12870818-12871318',
#  'chr19:4913867-4914367',
#  'chr4:107094382-107094882',
#  'chr12:10305280-10305780',
#  'chr2:239137812-239138312',
#  'chr3:17088910-17089410',
#  'chr9:96425695-96426195',
#  'chr12:120480948-120481448',
#  'chr1:91730655-91731155',
#  'chr1:19687655-19688155',
#  'chr18:79326397-79326897',
#  'chr10:110275078-110275578',
#  'chr3:109804675-109805175',
#  'chr14:101713451-101713951',
#  'chr1:53765664-53766164',
#  'chr8:100416164-100416664',
#  'chr6:105458324-105458824',
#  'chr1:67333022-67333522',
#  'chr1:24985021-24985521',
#  'chr13:114268617-114269117',
#  'chr6:157146898-157147398',
#  'chr5:142786819-142787319',
#  'chr12:31723112-31723612',
#  'chr2:8168276-8168776',
#  'chr10:4234677-4235177',
#  'chr19:7186351-7186851',
#  'chr13:30157123-30157623',
#  'chrX:19599154-19599654',
#  'chr17:35900458-35900958',
#  'chr11:23688697-23689197',
#  'chr11:88302944-88303444',
#  'chr14:68841332-68841832',
#  'chr20:24960786-24961286',
#  'chr1:225460658-225461158',
#  'chr16:17591920-17592420',
#  'chr2:173149508-173150008',
#  'chr1:91124866-91125366',
#  'chr19:51373329-51373829',
#  'chr2:8486099-8486599',
#  'chr5:148844576-148845076',
#  'chr2:102253338-102253838',
#  'chr11:128285292-128285792',
#  'chr6:107715827-107716327',
#  'chr8:127670836-127671336',
#  'chr1:67274610-67275110',
#  'chr3:57681709-57682209',
#  'chr5:1374017-1374517',
#  'chr1:35457608-35458108',
#  'chrX:124063952-124064452',
#  'chr1:55127883-55128383',
#  'chr2:9650365-9650865',
#  'chr5:172722148-172722648',
#  'chr2:234274091-234274591',
#  'chr8:127668777-127669277',
#  'chr1:159827539-159828039',
#  'chr14:91155026-91155526',
#  'chr8:134525439-134525939',
#  'chr10:6492123-6492623',
#  'chr10:71698264-71698764',
#  'chr6:152634719-152635219',
#  'chr15:95865418-95865918',
#  'chr20:51417648-51418148',
#  'chr9:129930572-129931072',
#  'chr12:68159562-68160062',
#  'chr17:67137809-67138309',
#  'chr12:96441847-96442347',
#  'chr2:235685109-235685609',
#  'chr13:99273049-99273549',
#  'chr10:110849986-110850486',
#  'chr12:104427511-104428011',
#  'chr1:15405286-15405786',
#  'chr8:102096225-102096725',
#  'chr2:239625927-239626427',
#  'chr6:37137439-37137939',
#  'chr2:119704492-119704992',
#  'chr8:47703860-47704360',
#  'chr10:49157241-49157741',
#  'chr6:13375156-13375656',
#  'chr2:181146119-181146619',
#  'chr10:22570673-22571173',
#  'chr9:91694416-91694916',
#  'chr20:5039115-5039615',
#  'chr8:93320508-93321008',
#  'chr7:43808345-43808845',
#  'chr5:42962035-42962535',
#  'chr22:22790392-22790892',
#  'chr12:31932212-31932712',
#  'chrX:47458523-47459023',
#  'chr15:93152185-93152685',
#  'chr17:47700383-47700883',
#  'chr11:119370359-119370859',
#  'chr10:70604129-70604629',
#  'chr10:27541646-27542146',
#  'chr12:9027096-9027596',
#  'chr21:42959038-42959538',
#  'chr20:24930207-24930707',
#  'chr7:159144681-159145181',
#  'chrX:107449469-107449969',
#  'chr14:50521381-50521881',
#  'chr20:57605800-57606300',
#  'chr1:100362815-100363315',
#  'chr16:2846862-2847362',
#  'chr18:12921140-12921640',
#  'chr7:158804198-158804698',
#  'chr14:24679625-24680125',
#  'chr1:167076138-167076638',
#  'chr2:9656259-9656759',
#  'chr10:7239250-7239750',
#  'chr5:99258688-99259188',
#  'chr8:20251627-20252127',
#  'chr15:60526236-60526736',
#  'chr1:198102515-198103015',
#  'chrX:149871935-149872435',
#  'chr9:121356934-121357434',
#  'chr8:127674839-127675339',
#  'chr16:11536049-11536549',
#  'chr19:54551222-54551722',
#  'chr2:144598099-144598599',
#  'chrX:9205500-9206000',
#  'chr11:130389294-130389794',
#  'chr5:73095955-73096455',
#  'chr2:159227328-159227828',
#  'chr12:10304067-10304567',
#  'chr19:10523069-10523569',
#  'chr10:69027574-69028074',
#  'chr5:107979876-107980376',
#  'chr4:114004488-114004988',
#  'chr1:19688398-19688898',
#  'chr1:10525093-10525593',
#  'chr1:53585105-53585605',
#  'chr22:46374263-46374763',
#  'chrX:104108928-104109428',
#  'chr7:139085323-139085823',
#  'chr6:105459008-105459508',
#  'chr15:86624534-86625034',
#  'chr19:52715679-52716179',
#  'chr1:212225386-212225886',
#  'chr7:66125763-66126263',
#  'chr12:1740425-1740925',
#  'chr16:89821489-89821989',
#  'chr12:68119194-68119694',
#  'chr11:1619321-1619821',
#  'chr5:142734004-142734504',
#  'chr8:66610163-66610663',
#  'chr1:101338586-101339086',
#  'chr12:91875628-91876128',
#  'chr10:3057936-3058436',
#  'chr21:46093908-46094408',
#  'chr12:1126038-1126538',
#  'chr19:3357384-3357884',
#  'chr2:241868697-241869197',
#  'chr3:113743196-113743696',
#  'chr13:30148729-30149229',
#  'chr2:128273544-128274044',
#  'chr6:150264003-150264503',
#  'chr6:75496346-75496846',
#  'chr3:111608258-111608758',
#  'chr6:105397871-105398371',
#  'chr21:46483246-46483746',
#  'chrX:13692118-13692618',
#  'chr9:33426860-33427360',
#  'chr11:36375333-36375833',
#  'chr6:130218100-130218600',
#  'chr8:100415637-100416137',
#  'chr3:113741952-113742452',
#  'chr5:76763083-76763583',
#  'chr11:115256088-115256588',
#  'chr3:197706631-197707131',
#  'chr20:10351533-10352033',
#  'chr6:168905670-168906170',
#  'chr6:16488211-16488711',
#  'chr3:45944740-45945240',
#  'chr4:158895773-158896273',
#  'chr5:107991090-107991590',
#  'chr5:132058984-132059484',
#  'chr8:47644134-47644634',
#  'chr6:10732954-10733454',
#  'chr18:22391570-22392070',
#  'chr14:68719637-68720137',
#  'chr3:11306813-11307313',
#  'chr14:99055715-99056215',
#  'chr7:158663072-158663572',
#  'chr3:16789330-16789830',
#  'chr2:25831725-25832225',
#  'chr14:64733847-64734347',
#  'chr1:219236082-219236582',
#  'chr11:3099162-3099662',
#  'chr7:38218747-38219247',
#  'chr5:127785578-127786078',
#  'chr7:29196175-29196675',
#  'chr14:94946186-94946686',
#  'chr3:27719835-27720335',
#  'chr17:35890652-35891152',
#  'chr3:149010187-149010687',
#  'chr6:158564999-158565499',
#  'chr12:113110391-113110891',
#  'chr6:157258898-157259398',
#  'chr4:36189809-36190309',
#  'chr19:38924360-38924860',
#  'chr9:127437816-127438316',
#  'chr6:158564486-158564986',
#  'chr6:41533330-41533830',
#  'chr7:55498093-55498593',
#  'chr8:139505281-139505781',
#  'chr10:50552797-50553297',
#  'chr1:67166147-67166647',
#  'chr17:4043858-4044358',
#  'chr4:15725629-15726129',
#  'chrY:7279780-7280280',
#  'chr5:142996342-142996842',
#  'chr7:159195759-159196259',
#  'chr10:22634108-22634608',
#  'chr10:73968032-73968532',
#  'chr7:35722960-35723460',
#  'chr4:26130983-26131483',
#  'chr1:53084496-53084996',
#  'chr1:9882276-9882776',
#  'chr11:128190237-128190737',
#  'chr22:46370859-46371359',
#  'chr14:97705917-97706417',
#  'chr15:39641509-39642009',
#  'chr5:139925924-139926424',
#  'chr10:11156403-11156903',
#  'chr2:227826111-227826611',
#  'chr15:60543480-60543980',
#  'chr17:47220428-47220928',
#  'chr19:47541491-47541991',
#  'chr19:19615009-19615509',
#  'chr7:66148339-66148839',
#  'chr4:7192238-7192738',
#  'chr10:119120242-119120742',
#  'chr2:128372612-128373112',
#  'chr4:158874037-158874537',
#  'chr4:158896404-158896904',
#  'chr7:55308916-55309416',
#  'chr17:57646191-57646691',
#  'chr2:25816205-25816705',
#  'chr5:127936558-127937058',
#  'chr11:65384348-65384848',
#  'chr17:49715088-49715588',
#  'chr20:59242632-59243132',
#  'chr18:63050914-63051414',
#  'chr11:88345409-88345909',
#  'chr11:30282169-30282669',
#  'chr11:85781550-85782050',
#  'chr10:6958675-6959175',
#  'chr3:27840801-27841301',
#  'chr3:56735137-56735637',
#  'chr16:4466369-4466869',
#  'chr15:73141196-73141696',
#  'chr7:26167220-26167720',
#  'chr10:43225403-43225903',
#  'chr4:3192142-3192642',
#  'chr13:114269171-114269671',
#  'chr10:104303714-104304214',
#  'chr10:6558742-6559242',
#  'chr1:23118515-23119015',
#  'chr15:31179715-31180215',
#  'chr22:25076275-25076775',
#  'chr8:144402594-144403094',
#  'chr9:126519586-126520086',
#  'chr19:52745807-52746307',
#  'chr4:169015968-169016468',
#  'chr19:46936519-46937019',
#  'chr10:133475793-133476293',
#  'chr2:193019-193519',
#  'chr19:17160865-17161365',
#  'chr1:231973739-231974239',
#  'chr11:36558644-36559144',
#  'chr18:22385676-22386176',
#  'chr16:2065184-2065684',
#  'chr1:91550933-91551433',
#  'chr12:117105797-117106297',
#  'chr22:46373193-46373693',
#  'chr9:88435258-88435758',
#  'chr17:77836682-77837182',
#  'chr10:133475184-133475684',
#  'chr21:32407782-32408282',
#  'chr10:124688802-124689302',
#  'chr2:97747214-97747714',
#  'chr4:970277-970777',
#  'chr2:86794751-86795251',
#  'chr13:113179844-113180344',
#  'chr1:92016706-92017206',
#  'chr16:87981348-87981848',
#  'chr6:143397303-143397803',
#  'chr18:22238026-22238526',
#  'chr14_GL000194v1_random:101126-101626',
#  'chr14:58198033-58198533',
#  'chr16:71856223-71856723',
#  'chr2:28544458-28544958',
#  'chr1:147688606-147689106',
#  'chr17:35530562-35531062',
#  'chr8:124650165-124650665',
#  'chr6:6494084-6494584',
#  'chr15:62128847-62129347',
#  'chr10:97095868-97096368',
#  'chr9:112734872-112735372',
#  'chr21:44074248-44074748',
#  'chr19:1939171-1939671',
#  'chr8:57000343-57000843',
#  'chr11:33777866-33778366',
#  'chr7:21412487-21412987',
#  'chr1:7931265-7931765',
#  'chr10:133453567-133454067',
#  'chr21:45226698-45227198',
#  'chr2:181393917-181394417',
#  'chr1:235872987-235873487',
#  'chr2:239548434-239548934',
#  'chr5:14745660-14746160',
#  'chr2:168378997-168379497',
#  'chr2:28273617-28274117',
#  'chr17:63597208-63597708',
#  'chr20:60011695-60012195',
#  'chr12:95805738-95806238',
#  'chr1:16123682-16124182',
#  'chr6:151374801-151375301',
#  'chr17:1119905-1120405',
#  'chr5:76737061-76737561',
#  'chr12:10369669-10370169',
#  'chr6:17633364-17633864',
#  'chr3:46353002-46353502',
#  'chr15:58608133-58608633',
#  'chr6:144353978-144354478',
#  'chr5:107476732-107477232',
#  'chr6:37962616-37963116',
#  'chr10:69465418-69465918',
#  'chr12:12384411-12384911',
#  'chr9:114369363-114369863',
#  'chr4:101015860-101016360',
#  'chr6:157143356-157143856',
#  'chr6:151373338-151373838',
#  'chr1:91730064-91730564',
#  'chr19:40765523-40766023',
#  'chr9:131839067-131839567',
#  'chrX:154731180-154731680',
#  'chr8:97980119-97980619',
#  'chr9:131840118-131840618',
#  'chr22:43376789-43377289',
#  'chr17:1258447-1258947',
#  'chr6:33616931-33617431',
#  'chr6:16486496-16486996',
#  'chr6:137666182-137666682',
#  'chr15:72358621-72359121',
#  'chr7:75727820-75728320',
#  'chr4:7965262-7965762',
#  'chr2:191128290-191128790',
#  'chrX:53547533-53548033',
#  'chr21:45228006-45228506',
#  'chr13:44352572-44353072',
#  'chr7:129914841-129915341',
#  'chr2:241763415-241763915',
#  'chr16:50160529-50161029',
#  'chr10:13116356-13116856',
#  'chr2:42183872-42184372',
#  'chr1:84876290-84876790',
#  'chr6:137105308-137105808',
#  'chr14:87959960-87960460',
#  'chr6:105646359-105646859',
#  'chr22:31958542-31959042',
#  'chr4:8408780-8409280',
#  'chr2:36834993-36835493',
#  'chr16:75616415-75616915',
#  'chr7:134641026-134641526',
#  'chr22:23278879-23279379',
#  'chr14:89067209-89067709',
#  'chr4:6177767-6178267',
#  'chr6:42357222-42357722',
#  'chr15:72967323-72967823',
#  'chr22:20091651-20092151',
#  'chr10:381823-382323',
#  'chr19:10516901-10517401',
#  'chr12:121557705-121558205',
#  'chr10:26721463-26721963',
#  'chr13:110857350-110857850',
#  'chr10:8416909-8417409',
#  'chr8:41477257-41477757',
#  'chr13:48214522-48215022',
#  'chr1:24856762-24857262',
#  'chr14:67881096-67881596',
#  'chr11:12216129-12216629',
#  'chr17:63598247-63598747',
#  'chr14:61379429-61379929',
#  'chr12:22409533-22410033',
#  'chr13:41974438-41974938',
#  'chr15:95864347-95864847',
#  'chr1:10307850-10308350',
#  'chr20:33350582-33351082',
#  'chr1:67336129-67336629',
#  'chr1:100028716-100029216',
#  'chr20:36628006-36628506',
#  'chr5:73694031-73694531',
#  'chr4:76354490-76354990',
#  'chr11:48011915-48012415',
#  'chr4:6172577-6173077',
#  'chr1:203655645-203656145',
#  'chr2:105373832-105374332',
#  'chr20:58982797-58983297',
#  'chr6:79964428-79964928',
#  'chr1:53106401-53106901',
#  'chr5:76732314-76732814',
#  'chr12:39372826-39373326',
#  'chr18:22344817-22345317',
#  'chr3:149009664-149010164',
#  'chr13:112768846-112769346',
#  'chr16:57588772-57589272',
#  'chr18:77073729-77074229',
#  'chr2:37460401-37460901',
#  'chr6:215602-216102',
#  'chr1:160755693-160756193',
#  'chr9:130130853-130131353',
#  'chr11:134412559-134413059',
#  'chr22:21766512-21767012',
#  'chr15:41515256-41515756',
#  'chr12:52566211-52566711',
#  'chr3:15529097-15529597',
#  'chr20:49594251-49594751',
#  'chr3:56732708-56733208',
#  'chr1:228765436-228765936',
#  'chr22:39205495-39205995',
#  'chr16:82924320-82924820',
#  'chr15:38695712-38696212',
#  'chr2:176931836-176932336',
#  'chr3:50427970-50428470',
#  'chr9:91798482-91798982',
#  'chr15:29057678-29058178',
#  'chr1:54861328-54861828',
#  'chr15:94305106-94305606',
#  'chr6:112285960-112286460',
#  'chr10:71434422-71434922',
#  'chr8:130006838-130007338',
#  'chr3:112672426-112672926',
#  'chr1:94020931-94021431',
#  'chrX:154441507-154442007',
#  'chr13:32390004-32390504',
#  ...]

# %%
for contrast in markers_dict.keys():
    markers = markers_dict[contrast].index.tolist()
    name = contrast.split('_VS')[0].replace(' ', '_')
    df = pd.DataFrame(markers)
    if len(df) == 0:
        print(f"no DARs found for {contrast} in {sample}")
    else:
        df[[0, 1]] = df[0].str.split(":", expand=True)
        df[[1, 2]] = df[1].str.split("-", expand=True)
        df[3] = markers_dict[contrast].index.tolist()
        df[3] = contrast.replace(" ", "_")  # + '_' + df[3].astype(str)
        score = markers_dict[contrast]["Log2FC"]
        score = score.reset_index(drop=True)
        df[4] = score
        df[5] = "."
        pval = markers_dict[contrast]["Adjusted_pval"]
        pval = pval.reset_index(drop=True)
        df[6] = pval
        

        df.to_csv(
            f'harmony_consensus_cell_type__mega_dars_bytech/{sample}/{sample}__{name}__1-2xfoldchange_DARs.bed',
            sep="\t",
            header=False,
            index=False,
        )
