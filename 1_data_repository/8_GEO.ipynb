# %% [markdown]
# # Upload to GEO

# %%
for filepath in ../full_1_vsn_preprocessing/full_preprocessing_out/data/fragments/*fragments.tsv.gz*
do
    echo $filepath
    lnname=$(basename $filepath)
    echo $lnname
    ln -S $filepath full_fragments/$newname
done
# Out:
# ../full_1_vsn_preprocessing/full_preprocessing_out/data/fragments/BIO_ddseq_1.FULL.fragments.tsv.gz
# BIO_ddseq_1.FULL.fragments.tsv.gz
# ln: full_fragments/: hard link not allowed for directory
# ../full_1_vsn_preprocessing/full_preprocessing_out/data/fragments/BIO_ddseq_1.FULL.fragments.tsv.gz.tbi
# BIO_ddseq_1.FULL.fragments.tsv.gz.tbi
# ln: full_fragments/: hard link not allowed for directory
# ../full_1_vsn_preprocessing/full_preprocessing_out/data/fragments/BIO_ddseq_2.FULL.fragments.tsv.gz
# BIO_ddseq_2.FULL.fragments.tsv.gz
# ln: full_fragments/: hard link not allowed for directory
# ../full_1_vsn_preprocessing/full_preprocessing_out/data/fragments/BIO_ddseq_2.FULL.fragments.tsv.gz.tbi
# BIO_ddseq_2.FULL.fragments.tsv.gz.tbi
# ln: full_fragments/: hard link not allowed for directory
# ../full_1_vsn_preprocessing/full_preprocessing_out/data/fragments/BIO_ddseq_3.FULL.fragments.tsv.gz
# BIO_ddseq_3.FULL.fragments.tsv.gz
# ...

# %%
find libds_fastq/* -type l -exec /lustre1/project/stg_00090/scatac_benchmark/0_resources/scripts/replace_links.sh  {} +

# %%
module load NcFTP/3.2.6-foss-2018a

# %%
ncftp

set passive on
set so-bufsize 33554432
open ftp://geoftp:[REDACTED]@ftp-private.ncbi.nlm.nih.gov

cd uploads/[REDACTED]

# %%
put /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq/*

# %%
put /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq/*

# %%
put /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq/EPF_hydrop_1*
# Out:
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq/EPF_hydrop_1__R1.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq/EPF_hydrop_1__R2.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq/EPF_hydrop_1__R3.FULL.fastq.gz

# %%
put /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/*multiome*
# Out:
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/CNA_10xmultiomerna_1__R1.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/CNA_10xmultiomerna_1__R2.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/CNA_10xmultiomerna_2__R1.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/CNA_10xmultiomerna_2__R2.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/SAN_10xmultiomerna_1__R1.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/SAN_10xmultiomerna_1__R2.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/SAN_10xmultiomerna_2__R1.FULL.fastq.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/full_fastq_scrna/SAN_10xmultiomerna_2__R2.FULL.fastq.gz
# ...

# %%
put /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/*.tsv.gz*
# Out:
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS.fragments.tsv.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_1.FIXEDCELLS.fragments.tsv.gz.tbi
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_2.FIXEDCELLS.fragments.tsv.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_2.FIXEDCELLS.fragments.tsv.gz.tbi
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_3.FIXEDCELLS.fragments.tsv.gz
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_3.FIXEDCELLS.fragments.tsv.gz.tbi
# /lustre1/project/stg_00090/scatac_benchmark/1_data_repository/fixedcells_fragments/BIO_ddseq_4.FIXEDCELLS.fragments.tsv.gz
# ...
