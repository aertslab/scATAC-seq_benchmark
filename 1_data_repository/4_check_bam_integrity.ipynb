# %% [markdown]
# # Check the integrity of all bam files generated by pipeline

# %% [markdown]
# in bash:
# ```
# samtools quickcheck *.bam && echo 'all ok' || echo 'fail!'
# ```

# %%
import pandas as pd
import glob
import os

# %%
bam_list = glob.glob('full_bams/*.bam')
bam_list
# Out:
# ['full_bams/EPF_hydrop_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_10xv1_1.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_hydrop_3.FULL.possorted.dbfixed.bam',
#  'full_bams/MDC_mtscatac_2.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_mtscatac_2.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xmultiome_1.FULL.possorted.dbfixed.bam',
#  'full_bams/BRO_mtscatac_2.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv11_4.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv2_1.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_ddseq_1.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_10xmultiome_1.FULL.possorted.dbfixed.bam',
#  'full_bams/HAR_ddseq_1.FULL.possorted.dbfixed.bam',
#  'full_bams/TXG_10xv2_1.FULL.possorted.dbfixed.bam',
#  'full_bams/SAN_10xmultiome_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_10xmultiome_2.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xmultiome_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_10xv2_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_mtscatac_2.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv11_3.FULL.possorted.dbfixed.bam',
#  'full_bams/SAN_10xmultiome_1.FULL.possorted.dbfixed.bam',
#  'full_bams/EPF_hydrop_4.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_hydrop_1.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_mtscatac_1.FULL.possorted.dbfixed.bam',
#  'full_bams/BIO_ddseq_1.FULL.possorted.dbfixed.bam',
#  'full_bams/STA_10xv11_1.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_hydrop_12.FULL.possorted.dbfixed.bam',
#  'full_bams/EPF_hydrop_3.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_10xv2_1.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_mtscatac_1.FULL.possorted.dbfixed.bam',
#  'full_bams/HAR_ddseq_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_10xv1_2.FULL.possorted.dbfixed.bam',
#  'full_bams/MDC_mtscatac_1.FULL.possorted.dbfixed.bam',
#  'full_bams/TXG_10xv2_2.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv2_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_hydrop_22.FULL.possorted.dbfixed.bam',
#  'full_bams/TXG_10xv11_1.FULL.possorted.dbfixed.bam',
#  'full_bams/BIO_ddseq_3.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_hydrop_11.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_ddseq_2.FULL.possorted.dbfixed.bam',
#  'full_bams/STA_10xv11_2.FULL.possorted.dbfixed.bam',
#  'full_bams/VIB_hydrop_21.FULL.possorted.dbfixed.bam',
#  'full_bams/BRO_mtscatac_1.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_hydrop_2.FULL.possorted.dbfixed.bam',
#  'full_bams/BIO_ddseq_4.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv11_2.FULL.possorted.dbfixed.bam',
#  'full_bams/EPF_hydrop_1.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv11_1.FULL.possorted.dbfixed.bam',
#  'full_bams/CNA_10xv11_5.FULL.possorted.dbfixed.bam']

# %%
bam_list = glob.glob('full_bams/*.bam')
with open('bamcheck.parallel', 'w') as f:
    for bam in bam_list:
        bamcheck_txt = f"{bam}.bamcheck.txt"
        if not os.path.exists(bamcheck_txt):
            f.write(f"samtools flagstat -@ 4 {bam} > {bamcheck_txt}\n")
            print(f"printed {bamcheck_txt} command")
        else:
            print(f"{bamcheck_txt} exists!")
# Out:
# printed full_bams/EPF_hydrop_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_10xv1_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_hydrop_3.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/MDC_mtscatac_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_mtscatac_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xmultiome_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/BRO_mtscatac_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv11_4.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv2_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_ddseq_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_10xmultiome_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/HAR_ddseq_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/TXG_10xv2_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/SAN_10xmultiome_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_10xmultiome_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xmultiome_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_10xv2_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_mtscatac_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv11_3.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/SAN_10xmultiome_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/EPF_hydrop_4.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_hydrop_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_mtscatac_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/BIO_ddseq_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/STA_10xv11_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_hydrop_12.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/EPF_hydrop_3.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_10xv2_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_mtscatac_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/HAR_ddseq_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_10xv1_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/MDC_mtscatac_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/TXG_10xv2_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv2_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_hydrop_22.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/TXG_10xv11_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/BIO_ddseq_3.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_hydrop_11.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_ddseq_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/STA_10xv11_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/VIB_hydrop_21.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/BRO_mtscatac_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_hydrop_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/BIO_ddseq_4.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv11_2.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/EPF_hydrop_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv11_1.FULL.possorted.dbfixed.bam.bamcheck.txt command
# printed full_bams/CNA_10xv11_5.FULL.possorted.dbfixed.bam.bamcheck.txt command

# %%
cat bamcheck.parallel | parallel -j 20 --progress
# Out:
# Computers / CPU cores / Max jobs to run
# 1:local / 128 / 20
#
# Computer:jobs running/jobs completed/%of started jobs/Average seconds to complete
# local:20/4/100%/39.2s

# %%
readlengths_file = '/dodrio/scratch/projects/starting_2022_023/benchmark/scatac_benchmark/1_data_repository/R1_lengths.sorted.txt'
readlengths = pd.read_csv(readlengths_file, sep='\t', header=None)
readlengths.index = [x.split('/')[-1].split('__')[0] for x in readlengths[0]]
readlengths
# Out:
#                                                                 0           1
# BIO_ddseq_1              full_fastq/BIO_ddseq_1__R1.FULL.fastq.gz  2496461262
# BIO_ddseq_2              full_fastq/BIO_ddseq_2__R1.FULL.fastq.gz   586078378
# BIO_ddseq_3              full_fastq/BIO_ddseq_3__R1.FULL.fastq.gz   114310431
# BIO_ddseq_4              full_fastq/BIO_ddseq_4__R1.FULL.fastq.gz   117075800
# BRO_mtscatac_1        full_fastq/BRO_mtscatac_1__R1.FULL.fastq.gz   146150399
# BRO_mtscatac_2        full_fastq/BRO_mtscatac_2__R1.FULL.fastq.gz   170806444
# CNA_10xmultiome_1  full_fastq/CNA_10xmultiome_1__R1.FULL.fastq.gz   206430093
# CNA_10xmultiome_2  full_fastq/CNA_10xmultiome_2__R1.FULL.fastq.gz   194200503
# CNA_10xv11_1            full_fastq/CNA_10xv11_1__R1.FULL.fastq.gz   235409552
# CNA_10xv11_2            full_fastq/CNA_10xv11_2__R1.FULL.fastq.gz   266533885
# CNA_10xv11_3            full_fastq/CNA_10xv11_3__R1.FULL.fastq.gz   205743191
# CNA_10xv11_4            full_fastq/CNA_10xv11_4__R1.FULL.fastq.gz   131672325
# CNA_10xv11_5            full_fastq/CNA_10xv11_5__R1.FULL.fastq.gz   118964825
# CNA_10xv2_1              full_fastq/CNA_10xv2_1__R1.FULL.fastq.gz   194069569
# CNA_10xv2_2              full_fastq/CNA_10xv2_2__R1.FULL.fastq.gz   329601526
# CNA_ddseq_1              full_fastq/CNA_ddseq_1__R1.FULL.fastq.gz    26344178
# CNA_ddseq_2              full_fastq/CNA_ddseq_2__R1.FULL.fastq.gz    25933454
# CNA_hydrop_41          full_fastq/CNA_hydrop_41__R1.FULL.fastq.gz   116195873
# CNA_hydrop_42          full_fastq/CNA_hydrop_42__R1.FULL.fastq.gz   156350198
# CNA_hydrop_51          full_fastq/CNA_hydrop_51__R1.FULL.fastq.gz   227553124
# CNA_hydrop_52          full_fastq/CNA_hydrop_52__R1.FULL.fastq.gz   192359113
# CNA_hydrop_61          full_fastq/CNA_hydrop_61__R1.FULL.fastq.gz   185262804
# CNA_hydrop_62          full_fastq/CNA_hydrop_62__R1.FULL.fastq.gz   183870440
# CNA_mtscatac_1        full_fastq/CNA_mtscatac_1__R1.FULL.fastq.gz   142849461
# CNA_mtscatac_2        full_fastq/CNA_mtscatac_2__R1.FULL.fastq.gz   148888242
# EPF_hydrop_21          full_fastq/EPF_hydrop_21__R1.FULL.fastq.gz    54895995
# EPF_hydrop_22          full_fastq/EPF_hydrop_22__R1.FULL.fastq.gz    50770537
# EPF_hydrop_23          full_fastq/EPF_hydrop_23__R1.FULL.fastq.gz    54599585
# EPF_hydrop_24          full_fastq/EPF_hydrop_24__R1.FULL.fastq.gz    38300753
# EPF_hydrop_31          full_fastq/EPF_hydrop_31__R1.FULL.fastq.gz   142121365
# EPF_hydrop_32          full_fastq/EPF_hydrop_32__R1.FULL.fastq.gz   145568846
# EPF_hydrop_33          full_fastq/EPF_hydrop_33__R1.FULL.fastq.gz   124675343
# EPF_hydrop_34          full_fastq/EPF_hydrop_34__R1.FULL.fastq.gz   120006719
# HAR_ddseq_1              full_fastq/HAR_ddseq_1__R1.FULL.fastq.gz   222262426
# HAR_ddseq_2              full_fastq/HAR_ddseq_2__R1.FULL.fastq.gz   216772744
# MDC_mtscatac_1        full_fastq/MDC_mtscatac_1__R1.FULL.fastq.gz   406647948
# MDC_mtscatac_2        full_fastq/MDC_mtscatac_2__R1.FULL.fastq.gz   346564932
# OHS_s3atac_1            full_fastq/OHS_s3atac_1__R1.FULL.fastq.gz  1787010669
# OHS_s3atac_2            full_fastq/OHS_s3atac_2__R1.FULL.fastq.gz   673274276
# SAN_10xmultiome_1  full_fastq/SAN_10xmultiome_1__R1.FULL.fastq.gz   477857492
# SAN_10xmultiome_2  full_fastq/SAN_10xmultiome_2__R1.FULL.fastq.gz   498975059
# STA_10xv11_1            full_fastq/STA_10xv11_1__R1.FULL.fastq.gz   221891009
# STA_10xv11_2            full_fastq/STA_10xv11_2__R1.FULL.fastq.gz   169619907
# TXG_10xv11_1            full_fastq/TXG_10xv11_1__R1.FULL.fastq.gz   525730203
# TXG_10xv2_1              full_fastq/TXG_10xv2_1__R1.FULL.fastq.gz   566333738
# TXG_10xv2_2              full_fastq/TXG_10xv2_2__R1.FULL.fastq.gz   466894746
# VIB_10xmultiome_1  full_fastq/VIB_10xmultiome_1__R1.FULL.fastq.gz   142259400
# VIB_10xmultiome_2  full_fastq/VIB_10xmultiome_2__R1.FULL.fastq.gz   159444545
# VIB_10xv11_1            full_fastq/VIB_10xv11_1__R1.FULL.fastq.gz   226819336
# VIB_10xv11_2            full_fastq/VIB_10xv11_2__R1.FULL.fastq.gz   347212992
# VIB_10xv1_1              full_fastq/VIB_10xv1_1__R1.FULL.fastq.gz   226819336
# VIB_10xv1_2              full_fastq/VIB_10xv1_2__R1.FULL.fastq.gz   347212992
# VIB_10xv2_1              full_fastq/VIB_10xv2_1__R1.FULL.fastq.gz   132758913
# VIB_10xv2_2              full_fastq/VIB_10xv2_2__R1.FULL.fastq.gz   116696854
# VIB_hydrop_11          full_fastq/VIB_hydrop_11__R1.FULL.fastq.gz   108109969
# VIB_hydrop_12          full_fastq/VIB_hydrop_12__R1.FULL.fastq.gz   108599793
# VIB_hydrop_21          full_fastq/VIB_hydrop_21__R1.FULL.fastq.gz    71624791
# VIB_hydrop_22          full_fastq/VIB_hydrop_22__R1.FULL.fastq.gz    97919545
# VIB_mtscatac_1        full_fastq/VIB_mtscatac_1__R1.FULL.fastq.gz   135898536
# VIB_mtscatac_2        full_fastq/VIB_mtscatac_2__R1.FULL.fastq.gz   102160506

# %%
stragglers_list = []
files = sorted(glob.glob('full_bams/*.bamcheck.txt'))
for file in files:
    if os.path.getsize(file) > 0:
        sample = file.split('/')[-1].split('__')[0]
        fastq_reads = readlengths[1].loc[sample]

        df = pd.read_csv(file, header=None)
        bam_reads = df.iloc[6][0].split(' ')[0]
        print(f"{sample}: {str(bam_reads)} in bam, {str(fastq_reads)} in FASTQ")
        diff = fastq_reads - int(bam_reads)
        diff_percent = round(diff/fastq_reads*100, 2)
        print(f"\tdiffering {diff}, or {diff_percent}%")
        if diff_percent > 0.5:
            stragglers_list = stragglers_list + [sample]
            print("\t\tStraggler detected!")
# Out:
# BIO_ddseq_2: 568867960 in bam, 586078378 in FASTQ
# 	differing 17210418, or 2.94%
# 		Straggler detected!
# BIO_ddseq_3: 98061137 in bam, 114310431 in FASTQ
# 	differing 16249294, or 14.22%
# 		Straggler detected!
# BIO_ddseq_4: 101397826 in bam, 117075800 in FASTQ
# 	differing 15677974, or 13.39%
# 		Straggler detected!
# BRO_mtscatac_1: 145604100 in bam, 146150399 in FASTQ
# 	differing 546299, or 0.37%
# BRO_mtscatac_2: 170196511 in bam, 170806444 in FASTQ
# 	differing 609933, or 0.36%
# CNA_10xmultiome_1: 206048774 in bam, 206430093 in FASTQ
# 	differing 381319, or 0.18%
# CNA_10xmultiome_2: 193909964 in bam, 194200503 in FASTQ
# 	differing 290539, or 0.15%
# CNA_10xv11_1: 235210366 in bam, 235409552 in FASTQ
# 	differing 199186, or 0.08%
# CNA_10xv11_2: 266303672 in bam, 266533885 in FASTQ
# 	differing 230213, or 0.09%
# CNA_10xv11_3: 205605806 in bam, 205743191 in FASTQ
# 	differing 137385, or 0.07%
# CNA_10xv11_4: 131562498 in bam, 131672325 in FASTQ
# 	differing 109827, or 0.08%
# CNA_10xv11_5: 118879482 in bam, 118964825 in FASTQ
# 	differing 85343, or 0.07%
# CNA_10xv2_1: 193959650 in bam, 194069569 in FASTQ
# 	differing 109919, or 0.06%
# CNA_10xv2_2: 329406199 in bam, 329601526 in FASTQ
# 	differing 195327, or 0.06%
# CNA_ddseq_1: 24734918 in bam, 26344178 in FASTQ
# 	differing 1609260, or 6.11%
# 		Straggler detected!
# CNA_ddseq_2: 24330662 in bam, 25933454 in FASTQ
# 	differing 1602792, or 6.18%
# 		Straggler detected!
# CNA_hydrop_41: 116115670 in bam, 116195873 in FASTQ
# 	differing 80203, or 0.07%
# CNA_hydrop_42: 156257545 in bam, 156350198 in FASTQ
# 	differing 92653, or 0.06%
# CNA_hydrop_51: 227418850 in bam, 227553124 in FASTQ
# 	differing 134274, or 0.06%
# CNA_hydrop_52: 192240223 in bam, 192359113 in FASTQ
# 	differing 118890, or 0.06%
# CNA_hydrop_61: 185166227 in bam, 185262804 in FASTQ
# 	differing 96577, or 0.05%
# CNA_hydrop_62: 183764247 in bam, 183870440 in FASTQ
# 	differing 106193, or 0.06%
# CNA_mtscatac_1: 142738016 in bam, 142849461 in FASTQ
# 	differing 111445, or 0.08%
# CNA_mtscatac_2: 148774230 in bam, 148888242 in FASTQ
# 	differing 114012, or 0.08%
# EPF_hydrop_21: 54864095 in bam, 54895995 in FASTQ
# 	differing 31900, or 0.06%
# EPF_hydrop_22: 50740217 in bam, 50770537 in FASTQ
# 	differing 30320, or 0.06%
# EPF_hydrop_23: 54569131 in bam, 54599585 in FASTQ
# 	differing 30454, or 0.06%
# EPF_hydrop_24: 38281227 in bam, 38300753 in FASTQ
# 	differing 19526, or 0.05%
# EPF_hydrop_31: 142039256 in bam, 142121365 in FASTQ
# 	differing 82109, or 0.06%
# EPF_hydrop_32: 145483006 in bam, 145568846 in FASTQ
# 	differing 85840, or 0.06%
# EPF_hydrop_33: 124607667 in bam, 124675343 in FASTQ
# 	differing 67676, or 0.05%
# EPF_hydrop_34: 119940570 in bam, 120006719 in FASTQ
# 	differing 66149, or 0.06%
# HAR_ddseq_1: 216532213 in bam, 222262426 in FASTQ
# 	differing 5730213, or 2.58%
# 		Straggler detected!
# HAR_ddseq_2: 211252689 in bam, 216772744 in FASTQ
# 	differing 5520055, or 2.55%
# 		Straggler detected!
# MDC_mtscatac_1: 406466302 in bam, 406647948 in FASTQ
# 	differing 181646, or 0.04%
# MDC_mtscatac_2: 346374083 in bam, 346564932 in FASTQ
# 	differing 190849, or 0.06%
# SAN_10xmultiome_1: 477505161 in bam, 477857492 in FASTQ
# 	differing 352331, or 0.07%
# SAN_10xmultiome_2: 498608426 in bam, 498975059 in FASTQ
# 	differing 366633, or 0.07%
# STA_10xv11_1: 221145825 in bam, 221891009 in FASTQ
# 	differing 745184, or 0.34%
# STA_10xv11_2: 169040262 in bam, 169619907 in FASTQ
# 	differing 579645, or 0.34%
# TXG_10xv11_1: 525348528 in bam, 525730203 in FASTQ
# 	differing 381675, or 0.07%
# TXG_10xv2_1: 565945124 in bam, 566333738 in FASTQ
# 	differing 388614, or 0.07%
# TXG_10xv2_2: 466592380 in bam, 466894746 in FASTQ
# 	differing 302366, or 0.06%
# VIB_10xmultiome_1: 141966022 in bam, 142259400 in FASTQ
# 	differing 293378, or 0.21%
# VIB_10xmultiome_2: 159125641 in bam, 159444545 in FASTQ
# 	differing 318904, or 0.2%
# VIB_10xv11_1: 140056893 in bam, 226819336 in FASTQ
# 	differing 86762443, or 38.25%
# 		Straggler detected!
# VIB_10xv1_1: 226657677 in bam, 226819336 in FASTQ
# 	differing 161659, or 0.07%
# VIB_10xv1_2: 346959872 in bam, 347212992 in FASTQ
# 	differing 253120, or 0.07%
# VIB_10xv2_1: 132698600 in bam, 132758913 in FASTQ
# 	differing 60313, or 0.05%
# VIB_10xv2_2: 116644769 in bam, 116696854 in FASTQ
# 	differing 52085, or 0.04%
# VIB_hydrop_11: 108047316 in bam, 108109969 in FASTQ
# 	differing 62653, or 0.06%
# VIB_hydrop_12: 108531243 in bam, 108599793 in FASTQ
# 	differing 68550, or 0.06%
# VIB_hydrop_21: 71583227 in bam, 71624791 in FASTQ
# 	differing 41564, or 0.06%
# VIB_hydrop_22: 97860382 in bam, 97919545 in FASTQ
# 	differing 59163, or 0.06%
# VIB_mtscatac_1: 135798224 in bam, 135898536 in FASTQ
# 	differing 100312, or 0.07%
# VIB_mtscatac_2: 102086174 in bam, 102160506 in FASTQ
# 	differing 74332, or 0.07%

# %%
stragglers_list = []
files = sorted(glob.glob('full_bams/*.bamcheck.txt'))
for file in files:
    if os.path.getsize(file) > 0:
        sample = file.split('/')[-1].split('__')[0]
        fastq_reads = readlengths[1].loc[sample]

        df = pd.read_csv(file, header=None)
        bam_reads = df.iloc[6][0].split(' ')[0]
        print(f"{sample}: {str(bam_reads)} in bam, {str(fastq_reads)} in FASTQ")
        diff = fastq_reads - int(bam_reads)
        diff_percent = round(diff/fastq_reads*100, 2)
        print(f"\tdiffering {diff}, or {diff_percent}%")
        if diff_percent > 0.5:
            stragglers_list = stragglers_list + [sample]
            print("\t\tStraggler detected!")
# Out:
# BIO_ddseq_2: 568867960 in bam, 586078378 in FASTQ
# 	differing 17210418, or 2.94%
# 		Straggler detected!
# BIO_ddseq_3: 98061137 in bam, 114310431 in FASTQ
# 	differing 16249294, or 14.22%
# 		Straggler detected!
# BIO_ddseq_4: 101397826 in bam, 117075800 in FASTQ
# 	differing 15677974, or 13.39%
# 		Straggler detected!
# BRO_mtscatac_1: 145604100 in bam, 146150399 in FASTQ
# 	differing 546299, or 0.37%
# BRO_mtscatac_2: 170196511 in bam, 170806444 in FASTQ
# 	differing 609933, or 0.36%
# CNA_10xmultiome_1: 103805718 in bam, 206430093 in FASTQ
# 	differing 102624375, or 49.71%
# 		Straggler detected!
# CNA_10xmultiome_2: 193909964 in bam, 194200503 in FASTQ
# 	differing 290539, or 0.15%
# CNA_10xv11_1: 235210366 in bam, 235409552 in FASTQ
# 	differing 199186, or 0.08%
# CNA_10xv11_2: 266303672 in bam, 266533885 in FASTQ
# 	differing 230213, or 0.09%
# CNA_10xv11_3: 205605806 in bam, 205743191 in FASTQ
# 	differing 137385, or 0.07%
# CNA_10xv11_4: 131562498 in bam, 131672325 in FASTQ
# 	differing 109827, or 0.08%
# CNA_10xv11_5: 118879482 in bam, 118964825 in FASTQ
# 	differing 85343, or 0.07%
# CNA_10xv2_1: 193959650 in bam, 194069569 in FASTQ
# 	differing 109919, or 0.06%
# CNA_10xv2_2: 329406199 in bam, 329601526 in FASTQ
# 	differing 195327, or 0.06%
# CNA_ddseq_1: 24734918 in bam, 26344178 in FASTQ
# 	differing 1609260, or 6.11%
# 		Straggler detected!
# CNA_ddseq_2: 24330662 in bam, 25933454 in FASTQ
# 	differing 1602792, or 6.18%
# 		Straggler detected!
# CNA_hydrop_41: 116115670 in bam, 116195873 in FASTQ
# 	differing 80203, or 0.07%
# CNA_hydrop_42: 156257545 in bam, 156350198 in FASTQ
# 	differing 92653, or 0.06%
# CNA_hydrop_51: 227418850 in bam, 227553124 in FASTQ
# 	differing 134274, or 0.06%
# CNA_hydrop_52: 192240223 in bam, 192359113 in FASTQ
# 	differing 118890, or 0.06%
# CNA_hydrop_61: 20733471 in bam, 185262804 in FASTQ
# 	differing 164529333, or 88.81%
# 		Straggler detected!
# CNA_hydrop_62: 29516994 in bam, 183870440 in FASTQ
# 	differing 154353446, or 83.95%
# 		Straggler detected!
# CNA_mtscatac_1: 142738016 in bam, 142849461 in FASTQ
# 	differing 111445, or 0.08%
# CNA_mtscatac_2: 102443126 in bam, 148888242 in FASTQ
# 	differing 46445116, or 31.19%
# 		Straggler detected!
# EPF_hydrop_21: 54864095 in bam, 54895995 in FASTQ
# 	differing 31900, or 0.06%
# EPF_hydrop_22: 50740217 in bam, 50770537 in FASTQ
# 	differing 30320, or 0.06%
# EPF_hydrop_23: 54569131 in bam, 54599585 in FASTQ
# 	differing 30454, or 0.06%
# EPF_hydrop_24: 38281227 in bam, 38300753 in FASTQ
# 	differing 19526, or 0.05%
# EPF_hydrop_31: 142039256 in bam, 142121365 in FASTQ
# 	differing 82109, or 0.06%
# EPF_hydrop_32: 145483006 in bam, 145568846 in FASTQ
# 	differing 85840, or 0.06%
# EPF_hydrop_33: 124607667 in bam, 124675343 in FASTQ
# 	differing 67676, or 0.05%
# EPF_hydrop_34: 119940570 in bam, 120006719 in FASTQ
# 	differing 66149, or 0.06%
# HAR_ddseq_1: 39247858 in bam, 222262426 in FASTQ
# 	differing 183014568, or 82.34%
# 		Straggler detected!
# HAR_ddseq_2: 13862246 in bam, 216772744 in FASTQ
# 	differing 202910498, or 93.61%
# 		Straggler detected!
# MDC_mtscatac_2: 346374083 in bam, 346564932 in FASTQ
# 	differing 190849, or 0.06%
# SAN_10xmultiome_1: 477505161 in bam, 477857492 in FASTQ
# 	differing 352331, or 0.07%
# SAN_10xmultiome_2: 498608426 in bam, 498975059 in FASTQ
# 	differing 366633, or 0.07%
# STA_10xv11_1: 18499833 in bam, 221891009 in FASTQ
# 	differing 203391176, or 91.66%
# 		Straggler detected!
# STA_10xv11_2: 2392041 in bam, 169619907 in FASTQ
# 	differing 167227866, or 98.59%
# 		Straggler detected!
# TXG_10xv11_1: 4947603 in bam, 525730203 in FASTQ
# 	differing 520782600, or 99.06%
# 		Straggler detected!
# TXG_10xv2_1: 565945124 in bam, 566333738 in FASTQ
# 	differing 388614, or 0.07%
# TXG_10xv2_2: 466592380 in bam, 466894746 in FASTQ
# 	differing 302366, or 0.06%
# VIB_10xmultiome_1: 59429207 in bam, 142259400 in FASTQ
# 	differing 82830193, or 58.22%
# 		Straggler detected!
# VIB_10xmultiome_2: 159125641 in bam, 159444545 in FASTQ
# 	differing 318904, or 0.2%
# VIB_10xv11_1: 1793243 in bam, 226819336 in FASTQ
# 	differing 225026093, or 99.21%
# 		Straggler detected!
# VIB_10xv1_1: 226657677 in bam, 226819336 in FASTQ
# 	differing 161659, or 0.07%
# VIB_10xv1_2: 346959872 in bam, 347212992 in FASTQ
# 	differing 253120, or 0.07%
# VIB_10xv2_1: 132698600 in bam, 132758913 in FASTQ
# 	differing 60313, or 0.05%
# VIB_10xv2_2: 116644769 in bam, 116696854 in FASTQ
# 	differing 52085, or 0.04%
# VIB_hydrop_11: 108047316 in bam, 108109969 in FASTQ
# 	differing 62653, or 0.06%
# VIB_hydrop_12: 108531243 in bam, 108599793 in FASTQ
# 	differing 68550, or 0.06%
# VIB_hydrop_21: 71583227 in bam, 71624791 in FASTQ
# 	differing 41564, or 0.06%
# VIB_hydrop_22: 97860382 in bam, 97919545 in FASTQ
# 	differing 59163, or 0.06%
# VIB_mtscatac_1: 135798224 in bam, 135898536 in FASTQ
# 	differing 100312, or 0.07%
# VIB_mtscatac_2: 102086174 in bam, 102160506 in FASTQ
# 	differing 74332, or 0.07%

# %%
stragglers_list
# Out:
# ['BIO_ddseq_2',
#  'BIO_ddseq_3',
#  'BIO_ddseq_4',
#  'CNA_10xmultiome_1',
#  'CNA_ddseq_1',
#  'CNA_ddseq_2',
#  'CNA_hydrop_61',
#  'CNA_hydrop_62',
#  'CNA_mtscatac_2',
#  'HAR_ddseq_1',
#  'HAR_ddseq_2',
#  'STA_10xv11_1',
#  'STA_10xv11_2',
#  'TXG_10xv11_1',
#  'VIB_10xmultiome_1',
#  'VIB_10xv11_1']

# %%
for sample in readlengths.index:
    if os.path.exists(f"full_fragments/{sample}.fragments.raw.tsv.gz"):
        print(f"{sample} has complete fragments")
    else:
        print(f"\t{sample} does not have complete fragments")
        if sample in stragglers_list:
            print(f"\t\t{sample} is in stragglers_list")
        else:
            print(f"\t\t{sample} is not in stragglers_list!!")
# Out:
# 	BIO_ddseq_1 does not have complete fragments
# 		BIO_ddseq_1 is not in stragglers_list!!
# BIO_ddseq_2 has complete fragments
# BIO_ddseq_3 has complete fragments
# BIO_ddseq_4 has complete fragments
# 	BRO_mtscatac_1 does not have complete fragments
# 		BRO_mtscatac_1 is not in stragglers_list!!
# 	BRO_mtscatac_2 does not have complete fragments
# 		BRO_mtscatac_2 is not in stragglers_list!!
# CNA_10xmultiome_1 has complete fragments
# 	CNA_10xmultiome_2 does not have complete fragments
# 		CNA_10xmultiome_2 is not in stragglers_list!!
# 	CNA_10xv11_1 does not have complete fragments
# 		CNA_10xv11_1 is not in stragglers_list!!
# 	CNA_10xv11_2 does not have complete fragments
# 		CNA_10xv11_2 is not in stragglers_list!!
# 	CNA_10xv11_3 does not have complete fragments
# 		CNA_10xv11_3 is not in stragglers_list!!
# 	CNA_10xv11_4 does not have complete fragments
# 		CNA_10xv11_4 is not in stragglers_list!!
# 	CNA_10xv11_5 does not have complete fragments
# 		CNA_10xv11_5 is not in stragglers_list!!
# 	CNA_10xv2_1 does not have complete fragments
# 		CNA_10xv2_1 is not in stragglers_list!!
# 	CNA_10xv2_2 does not have complete fragments
# 		CNA_10xv2_2 is not in stragglers_list!!
# CNA_ddseq_1 has complete fragments
# CNA_ddseq_2 has complete fragments
# 	CNA_hydrop_41 does not have complete fragments
# 		CNA_hydrop_41 is not in stragglers_list!!
# 	CNA_hydrop_42 does not have complete fragments
# 		CNA_hydrop_42 is not in stragglers_list!!
# 	CNA_hydrop_51 does not have complete fragments
# 		CNA_hydrop_51 is not in stragglers_list!!
# 	CNA_hydrop_52 does not have complete fragments
# 		CNA_hydrop_52 is not in stragglers_list!!
# CNA_hydrop_61 has complete fragments
# CNA_hydrop_62 has complete fragments
# 	CNA_mtscatac_1 does not have complete fragments
# 		CNA_mtscatac_1 is not in stragglers_list!!
# CNA_mtscatac_2 has complete fragments
# 	EPF_hydrop_21 does not have complete fragments
# 		EPF_hydrop_21 is not in stragglers_list!!
# 	EPF_hydrop_22 does not have complete fragments
# 		EPF_hydrop_22 is not in stragglers_list!!
# 	EPF_hydrop_23 does not have complete fragments
# 		EPF_hydrop_23 is not in stragglers_list!!
# 	EPF_hydrop_24 does not have complete fragments
# 		EPF_hydrop_24 is not in stragglers_list!!
# 	EPF_hydrop_31 does not have complete fragments
# 		EPF_hydrop_31 is not in stragglers_list!!
# 	EPF_hydrop_32 does not have complete fragments
# 		EPF_hydrop_32 is not in stragglers_list!!
# 	EPF_hydrop_33 does not have complete fragments
# 		EPF_hydrop_33 is not in stragglers_list!!
# 	EPF_hydrop_34 does not have complete fragments
# 		EPF_hydrop_34 is not in stragglers_list!!
# HAR_ddseq_1 has complete fragments
# HAR_ddseq_2 has complete fragments
# 	MDC_mtscatac_1 does not have complete fragments
# 		MDC_mtscatac_1 is not in stragglers_list!!
# 	MDC_mtscatac_2 does not have complete fragments
# 		MDC_mtscatac_2 is not in stragglers_list!!
# 	OHS_s3atac_1 does not have complete fragments
# 		OHS_s3atac_1 is not in stragglers_list!!
# 	OHS_s3atac_2 does not have complete fragments
# 		OHS_s3atac_2 is not in stragglers_list!!
# 	SAN_10xmultiome_1 does not have complete fragments
# 		SAN_10xmultiome_1 is not in stragglers_list!!
# 	SAN_10xmultiome_2 does not have complete fragments
# 		SAN_10xmultiome_2 is not in stragglers_list!!
# STA_10xv11_1 has complete fragments
# STA_10xv11_2 has complete fragments
# TXG_10xv11_1 has complete fragments
# 	TXG_10xv2_1 does not have complete fragments
# 		TXG_10xv2_1 is not in stragglers_list!!
# 	TXG_10xv2_2 does not have complete fragments
# 		TXG_10xv2_2 is not in stragglers_list!!
# VIB_10xmultiome_1 has complete fragments
# 	VIB_10xmultiome_2 does not have complete fragments
# 		VIB_10xmultiome_2 is not in stragglers_list!!
# VIB_10xv11_1 has complete fragments
# 	VIB_10xv11_2 does not have complete fragments
# 		VIB_10xv11_2 is not in stragglers_list!!
# 	VIB_10xv1_1 does not have complete fragments
# 		VIB_10xv1_1 is not in stragglers_list!!
# 	VIB_10xv1_2 does not have complete fragments
# 		VIB_10xv1_2 is not in stragglers_list!!
# 	VIB_10xv2_1 does not have complete fragments
# 		VIB_10xv2_1 is not in stragglers_list!!
# 	VIB_10xv2_2 does not have complete fragments
# 		VIB_10xv2_2 is not in stragglers_list!!
# 	VIB_hydrop_11 does not have complete fragments
# 		VIB_hydrop_11 is not in stragglers_list!!
# 	VIB_hydrop_12 does not have complete fragments
# 		VIB_hydrop_12 is not in stragglers_list!!
# 	VIB_hydrop_21 does not have complete fragments
# 		VIB_hydrop_21 is not in stragglers_list!!
# 	VIB_hydrop_22 does not have complete fragments
# 		VIB_hydrop_22 is not in stragglers_list!!
# 	VIB_mtscatac_1 does not have complete fragments
# 		VIB_mtscatac_1 is not in stragglers_list!!
# 	VIB_mtscatac_2 does not have complete fragments
# 		VIB_mtscatac_2 is not in stragglers_list!!

# %% [markdown]
# Then re-run these through the mapping pipeline.
